# %%
from utils.ticker_fetcher import get_all_us_listed_tickers

tickers = get_all_us_listed_tickers()
tickers
# Out:
# ['AACB',
#  'AACBR',
#  'AACBU',
#  'AACG',
#  'AADR',
#  'AAL',
#  'AALG',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPB',
#  'AAPD',
#  'AAPG',
#  'AAPL',
#  'AAPU',
#  'AARD',
#  'AAUS',
#  'AAVM',
#  'AAXJ',
#  'ABAT',
#  'ABCL',
#  'ABCS',
#  'ABEO',
#  'ABI',
#  'ABIG',
#  'ABL',
#  'ABLLL',
#  'ABLV',
#  'ABLVW',
#  'ABNB',
#  'ABOS',
#  'ABP',
#  'ABPWW',
#  'ABSI',
#  'ABTC',
#  'ABTS',
#  'ABUS',
#  'ABVC',
#  'ABVE',
#  'ABVEW',
#  'ABVX',
#  'ACAD',
#  'ACB',
#  'ACCL',
#  'ACDC',
#  'ACET',
#  'ACFN',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACHC',
#  'ACHV',
#  'ACIC',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACMR',
#  'ACNB',
#  'ACNT',
#  'ACOG',
#  'ACON',
#  'ACONW',
#  'ACRS',
#  'ACRV',
#  'ACT',
#  'ACTG',
#  'ACTU',
#  'ACWI',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADAM',
#  'ADAMG',
#  'ADAMH',
#  'ADAMI',
#  'ADAML',
#  'ADAMM',
#  'ADAMN',
#  'ADAMZ',
#  'ADBE',
#  'ADBG',
#  'ADEA',
#  'ADGM',
#  'ADI',
#  'ADIL',
#  'ADMA',
#  'ADP',
#  'ADPT',
#  'ADSE',
# ...

# %%
from utils.multi_fetcher import multi_fetcher
calls, puts = multi_fetcher(tickers)
# Out:
# 2025-11-10T09:13:37.057657 [INFO] round 1/10 — remaining tickers: 11971
# 2025-11-10T09:13:37.646802 [OK] 1/11971 ticker=PMAX finished in 0.58s (calls_rows=0, puts_rows=0)
# 2025-11-10T09:13:40.375757 [OK] 2/11971 ticker=WES finished in 2.57s (calls_rows=114, puts_rows=106)
# 2025-11-10T09:13:42.640940 [OK] 3/11971 ticker=HE finished in 2.11s (calls_rows=53, puts_rows=36)
# 2025-11-10T09:13:46.267983 [OK] 4/11971 ticker=UEC finished in 3.47s (calls_rows=304, puts_rows=234)
# 2025-11-10T09:13:47.567400 [OK] 5/11971 ticker=ECON finished in 1.15s (calls_rows=0, puts_rows=5)
# 2025-11-10T09:13:47.889764 [OK] 6/11971 ticker=MUA finished in 0.16s (calls_rows=0, puts_rows=0)
# 2025-11-10T09:13:49.969759 [OK] 7/11971 ticker=MIDD finished in 1.93s (calls_rows=61, puts_rows=65)
# 2025-11-10T09:13:50.302879 [OK] 8/11971 ticker=ESLAW finished in 0.17s (calls_rows=0, puts_rows=0)
# 2025-11-10T09:13:52.355492 [OK] 9/11971 ticker=CHRS finished in 1.90s (calls_rows=32, puts_rows=16)
# ...

# %%
calls
# Out:
#              contractSymbol             lastTradeDate  strike  lastPrice  \
# 0        WES251121C00020000 2025-11-06 16:39:29+00:00    20.0      18.03
# 1        WES251121C00025000 2025-10-09 16:30:15+00:00    25.0      13.90
# 2        WES251121C00027000 2025-11-07 15:41:43+00:00    27.0      11.50
# 3        WES251121C00028000 2025-10-30 18:54:09+00:00    28.0      10.40
# 4        WES251121C00029000 2025-10-30 18:54:09+00:00    29.0       9.40
# ...                     ...                       ...     ...        ...
# 508595  AIRR260515C00100000 2025-10-14 15:04:03+00:00   100.0       6.00
# 508596  AIRR260515C00101000 2025-10-30 15:41:50+00:00   101.0       8.00
# 508597  AIRR260515C00105000 2025-10-17 13:44:57+00:00   105.0       3.11
# 508598  AIRR260515C00110000 2025-11-03 20:16:24+00:00   110.0       4.00
# 508599  AIRR260515C00115000 2025-10-06 17:28:51+00:00   115.0       3.00
#
#          bid    ask  change  percentChange  volume  openInterest  \
# ...

# %%
from interest.interest_rates import fetch_treasury_yield_curve_latest, interest_rate_interpolation
as_of, curve_series = fetch_treasury_yield_curve_latest()
calls["r"] = interest_rate_interpolation(curve_series, calls["TTM"])
puts["r"] = interest_rate_interpolation(curve_series, puts["TTM"])

# %%
calls[calls.ticker == "AMZN"]
# Out:
#              contractSymbol             lastTradeDate  strike  lastPrice  \
# 153647  AMZN251114C00120000 2025-11-07 15:40:31+00:00   120.0     120.85
# 153648  AMZN251114C00125000 2025-11-06 20:50:27+00:00   125.0     118.69
# 153649  AMZN251114C00130000 2025-11-03 17:44:19+00:00   130.0     127.17
# 153650  AMZN251114C00135000 2025-11-07 16:02:45+00:00   135.0     105.23
# 153651  AMZN251114C00140000 2025-11-05 16:50:31+00:00   140.0     110.02
# ...                     ...                       ...     ...        ...
# 154677  AMZN280121C00330000 2025-11-07 20:02:44+00:00   330.0      33.30
# 154678  AMZN280121C00340000 2025-11-10 15:26:26+00:00   340.0      30.45
# 154679  AMZN280121C00350000 2025-11-10 15:40:10+00:00   350.0      27.55
# 154680  AMZN280121C00360000 2025-11-10 15:49:09+00:00   360.0      25.50
# 154681  AMZN280121C00370000 2025-11-10 15:49:09+00:00   370.0      23.55
#
#            bid     ask    change  percentChange  volume  openInterest  ...  \
# ...

# %%
from datetime import date
calls.to_csv(f"calls_yfin_{date.today()}.csv", index=False)

# %%
puts.to_csv(f"puts_yfin_{date.today()}.csv", index=False)
