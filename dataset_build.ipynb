# %%
from utils.ticker_fetcher import get_all_us_listed_tickers

tickers = get_all_us_listed_tickers()
tickers
# Out:
# ['AACB',
#  'AACBR',
#  'AACBU',
#  'AACG',
#  'AADR',
#  'AAL',
#  'AALG',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPB',
#  'AAPD',
#  'AAPG',
#  'AAPL',
#  'AAPU',
#  'AARD',
#  'AAUS',
#  'AAVM',
#  'AAXJ',
#  'ABAT',
#  'ABCL',
#  'ABCS',
#  'ABEO',
#  'ABI',
#  'ABIG',
#  'ABL',
#  'ABLLL',
#  'ABLV',
#  'ABLVW',
#  'ABNB',
#  'ABOS',
#  'ABP',
#  'ABPWW',
#  'ABSI',
#  'ABTC',
#  'ABTS',
#  'ABUS',
#  'ABVC',
#  'ABVE',
#  'ABVEW',
#  'ABVX',
#  'ACAD',
#  'ACB',
#  'ACCL',
#  'ACDC',
#  'ACET',
#  'ACFN',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACHC',
#  'ACHV',
#  'ACIC',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACMR',
#  'ACNB',
#  'ACNT',
#  'ACOG',
#  'ACON',
#  'ACONW',
#  'ACRS',
#  'ACRV',
#  'ACT',
#  'ACTG',
#  'ACTU',
#  'ACWI',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADAM',
#  'ADAMG',
#  'ADAMH',
#  'ADAMI',
#  'ADAML',
#  'ADAMM',
#  'ADAMN',
#  'ADAMZ',
#  'ADBE',
#  'ADBG',
#  'ADEA',
#  'ADGM',
#  'ADI',
#  'ADIL',
#  'ADMA',
#  'ADP',
#  'ADPT',
#  'ADSE',
#  'ADSEW',
#  'ADSK',
#  'ADTN',
#  'ADTX',
#  'ADUR',
#  'ADUS',
#  'ADV',
#  'ADVB',
#  'ADVM',
#  'ADXN',
#  'AEBI',
#  'AEC',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEMD',
#  'AENT',
#  'AENTW',
#  'AEP',
#  'AERT',
#  'AERTW',
#  'AEVA',
#  'AEVAW',
#  'AEYE',
#  'AFBI',
#  'AFCG',
#  'AFJK',
#  'AFJKR',
#  'AFJKU',
#  'AFOS',
#  'AFRI',
#  'AFRIW',
#  'AFRM',
#  'AFSC',
#  'AFYA',
#  'AGAE',
#  'AGCC',
#  'AGEM',
#  'AGEN',
#  'AGGA',
#  'AGH',
#  'AGIO',
#  'AGIX',
#  'AGMH',
#  'AGMI',
#  'AGNC',
#  'AGNCL',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGNCZ',
#  'AGNG',
#  'AGRI',
#  'AGRZ',
#  'AGYS',
#  'AGZD',
#  'AHCO',
#  'AHG',
#  'AHMA',
#  'AIA',
#  'AIFD',
#  'AIFF',
#  'AIFU',
#  'AIHS',
#  'AIIO',
#  'AIIOW',
#  'AIMD',
#  'AIMDW',
#  'AIOT',
#  'AIP',
#  'AIPI',
#  'AIPO',
#  'AIQ',
#  'AIRE',
#  'AIRG',
#  'AIRJ',
#  'AIRJW',
#  'AIRO',
#  'AIRR',
#  'AIRS',
#  'AIRT',
#  'AIRTP',
#  'AISP',
#  'AISPW',
#  'AIXI',
#  'AKAM',
#  'AKAN',
#  'AKBA',
#  'AKRO',
#  'AKTX',
#  'ALAB',
#  'ALAR',
#  'ALBT',
#  'ALCO',
#  'ALCY',
#  'ALCYU',
#  'ALCYW',
#  'ALDF',
#  'ALDFU',
#  'ALDFW',
#  'ALDX',
#  'ALEC',
#  'ALF',
#  'ALFUU',
#  'ALFUW',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIL',
#  'ALISU',
#  'ALKS',
#  'ALKT',
#  'ALLO',
#  'ALLR',
#  'ALLT',
#  'ALLW',
#  'ALM',
#  'ALMS',
#  'ALMU',
#  'ALNT',
#  'ALNY',
#  'ALOT',
#  'ALPS',
#  'ALRM',
#  'ALRS',
#  'ALT',
#  'ALTI',
#  'ALTO',
#  'ALTS',
#  'ALTY',
#  'ALVO',
#  'ALVOW',
#  'ALXO',
#  'ALZN',
#  'AMAL',
#  'AMAT',
#  'AMBA',
#  'AMBR',
#  'AMCX',
#  'AMD',
#  'AMDD',
#  'AMDG',
#  'AMDL',
#  'AMDU',
#  'AMGN',
#  'AMID',
#  'AMIX',
#  'AMKR',
#  'AMLX',
#  'AMOD',
#  'AMODW',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPL',
#  'AMRK',
#  'AMRN',
#  'AMRX',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMTX',
#  'AMUN',
#  'AMUU',
#  'AMWD',
#  'AMYY',
#  'AMZD',
#  'AMZN',
#  'AMZU',
#  'AMZZ',
#  'ANAB',
#  'ANDE',
#  'ANEB',
#  'ANEL',
#  'ANGH',
#  'ANGHW',
#  'ANGI',
#  'ANGL',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANL',
#  'ANNA',
#  'ANNAW',
#  'ANNX',
#  'ANPA',
#  'ANSC',
#  'ANSCU',
#  'ANSCW',
#  'ANTA',
#  'ANTX',
#  'ANY',
#  'AOHY',
#  'AOSL',
#  'AOTG',
#  'AOUT',
#  'APA',
#  'APACU',
#  'APAD',
#  'APADR',
#  'APADU',
#  'APED',
#  'APEI',
#  'APGE',
#  'API',
#  'APLD',
#  'APLM',
#  'APLMW',
#  'APLS',
#  'APLT',
#  'APM',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APPX',
#  'APRE',
#  'APVO',
#  'APWC',
#  'APXTU',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQST',
#  'AQWA',
#  'ARAI',
#  'ARAY',
#  'ARBB',
#  'ARBE',
#  'ARBEW',
#  'ARBK',
#  'ARBKL',
#  'ARCB',
#  'ARCC',
#  'ARCT',
#  'ARDX',
#  'AREB',
#  'AREBW',
#  'AREC',
#  'ARGX',
#  'ARHS',
#  'ARKO',
#  'ARKOW',
#  'ARKR',
#  'ARLP',
#  'ARM',
#  'ARMG',
#  'AROW',
#  'ARQ',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARRY',
#  'ARTL',
#  'ARTNA',
#  'ARTV',
#  'ARTW',
#  'ARVN',
#  'ARVR',
#  'ARWR',
#  'ASBP',
#  'ASBPW',
#  'ASCI',
#  'ASLE',
#  'ASMB',
#  'ASMG',
#  'ASML',
#  'ASND',
#  'ASNS',
#  'ASO',
#  'ASPC',
#  'ASPCR',
#  'ASPCU',
#  'ASPI',
#  'ASPS',
#  'ASPSW',
#  'ASPSZ',
#  'ASRT',
#  'ASRV',
#  'ASST',
#  'ASTC',
#  'ASTE',
#  'ASTH',
#  'ASTI',
#  'ASTL',
#  'ASTLW',
#  'ASTS',
#  'ASUR',
#  'ASYS',
#  'ATAI',
#  'ATAT',
#  'ATEC',
#  'ATER',
#  'ATEX',
#  'ATGL',
#  'ATHA',
#  'ATHE',
#  'ATHR',
#  'ATII',
#  'ATIIU',
#  'ATIIW',
#  'ATLC',
#  'ATLCL',
#  'ATLCP',
#  'ATLCZ',
#  'ATLN',
#  'ATLO',
#  'ATLX',
#  'ATMC',
#  'ATMCR',
#  'ATMCU',
#  'ATMCW',
#  'ATMV',
#  'ATMVR',
#  'ATMVU',
#  'ATNI',
#  'ATOM',
#  'ATON',
#  'ATOS',
#  'ATPC',
#  'ATRA',
#  'ATRC',
#  'ATRO',
#  'ATXG',
#  'ATXS',
#  'ATYR',
#  'AUBN',
#  'AUDC',
#  'AUGO',
#  'AUID',
#  'AUMI',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AURE',
#  'AUROW',
#  'AUTL',
#  'AUUD',
#  'AUUDW',
#  'AVAH',
#  'AVAV',
#  'AVBH',
#  'AVBP',
#  'AVDL',
#  'AVGB',
#  'AVGG',
#  'AVGO',
#  'AVGU',
#  'AVGX',
#  'AVIR',
#  'AVL',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVR',
#  'AVS',
#  'AVT',
#  'AVTX',
#  'AVUQ',
#  'AVXC',
#  'AVXL',
#  'AVXX',
#  'AWRE',
#  'AXG',
#  'AXGN',
#  'AXIN',
#  'AXINR',
#  'AXINU',
#  'AXON',
#  'AXSM',
#  'AXTI',
#  'AYTU',
#  'AZ',
#  'AZI',
#  'AZN',
#  'AZTA',
#  'AZYY',
#  'BABX',
#  'BACC',
#  'BACCR',
#  'BACCU',
#  'BACQ',
#  'BACQR',
#  'BACQU',
#  'BAER',
#  'BAERW',
#  'BAFE',
#  'BAFN',
#  'BAIG',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANL',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BASG',
#  'BASV',
#  'BATRA',
#  'BATRK',
#  'BAYA',
#  'BAYAR',
#  'BAYAU',
#  'BBB',
#  'BBCP',
#  'BBGI',
#  'BBH',
#  'BBIO',
#  'BBLG',
#  'BBLGW',
#  'BBNX',
#  'BBOT',
#  'BBSI',
#  'BBYY',
#  'BCAB',
#  'BCAL',
#  'BCAR',
#  'BCARU',
#  'BCARW',
#  'BCAX',
#  'BCBP',
#  'BCDA',
#  'BCG',
#  'BCGWW',
#  'BCIC',
#  'BCLO',
#  'BCML',
#  'BCPC',
#  'BCRX',
#  'BCTX',
#  'BCTXW',
#  'BCTXZ',
#  'BCYC',
#  'BDCI',
#  'BDCIU',
#  'BDCIW',
#  'BDGS',
#  'BDMD',
#  'BDMDW',
#  'BDRX',
#  'BDSX',
#  'BDTX',
#  'BDVL',
#  'BDYN',
#  'BEAG',
#  'BEAGR',
#  'BEAGU',
#  'BEAM',
#  'BEAT',
#  'BEATW',
#  'BEEM',
#  'BEEP',
#  'BEEX',
#  'BEEZ',
#  'BELFA',
#  'BELFB',
#  'BELT',
#  'BENF',
#  'BENFW',
#  'BETR',
#  'BETRW',
#  'BFC',
#  'BFIN',
#  'BFRG',
#  'BFRGW',
#  'BFRI',
#  'BFRIW',
#  'BFST',
#  'BGC',
#  'BGIN',
#  'BGL',
#  'BGLC',
#  'BGLWW',
#  'BGM',
#  'BGMS',
#  'BGMSP',
#  'BGRN',
#  'BGRO',
#  'BHAT',
#  'BHF',
#  'BHFAL',
#  'BHFAM',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BHRB',
#  'BHST',
#  'BIAF',
#  'BIAFW',
#  'BIB',
#  'BIDU',
#  'BIIB',
#  'BILI',
#  'BIOA',
#  'BIOX',
#  'BIRD',
#  'BIS',
#  'BITF',
#  'BITS',
#  'BIVI',
#  'BIVIW',
#  'BIYA',
#  'BJDX',
#  'BJK',
#  'BJRI',
#  'BKCH',
#  'BKHA',
#  'BKHAR',
#  'BKHAU',
#  'BKNG',
#  'BKR',
#  'BKYI',
#  'BL',
#  'BLBD',
#  'BLBX',
#  'BLCN',
#  'BLCR',
#  'BLDP',
#  'BLFS',
#  'BLFY',
#  'BLIN',
#  'BLIV',
#  'BLKB',
#  'BLLN',
#  'BLMN',
#  'BLMZ',
#  'BLNE',
#  'BLNK',
#  'BLRX',
#  'BLSG',
#  'BLTE',
#  'BLUW',
#  'BLUWU',
#  'BLUWW',
#  'BLZE',
#  'BLZR',
#  'BLZRU',
#  'BLZRW',
#  'BMAX',
#  'BMBL',
#  'BMDL',
#  'BMEA',
#  'BMGL',
#  'BMHL',
#  'BMNG',
#  'BMR',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BNAI',
#  'BNAIW',
#  'BNBX',
#  'BNC',
#  'BNCWW',
#  'BND',
#  'BNDW',
#  'BNDX',
#  'BNGO',
#  'BNKK',
#  'BNR',
#  'BNRG',
#  'BNTC',
#  'BNTX',
#  'BNZI',
#  'BNZIW',
#  'BODI',
#  'BOED',
#  'BOEG',
#  'BOEU',
#  'BOF',
#  'BOKF',
#  'BOLD',
#  'BOLT',
#  'BON',
#  'BOOM',
#  'BOSC',
#  'BOTJ',
#  'BOTT',
#  'BOTZ',
#  'BOXL',
#  'BPOP',
#  'BPOPM',
#  'BPRN',
#  'BPYPM',
#  'BPYPN',
#  'BPYPO',
#  'BPYPP',
#  'BRAG',
#  'BRBI',
#  'BRCB',
#  'BREM',
#  'BRFH',
#  'BRHY',
#  'BRID',
#  'BRKD',
#  'BRKR',
#  'BRKRP',
#  'BRKU',
#  'BRLS',
#  'BRLSW',
#  'BRLT',
#  'BRNS',
#  'BRNY',
#  'BRR',
#  'BRRR',
#  'BRRWU',
#  'BRRWW',
#  'BRTR',
#  'BRTX',
#  'BRY',
#  'BRZE',
#  'BSAA',
#  'BSAAR',
#  'BSAAU',
#  'BSBK',
#  'BSCP',
#  'BSCQ',
#  'BSCR',
#  'BSCS',
#  'BSCT',
#  'BSCU',
#  'BSCV',
#  'BSCW',
#  'BSCX',
#  'BSCY',
#  'BSCZ',
#  'BSET',
#  'BSJP',
#  'BSJQ',
#  'BSJR',
#  'BSJS',
#  'BSJT',
#  'BSJU',
#  'BSJV',
#  'BSJW',
#  'BSJX',
#  'BSLK',
#  'BSLKW',
#  'BSMP',
#  'BSMQ',
#  'BSMR',
#  'BSMS',
#  'BSMT',
#  'BSMU',
#  'BSMV',
#  'BSMW',
#  'BSMY',
#  'BSMZ',
#  'BSRR',
#  'BSSX',
#  'BSVN',
#  'BSVO',
#  'BSY',
#  'BTAI',
#  'BTBD',
#  'BTBDW',
#  'BTBT',
#  'BTCS',
#  'BTCT',
#  'BTDR',
#  'BTF',
#  'BTFX',
#  'BTGD',
#  'BTM',
#  'BTMD',
#  'BTMWW',
#  'BTOC',
#  'BTOG',
#  'BTQ',
#  'BTSG',
#  'BTSGU',
#  'BTTC',
#  'BUFC',
#  'BUFI',
#  'BUFM',
#  'BUG',
#  'BULD',
#  'BULG',
#  'BULL',
#  'BULLW',
#  'BULX',
#  'BUSE',
#  'BUSEP',
#  'BUUU',
#  'BVFL',
#  'BVS',
#  'BWAY',
#  'BWB',
#  'BWBBP',
#  'BWEN',
#  'BWFG',
#  'BWIN',
#  'BWMN',
#  'BYAH',
#  'BYFC',
#  'BYND',
#  'BYRN',
#  'BYSI',
#  'BZ',
#  'BZAI',
#  'BZAIW',
#  'BZFD',
#  'BZFDW',
#  'BZUN',
#  'CA',
#  'CAAS',
#  'CABA',
#  'CAC',
#  'CACC',
#  'CADL',
#  'CAEP',
#  'CAFG',
#  'CAI',
#  'CAKE',
#  'CALC',
#  'CALI',
#  'CALM',
#  'CAMP',
#  'CAMT',
#  'CAN',
#  'CANC',
#  'CANQ',
#  'CAPN',
#  'CAPNR',
#  'CAPNU',
#  'CAPR',
#  'CAPS',
#  'CAPT',
#  'CAPTW',
#  'CAR',
#  'CARE',
#  'CARG',
#  'CARL',
#  'CART',
#  'CARV',
#  'CARY',
#  'CARZ',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CATH',
#  'CATY',
#  'CBAT',
#  'CBFV',
#  'CBIO',
#  'CBK',
#  'CBLL',
#  'CBNK',
#  'CBRL',
#  'CBSH',
#  'CBUS',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCC',
#  'CCCC',
#  'CCCX',
#  'CCCXU',
#  'CCCXW',
#  'CCD',
#  'CCEC',
#  'CCEP',
#  'CCFE',
#  'CCG',
#  'CCGWW',
#  'CCHH',
#  'CCII',
#  'CCIIU',
#  'CCIIW',
#  'CCIX',
#  'CCIXU',
#  'CCIXW',
#  'CCLD',
#  'CCLDO',
#  'CCNE',
#  'CCNEP',
#  'CCNR',
#  'CCOI',
#  'CCRN',
#  'CCSB',
#  'CCSI',
#  'CCSO',
#  'CCTG',
#  'CDC',
#  'CDIG',
#  'CDIO',
#  'CDIOW',
#  'CDL',
#  'CDLX',
#  'CDNA',
#  'CDNS',
#  'CDRO',
#  'CDROW',
#  'CDT',
#  'CDTG',
#  'CDTTW',
#  'CDTX',
#  'CDW',
#  'CDXS',
#  'CDZI',
#  'CDZIP',
#  'CECO',
#  'CEFA',
#  'CEG',
#  'CELC',
#  'CELH',
#  'CELU',
#  'CELUW',
#  'CELZ',
#  'CENN',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CEP',
#  'CEPF',
#  'CEPI',
#  'CEPO',
#  'CEPT',
#  'CEPV',
#  'CERS',
#  'CERT',
#  'CETX',
#  'CETY',
#  'CEVA',
#  'CFA',
#  'CFBK',
#  'CFFI',
#  'CFFN',
#  'CFLT',
#  'CFO',
#  'CG',
#  'CGABL',
#  'CGBD',
#  'CGBDL',
#  'CGC',
#  'CGCT',
#  'CGCTU',
#  'CGCTW',
#  'CGEM',
#  'CGEN',
#  'CGNT',
#  'CGNX',
#  'CGO',
#  'CGON',
#  'CGTL',
#  'CGTX',
#  'CHA',
#  'CHAC',
#  'CHACR',
#  'CHACU',
#  'CHAI',
#  'CHAR',
#  'CHARR',
#  'CHARU',
#  'CHCI',
#  'CHCO',
#  'CHDN',
#  'CHECU',
#  'CHEF',
#  'CHEK',
#  'CHGX',
#  'CHI',
#  'CHKP',
#  'CHMG',
#  'CHNR',
#  'CHPG',
#  'CHPGR',
#  'CHPGU',
#  'CHPS',
#  'CHPX',
#  'CHR',
#  'CHRD',
#  'CHRI',
#  'CHRS',
#  'CHRW',
#  'CHSCL',
#  'CHSCM',
#  'CHSCN',
#  'CHSCO',
#  'CHSCP',
#  'CHSN',
#  'CHTR',
#  'CHW',
#  'CHY',
#  'CHYM',
#  'CIBR',
#  'CIFR',
#  'CIFRW',
#  'CIGI',
#  'CIGL',
#  'CIIT',
#  'CIL',
#  'CINF',
#  'CING',
#  'CINGW',
#  'CISO',
#  'CISS',
#  'CIVB',
#  'CJET',
#  'CJMB',
#  'CLAR',
#  'CLBK',
#  'CLBT',
#  ...]

# %%
from utils.multi_fetcher import multi_fetcher
calls, puts = multi_fetcher(tickers)
# Out:
# [AACB] no expiries (likely no options listed).
# [AACBR] no expiries (likely no options listed).
# [AACBU] no expiries (likely no options listed).
# [AACG] no expiries (likely no options listed).
# [AADR] no expiries (likely no options listed).
# [AALG] no expiries (likely no options listed).
# [AAME] no expiries (likely no options listed).
# [AAPG] no expiries (likely no options listed).
# [AARD] no expiries (likely no options listed).
# [AAUS] no expiries (likely no options listed).
# [AAVM] no expiries (likely no options listed).
# [ABCS] no expiries (likely no options listed).
# [ABI] no expiries (likely no options listed).
# [ABIG] no expiries (likely no options listed).
# [ABLLL] no expiries (likely no options listed).
# [ABLV] no expiries (likely no options listed).
# [ABLVW] no expiries (likely no options listed).
# [ABP] no expiries (likely no options listed).
# [ABPWW] no expiries (likely no options listed).
# [ABTS] no expiries (likely no options listed).
# [ABVEW] no expiries (likely no options listed).
# [ACCL] no expiries (likely no options listed).
# [ACFN] no expiries (likely no options listed).
# [ACGLN] no expiries (likely no options listed).
# [ACGLO] no expiries (likely no options listed).
# [ACOG] no expiries (likely no options listed).
# [ACON] no expiries (likely no options listed).
# [ACONW] no expiries (likely no options listed).
# [ACRV] no expiries (likely no options listed).
# [ACTU] no expiries (likely no options listed).
# [ADAG] no expiries (likely no options listed).
# [ADAMG] no expiries (likely no options listed).
# [ADAMH] no expiries (likely no options listed).
# [ADAMI] no expiries (likely no options listed).
# [ADAML] no expiries (likely no options listed).
# [ADAMM] no expiries (likely no options listed).
# [ADAMN] no expiries (likely no options listed).
# [ADAMZ] no expiries (likely no options listed).
# [ADGM] no expiries (likely no options listed).
# [ADIL] no expiries (likely no options listed).
# [ADSEW] no expiries (likely no options listed).
# [ADTX] no expiries (likely no options listed).
# [ADVB] no expiries (likely no options listed).
# [ADXN] no expiries (likely no options listed).
# [AEC] no expiries (likely no options listed).
# [AEHL] no expiries (likely no options listed).
# [AEI] no expiries (likely no options listed).
# [AEMD] no expiries (likely no options listed).
# [AENT] no expiries (likely no options listed).
# [AENTW] no expiries (likely no options listed).
# [AERT] no expiries (likely no options listed).
# [AERTW] no expiries (likely no options listed).
# [AEVAW] no expiries (likely no options listed).
# [AEYE] rate-limited on 2026-03-20: Too Many Requests. Rate limited. Try after a while.
# [AFBI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AEYE] rate-limited on 2026-06-18: Too Many Requests. Rate limited. Try after a while.
# [AFCG] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AFJK] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] AEYE: failed -> 'NoneType' object has no attribute 'get'
# [AFJKR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AFJKU] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AFOS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AFRI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AFRIW] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AFRM] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AFSC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AFYA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGAE] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGCC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGEM] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGEN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGGA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGIO] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGIX] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGMH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGMI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGNC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGNCL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AGNCM] no expiries (likely no options listed).
# [AGNCO] no expiries (likely no options listed).
# [AGNCP] no expiries (likely no options listed).
# [AGNCZ] no expiries (likely no options listed).
# [AGNCN] no expiries (likely no options listed).
# [AGRI] no expiries (likely no options listed).
# [AGRZ] no expiries (likely no options listed).
# [AGZD] no expiries (likely no options listed).
# [AHG] no expiries (likely no options listed).
# [AHMA] no expiries (likely no options listed).
# [AIFF] no expiries (likely no options listed).
# [AIHS] no expiries (likely no options listed).
# [AIIO] no expiries (likely no options listed).
# [AIIOW] no expiries (likely no options listed).
# [AIMD] no expiries (likely no options listed).
# [AIMDW] no expiries (likely no options listed).
# [AIPO] no expiries (likely no options listed).
# [AIRE] no expiries (likely no options listed).
# [AIRJW] no expiries (likely no options listed).
# [AIRT] no expiries (likely no options listed).
# [AIRTP] no expiries (likely no options listed).
# [AISPW] no expiries (likely no options listed).
# [AIXI] no expiries (likely no options listed).
# [AKAN] no expiries (likely no options listed).
# [AKTX] no expiries (likely no options listed).
# [ALAR] no expiries (likely no options listed).
# [ALBT] no expiries (likely no options listed).
# [ALCO] no expiries (likely no options listed).
# [ALCY] no expiries (likely no options listed).
# [ALCYU] no expiries (likely no options listed).
# [ALCYW] no expiries (likely no options listed).
# [ALDF] no expiries (likely no options listed).
# [ALDFU] no expiries (likely no options listed).
# [ALDFW] no expiries (likely no options listed).
# [ALF] no expiries (likely no options listed).
# [ALFUU] no expiries (likely no options listed).
# [ALFUW] no expiries (likely no options listed).
# [ALGS] no expiries (likely no options listed).
# [ALIL] no expiries (likely no options listed).
# [ALISU] no expiries (likely no options listed).
# [ALLR] no expiries (likely no options listed).
# [ALLW] no expiries (likely no options listed).
# [ALM] no expiries (likely no options listed).
# [ALOT] no expiries (likely no options listed).
# [ALPS] no expiries (likely no options listed).
# [ALVO] no expiries (likely no options listed).
# [ALVOW] no expiries (likely no options listed).
# [ALZN] no expiries (likely no options listed).
# [AMDD] no expiries (likely no options listed).
# [AMDU] no expiries (likely no options listed).
# [AMID] no expiries (likely no options listed).
# [AMIX] no expiries (likely no options listed).
# [AMOD] no expiries (likely no options listed).
# [AMODW] no expiries (likely no options listed).
# [AMPGW] no expiries (likely no options listed).
# [AMST] no expiries (likely no options listed).
# [AMUN] no expiries (likely no options listed).
# [AMUU] no expiries (likely no options listed).
# [AMZN] rate-limited on 2026-09-18: Too Many Requests. Rate limited. Try after a while.
# [AMZN] rate-limited on 2026-08-21: Too Many Requests. Rate limited. Try after a while.
# [AMZZ] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AMZN] rate-limited on 2026-12-18: Too Many Requests. Rate limited. Try after a while.
# [ANAB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AMZN] rate-limited on 2027-01-15: Too Many Requests. Rate limited. Try after a while.
# [AMZN] rate-limited on 2027-06-17: Too Many Requests. Rate limited. Try after a while.
# [ANDE] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AMZN] rate-limited on 2027-12-17: Too Many Requests. Rate limited. Try after a while.
# [AMZN] rate-limited on 2028-01-21: Too Many Requests. Rate limited. Try after a while.
# [ANEB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANEL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANGH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] AMZN: failed -> 'NoneType' object has no attribute 'get'
# [ANGHW] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANGI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANGL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANGO] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANIK] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANIP] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANIX] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANNAW] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANNA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANNX] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANPA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANSC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANSCU] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ANSCW] no expiries (likely no options listed).
# [ANTX] no expiries (likely no options listed).
# [ANTA] no expiries (likely no options listed).
# [AOHY] no expiries (likely no options listed).
# [AOTG] no expiries (likely no options listed).
# [APACU] no expiries (likely no options listed).
# [APAD] no expiries (likely no options listed).
# [APADR] no expiries (likely no options listed).
# [APADU] no expiries (likely no options listed).
# [APED] no expiries (likely no options listed).
# [APLM] no expiries (likely no options listed).
# [APLMW] no expiries (likely no options listed).
# [APM] no expiries (likely no options listed).
# [APRE] no expiries (likely no options listed).
# [APVO] no expiries (likely no options listed).
# [APWC] no expiries (likely no options listed).
# [APXTU] no expiries (likely no options listed).
# [AQB] no expiries (likely no options listed).
# [ARAI] no expiries (likely no options listed).
# [ARBB] no expiries (likely no options listed).
# [ARBEW] no expiries (likely no options listed).
# [ARBKL] no expiries (likely no options listed).
# [AREB] no expiries (likely no options listed).
# [AREBW] no expiries (likely no options listed).
# [ARKOW] no expiries (likely no options listed).
# [ARKR] no expiries (likely no options listed).
# [ARQQW] no expiries (likely no options listed).
# [ARTL] no expiries (likely no options listed).
# [ARTNA] no expiries (likely no options listed).
# [ARTV] no expiries (likely no options listed).
# [ARTW] no expiries (likely no options listed).
# [ARVR] no expiries (likely no options listed).
# [ASBP] no expiries (likely no options listed).
# [ASBPW] no expiries (likely no options listed).
# [ASCI] no expiries (likely no options listed).
# [ASNS] no expiries (likely no options listed).
# [ASPC] no expiries (likely no options listed).
# [ASPCR] no expiries (likely no options listed).
# [ASPCU] no expiries (likely no options listed).
# [ASPS] no expiries (likely no options listed).
# [ASPSW] no expiries (likely no options listed).
# [ASPSZ] no expiries (likely no options listed).
# [ASTC] no expiries (likely no options listed).
# [ASTI] no expiries (likely no options listed).
# [ASTLW] no expiries (likely no options listed).
# [ATGL] no expiries (likely no options listed).
# [ATHE] no expiries (likely no options listed).
# [ATHR] no expiries (likely no options listed).
# [ATII] no expiries (likely no options listed).
# [ATIIU] no expiries (likely no options listed).
# [ATIIW] no expiries (likely no options listed).
# [ATLC] no expiries (likely no options listed).
# [ATLCL] no expiries (likely no options listed).
# [ATLCP] no expiries (likely no options listed).
# [ATLCZ] no expiries (likely no options listed).
# [ATLN] no expiries (likely no options listed).
# [ATMC] no expiries (likely no options listed).
# [ATMCU] no expiries (likely no options listed).
# [ATMCR] no expiries (likely no options listed).
# [ATMCW] no expiries (likely no options listed).
# [ATMV] no expiries (likely no options listed).
# [ATMVR] no expiries (likely no options listed).
# [ATMVU] no expiries (likely no options listed).
# [ATON] no expiries (likely no options listed).
# [ATPC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ATOS] rate-limited on 2025-12-19: Too Many Requests. Rate limited. Try after a while.
# [ATOS] rate-limited on 2025-11-21: Too Many Requests. Rate limited. Try after a while.
# [ATOS] rate-limited on 2026-04-17: Too Many Requests. Rate limited. Try after a while.
# [ATOS] rate-limited on 2026-01-16: Too Many Requests. Rate limited. Try after a while.
# [ATRA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ATRC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] ATOS: failed -> 'NoneType' object has no attribute 'get'
# [ATRO] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ATXS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ATXG] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [ATYR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUBN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUDC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUGO] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUID] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUMI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUPH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AURA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AURE] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUROW] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUTL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUUD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AUUDW] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AVAH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AVAV] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [AVBH] no expiries (likely no options listed).
# [AVGB] no expiries (likely no options listed).
# [AVGU] no expiries (likely no options listed).
# [AVR] no expiries (likely no options listed).
# [AVS] no expiries (likely no options listed).
# [AVUQ] no expiries (likely no options listed).
# [AVXC] no expiries (likely no options listed).
# [AVXX] no expiries (likely no options listed).
# [AXG] no expiries (likely no options listed).
# [AXIN] no expiries (likely no options listed).
# [AXINR] no expiries (likely no options listed).
# [AXINU] no expiries (likely no options listed).
# [AYTU] no expiries (likely no options listed).
# [AZI] no expiries (likely no options listed).
# [BACC] no expiries (likely no options listed).
# [BACCR] no expiries (likely no options listed).
# [BACCU] no expiries (likely no options listed).
# [BACQ] no expiries (likely no options listed).
# [BACQR] no expiries (likely no options listed).
# [BACQU] no expiries (likely no options listed).
# [BAER] no expiries (likely no options listed).
# [BAERW] no expiries (likely no options listed).
# [BAFE] no expiries (likely no options listed).
# [BAFN] no expiries (likely no options listed).
# [BANFP] no expiries (likely no options listed).
# [BANL] no expiries (likely no options listed).
# [BAOS] no expiries (likely no options listed).
# [BASG] no expiries (likely no options listed).
# [BASV] no expiries (likely no options listed).
# [BAYA] no expiries (likely no options listed).
# [BAYAR] no expiries (likely no options listed).
# [BAYAU] no expiries (likely no options listed).
# [BBGI] no expiries (likely no options listed).
# [BBLG] no expiries (likely no options listed).
# [BBLGW] no expiries (likely no options listed).
# [BBNX] no expiries (likely no options listed).
# [BBOT] no expiries (likely no options listed).
# [BBYY] no expiries (likely no options listed).
# [BCAL] no expiries (likely no options listed).
# [BCARU] no expiries (likely no options listed).
# [BCAR] no expiries (likely no options listed).
# [BCARW] no expiries (likely no options listed).
# [BCDA] no expiries (likely no options listed).
# [BCG] no expiries (likely no options listed).
# [BCGWW] no expiries (likely no options listed).
# [BCLO] no expiries (likely no options listed).
# [BCTX] no expiries (likely no options listed).
# [BCTXW] no expiries (likely no options listed).
# [BCTXZ] no expiries (likely no options listed).
# [BDCI] no expiries (likely no options listed).
# [BDCIU] no expiries (likely no options listed).
# [BDCIW] no expiries (likely no options listed).
# [BDGS] no expiries (likely no options listed).
# [BDMD] no expiries (likely no options listed).
# [BDMDW] no expiries (likely no options listed).
# [BDRX] no expiries (likely no options listed).
# [BDVL] no expiries (likely no options listed).
# [BDYN] no expiries (likely no options listed).
# [BEAG] no expiries (likely no options listed).
# [BEAGR] no expiries (likely no options listed).
# [BEAGU] no expiries (likely no options listed).
# [BEAT] no expiries (likely no options listed).
# [BEATW] no expiries (likely no options listed).
# [BEEP] no expiries (likely no options listed).
# [BEEX] no expiries (likely no options listed).
# [BEEZ] no expiries (likely no options listed).
# [BELFA] no expiries (likely no options listed).
# [BELT] no expiries (likely no options listed).
# [BENF] no expiries (likely no options listed).
# [BENFW] no expiries (likely no options listed).
# [BETRW] no expiries (likely no options listed).
# [BFC] no expiries (likely no options listed).
# [BFRG] no expiries (likely no options listed).
# [BFRGW] no expiries (likely no options listed).
# [BFRI] no expiries (likely no options listed).
# [BFRIW] no expiries (likely no options listed).
# [BGIN] no expiries (likely no options listed).
# [BGL] no expiries (likely no options listed).
# [BGLC] no expiries (likely no options listed).
# [BGLWW] no expiries (likely no options listed).
# [BGM] no expiries (likely no options listed).
# [BGMS] no expiries (likely no options listed).
# [BGMSP] no expiries (likely no options listed).
# [BGRN] no expiries (likely no options listed).
# [BGRO] no expiries (likely no options listed).
# [BHAT] no expiries (likely no options listed).
# [BHFAL] no expiries (likely no options listed).
# [BHFAM] no expiries (likely no options listed).
# [BHFAN] no expiries (likely no options listed).
# [BHFAO] no expiries (likely no options listed).
# [BHFAP] no expiries (likely no options listed).
# [BHRB] no expiries (likely no options listed).
# [BHST] no expiries (likely no options listed).
# [BIAF] no expiries (likely no options listed).
# [BIAFW] no expiries (likely no options listed).
# [BIRD] no expiries (likely no options listed).
# [BIVI] no expiries (likely no options listed).
# [BIVIW] no expiries (likely no options listed).
# [BIYA] no expiries (likely no options listed).
# [BJDX] no expiries (likely no options listed).
# [BKHA] no expiries (likely no options listed).
# [BKHAR] no expiries (likely no options listed).
# [BKHAU] no expiries (likely no options listed).
# [BKYI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] BKNG: failed -> 'NoneType' object has no attribute 'get'
# [BLBD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLBX] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLCN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLCR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLDP] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLFS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLFY] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLIN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLIV] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLKB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLLN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLMN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLMZ] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLNE] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLRX] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLNK] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLSG] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLTE] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLUW] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLUWU] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [BLUWW] no expiries (likely no options listed).
# [BLZR] no expiries (likely no options listed).
# [BLZRU] no expiries (likely no options listed).
# [BLZRW] no expiries (likely no options listed).
# [BMDL] no expiries (likely no options listed).
# [BMGL] no expiries (likely no options listed).
# [BMHL] no expiries (likely no options listed).
# [BMNG] no expiries (likely no options listed).
# [BMR] no expiries (likely no options listed).
# [BMRA] no expiries (likely no options listed).
# [BNAI] no expiries (likely no options listed).
# [BNAIW] no expiries (likely no options listed).
# [BNBX] no expiries (likely no options listed).
# [BNCWW] no expiries (likely no options listed).
# [BNGO] no expiries (likely no options listed).
# [BNR] no expiries (likely no options listed).
# [BNRG] no expiries (likely no options listed).
# [BNZI] no expiries (likely no options listed).
# [BNZIW] no expiries (likely no options listed).
# [BODI] no expiries (likely no options listed).
# [BOED] no expiries (likely no options listed).
# [BOEG] no expiries (likely no options listed).
# [BOEU] no expiries (likely no options listed).
# [BOF] no expiries (likely no options listed).
# [BOLD] no expiries (likely no options listed).
# [BOLT] no expiries (likely no options listed).
# [BON] no expiries (likely no options listed).
# [BOSC] no expiries (likely no options listed).
# [BOTJ] no expiries (likely no options listed).
# [BOTT] no expiries (likely no options listed).
# [BOXL] no expiries (likely no options listed).
# [BPOPM] no expiries (likely no options listed).
# [BPRN] no expiries (likely no options listed).
# [BPYPM] no expiries (likely no options listed).
# [BPYPN] no expiries (likely no options listed).
# [BPYPO] no expiries (likely no options listed).
# [BPYPP] no expiries (likely no options listed).
# [BRBI] no expiries (likely no options listed).
# [BREM] no expiries (likely no options listed).
# [BRFH] no expiries (likely no options listed).
# [BRHY] no expiries (likely no options listed).
# [BRID] no expiries (likely no options listed).
# [BRKD] no expiries (likely no options listed).
# [BRKRP] no expiries (likely no options listed).
# [BRKU] no expiries (likely no options listed).
# [BRLS] no expiries (likely no options listed).
# [BRLSW] no expiries (likely no options listed).
# [BRNS] no expiries (likely no options listed).
# [BRNY] no expiries (likely no options listed).
# [BRRR] no expiries (likely no options listed).
# [BRRWU] no expiries (likely no options listed).
# [BRRWW] no expiries (likely no options listed).
# [BRTR] no expiries (likely no options listed).
# [BRTX] no expiries (likely no options listed).
# [BSAA] no expiries (likely no options listed).
# [BSAAR] no expiries (likely no options listed).
# [BSAAU] no expiries (likely no options listed).
# [BSBK] no expiries (likely no options listed).
# [BSCP] no expiries (likely no options listed).
# [BSCQ] no expiries (likely no options listed).
# [BSCR] no expiries (likely no options listed).
# [BSCS] no expiries (likely no options listed).
# [BSCT] no expiries (likely no options listed).
# [BSCU] no expiries (likely no options listed).
# [BSCV] no expiries (likely no options listed).
# [BSCW] no expiries (likely no options listed).
# [BSCX] no expiries (likely no options listed).
# [BSCY] no expiries (likely no options listed).
# [BSCZ] no expiries (likely no options listed).
# [BSJP] no expiries (likely no options listed).
# [BSJQ] no expiries (likely no options listed).
# [BSJR] no expiries (likely no options listed).
# [BSJS] no expiries (likely no options listed).
# [BSJT] no expiries (likely no options listed).
# [BSJU] no expiries (likely no options listed).
# [BSJV] no expiries (likely no options listed).
# [BSJW] no expiries (likely no options listed).
# [BSJX] no expiries (likely no options listed).
# [BSLK] no expiries (likely no options listed).
# [BSLKW] no expiries (likely no options listed).
# [BSMP] no expiries (likely no options listed).
# [BSMQ] no expiries (likely no options listed).
# [BSMR] no expiries (likely no options listed).
# [BSMS] no expiries (likely no options listed).
# [BSMT] no expiries (likely no options listed).
# [BSMU] no expiries (likely no options listed).
# [BSMV] no expiries (likely no options listed).
# [BSMW] no expiries (likely no options listed).
# [BSMY] no expiries (likely no options listed).
# [BSMZ] no expiries (likely no options listed).
# [BSSX] no expiries (likely no options listed).
# [BSVN] no expiries (likely no options listed).
# [BTBD] no expiries (likely no options listed).
# [BTBDW] no expiries (likely no options listed).
# [BTCT] no expiries (likely no options listed).
# [BTMD] no expiries (likely no options listed).
# [BTMWW] no expiries (likely no options listed).
# [BTOC] no expiries (likely no options listed).
# [BTOG] no expiries (likely no options listed).
# [BTSGU] no expiries (likely no options listed).
# [BTTC] no expiries (likely no options listed).
# [BUFC] no expiries (likely no options listed).
# [BUFI] no expiries (likely no options listed).
# [BUFM] no expiries (likely no options listed).
# [BULD] no expiries (likely no options listed).
# [BULLW] no expiries (likely no options listed).
# [BULX] no expiries (likely no options listed).
# [BUUU] no expiries (likely no options listed).[BUSEP] no expiries (likely no options listed).
#
# [BVFL] no expiries (likely no options listed).
# [BWBBP] no expiries (likely no options listed).
# [BWFG] no expiries (likely no options listed).
# [BYAH] no expiries (likely no options listed).
# [BYFC] no expiries (likely no options listed).
# [BZAIW] no expiries (likely no options listed).
# [BZFDW] no expiries (likely no options listed).
# [CA] no expiries (likely no options listed).
# [CAEP] no expiries (likely no options listed).
# [CAFG] no expiries (likely no options listed).
# [CALC] no expiries (likely no options listed).
# [CALI] no expiries (likely no options listed).
# [CAMP] no expiries (likely no options listed).
# [CANC] no expiries (likely no options listed).
# [CANQ] no expiries (likely no options listed).
# [CAPN] no expiries (likely no options listed).
# [CAPNR] no expiries (likely no options listed).
# [CAPNU] no expiries (likely no options listed).
# [CAPS] no expiries (likely no options listed).
# [CAPT] rate-limited on 2025-11-21: Too Many Requests. Rate limited. Try after a while.
# [CAPR] rate-limited on 2028-01-21: Too Many Requests. Rate limited. Try after a while.
# [CAPT] rate-limited on 2026-04-17: Too Many Requests. Rate limited. Try after a while.
# [CAPR] rate-limited on 2027-01-15: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] CAPT: failed -> 'NoneType' object has no attribute 'get'
# [multi_fetcher] CAPR: failed -> 'NoneType' object has no attribute 'get'
# [CAPTW] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CAR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CARE] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CARG] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CARL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CART] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CARV] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CARY] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CARZ] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CASH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CASI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CASS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CASY] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CATH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CATY] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CBAT] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CBFV] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CBIO] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CBK] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CCCXU] no expiries (likely no options listed).
# [CCCXW] no expiries (likely no options listed).
# [CCD] no expiries (likely no options listed).
# [CCFE] no expiries (likely no options listed).
# [CCG] no expiries (likely no options listed).
# [CCGWW] no expiries (likely no options listed).
# [CCHH] no expiries (likely no options listed).
# [CCII] no expiries (likely no options listed).
# [CCIIU] no expiries (likely no options listed).
# [CCIIW] no expiries (likely no options listed).
# [CCIX] no expiries (likely no options listed).
# [CCIXU] no expiries (likely no options listed).
# [CCIXW] no expiries (likely no options listed).
# [CCLDO] no expiries (likely no options listed).
# [CCNEP] no expiries (likely no options listed).
# [CCNR] no expiries (likely no options listed).
# [CCSB] no expiries (likely no options listed).
# [CCSO] no expiries (likely no options listed).
# [CCTG] no expiries (likely no options listed).
# [CDIG] no expiries (likely no options listed).
# [CDIO] no expiries (likely no options listed).
# [CDL] no expiries (likely no options listed).
# [CDIOW] no expiries (likely no options listed).
# [CDRO] no expiries (likely no options listed).
# [CDROW] no expiries (likely no options listed).
# [CDT] no expiries (likely no options listed).
# [CDTG] no expiries (likely no options listed).
# [CDTTW] no expiries (likely no options listed).
# [CDZIP] no expiries (likely no options listed).
# [CEFA] no expiries (likely no options listed).
# [CELUW] no expiries (likely no options listed).
# [CELZ] no expiries (likely no options listed).
# [CEPF] no expiries (likely no options listed).
# [CEPT] no expiries (likely no options listed).
# [CEPV] no expiries (likely no options listed).
# [CETX] no expiries (likely no options listed).
# [CETY] no expiries (likely no options listed).
# [CFBK] no expiries (likely no options listed).
# [CFFI] no expiries (likely no options listed).
# [CFO] no expiries (likely no options listed).
# [CGABL] no expiries (likely no options listed).
# [CGBDL] no expiries (likely no options listed).
# [CGCT] no expiries (likely no options listed).
# [CGCTU] no expiries (likely no options listed).
# [CGCTW] no expiries (likely no options listed).
# [CGO] no expiries (likely no options listed).
# [CGTL] no expiries (likely no options listed).
# [CGTX] no expiries (likely no options listed).
# [CHA] no expiries (likely no options listed).
# [CHAC] no expiries (likely no options listed).
# [CHACR] no expiries (likely no options listed).
# [CHACU] no expiries (likely no options listed).
# [CHAI] no expiries (likely no options listed).
# [CHAR] no expiries (likely no options listed).
# [CHARR] no expiries (likely no options listed).
# [CHARU] no expiries (likely no options listed).
# [CHCI] no expiries (likely no options listed).
# [CHECU] no expiries (likely no options listed).
# [CHEK] no expiries (likely no options listed).
# [CHGX] no expiries (likely no options listed).
# [CHI] no expiries (likely no options listed).
# [CHMG] no expiries (likely no options listed).
# [CHNR] no expiries (likely no options listed).
# [CHPG] no expiries (likely no options listed).
# [CHPGR] no expiries (likely no options listed).
# [CHPGU] no expiries (likely no options listed).
# [CHPX] no expiries (likely no options listed).
# [CHR] no expiries (likely no options listed).
# [CHRI] no expiries (likely no options listed).
# [CHSCL] no expiries (likely no options listed).
# [CHSCM] no expiries (likely no options listed).
# [CHSCN] no expiries (likely no options listed).
# [CHSCO] no expiries (likely no options listed).
# [CHSCP] no expiries (likely no options listed).
# [CHSN] no expiries (likely no options listed).
# [CHW] no expiries (likely no options listed).
# [CHY] no expiries (likely no options listed).
# [CIFRW] no expiries (likely no options listed).
# [CIGL] no expiries (likely no options listed).
# [CIIT] no expiries (likely no options listed).
# [CIL] no expiries (likely no options listed).
# [CING] no expiries (likely no options listed).
# [CINGW] no expiries (likely no options listed).
# [CISO] no expiries (likely no options listed).
# [CISS] no expiries (likely no options listed).
# [multi_fetcher] CINF: failed -> 'NoneType' object has no attribute 'get'
# [CJET] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] CIVB: failed -> 'NoneType' object has no attribute 'get'
# [CJMB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLAR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLBK] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLBT] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLDX] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLFD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLGN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLIK] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLIR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLLS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLMB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLMT] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLNE] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLNN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLNNW] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLOA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLOD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLOU] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLOV] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLPS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLPT] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLRB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CLRO] no expiries (likely no options listed).
# [CLSKW] no expiries (likely no options listed).
# [CLSM] no expiries (likely no options listed).
# [CLST] no expiries (likely no options listed).
# [CLWT] no expiries (likely no options listed).
# [CLYM] no expiries (likely no options listed).
# [CMBO] no expiries (likely no options listed).
# [CMCT] no expiries (likely no options listed).
# [CMMB] no expiries (likely no options listed).
# [CMND] no expiries (likely no options listed).
# [CMPOW] no expiries (likely no options listed).
# [CNCK] no expiries (likely no options listed).
# [CNCKW] no expiries (likely no options listed).
# [CNET] no expiries (likely no options listed).
# [CNEY] no expiries (likely no options listed).
# [CNOBP] no expiries (likely no options listed).
# [CNQQ] no expiries (likely no options listed).
# [CNSP] no expiries (likely no options listed).
# [CNTX] no expiries (likely no options listed).
# [COCH] no expiries (likely no options listed).
# [COCHW] no expiries (likely no options listed).
# [COCP] no expiries (likely no options listed).
# [CODA] no expiries (likely no options listed).
# [COEP] no expiries (likely no options listed).
# [COEPW] no expiries (likely no options listed).
# [COFS] no expiries (likely no options listed).
# [COLA] no expiries (likely no options listed).
# [COLAR] no expiries (likely no options listed).
# [COLAU] no expiries (likely no options listed).
# [COOT] no expiries (likely no options listed).
# [COPJ] no expiries (likely no options listed).
# [COOTW] no expiries (likely no options listed).
# [COPP] no expiries (likely no options listed).
# [CORZW] no expiries (likely no options listed).
# [CORZZ] no expiries (likely no options listed).
# [COTG] no expiries (likely no options listed).
# [COWG] no expiries (likely no options listed).
# [CPAG] no expiries (likely no options listed).
# [CPBI] no expiries (likely no options listed).
# [CPHC] no expiries (likely no options listed).
# [CPHY] no expiries (likely no options listed).
# [CPLS] no expiries (likely no options listed).
# [CPOP] no expiries (likely no options listed).
# [CPZ] no expiries (likely no options listed).
# [CRACU] no expiries (likely no options listed).
# [CRAQ] no expiries (likely no options listed).
# [CRAQR] no expiries (likely no options listed).
# [CRAQU] no expiries (likely no options listed).
# [CRE] no expiries (likely no options listed).
# [CREG] no expiries (likely no options listed).
# [CRESW] no expiries (likely no options listed).
# [CREV] no expiries (likely no options listed).
# [CREVW] no expiries (likely no options listed).
# [CREX] no expiries (likely no options listed).
# [CRGO] no expiries (likely no options listed).
# [CRGOW] no expiries (likely no options listed).
# [CRIS] no expiries (likely no options listed).
# [CRMLW] no expiries (likely no options listed).
# [CRMT] no expiries (likely no options listed).
# [CRSP] rate-limited on 2026-04-17: Too Many Requests. Rate limited. Try after a while.
# [CRSP] rate-limited on 2026-01-16: Too Many Requests. Rate limited. Try after a while.
# [CRSR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CRSP] rate-limited on 2026-06-18: Too Many Requests. Rate limited. Try after a while.
# [CRSP] rate-limited on 2026-09-18: Too Many Requests. Rate limited. Try after a while.
# [CRTO] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CRSP] rate-limited on 2028-01-21: Too Many Requests. Rate limited. Try after a while.
# [CRSP] rate-limited on 2027-01-15: Too Many Requests. Rate limited. Try after a while.
# [CRUS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CRVL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CRVO] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] CRSP: failed -> 'NoneType' object has no attribute 'get'
# [CRVS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CRWD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CRWL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CRWG] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CRWS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CRWV] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSAI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSBR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSCL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSCO] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSCS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSGP] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSGS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSIQ] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSPI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [CSQ] no expiries (likely no options listed).
# [CTNT] no expiries (likely no options listed).
# [CTOR] no expiries (likely no options listed).
# [CTW] no expiries (likely no options listed).
# [CUB] no expiries (likely no options listed).
# [CUBWU] no expiries (likely no options listed).
# [CUBWW] no expiries (likely no options listed).
# [CUPR] no expiries (likely no options listed).
# [CURR] no expiries (likely no options listed).
# [CURX] no expiries (likely no options listed).
# [CV] no expiries (likely no options listed).
# [CVKD] no expiries (likely no options listed).
# [CVNX] no expiries (likely no options listed).
# [CVV] no expiries (likely no options listed).
# [CWD] no expiries (likely no options listed).
# [CXAIW] no expiries (likely no options listed).
# [CYCN] no expiries (likely no options listed).
# [CYCU] no expiries (likely no options listed).
# [CYCUW] no expiries (likely no options listed).
# [CYN] no expiries (likely no options listed).
# [CZAR] no expiries (likely no options listed).
# [CZFS] no expiries (likely no options listed).
# [CZWI] no expiries (likely no options listed).
# [DAAQ] no expiries (likely no options listed).
# [DAAQU] no expiries (likely no options listed).
# [DAAQW] no expiries (likely no options listed).
# [DADS] no expiries (likely no options listed).
# [DAIC] no expiries (likely no options listed).
# [DAICW] no expiries (likely no options listed).
# [DAK] no expiries (likely no options listed).
# [DALI] no expiries (likely no options listed).
# [DARE] no expiries (likely no options listed).
# [DAVEW] no expiries (likely no options listed).
# [DBGI] no expiries (likely no options listed).
# [DBVT] no expiries (likely no options listed).
# [DCOMG] no expiries (likely no options listed).
# [DCOMP] no expiries (likely no options listed).
# [DDI] no expiries (likely no options listed).
# [DDIV] no expiries (likely no options listed).
# [DEMZ] no expiries (likely no options listed).
# [DERM] no expiries (likely no options listed).
# [DEVS] no expiries (likely no options listed).
# [DFDVW] no expiries (likely no options listed).
# [DFGP] no expiries (likely no options listed).
# [DFGX] no expiries (likely no options listed).
# [DFLIW] no expiries (likely no options listed).
# [DFSC] no expiries (likely no options listed).
# [DFSCW] no expiries (likely no options listed).
# [DGCB] no expiries (likely no options listed).
# [DGICB] no expiries (likely no options listed).
# [DGLO] no expiries (likely no options listed).
# [DGLY] no expiries (likely no options listed).
# [DGRE] no expiries (likely no options listed).
# [DHCNI] no expiries (likely no options listed).
# [DHCNL] no expiries (likely no options listed).
# [DHIL] no expiries (likely no options listed).
# [DIME] no expiries (likely no options listed).
# [DIVD] no expiries (likely no options listed).
# [DJCO] no expiries (likely no options listed).
# [DJTWW] no expiries (likely no options listed).
# [DKI] no expiries (likely no options listed).
# [DKNX] no expiries (likely no options listed).
# [DLPN] rate-limited on 2026-03-20: Too Many Requests. Rate limited. Try after a while.
# [DLO] rate-limited on 2027-01-15: Too Many Requests. Rate limited. Try after a while.
# [DLO] rate-limited on 2027-12-17: Too Many Requests. Rate limited. Try after a while.
# [DLPN] rate-limited on 2026-06-18: Too Many Requests. Rate limited. Try after a while.
# [DLO] rate-limited on 2028-01-21: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] DLPN: failed -> 'NoneType' object has no attribute 'get'
# [multi_fetcher] DLO: failed -> 'NoneType' object has no attribute 'get'
# [DLTH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DLTR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DLXY] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DMAA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DMAAR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DMAAU] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DMAC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DMAT] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DMIIU] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DMLP] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DMRC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DMXF] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DNLI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DNMXU] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [DNTH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# ...
# [VEU] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VFC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VFH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VFMF] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VFL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VGHY] no expiries (likely no options listed).
# [VGI] no expiries (likely no options listed).
# [VGM] no expiries (likely no options listed).
# [VGMS] no expiries (likely no options listed).
# [VGVT] no expiries (likely no options listed).
# [VHI] no expiries (likely no options listed).
# [VIA] no expiries (likely no options listed).
# [VIDI] no expiries (likely no options listed).
# [VIOO] no expiries (likely no options listed).
# [VIOV] no expiries (likely no options listed).
# [VKI] no expiries (likely no options listed).
# [VKQ] no expiries (likely no options listed).
# [VLLU] no expiries (likely no options listed).
# [VLN.W] no expiries (likely no options listed).
# [VLT] no expiries (likely no options listed).
# [VMAX] no expiries (likely no options listed).
# [VMO] no expiries (likely no options listed).
# [VNAM] no expiries (likely no options listed).
# [VNIE] no expiries (likely no options listed).
# [VNLA] no expiries (likely no options listed).
# [VNO$L] no expiries (likely no options listed).
# [VNO$M] no expiries (likely no options listed).
# [VNO$N] no expiries (likely no options listed).
# [VNO$O] no expiries (likely no options listed).
# [VNSE] no expiries (likely no options listed).
# [VNTG] no expiries (likely no options listed).
# [VOYA$B] no expiries (likely no options listed).
# [VPC] no expiries (likely no options listed).
# [VPV] no expiries (likely no options listed).
# [VRAI] no expiries (likely no options listed).
# [VRTS] no expiries (likely no options listed).
# [VSDB] no expiries (likely no options listed).
# [VSDM] no expiries (likely no options listed).
# [VSHY] no expiries (likely no options listed).
# [VSLU] no expiries (likely no options listed).
# [VTAK] no expiries (likely no options listed).
# [VTEL] no expiries (likely no options listed).
# [VTG] no expiries (likely no options listed).
# [VTMX] no expiries (likely no options listed).
# [VTN] no expiries (likely no options listed).
# [VTP] no expiries (likely no options listed).
# [VUSE] no expiries (likely no options listed).
# [VVR] no expiries (likely no options listed).
# [VVV] rate-limited on 2025-11-21: Too Many Requests. Rate limited. Try after a while.
# [VV] rate-limited on 2026-01-16: Too Many Requests. Rate limited. Try after a while.
# [VV] rate-limited on 2025-11-21: Too Many Requests. Rate limited. Try after a while.
# [VVV] rate-limited on 2025-12-19: Too Many Requests. Rate limited. Try after a while.
# [VVV] rate-limited on 2026-01-16: Too Many Requests. Rate limited. Try after a while.
# [VV] rate-limited on 2026-04-17: Too Many Requests. Rate limited. Try after a while.
# [VVV] rate-limited on 2026-04-17: Too Many Requests. Rate limited. Try after a while.
# [VVV] rate-limited on 2026-07-17: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] VV: failed -> 'NoneType' object has no attribute 'get'
# [VVX] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] VVV: failed -> 'NoneType' object has no attribute 'get'
# [VWO] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VWID] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VXF] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VXX] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VXZ] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VYLD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VYM] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VYX] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VZ] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [VZLA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [W] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [WAB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [WAL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [WAL$A] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [WANT] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [WAR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [WBIF] no expiries (likely no options listed).
# [WBIG] no expiries (likely no options listed).
# [WBIL] no expiries (likely no options listed).
# [WBIY] no expiries (likely no options listed).
# [WBS$F] no expiries (likely no options listed).
# [WBS$G] no expiries (likely no options listed).
# [WCAP] no expiries (likely no options listed).
# [WCEO] no expiries (likely no options listed).
# [WCME] no expiries (likely no options listed).
# [WCMI] no expiries (likely no options listed).
# [WCPB] no expiries (likely no options listed).
# [WDEF] no expiries (likely no options listed).
# [WDH] no expiries (likely no options listed).
# [WDI] no expiries (likely no options listed).
# [WEA] no expiries (likely no options listed).
# [WEEK] no expiries (likely no options listed).
# [WEEL] no expiries (likely no options listed).
# [WF] no expiries (likely no options listed).
# [WFC$A] no expiries (likely no options listed).
# [WFC$C] no expiries (likely no options listed).
# [WFC$D] no expiries (likely no options listed).
# [WFC$L] no expiries (likely no options listed).
# [WFC$Y] no expiries (likely no options listed).
# [WFC$Z] no expiries (likely no options listed).
# [WHTX] no expiries (likely no options listed).
# [WIA] no expiries (likely no options listed).
# [WILD] no expiries (likely no options listed).
# [WINN] no expiries (likely no options listed).
# [WISD] no expiries (likely no options listed).
# [WIW] no expiries (likely no options listed).
# [WLDR] no expiries (likely no options listed).
# [WLTG] no expiries (likely no options listed).
# [WLYB] no expiries (likely no options listed).
# [WMSB] no expiries (likely no options listed).
# [WMTI] no expiries (likely no options listed).
# [WOMN] no expiries (likely no options listed).
# [WQTM] no expiries (likely no options listed).
# [WRB$E] no expiries (likely no options listed).
# [WRB$F] no expiries (likely no options listed).
# [WRB$G] no expiries (likely no options listed).
# [WRB$H] no expiries (likely no options listed).
# [WRN] no expiries (likely no options listed).
# [WSO.B] no expiries (likely no options listed).
# [WTID] no expiries (likely no options listed).
# [WTIU] no expiries (likely no options listed).
# [WTM] no expiries (likely no options listed).
# [WUGI] no expiries (likely no options listed).
# [WWJD] no expiries (likely no options listed).
# [multi_fetcher] WWW: failed -> 'NoneType' object has no attribute 'get'
# [multi_fetcher] WWR: failed -> 'NoneType' object has no attribute 'get'
# [WXET] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [WY] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [WYY] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [WZRD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XAPR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XAR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XAUG] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XBAP] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XBB] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XBI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XBJA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XBJL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XBOC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XCCC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XCEM] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XCLR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XCOR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XDAT] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [XDEC] no expiries (likely no options listed).
# [XDQQ] no expiries (likely no options listed).
# [XDSQ] no expiries (likely no options listed).
# [XEMD] no expiries (likely no options listed).
# [XFEB] no expiries (likely no options listed).
# [XFIV] no expiries (likely no options listed).
# [XFLT] no expiries (likely no options listed).
# [XFLX] no expiries (likely no options listed).
# [XHLF] no expiries (likely no options listed).
# [XHYC] no expiries (likely no options listed).
# [XHYI] no expiries (likely no options listed).
# [XIDE] no expiries (likely no options listed).
# [XIDV] no expiries (likely no options listed).
# [XIJN] no expiries (likely no options listed).
# [XIMR] no expiries (likely no options listed).
# [XISE] no expiries (likely no options listed).
# [XJAN] no expiries (likely no options listed).
# [XJH] no expiries (likely no options listed).
# [XJR] no expiries (likely no options listed).
# [XJUL] no expiries (likely no options listed).
# [XJUN] no expiries (likely no options listed).
# [XLBI] no expiries (likely no options listed).
# [XLCI] no expiries (likely no options listed).
# [XLEI] no expiries (likely no options listed).
# [XLFI] no expiries (likely no options listed).
# [XLII] no expiries (likely no options listed).
# [XLKI] no expiries (likely no options listed).
# [XLRI] no expiries (likely no options listed).
# [XLSI] no expiries (likely no options listed).
# [XLSR] no expiries (likely no options listed).
# [XLUI] no expiries (likely no options listed).
# [XLVI] no expiries (likely no options listed).
# [XLYI] no expiries (likely no options listed).
# [XMAR] no expiries (likely no options listed).
# [XMAY] no expiries (likely no options listed).
# [XMPT] no expiries (likely no options listed).
# [XMVM] no expiries (likely no options listed).
# [XNAV] no expiries (likely no options listed).
# [XNOV] no expiries (likely no options listed).
# [XOCT] no expiries (likely no options listed).
# [XOEF] no expiries (likely no options listed).
# [XONE] no expiries (likely no options listed).
# [XPAY] no expiries (likely no options listed).
# [XPL] no expiries (likely no options listed).
# [XPND] no expiries (likely no options listed).
# [XRLV] no expiries (likely no options listed).
# [XRLX] no expiries (likely no options listed).
# [XRMI] no expiries (likely no options listed).
# [XSEP] no expiries (likely no options listed).
# [XSVN] no expiries (likely no options listed).
# [XTAP] no expiries (likely no options listed).
# [XTEN] no expiries (likely no options listed).
# [XTJA] no expiries (likely no options listed).
# [XTJL] no expiries (likely no options listed).
# [XTNT] no expiries (likely no options listed).
# [XTOC] no expiries (likely no options listed).
# [XTR] no expiries (likely no options listed).
# [XTRE] no expiries (likely no options listed).
# [XTWO] no expiries (likely no options listed).
# [XTWY] no expiries (likely no options listed).
# [XUDV] no expiries (likely no options listed).
# [XUSP] no expiries (likely no options listed).
# [XV] no expiries (likely no options listed).
# [XVOL] no expiries (likely no options listed).
# [XVV] no expiries (likely no options listed).
# [XYF] no expiries (likely no options listed).
# [XZO] no expiries (likely no options listed).
# [YBIT] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [multi_fetcher] YANG: failed -> 'NoneType' object has no attribute 'get'
# [YBTC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YCL] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YCBD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YCS] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YCY] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YCY.U] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YCY.W] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YDEC] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YEAR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YELP] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YETH] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YETI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YEXT] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YFFI] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YFYA] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YGLD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YINN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YJUN] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YLD] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YMAG] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YMAR] rate-limited while listing expiries: Too Many Requests. Rate limited. Try after a while.
# [YSEP] no expiries (likely no options listed).
# [ZALT] no expiries (likely no options listed).
# [ZAPR] no expiries (likely no options listed).
# [ZAUG] no expiries (likely no options listed).
# [ZBZX] no expiries (likely no options listed).
# [ZDEK] no expiries (likely no options listed).
# [ZECP] no expiries (likely no options listed).
# [ZEXIT] no expiries (likely no options listed).
# [ZFEB] no expiries (likely no options listed).
# [ZHDG] no expiries (likely no options listed).
# [ZIEXT] no expiries (likely no options listed).
# [ZIG] no expiries (likely no options listed).
# [ZJAN] no expiries (likely no options listed).
# [ZJUL] no expiries (likely no options listed).
# [ZJUN] no expiries (likely no options listed).
# [ZKH] no expiries (likely no options listed).
# [ZMAR] no expiries (likely no options listed).
# [ZMAY] no expiries (likely no options listed).
# [ZNOV] no expiries (likely no options listed).
# [ZOCT] no expiries (likely no options listed).
# [ZONE] no expiries (likely no options listed).
# [ZSB] no expiries (likely no options listed).
# [ZSC] no expiries (likely no options listed).
# [ZSEP] no expiries (likely no options listed).
# [ZTAX] no expiries (likely no options listed).
# [ZTEST] no expiries (likely no options listed).
# [ZTR] no expiries (likely no options listed).
# [ZVOL] no expiries (likely no options listed).
# [ZVV] no expiries (likely no options listed).
# [ZXIET] no expiries (likely no options listed).

# %%
calls
# Out:
#              contractSymbol             lastTradeDate  strike  lastPrice  \
# 0       DTCR251219C00021000 2025-11-07 15:32:00+00:00    21.0       1.21
# 1       DTCR251219C00022000 2025-10-30 18:05:44+00:00    22.0       0.55
# 2       DTCR251219C00025000 2025-10-31 13:32:32+00:00    25.0       0.35
# 3       DTCR251121C00017000 2025-10-01 19:54:26+00:00    17.0       3.95
# 4       DTCR251121C00019000 2025-09-25 14:31:31+00:00    19.0       1.73
# ...                     ...                       ...     ...        ...
# 383426   ZWS260220C00047500 2025-10-30 13:30:17+00:00    47.5       3.43
# 383427   ZWS260220C00050000 2025-10-30 18:43:51+00:00    50.0       2.15
# 383428   ZWS260220C00055000 2025-10-01 19:50:16+00:00    55.0       1.05
# 383429   ZWS260515C00040000 2025-09-24 18:24:18+00:00    40.0       9.20
# 383430   ZWS260515C00047500 2025-10-31 13:30:23+00:00    47.5       5.60
#
#          bid    ask  change  percentChange  volume  openInterest  \
# 0       0.50   1.65   -0.54     -30.857141    10.0           1.0
# 1       0.50   1.00   -0.80     -59.259260     5.0          13.0
# 2       0.00   0.30    0.00       0.000000     2.0           2.0
# 3       3.90   4.90    0.00       0.000000    30.0          30.0
# 4       2.10   2.95    0.00       0.000000     NaN           2.0
# ...      ...    ...     ...            ...     ...           ...
# 383426  1.55   5.40    0.00       0.000000    70.0         108.0
# 383427  0.25   4.30    0.00       0.000000     1.0          92.0
# 383428  0.00   2.95    0.00       0.000000     7.0           0.0
# 383429  7.50  11.70    0.00       0.000000     NaN          10.0
# 383430  2.75   6.90    0.00       0.000000     4.0           4.0
#
#         impliedVolatility  inTheMoney contractSize currency option_type  \
# 0                0.430670        True      REGULAR      USD        call
# 1                0.380377       False      REGULAR      USD        call
# 2                0.426764       False      REGULAR      USD        call
# 3                0.957032        True      REGULAR      USD        call
# 4                0.667972        True      REGULAR      USD        call
# ...                   ...         ...          ...      ...         ...
# 383426           0.535283       False      REGULAR      USD        call
# 383427           0.527104       False      REGULAR      USD        call
# 383428           0.548344       False      REGULAR      USD        call
# 383429           0.593510        True      REGULAR      USD        call
# 383430           0.510503       False      REGULAR      USD        call
#
#         expiration       TTM ticker  dividendYield  spot_price
# 0       2025-12-19  0.115068   DTCR           1.34   21.740000
# 1       2025-12-19  0.115068   DTCR           1.34   21.740000
# 2       2025-12-19  0.115068   DTCR           1.34   21.740000
# 3       2025-11-21  0.038356   DTCR           1.34   21.740000
# 4       2025-11-21  0.038356   DTCR           1.34   21.740000
# ...            ...       ...    ...            ...         ...
# 383426  2026-02-20  0.284932    ZWS           0.76   47.459999
# 383427  2026-02-20  0.284932    ZWS           0.76   47.459999
# 383428  2026-02-20  0.284932    ZWS           0.76   47.459999
# 383429  2026-05-15  0.515068    ZWS           0.76   47.459999
# 383430  2026-05-15  0.515068    ZWS           0.76   47.459999
#
# [383431 rows x 20 columns]

# %%
calls[calls.ticker == "AMZN"]
# Out:
# Empty DataFrame
# Columns: [contractSymbol, lastTradeDate, strike, lastPrice, bid, ask, change, percentChange, volume, openInterest, impliedVolatility, inTheMoney, contractSize, currency, option_type, expiration, TTM, ticker, dividendYield, spot_price]
# Index: []

# %%
tickers.__contains__("AMZN")
# Out:
# True

# %%
#calls.to_csv("calls.csv")

# %%
#puts.to_csv("puts.csv")
