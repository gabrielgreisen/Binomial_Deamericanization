# %%
from utils.ticker_fetcher import get_all_us_listed_tickers

tickers = get_all_us_listed_tickers()
tickers
# Out:
# ['AACB',
#  'AACBR',
#  'AACBU',
#  'AACG',
#  'AADR',
#  'AAL',
#  'AALG',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPB',
#  'AAPD',
#  'AAPG',
#  'AAPL',
#  'AAPU',
#  'AARD',
#  'AAUS',
#  'AAVM',
#  'AAXJ',
#  'ABAT',
#  'ABCL',
#  'ABCS',
#  'ABEO',
#  'ABI',
#  'ABIG',
#  'ABL',
#  'ABLLL',
#  'ABLV',
#  'ABLVW',
#  'ABNB',
#  'ABOS',
#  'ABP',
#  'ABPWW',
#  'ABSI',
#  'ABTC',
#  'ABTS',
#  'ABUS',
#  'ABVC',
#  'ABVE',
#  'ABVEW',
#  'ABVX',
#  'ACAD',
#  'ACB',
#  'ACCL',
#  'ACDC',
#  'ACET',
#  'ACFN',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACHC',
#  'ACHV',
#  'ACIC',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACMR',
#  'ACNB',
#  'ACNT',
#  'ACOG',
#  'ACON',
#  'ACONW',
#  'ACRS',
#  'ACRV',
#  'ACT',
#  'ACTG',
#  'ACTU',
#  'ACWI',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADAM',
#  'ADAMG',
#  'ADAMH',
#  'ADAMI',
#  'ADAML',
#  'ADAMM',
#  'ADAMN',
#  'ADAMZ',
#  'ADBE',
#  'ADBG',
#  'ADEA',
#  'ADGM',
#  'ADI',
#  'ADIL',
#  'ADMA',
#  'ADP',
#  'ADPT',
#  'ADSE',
#  'ADSEW',
#  'ADSK',
#  'ADTN',
#  'ADTX',
#  'ADUR',
#  'ADUS',
#  'ADV',
#  'ADVB',
#  'ADVM',
#  'ADXN',
#  'AEBI',
#  'AEC',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEMD',
#  'AENT',
#  'AENTW',
#  'AEP',
#  'AERT',
#  'AERTW',
#  'AEVA',
#  'AEVAW',
#  'AEYE',
#  'AFBI',
#  'AFCG',
#  'AFJK',
#  'AFJKR',
#  'AFJKU',
#  'AFOS',
#  'AFRI',
#  'AFRIW',
#  'AFRM',
#  'AFSC',
#  'AFYA',
#  'AGAE',
#  'AGCC',
#  'AGEM',
#  'AGEN',
#  'AGGA',
#  'AGH',
#  'AGIO',
#  'AGIX',
#  'AGMH',
#  'AGMI',
#  'AGNC',
#  'AGNCL',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGNCZ',
#  'AGNG',
#  'AGRI',
#  'AGRZ',
#  'AGYS',
#  'AGZD',
#  'AHCO',
#  'AHG',
#  'AHMA',
#  'AIA',
#  'AIFD',
#  'AIFF',
#  'AIFU',
#  'AIHS',
#  'AIIO',
#  'AIIOW',
#  'AIMD',
#  'AIMDW',
#  'AIOT',
#  'AIP',
#  'AIPI',
#  'AIPO',
#  'AIQ',
#  'AIRE',
#  'AIRG',
#  'AIRJ',
#  'AIRJW',
#  'AIRO',
#  'AIRR',
#  'AIRS',
#  'AIRT',
#  'AIRTP',
#  'AISP',
#  'AISPW',
#  'AIXI',
#  'AKAM',
#  'AKAN',
#  'AKBA',
#  'AKRO',
#  'AKTX',
#  'ALAB',
#  'ALAR',
#  'ALBT',
#  'ALCO',
#  'ALCY',
#  'ALCYU',
#  'ALCYW',
#  'ALDF',
#  'ALDFU',
#  'ALDFW',
#  'ALDX',
#  'ALEC',
#  'ALF',
#  'ALFUU',
#  'ALFUW',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIL',
#  'ALISU',
#  'ALKS',
#  'ALKT',
#  'ALLO',
#  'ALLR',
#  'ALLT',
#  'ALLW',
#  'ALM',
#  'ALMS',
#  'ALMU',
#  'ALNT',
#  'ALNY',
#  'ALOT',
#  'ALPS',
#  'ALRM',
#  'ALRS',
#  'ALT',
#  'ALTI',
#  'ALTO',
#  'ALTS',
#  'ALTY',
#  'ALVO',
#  'ALVOW',
#  'ALXO',
#  'ALZN',
#  'AMAL',
#  'AMAT',
#  'AMBA',
#  'AMBR',
#  'AMCX',
#  'AMD',
#  'AMDD',
#  'AMDG',
#  'AMDL',
#  'AMDU',
#  'AMGN',
#  'AMID',
#  'AMIX',
#  'AMKR',
#  'AMLX',
#  'AMOD',
#  'AMODW',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPL',
#  'AMRK',
#  'AMRN',
#  'AMRX',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMTX',
#  'AMUN',
#  'AMUU',
#  'AMWD',
#  'AMYY',
#  'AMZD',
#  'AMZN',
#  'AMZU',
#  'AMZZ',
#  'ANAB',
#  'ANDE',
#  'ANEB',
#  'ANEL',
#  'ANGH',
#  'ANGHW',
#  'ANGI',
#  'ANGL',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANL',
#  'ANNA',
#  'ANNAW',
#  'ANNX',
#  'ANPA',
#  'ANSC',
#  'ANSCU',
#  'ANSCW',
#  'ANTA',
#  'ANTX',
#  'ANY',
#  'AOHY',
#  'AOSL',
#  'AOTG',
#  'AOUT',
#  'APA',
#  'APACU',
#  'APAD',
#  'APADR',
#  'APADU',
#  'APED',
#  'APEI',
#  'APGE',
#  'API',
#  'APLD',
#  'APLM',
#  'APLMW',
#  'APLS',
#  'APLT',
#  'APM',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APPX',
#  'APRE',
#  'APVO',
#  'APWC',
#  'APXTU',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQST',
#  'AQWA',
#  'ARAI',
#  'ARAY',
#  'ARBB',
#  'ARBE',
#  'ARBEW',
#  'ARBK',
#  'ARBKL',
#  'ARCB',
#  'ARCC',
#  'ARCT',
#  'ARDX',
#  'AREB',
#  'AREBW',
#  'AREC',
#  'ARGX',
#  'ARHS',
#  'ARKO',
#  'ARKOW',
#  'ARKR',
#  'ARLP',
#  'ARM',
#  'ARMG',
#  'AROW',
#  'ARQ',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARRY',
#  'ARTL',
#  'ARTNA',
#  'ARTV',
#  'ARTW',
#  'ARVN',
#  'ARVR',
#  'ARWR',
#  'ASBP',
#  'ASBPW',
#  'ASCI',
#  'ASLE',
#  'ASMB',
#  'ASMG',
#  'ASML',
#  'ASND',
#  'ASNS',
#  'ASO',
#  'ASPC',
#  'ASPCR',
#  'ASPCU',
#  'ASPI',
#  'ASPS',
#  'ASPSW',
#  'ASPSZ',
#  'ASRT',
#  'ASRV',
#  'ASST',
#  'ASTC',
#  'ASTE',
#  'ASTH',
#  'ASTI',
#  'ASTL',
#  'ASTLW',
#  'ASTS',
#  'ASUR',
#  'ASYS',
#  'ATAI',
#  'ATAT',
#  'ATEC',
#  'ATER',
#  'ATEX',
#  'ATGL',
#  'ATHA',
#  'ATHE',
#  'ATHR',
#  'ATII',
#  'ATIIU',
#  'ATIIW',
#  'ATLC',
#  'ATLCL',
#  'ATLCP',
#  'ATLCZ',
#  'ATLN',
#  'ATLO',
#  'ATLX',
#  'ATMC',
#  'ATMCR',
#  'ATMCU',
#  'ATMCW',
#  'ATMV',
#  'ATMVR',
#  'ATMVU',
#  'ATNI',
#  'ATOM',
#  'ATON',
#  'ATOS',
#  'ATPC',
#  'ATRA',
#  'ATRC',
#  'ATRO',
#  'ATXG',
#  'ATXS',
#  'ATYR',
#  'AUBN',
#  'AUDC',
#  'AUGO',
#  'AUID',
#  'AUMI',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AURE',
#  'AUROW',
#  'AUTL',
#  'AUUD',
#  'AUUDW',
#  'AVAH',
#  'AVAV',
#  'AVBH',
#  'AVBP',
#  'AVDL',
#  'AVGB',
#  'AVGG',
#  'AVGO',
#  'AVGU',
#  'AVGX',
#  'AVIR',
#  'AVL',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVR',
#  'AVS',
#  'AVT',
#  'AVTX',
#  'AVUQ',
#  'AVXC',
#  'AVXL',
#  'AVXX',
#  'AWRE',
#  'AXG',
#  'AXGN',
#  'AXIN',
#  'AXINR',
#  'AXINU',
#  'AXON',
#  'AXSM',
#  'AXTI',
#  'AYTU',
#  'AZ',
#  'AZI',
#  'AZN',
#  'AZTA',
#  'AZYY',
#  'BABX',
#  'BACC',
#  'BACCR',
#  'BACCU',
#  'BACQ',
#  'BACQR',
#  'BACQU',
#  'BAER',
#  'BAERW',
#  'BAFE',
#  'BAFN',
#  'BAIG',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANL',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BASG',
#  'BASV',
#  'BATRA',
#  'BATRK',
#  'BAYA',
#  'BAYAR',
#  'BAYAU',
#  'BBB',
#  'BBCP',
#  'BBGI',
#  'BBH',
#  'BBIO',
#  'BBLG',
#  'BBLGW',
#  'BBNX',
#  'BBOT',
#  'BBSI',
#  'BBYY',
#  'BCAB',
#  'BCAL',
#  'BCAR',
#  'BCARU',
#  'BCARW',
#  'BCAX',
#  'BCBP',
#  'BCDA',
#  'BCG',
#  'BCGWW',
#  'BCIC',
#  'BCLO',
#  'BCML',
#  'BCPC',
#  'BCRX',
#  'BCTX',
#  'BCTXW',
#  'BCTXZ',
#  'BCYC',
#  'BDCI',
#  'BDCIU',
#  'BDCIW',
#  'BDGS',
#  'BDMD',
#  'BDMDW',
#  'BDRX',
#  'BDSX',
#  'BDTX',
#  'BDVL',
#  'BDYN',
#  'BEAG',
#  'BEAGR',
#  'BEAGU',
#  'BEAM',
#  'BEAT',
#  'BEATW',
#  'BEEM',
#  'BEEP',
#  'BEEX',
#  'BEEZ',
#  'BELFA',
#  'BELFB',
#  'BELT',
#  'BENF',
#  'BENFW',
#  'BETR',
#  'BETRW',
#  'BFC',
#  'BFIN',
#  'BFRG',
#  'BFRGW',
#  'BFRI',
#  'BFRIW',
#  'BFST',
#  'BGC',
#  'BGIN',
#  'BGL',
#  'BGLC',
#  'BGLWW',
#  'BGM',
#  'BGMS',
#  'BGMSP',
#  'BGRN',
#  'BGRO',
#  'BHAT',
#  'BHF',
#  'BHFAL',
#  'BHFAM',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BHRB',
#  'BHST',
#  'BIAF',
#  'BIAFW',
#  'BIB',
#  'BIDU',
#  'BIIB',
#  'BILI',
#  'BIOA',
#  'BIOX',
#  'BIRD',
#  'BIS',
#  'BITF',
#  'BITS',
#  'BIVI',
#  'BIVIW',
#  'BIYA',
#  'BJDX',
#  'BJK',
#  'BJRI',
#  'BKCH',
#  'BKHA',
#  'BKHAR',
#  'BKHAU',
#  'BKNG',
#  'BKR',
#  'BKYI',
#  'BL',
#  'BLBD',
#  'BLBX',
#  'BLCN',
#  'BLCR',
#  'BLDP',
#  'BLFS',
#  'BLFY',
#  'BLIN',
#  'BLIV',
#  'BLKB',
#  'BLLN',
#  'BLMN',
#  'BLMZ',
#  'BLNE',
#  'BLNK',
#  'BLRX',
#  'BLSG',
#  'BLTE',
#  'BLUW',
#  'BLUWU',
#  'BLUWW',
#  'BLZE',
#  'BLZR',
#  'BLZRU',
#  'BLZRW',
#  'BMAX',
#  'BMBL',
#  'BMDL',
#  'BMEA',
#  'BMGL',
#  'BMHL',
#  'BMNG',
#  'BMR',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BNAI',
#  'BNAIW',
#  'BNBX',
#  'BNC',
#  'BNCWW',
#  'BND',
#  'BNDW',
#  'BNDX',
#  'BNGO',
#  'BNKK',
#  'BNR',
#  'BNRG',
#  'BNTC',
#  'BNTX',
#  'BNZI',
#  'BNZIW',
#  'BODI',
#  'BOED',
#  'BOEG',
#  'BOEU',
#  'BOF',
#  'BOKF',
#  'BOLD',
#  'BOLT',
#  'BON',
#  'BOOM',
#  'BOSC',
#  'BOTJ',
#  'BOTT',
#  'BOTZ',
#  'BOXL',
#  'BPOP',
#  'BPOPM',
#  'BPRN',
#  'BPYPM',
#  'BPYPN',
#  'BPYPO',
#  'BPYPP',
#  'BRAG',
#  'BRBI',
#  'BRCB',
#  'BREM',
#  'BRFH',
#  'BRHY',
#  'BRID',
#  'BRKD',
#  'BRKR',
#  'BRKRP',
#  'BRKU',
#  'BRLS',
#  'BRLSW',
#  'BRLT',
#  'BRNS',
#  'BRNY',
#  'BRR',
#  'BRRR',
#  'BRRWU',
#  'BRRWW',
#  'BRTR',
#  'BRTX',
#  'BRY',
#  'BRZE',
#  'BSAA',
#  'BSAAR',
#  'BSAAU',
#  'BSBK',
#  'BSCP',
#  'BSCQ',
#  'BSCR',
#  'BSCS',
#  'BSCT',
#  'BSCU',
#  'BSCV',
#  'BSCW',
#  'BSCX',
#  'BSCY',
#  'BSCZ',
#  'BSET',
#  'BSJP',
#  'BSJQ',
#  'BSJR',
#  'BSJS',
#  'BSJT',
#  'BSJU',
#  'BSJV',
#  'BSJW',
#  'BSJX',
#  'BSLK',
#  'BSLKW',
#  'BSMP',
#  'BSMQ',
#  'BSMR',
#  'BSMS',
#  'BSMT',
#  'BSMU',
#  'BSMV',
#  'BSMW',
#  'BSMY',
#  'BSMZ',
#  'BSRR',
#  'BSSX',
#  'BSVN',
#  'BSVO',
#  'BSY',
#  'BTAI',
#  'BTBD',
#  'BTBDW',
#  'BTBT',
#  'BTCS',
#  'BTCT',
#  'BTDR',
#  'BTF',
#  'BTFX',
#  'BTGD',
#  'BTM',
#  'BTMD',
#  'BTMWW',
#  'BTOC',
#  'BTOG',
#  'BTQ',
#  'BTSG',
#  'BTSGU',
#  'BTTC',
#  'BUFC',
#  'BUFI',
#  'BUFM',
#  'BUG',
#  'BULD',
#  'BULG',
#  'BULL',
#  'BULLW',
#  'BULX',
#  'BUSE',
#  'BUSEP',
#  'BUUU',
#  'BVFL',
#  'BVS',
#  'BWAY',
#  'BWB',
#  'BWBBP',
#  'BWEN',
#  'BWFG',
#  'BWIN',
#  'BWMN',
#  'BYAH',
#  'BYFC',
#  'BYND',
#  'BYRN',
#  'BYSI',
#  'BZ',
#  'BZAI',
#  'BZAIW',
#  'BZFD',
#  'BZFDW',
#  'BZUN',
#  'CA',
#  'CAAS',
#  'CABA',
#  'CAC',
#  'CACC',
#  'CADL',
#  'CAEP',
#  'CAFG',
#  'CAI',
#  'CAKE',
#  'CALC',
#  'CALI',
#  'CALM',
#  'CAMP',
#  'CAMT',
#  'CAN',
#  'CANC',
#  'CANQ',
#  'CAPN',
#  'CAPNR',
#  'CAPNU',
#  'CAPR',
#  'CAPS',
#  'CAPT',
#  'CAPTW',
#  'CAR',
#  'CARE',
#  'CARG',
#  'CARL',
#  'CART',
#  'CARV',
#  'CARY',
#  'CARZ',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CATH',
#  'CATY',
#  'CBAT',
#  'CBFV',
#  'CBIO',
#  'CBK',
#  'CBLL',
#  'CBNK',
#  'CBRL',
#  'CBSH',
#  'CBUS',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCC',
#  'CCCC',
#  'CCCX',
#  'CCCXU',
#  'CCCXW',
#  'CCD',
#  'CCEC',
#  'CCEP',
#  'CCFE',
#  'CCG',
#  'CCGWW',
#  'CCHH',
#  'CCII',
#  'CCIIU',
#  'CCIIW',
#  'CCIX',
#  'CCIXU',
#  'CCIXW',
#  'CCLD',
#  'CCLDO',
#  'CCNE',
#  'CCNEP',
#  'CCNR',
#  'CCOI',
#  'CCRN',
#  'CCSB',
#  'CCSI',
#  'CCSO',
#  'CCTG',
#  'CDC',
#  'CDIG',
#  'CDIO',
#  'CDIOW',
#  'CDL',
#  'CDLX',
#  'CDNA',
#  'CDNS',
#  'CDRO',
#  'CDROW',
#  'CDT',
#  'CDTG',
#  'CDTTW',
#  'CDTX',
#  'CDW',
#  'CDXS',
#  'CDZI',
#  'CDZIP',
#  'CECO',
#  'CEFA',
#  'CEG',
#  'CELC',
#  'CELH',
#  'CELU',
#  'CELUW',
#  'CELZ',
#  'CENN',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CEP',
#  'CEPF',
#  'CEPI',
#  'CEPO',
#  'CEPT',
#  'CEPV',
#  'CERS',
#  'CERT',
#  'CETX',
#  'CETY',
#  'CEVA',
#  'CFA',
#  'CFBK',
#  'CFFI',
#  'CFFN',
#  'CFLT',
#  'CFO',
#  'CG',
#  'CGABL',
#  'CGBD',
#  'CGBDL',
#  'CGC',
#  'CGCT',
#  'CGCTU',
#  'CGCTW',
#  'CGEM',
#  'CGEN',
#  'CGNT',
#  'CGNX',
#  'CGO',
#  'CGON',
#  'CGTL',
#  'CGTX',
#  'CHA',
#  'CHAC',
#  'CHACR',
#  'CHACU',
#  'CHAI',
#  'CHAR',
#  'CHARR',
#  'CHARU',
#  'CHCI',
#  'CHCO',
#  'CHDN',
#  'CHECU',
#  'CHEF',
#  'CHEK',
#  'CHGX',
#  'CHI',
#  'CHKP',
#  'CHMG',
#  'CHNR',
#  'CHPG',
#  'CHPGR',
#  'CHPGU',
#  'CHPS',
#  'CHPX',
#  'CHR',
#  'CHRD',
#  'CHRI',
#  'CHRS',
#  'CHRW',
#  'CHSCL',
#  'CHSCM',
#  'CHSCN',
#  'CHSCO',
#  'CHSCP',
#  'CHSN',
#  'CHTR',
#  'CHW',
#  'CHY',
#  'CHYM',
#  'CIBR',
#  'CIFR',
#  'CIFRW',
#  'CIGI',
#  'CIGL',
#  'CIIT',
#  'CIL',
#  'CINF',
#  'CING',
#  'CINGW',
#  'CISO',
#  'CISS',
#  'CIVB',
#  'CJET',
#  'CJMB',
#  'CLAR',
#  'CLBK',
#  'CLBT',
#  ...]

# %%
from utils.multi_fetcher import multi_fetcher
calls, puts = multi_fetcher(tickers)
# Out:
# [AACB] Live price unavailable — using last close: 10.25
# [AACBR] Live price unavailable — using last close: 0.31
# $AACBU: possibly delisted; no price data found  (period=1d)
# [AACBU] No live or historical data available.
# [AACG] Live price unavailable — using last close: 1.19
# [AADR] Live price unavailable — using last close: 83.76
# [AAL] Live price unavailable — using last close: 13.65
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AALG] Live price unavailable — using last close: 14.76
# [AAME] Live price unavailable — using last close: 2.89
# [AAOI] Live price unavailable — using last close: 28.57
# [AAON] Live price unavailable — using last close: 105.53
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AAPB] Live price unavailable — using last close: 32.96
# [AAPD] Live price unavailable — using last close: 13.31
# [AAPG] Live price unavailable — using last close: 31.73
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AAPL] Live price unavailable — using last close: 268.47
# [AAPU] Live price unavailable — using last close: 35.48
# [AARD] Live price unavailable — using last close: 10.14
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AAUS] Live price unavailable — using last close: 54.23
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AAVM] Live price unavailable — using last close: 28.89
# [AAXJ] Live price unavailable — using last close: 93.33
# [ABAT] Live price unavailable — using last close: 4.43
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABCL] Live price unavailable — using last close: 3.91
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABCS] Live price unavailable — using last close: 29.40
# [ABEO] Live price unavailable — using last close: 4.20
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABI] Live price unavailable — using last close: 24.88
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABIG] Live price unavailable — using last close: 31.53
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABL] Live price unavailable — using last close: 6.45
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABLLL] Live price unavailable — using last close: 25.30
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABLV] Live price unavailable — using last close: 0.84
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABLVW] Live price unavailable — using last close: 0.02
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABNB] Live price unavailable — using last close: 120.88
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABOS] Live price unavailable — using last close: 1.88
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABP] Live price unavailable — using last close: 5.62
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABPWW] Live price unavailable — using last close: 0.02
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABSI] Live price unavailable — using last close: 3.34
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABTC] Live price unavailable — using last close: 4.64
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABTS] Live price unavailable — using last close: 5.95
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABUS] Live price unavailable — using last close: 4.50
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABVC] Live price unavailable — using last close: 2.91
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABVE] Live price unavailable — using last close: 2.73
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABVEW] Live price unavailable — using last close: 0.86
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ABVX] Live price unavailable — using last close: 105.27
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACAD] Live price unavailable — using last close: 22.57
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACB] Live price unavailable — using last close: 4.55
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACCL] Live price unavailable — using last close: 4.00
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACDC] Live price unavailable — using last close: 5.03
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACET] Live price unavailable — using last close: 0.64
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACFN] Live price unavailable — using last close: 15.13
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACGL] Live price unavailable — using last close: 89.57
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACGLN] Live price unavailable — using last close: 17.45
# [ACGLO] Live price unavailable — using last close: 21.15
# [ACHC] Live price unavailable — using last close: 19.51
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACHV] Live price unavailable — using last close: 4.59
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACIC] Live price unavailable — using last close: 12.14
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACIU] Live price unavailable — using last close: 3.30
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACIW] Live price unavailable — using last close: 48.96
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACLS] Live price unavailable — using last close: 85.74
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACLX] Live price unavailable — using last close: 86.55
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACMR] Live price unavailable — using last close: 31.10
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACNB] Live price unavailable — using last close: 46.98
# [ACNT] Live price unavailable — using last close: 12.69
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACOG] Live price unavailable — using last close: 5.72
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACON] Live price unavailable — using last close: 7.23
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACONW] Live price unavailable — using last close: 0.05
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACRS] Live price unavailable — using last close: 2.32
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACRV] Live price unavailable — using last close: 1.88
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACT] Live price unavailable — using last close: 37.00
# [ACTG] Live price unavailable — using last close: 3.56
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACTU] Live price unavailable — using last close: 6.14
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ACWI] Live price unavailable — using last close: 139.54
# [ACWX] Live price unavailable — using last close: 65.92
# [ACXP] Live price unavailable — using last close: 4.73
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# ...
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ATXG] Live price unavailable — using last close: 0.45
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ATXS] Live price unavailable — using last close: 12.51
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [ATYR] Live price unavailable — using last close: 0.82
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AUBN] Live price unavailable — using last close: 26.48
# [AUDC] Live price unavailable — using last close: 9.28
# [AUGO] Live price unavailable — using last close: 34.29
# [AUID] Live price unavailable — using last close: 2.48
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AUMI] Live price unavailable — using last close: 78.21
# [AUPH] Live price unavailable — using last close: 14.61
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AUR] Live price unavailable — using last close: 4.32
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AURA] Live price unavailable — using last close: 5.35
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AURE] Live price unavailable — using last close: 0.40
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AUROW] Live price unavailable — using last close: 0.35
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# [AUTL] Spot price fetch failed: Too Many Requests. Rate limited. Try after a while.
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   calls = pd.concat([calls, ticker_call], ignore_index=True)
# /Users/GabrielReisen/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   puts = pd.concat([puts, ticker_put], ignore_index=True)
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[2], line 2
#       1 from utils.multi_fetcher import multi_fetcher
# ----> 2 calls, puts = multi_fetcher(tickers)
#
# File ~/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:8, in multi_fetcher(ticker_array)
#       6 puts = pd.DataFrame()
#       7 for ticker in ticker_array:
# ----> 8     ticker_call, ticker_put = get_option_chains_all(ticker)
#       9     calls = pd.concat([calls, ticker_call], ignore_index=True)
#      10     puts = pd.concat([puts, ticker_put], ignore_index=True)
#
# File ~/Desktop/Binomial Deamericanization Project/utils/data_fetcher.py:114, in get_option_chains_all(ticker, max_workers)
#      93 """
#      94 Fetches option chains (calls and puts) for every available expiry of a given ticker,
#      95 performing API requests in parallel to reduce total fetch time.
#    (...)    111     - puts_df: DataFrame containing all puts with the same added columns.
#     112 """
#     113 stock = yf.Ticker(ticker)
# --> 114 expiries = stock.options  # list of expiry date strings
#     115 today = datetime.today().date()
#     117 calls_accum = []
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/ticker.py:311, in Ticker.options(self)
#     308 @property
#     309 def options(self) -> tuple:
#     310     if not self._expirations:
# --> 311         self._download_options()
#     312     return tuple(self._expirations.keys())
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/ticker.py:52, in Ticker._download_options(self, date)
#      49 else:
#      50     url = f"{_BASE_URL_}/v7/finance/options/{self.ticker}?date={date}"
# ---> 52 r = self._data.get(url=url).json()
#      53 if len(r.get('optionChain', {}).get('result', [])) > 0:
#      54     for exp in r['optionChain']['result'][0]['expirationDates']:
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/data.py:371, in YfData.get(self, url, params, timeout)
#     369 @utils.log_indent_decorator
#     370 def get(self, url, params=None, timeout=30):
# --> 371     response = self._make_request(url, request_method = self._session.get, params=params, timeout=timeout)
#     373     # Accept cookie-consent if redirected to consent page
#     374     if not self._is_this_consent_url(response.url):
#     375         # "Consent Page not detected"
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/data.py:425, in YfData._make_request(self, url, request_method, body, params, timeout)
#     423 else:
#     424     self._set_cookie_strategy('basic')
# --> 425 crumb, strategy = self._get_cookie_and_crumb(timeout)
#     426 request_args['params']['crumb'] = crumb
#     427 response = request_method(**request_args)
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/data.py:361, in YfData._get_cookie_and_crumb(self, timeout)
#     358         crumb = self._get_cookie_and_crumb_basic(timeout)
#     359 else:
#     360     # Fallback strategy
# --> 361     crumb = self._get_cookie_and_crumb_basic(timeout)
#     362     if crumb is None:
#     363         # Fail
#     364         self._set_cookie_strategy('csrf', have_lock=True)
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/data.py:242, in YfData._get_cookie_and_crumb_basic(self, timeout)
#     240 if not self._get_cookie_basic(timeout):
#     241     return None
# --> 242 return self._get_crumb_basic(timeout)
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/utils.py:92, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#      89 logger.debug(f'Entering {func.__name__}()')
#      91 with IndentationContext():
# ---> 92     result = func(*args, **kwargs)
#      94 logger.debug(f'Exiting {func.__name__}()')
#      95 return result
#
# File /opt/homebrew/lib/python3.13/site-packages/yfinance/data.py:229, in YfData._get_crumb_basic(self, timeout)
#     227 if crumb_response.status_code == 429 or "Too Many Requests" in self._crumb:
#     228     utils.get_yf_logger().debug(f"Didn't receive crumb {self._crumb}")
# --> 229     raise YFRateLimitError()
#     231 if self._crumb is None or '<html>' in self._crumb:
#     232     utils.get_yf_logger().debug("Didn't receive crumb")
#
# YFRateLimitError: Too Many Requests. Rate limited. Try after a while.

# %%
calls
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 calls, puts = multi_fetcher(tickers)
#
# File ~/Desktop/Binomial Deamericanization Project/utils/multi_fetcher.py:8, in multi_fetcher(ticker_array)
#       6 puts = pd.DataFrame()
#       7 for ticker in ticker_array:
# ----> 8     ticker_call, ticker_put = get_option_chains_all
#       9     calls = pd.concat([calls, ticker_call], ignore_index=True)
#      10     puts = pd.concat([puts, ticker_put], ignore_index=True)
#
# TypeError: cannot unpack non-iterable function object
