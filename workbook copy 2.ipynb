# %% [markdown]
# **Imports**

# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
from typing import Tuple
from concurrent.futures import ThreadPoolExecutor, as_completed
import numpy as np
import math
import QuantLib as ql

# %% [markdown]
# **Define price fetcher**

# %%
def get_spot_price(ticker):
    """
    Fetches the current spot price for a stock ticker. Falls back to the most recent
    close if a live price is not available.

    Parameters
    ----------
    ticker : str
        Stock ticker symbol (e.g., 'AAPL').

    Returns
    -------
    float or None
        Spot price (live if available, else last close). Returns None if unavailable.
    """

    try:
        tk = yf.Ticker(ticker)
        
        # Attempt to fetch live price
        live_price = tk.fast_info.get("last_price", None)
        if live_price and live_price > 0:
            return live_price

        # Fallback: most recent close
        hist = tk.history(period="1d")
        if not hist.empty:
            fallback_price = hist["Close"].iloc[-1]
            print(f"[{ticker}] Live price unavailable — using last close: {fallback_price:.2f}")
            return fallback_price

        print(f"[{ticker}] No live or historical data available.")
        return None

    except Exception as e:
        print(f"[{ticker}] Spot price fetch failed: {e}")
        return None

# %% [markdown]
# **Define Option Chain Fetcher**

# %%
def get_option_chains_all(ticker: str,
                                  max_workers: int = 8) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Fetches option chains (calls and puts) for every available expiry of a given ticker,
    performing API requests in parallel to reduce total fetch time.

    Parameters
    ----------
    ticker : str
        Stock ticker symbol (e.g., 'AAPL').
    max_workers : int, optional
        Maximum number of threads to use for concurrent fetching (default is 8).

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        - calls_df: DataFrame containing all calls across expiries, with added columns:
            * 'option_type' = 'call'
            * 'expiration'  = expiry date string 'YYYY-MM-DD'
            * 'TTM'         = time to maturity in years
        - puts_df: DataFrame containing all puts with the same added columns.
    """
    stock = yf.Ticker(ticker)
    expiries = stock.options  # list of expiry date strings
    today = datetime.now().date()

    calls_accum = []
    puts_accum  = []

    def fetch_chain(expiry: str):
        """Fetch calls/puts for a single expiry and return (expiry, calls_df, puts_df)."""
        try:
            chain = stock.option_chain(expiry)
            calls = chain.calls.copy()
            puts  = chain.puts.copy()
        except Exception as e:
            # Return None on error so we can skip later
            return expiry, None, None

        # Tag each row with type and expiration
        calls['option_type']  = 'call'
        puts ['option_type']  = 'put'
        calls['expiration']   = expiry
        puts ['expiration']   = expiry

        # Compute time-to-maturity once
        exp_date = datetime.strptime(expiry, "%Y-%m-%d").date()
        ttm = max((exp_date - today).days / 365.0, 0.0)
        calls['TTM'] = ttm
        puts ['TTM'] = ttm

        return expiry, calls, puts

    # Fetch in parallel
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(fetch_chain, exp) for exp in expiries]
        for future in as_completed(futures):
            expiry, calls_df, puts_df = future.result()
            if calls_df is not None and not calls_df.empty:
                calls_accum.append(calls_df)
            if puts_df  is not None and not puts_df.empty:
                puts_accum.append(puts_df)

    # Concatenate results
    all_calls = pd.concat(calls_accum, ignore_index=True) if calls_accum else pd.DataFrame()
    all_puts  = pd.concat(puts_accum,  ignore_index=True) if puts_accum  else pd.DataFrame()

    # Fetch dividend yield for the company
    dividendYield = stock.info.get("dividendYield")/100 # percentages on decimal basis
    all_calls["dividendYield"] = dividendYield
    all_puts["dividendYield"] = dividendYield

    all_calls["ticker"] = ticker
    all_puts["ticker"] = ticker

    spot_price = get_spot_price(ticker)
    all_calls["spot_price"] = spot_price
    all_puts["spot_price"] = spot_price

    return all_calls, all_puts

# %% [markdown]
# Get option chain and dividend yield

# %%
calls, puts = get_option_chains_all("JPM")
# Out:
# [JPM] Live price unavailable — using last close: 314.21

# %%
calls
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    JPM251128C00180000 2025-11-03 18:02:15+00:00   180.0     130.43  132.70
# 1    JPM251128C00185000 2025-10-22 16:30:49+00:00   185.0     107.25  127.70
# 2    JPM251128C00225000 2025-10-10 18:50:55+00:00   225.0      79.80   87.85
# 3    JPM251128C00230000 2025-10-14 13:35:01+00:00   230.0      71.05   82.85
# 4    JPM251128C00250000 2025-10-20 17:42:50+00:00   250.0      54.50   63.00
# ..                  ...                       ...     ...        ...     ...
# 879  JPM280121C00430000 2025-10-21 19:58:31+00:00   430.0       9.85   13.70
# 880  JPM280121C00440000 2025-10-31 16:59:23+00:00   440.0      11.60   10.65
# 881  JPM280121C00450000 2025-10-30 17:44:38+00:00   450.0       9.90   11.00
# 882  JPM280121C00460000 2025-10-22 16:30:37+00:00   460.0       6.03    9.95
# 883  JPM280121C00470000 2025-11-07 20:05:53+00:00   470.0       9.20    8.90
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0    136.15    0.00       0.000000    20.0            10           0.989258
# 1    131.15    0.00       0.000000     NaN             1           0.945313
# 2     91.40    0.00       0.000000     NaN             1           0.690433
# 3     86.30    0.00       0.000000     NaN             0           0.637699
# 4     66.45    0.00       0.000000     2.0             2           0.518560
# ..      ...     ...            ...     ...           ...                ...
# 879   15.10    0.00       0.000000     1.0             2           0.250496
# 880   14.45    0.00       0.000000     4.0            14           0.255989
# 881   12.90    0.00       0.000000     4.0            17           0.254539
# 882   11.55    0.00       0.000000     2.0             6           0.253532
# 883   10.35    0.48       5.504582    20.0           123           0.252708
#
#      inTheMoney contractSize currency option_type  expiration       TTM  \
# 0          True      REGULAR      USD        call  2025-11-28  0.057534
# 1          True      REGULAR      USD        call  2025-11-28  0.057534
# 2          True      REGULAR      USD        call  2025-11-28  0.057534
# 3          True      REGULAR      USD        call  2025-11-28  0.057534
# 4          True      REGULAR      USD        call  2025-11-28  0.057534
# ..          ...          ...      ...         ...         ...       ...
# 879       False      REGULAR      USD        call  2028-01-21  2.205479
# 880       False      REGULAR      USD        call  2028-01-21  2.205479
# 881       False      REGULAR      USD        call  2028-01-21  2.205479
# 882       False      REGULAR      USD        call  2028-01-21  2.205479
# 883       False      REGULAR      USD        call  2028-01-21  2.205479
#
#      dividendYield ticker  spot_price
# 0           0.0191    JPM  314.209991
# 1           0.0191    JPM  314.209991
# 2           0.0191    JPM  314.209991
# 3           0.0191    JPM  314.209991
# 4           0.0191    JPM  314.209991
# ..             ...    ...         ...
# 879         0.0191    JPM  314.209991
# 880         0.0191    JPM  314.209991
# 881         0.0191    JPM  314.209991
# 882         0.0191    JPM  314.209991
# 883         0.0191    JPM  314.209991
#
# [884 rows x 20 columns]

# %%
puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    JPM251128P00175000 2025-10-22 19:47:28+00:00   175.0       0.03    0.00
# 1    JPM251128P00220000 2025-10-17 14:28:32+00:00   220.0       0.39    0.00
# 2    JPM251128P00235000 2025-10-23 18:37:04+00:00   235.0       0.48    0.00
# 3    JPM251128P00240000 2025-10-17 19:24:44+00:00   240.0       0.60    0.00
# 4    JPM251128P00245000 2025-10-27 19:48:25+00:00   245.0       0.29    0.00
# ..                  ...                       ...     ...        ...     ...
# 778  JPM280121P00400000 2025-11-07 19:10:43+00:00   400.0      95.10   92.00
# 779  JPM280121P00410000 2025-09-29 16:42:36+00:00   410.0      99.85  100.00
# 780  JPM280121P00420000 2025-10-09 18:48:52+00:00   420.0     116.05  108.75
# 781  JPM280121P00460000 2025-09-30 15:35:29+00:00   460.0     149.81  143.50
# 782  JPM280121P00470000 2025-09-30 15:35:29+00:00   470.0     159.60  153.50
#
#         ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0      2.13  0.000000       0.000000     NaN            11           1.321781
# 1      2.14  0.000000       0.000000     3.0             2           0.864747
# 2      2.16  0.000000       0.000000     NaN            13           0.730716
# 3      2.17  0.000000       0.000000    10.0            11           0.687747
# 4      2.06  0.000000       0.000000    10.0            82           0.637211
# ..      ...       ...            ...     ...           ...                ...
# 778   94.80 -3.849998      -3.890852    10.0             3           0.177514
# 779  103.50  0.000000       0.000000     NaN             1           0.178094
# 780  112.00  0.000000       0.000000     NaN             2           0.175408
# 781  148.00  0.000000       0.000000     NaN             0           0.163644
# 782  158.00  0.000000       0.000000     NaN             0           0.170541
#
#      inTheMoney contractSize currency option_type  expiration       TTM  \
# 0         False      REGULAR      USD         put  2025-11-28  0.057534
# 1         False      REGULAR      USD         put  2025-11-28  0.057534
# 2         False      REGULAR      USD         put  2025-11-28  0.057534
# 3         False      REGULAR      USD         put  2025-11-28  0.057534
# 4         False      REGULAR      USD         put  2025-11-28  0.057534
# ..          ...          ...      ...         ...         ...       ...
# 778        True      REGULAR      USD         put  2028-01-21  2.205479
# 779        True      REGULAR      USD         put  2028-01-21  2.205479
# 780        True      REGULAR      USD         put  2028-01-21  2.205479
# 781        True      REGULAR      USD         put  2028-01-21  2.205479
# 782        True      REGULAR      USD         put  2028-01-21  2.205479
#
#      dividendYield ticker  spot_price
# 0           0.0191    JPM  314.209991
# 1           0.0191    JPM  314.209991
# 2           0.0191    JPM  314.209991
# 3           0.0191    JPM  314.209991
# 4           0.0191    JPM  314.209991
# ..             ...    ...         ...
# 778         0.0191    JPM  314.209991
# 779         0.0191    JPM  314.209991
# 780         0.0191    JPM  314.209991
# 781         0.0191    JPM  314.209991
# 782         0.0191    JPM  314.209991
#
# [783 rows x 20 columns]

# %%
calls.describe()
# Out:
#            strike   lastPrice         bid         ask      change  \
# count  884.000000  884.000000  884.000000  884.000000  884.000000
# mean   279.736991   59.886765   61.534706   63.706968    0.009514
# std     94.121347   59.276993   61.384402   62.465660    1.283287
# min     65.000000    0.010000    0.000000    0.000000   -5.450005
# 25%    200.000000    7.097500    6.487500    7.737500    0.000000
# 50%    287.500000   38.625000   38.475000   40.750000    0.000000
# 75%    350.000000  107.340000  111.487500  114.225000    0.000000
# max    470.000000  240.200000  242.750000  246.100000   13.110001
#
#        percentChange       volume  openInterest  impliedVolatility  \
# count     884.000000   837.000000    884.000000         884.000000
# mean        1.305206    65.540024    436.348416           0.433174
# std        34.770268   362.538300    993.660580           0.387665
# min       -98.461540     1.000000      0.000000           0.000010
# 25%         0.000000     2.000000     12.000000           0.259918
# 50%         0.000000     4.000000     72.000000           0.327292
# 75%         0.000000    20.000000    349.750000           0.482732
# max       800.000240  6744.000000   8789.000000           6.646486
#
#               TTM  dividendYield  spot_price
# count  884.000000       884.0000  884.000000
# mean     0.635917         0.0191  314.209991
# std      0.652016         0.0000    0.000000
# min      0.000000         0.0191  314.209991
# 25%      0.115068         0.0191  314.209991
# 50%      0.364384         0.0191  314.209991
# 75%      1.112329         0.0191  314.209991
# max      2.205479         0.0191  314.209991

# %% [markdown]
# Initial Dataset Clean

# %%
def initial_dataset_clean(dataset : pd.DataFrame):
    # Removing columns that will not be used for training or filtering
    #cols_to_drop = ["contractSymbol", "lastTradeDate", "change", "percentChange", "expiration", "inTheMoney"]
    #dataset.drop(columns=[c for c in cols_to_drop if c in dataset.columns], inplace=True)

    # Removing NA values for stale options
    dataset.dropna(axis=0,subset=["volume"], inplace=True)

    
    return dataset

# %%
calls_clean = initial_dataset_clean(calls)
calls_clean
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    JPM251128C00180000 2025-11-03 18:02:15+00:00   180.0     130.43  132.70
# 4    JPM251128C00250000 2025-10-20 17:42:50+00:00   250.0      54.50   63.00
# 6    JPM251128C00270000 2025-10-30 18:20:08+00:00   270.0      43.28   43.25
# 7    JPM251128C00275000 2025-10-29 15:03:05+00:00   275.0      33.00   39.15
# 8    JPM251128C00280000 2025-11-03 18:24:42+00:00   280.0      31.15   34.30
# ..                  ...                       ...     ...        ...     ...
# 879  JPM280121C00430000 2025-10-21 19:58:31+00:00   430.0       9.85   13.70
# 880  JPM280121C00440000 2025-10-31 16:59:23+00:00   440.0      11.60   10.65
# 881  JPM280121C00450000 2025-10-30 17:44:38+00:00   450.0       9.90   11.00
# 882  JPM280121C00460000 2025-10-22 16:30:37+00:00   460.0       6.03    9.95
# 883  JPM280121C00470000 2025-11-07 20:05:53+00:00   470.0       9.20    8.90
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0    136.15    0.00       0.000000    20.0            10           0.989258
# 4     66.45    0.00       0.000000     2.0             2           0.518560
# 6     46.00    0.00       0.000000     2.0             2           0.494390
# 7     40.75    0.00       0.000000     1.0             6           0.430914
# 8     35.95    0.00       0.000000     2.0             4           0.401129
# ..      ...     ...            ...     ...           ...                ...
# 879   15.10    0.00       0.000000     1.0             2           0.250496
# 880   14.45    0.00       0.000000     4.0            14           0.255989
# 881   12.90    0.00       0.000000     4.0            17           0.254539
# 882   11.55    0.00       0.000000     2.0             6           0.253532
# 883   10.35    0.48       5.504582    20.0           123           0.252708
#
#      inTheMoney contractSize currency option_type  expiration       TTM  \
# 0          True      REGULAR      USD        call  2025-11-28  0.057534
# 4          True      REGULAR      USD        call  2025-11-28  0.057534
# 6          True      REGULAR      USD        call  2025-11-28  0.057534
# 7          True      REGULAR      USD        call  2025-11-28  0.057534
# 8          True      REGULAR      USD        call  2025-11-28  0.057534
# ..          ...          ...      ...         ...         ...       ...
# 879       False      REGULAR      USD        call  2028-01-21  2.205479
# 880       False      REGULAR      USD        call  2028-01-21  2.205479
# 881       False      REGULAR      USD        call  2028-01-21  2.205479
# 882       False      REGULAR      USD        call  2028-01-21  2.205479
# 883       False      REGULAR      USD        call  2028-01-21  2.205479
#
#      dividendYield ticker  spot_price
# 0           0.0191    JPM  314.209991
# 4           0.0191    JPM  314.209991
# 6           0.0191    JPM  314.209991
# 7           0.0191    JPM  314.209991
# 8           0.0191    JPM  314.209991
# ..             ...    ...         ...
# 879         0.0191    JPM  314.209991
# 880         0.0191    JPM  314.209991
# 881         0.0191    JPM  314.209991
# 882         0.0191    JPM  314.209991
# 883         0.0191    JPM  314.209991
#
# [837 rows x 20 columns]

# %%
calls_clean.describe()
# Out:
#            strike   lastPrice         bid         ask      change  \
# count  837.000000  837.000000  837.000000  837.000000  837.000000
# mean   280.400239   59.668220   61.124504   63.278292    0.010048
# std     93.288559   59.706082   61.695467   62.784608    1.318865
# min     65.000000    0.010000    0.000000    0.000000   -5.450005
# 25%    205.000000    7.000000    6.500000    7.800000    0.000000
# 50%    290.000000   37.330000   37.250000   39.700000    0.000000
# 75%    350.000000  107.010000  110.550000  113.300000    0.000000
# max    470.000000  240.200000  242.750000  246.100000   13.110001
#
#        percentChange       volume  openInterest  impliedVolatility  \
# count     837.000000   837.000000    837.000000         837.000000
# mean        1.378497    65.540024    460.659498           0.428916
# std        35.732882   362.538300   1015.745730           0.388136
# min       -98.461540     1.000000      0.000000           0.000010
# 25%         0.000000     2.000000     18.000000           0.259926
# 50%         0.000000     4.000000     82.000000           0.323218
# 75%         0.000000    20.000000    384.000000           0.468999
# max       800.000240  6744.000000   8789.000000           6.646486
#
#               TTM  dividendYield  spot_price
# count  837.000000   8.370000e+02  837.000000
# mean     0.644006   1.910000e-02  314.209991
# std      0.653501   3.471521e-18    0.000000
# min      0.000000   1.910000e-02  314.209991
# 25%      0.115068   1.910000e-02  314.209991
# 50%      0.364384   1.910000e-02  314.209991
# 75%      1.112329   1.910000e-02  314.209991
# max      2.205479   1.910000e-02  314.209991

# %%
puts_clean = initial_dataset_clean(puts)
puts_clean
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 1    JPM251128P00220000 2025-10-17 14:28:32+00:00   220.0       0.39   0.00
# 3    JPM251128P00240000 2025-10-17 19:24:44+00:00   240.0       0.60   0.00
# 4    JPM251128P00245000 2025-10-27 19:48:25+00:00   245.0       0.29   0.00
# 5    JPM251128P00250000 2025-10-24 15:22:43+00:00   250.0       0.48   0.00
# 6    JPM251128P00255000 2025-10-28 19:46:32+00:00   255.0       0.41   0.00
# ..                  ...                       ...     ...        ...    ...
# 774  JPM280121P00360000 2025-11-07 16:57:38+00:00   360.0      68.12  64.15
# 775  JPM280121P00370000 2025-11-07 17:20:14+00:00   370.0      75.25  70.00
# 776  JPM280121P00380000 2025-10-09 18:48:03+00:00   380.0      83.30  77.95
# 777  JPM280121P00390000 2025-11-07 19:10:43+00:00   390.0      88.60  84.95
# 778  JPM280121P00400000 2025-11-07 19:10:43+00:00   400.0      95.10  92.00
#
#        ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 1     2.14  0.000000       0.000000     3.0             2           0.864747
# 3     2.17  0.000000       0.000000    10.0            11           0.687747
# 4     2.06  0.000000       0.000000    10.0            82           0.637211
# 5     2.22  0.000000       0.000000     2.0             3           0.604740
# 6     1.32  0.000000       0.000000    27.0            66           0.504155
# ..     ...       ...            ...     ...           ...                ...
# 774  67.70 -0.649994      -0.945171     1.0            16           0.205490
# 775  74.50 -3.919998      -4.951368    11.0             3           0.202050
# 776  80.25  0.000000       0.000000    14.0             8           0.190171
# 777  86.95 -5.419998      -5.764729    10.0             4           0.181267
# 778  94.80 -3.849998      -3.890852    10.0             3           0.177514
#
#      inTheMoney contractSize currency option_type  expiration       TTM  \
# 1         False      REGULAR      USD         put  2025-11-28  0.057534
# 3         False      REGULAR      USD         put  2025-11-28  0.057534
# 4         False      REGULAR      USD         put  2025-11-28  0.057534
# 5         False      REGULAR      USD         put  2025-11-28  0.057534
# 6         False      REGULAR      USD         put  2025-11-28  0.057534
# ..          ...          ...      ...         ...         ...       ...
# 774        True      REGULAR      USD         put  2028-01-21  2.205479
# 775        True      REGULAR      USD         put  2028-01-21  2.205479
# 776        True      REGULAR      USD         put  2028-01-21  2.205479
# 777        True      REGULAR      USD         put  2028-01-21  2.205479
# 778        True      REGULAR      USD         put  2028-01-21  2.205479
#
#      dividendYield ticker  spot_price
# 1           0.0191    JPM  314.209991
# 3           0.0191    JPM  314.209991
# 4           0.0191    JPM  314.209991
# 5           0.0191    JPM  314.209991
# 6           0.0191    JPM  314.209991
# ..             ...    ...         ...
# 774         0.0191    JPM  314.209991
# 775         0.0191    JPM  314.209991
# 776         0.0191    JPM  314.209991
# 777         0.0191    JPM  314.209991
# 778         0.0191    JPM  314.209991
#
# [738 rows x 20 columns]

# %% [markdown]
# **Join Calls and Puts**

# %%
df = pd.concat([puts_clean, calls_clean], ignore_index=True)
df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251128P00220000 2025-10-17 14:28:32+00:00   220.0       0.39   0.00
# 1     JPM251128P00240000 2025-10-17 19:24:44+00:00   240.0       0.60   0.00
# 2     JPM251128P00245000 2025-10-27 19:48:25+00:00   245.0       0.29   0.00
# 3     JPM251128P00250000 2025-10-24 15:22:43+00:00   250.0       0.48   0.00
# 4     JPM251128P00255000 2025-10-28 19:46:32+00:00   255.0       0.41   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM280121C00430000 2025-10-21 19:58:31+00:00   430.0       9.85  13.70
# 1571  JPM280121C00440000 2025-10-31 16:59:23+00:00   440.0      11.60  10.65
# 1572  JPM280121C00450000 2025-10-30 17:44:38+00:00   450.0       9.90  11.00
# 1573  JPM280121C00460000 2025-10-22 16:30:37+00:00   460.0       6.03   9.95
# 1574  JPM280121C00470000 2025-11-07 20:05:53+00:00   470.0       9.20   8.90
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0      2.14    0.00       0.000000     3.0             2           0.864747
# 1      2.17    0.00       0.000000    10.0            11           0.687747
# 2      2.06    0.00       0.000000    10.0            82           0.637211
# 3      2.22    0.00       0.000000     2.0             3           0.604740
# 4      1.32    0.00       0.000000    27.0            66           0.504155
# ...     ...     ...            ...     ...           ...                ...
# 1570  15.10    0.00       0.000000     1.0             2           0.250496
# 1571  14.45    0.00       0.000000     4.0            14           0.255989
# 1572  12.90    0.00       0.000000     4.0            17           0.254539
# 1573  11.55    0.00       0.000000     2.0             6           0.253532
# 1574  10.35    0.48       5.504582    20.0           123           0.252708
#
#       inTheMoney contractSize currency option_type  expiration       TTM  \
# 0          False      REGULAR      USD         put  2025-11-28  0.057534
# 1          False      REGULAR      USD         put  2025-11-28  0.057534
# 2          False      REGULAR      USD         put  2025-11-28  0.057534
# 3          False      REGULAR      USD         put  2025-11-28  0.057534
# 4          False      REGULAR      USD         put  2025-11-28  0.057534
# ...          ...          ...      ...         ...         ...       ...
# 1570       False      REGULAR      USD        call  2028-01-21  2.205479
# 1571       False      REGULAR      USD        call  2028-01-21  2.205479
# 1572       False      REGULAR      USD        call  2028-01-21  2.205479
# 1573       False      REGULAR      USD        call  2028-01-21  2.205479
# 1574       False      REGULAR      USD        call  2028-01-21  2.205479
#
#       dividendYield ticker  spot_price
# 0            0.0191    JPM  314.209991
# 1            0.0191    JPM  314.209991
# 2            0.0191    JPM  314.209991
# 3            0.0191    JPM  314.209991
# 4            0.0191    JPM  314.209991
# ...             ...    ...         ...
# 1570         0.0191    JPM  314.209991
# 1571         0.0191    JPM  314.209991
# 1572         0.0191    JPM  314.209991
# 1573         0.0191    JPM  314.209991
# 1574         0.0191    JPM  314.209991
#
# [1575 rows x 20 columns]

# %%
def optionType(OPTtype):
    # Puts are type 1
    if OPTtype == "put":
        return "put"
    else:
    # Calls are type 0
        return "call"

# %%
df["optionType"] = df["option_type"].apply(optionType)
#df.drop(columns="option_type", inplace=True)
df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251128P00220000 2025-10-17 14:28:32+00:00   220.0       0.39   0.00
# 1     JPM251128P00240000 2025-10-17 19:24:44+00:00   240.0       0.60   0.00
# 2     JPM251128P00245000 2025-10-27 19:48:25+00:00   245.0       0.29   0.00
# 3     JPM251128P00250000 2025-10-24 15:22:43+00:00   250.0       0.48   0.00
# 4     JPM251128P00255000 2025-10-28 19:46:32+00:00   255.0       0.41   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM280121C00430000 2025-10-21 19:58:31+00:00   430.0       9.85  13.70
# 1571  JPM280121C00440000 2025-10-31 16:59:23+00:00   440.0      11.60  10.65
# 1572  JPM280121C00450000 2025-10-30 17:44:38+00:00   450.0       9.90  11.00
# 1573  JPM280121C00460000 2025-10-22 16:30:37+00:00   460.0       6.03   9.95
# 1574  JPM280121C00470000 2025-11-07 20:05:53+00:00   470.0       9.20   8.90
#
#         ask  change  percentChange  volume  openInterest  ...  inTheMoney  \
# 0      2.14    0.00       0.000000     3.0             2  ...       False
# 1      2.17    0.00       0.000000    10.0            11  ...       False
# 2      2.06    0.00       0.000000    10.0            82  ...       False
# 3      2.22    0.00       0.000000     2.0             3  ...       False
# 4      1.32    0.00       0.000000    27.0            66  ...       False
# ...     ...     ...            ...     ...           ...  ...         ...
# 1570  15.10    0.00       0.000000     1.0             2  ...       False
# 1571  14.45    0.00       0.000000     4.0            14  ...       False
# 1572  12.90    0.00       0.000000     4.0            17  ...       False
# 1573  11.55    0.00       0.000000     2.0             6  ...       False
# 1574  10.35    0.48       5.504582    20.0           123  ...       False
#
#       contractSize currency option_type  expiration       TTM  dividendYield  \
# 0          REGULAR      USD         put  2025-11-28  0.057534         0.0191
# 1          REGULAR      USD         put  2025-11-28  0.057534         0.0191
# 2          REGULAR      USD         put  2025-11-28  0.057534         0.0191
# 3          REGULAR      USD         put  2025-11-28  0.057534         0.0191
# 4          REGULAR      USD         put  2025-11-28  0.057534         0.0191
# ...            ...      ...         ...         ...       ...            ...
# 1570       REGULAR      USD        call  2028-01-21  2.205479         0.0191
# 1571       REGULAR      USD        call  2028-01-21  2.205479         0.0191
# 1572       REGULAR      USD        call  2028-01-21  2.205479         0.0191
# 1573       REGULAR      USD        call  2028-01-21  2.205479         0.0191
# 1574       REGULAR      USD        call  2028-01-21  2.205479         0.0191
#
#       ticker  spot_price  optionType
# 0        JPM  314.209991         put
# 1        JPM  314.209991         put
# 2        JPM  314.209991         put
# 3        JPM  314.209991         put
# 4        JPM  314.209991         put
# ...      ...         ...         ...
# 1570     JPM  314.209991        call
# 1571     JPM  314.209991        call
# 1572     JPM  314.209991        call
# 1573     JPM  314.209991        call
# 1574     JPM  314.209991        call
#
# [1575 rows x 21 columns]

# %% [markdown]
# **Interest Rate Interpolation**

# %%
# Needs to figure out if we're using a interpolation structure to match each of them, also considering zero bond rates for the interpolation
def interest_rate(row):
    # Need to change this to interpolation calculation
    return (0.04)

# %%
df["r"] = .04
df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251128P00220000 2025-10-17 14:28:32+00:00   220.0       0.39   0.00
# 1     JPM251128P00240000 2025-10-17 19:24:44+00:00   240.0       0.60   0.00
# 2     JPM251128P00245000 2025-10-27 19:48:25+00:00   245.0       0.29   0.00
# 3     JPM251128P00250000 2025-10-24 15:22:43+00:00   250.0       0.48   0.00
# 4     JPM251128P00255000 2025-10-28 19:46:32+00:00   255.0       0.41   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM280121C00430000 2025-10-21 19:58:31+00:00   430.0       9.85  13.70
# 1571  JPM280121C00440000 2025-10-31 16:59:23+00:00   440.0      11.60  10.65
# 1572  JPM280121C00450000 2025-10-30 17:44:38+00:00   450.0       9.90  11.00
# 1573  JPM280121C00460000 2025-10-22 16:30:37+00:00   460.0       6.03   9.95
# 1574  JPM280121C00470000 2025-11-07 20:05:53+00:00   470.0       9.20   8.90
#
#         ask  change  percentChange  volume  openInterest  ...  contractSize  \
# 0      2.14    0.00       0.000000     3.0             2  ...       REGULAR
# 1      2.17    0.00       0.000000    10.0            11  ...       REGULAR
# 2      2.06    0.00       0.000000    10.0            82  ...       REGULAR
# 3      2.22    0.00       0.000000     2.0             3  ...       REGULAR
# 4      1.32    0.00       0.000000    27.0            66  ...       REGULAR
# ...     ...     ...            ...     ...           ...  ...           ...
# 1570  15.10    0.00       0.000000     1.0             2  ...       REGULAR
# 1571  14.45    0.00       0.000000     4.0            14  ...       REGULAR
# 1572  12.90    0.00       0.000000     4.0            17  ...       REGULAR
# 1573  11.55    0.00       0.000000     2.0             6  ...       REGULAR
# 1574  10.35    0.48       5.504582    20.0           123  ...       REGULAR
#
#       currency option_type  expiration       TTM dividendYield  ticker  \
# 0          USD         put  2025-11-28  0.057534        0.0191     JPM
# 1          USD         put  2025-11-28  0.057534        0.0191     JPM
# 2          USD         put  2025-11-28  0.057534        0.0191     JPM
# 3          USD         put  2025-11-28  0.057534        0.0191     JPM
# 4          USD         put  2025-11-28  0.057534        0.0191     JPM
# ...        ...         ...         ...       ...           ...     ...
# 1570       USD        call  2028-01-21  2.205479        0.0191     JPM
# 1571       USD        call  2028-01-21  2.205479        0.0191     JPM
# 1572       USD        call  2028-01-21  2.205479        0.0191     JPM
# 1573       USD        call  2028-01-21  2.205479        0.0191     JPM
# 1574       USD        call  2028-01-21  2.205479        0.0191     JPM
#
#       spot_price optionType     r
# 0     314.209991        put  0.04
# 1     314.209991        put  0.04
# 2     314.209991        put  0.04
# 3     314.209991        put  0.04
# 4     314.209991        put  0.04
# ...          ...        ...   ...
# 1570  314.209991       call  0.04
# 1571  314.209991       call  0.04
# 1572  314.209991       call  0.04
# 1573  314.209991       call  0.04
# 1574  314.209991       call  0.04
#
# [1575 rows x 22 columns]

# %% [markdown]
# **Forward log-Moneyness**

# %% [markdown]
# We decided to use forward log-moneyness because its adjusted for r and q which are crucial in pricing the EEP

# %%
def forward_log_moneyness(S: float, r:float, q:float, T:float, K:float):
    """
    Calculates the log_moneyness in relation to the Forward Price of the stock

    Parameters
    ----------
    S : float
        Current spot_price of the stock.
    r : float
        Risk-free rate associated with that particular option maturity
    q : float
        Dividend-yield rate associated with that particular option maturity
    T : float
        Maturity of the option contract
    K : float
        Strike price of the option contract

    Returns
    -------
    Float
        - Forward log moneyness 
    """
    forward_price = S * np.exp((r - q)*T)
    
    return np.log(K/forward_price)

# %%
df["forward_log_moneyness"] = forward_log_moneyness(
    S=df["spot_price"].to_numpy(),
    r=df["r"].to_numpy(),
    q=df["dividendYield"].to_numpy(),
    T=df["TTM"].to_numpy(),
    K=df["strike"].to_numpy(),
)

df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251128P00220000 2025-10-17 14:28:32+00:00   220.0       0.39   0.00
# 1     JPM251128P00240000 2025-10-17 19:24:44+00:00   240.0       0.60   0.00
# 2     JPM251128P00245000 2025-10-27 19:48:25+00:00   245.0       0.29   0.00
# 3     JPM251128P00250000 2025-10-24 15:22:43+00:00   250.0       0.48   0.00
# 4     JPM251128P00255000 2025-10-28 19:46:32+00:00   255.0       0.41   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM280121C00430000 2025-10-21 19:58:31+00:00   430.0       9.85  13.70
# 1571  JPM280121C00440000 2025-10-31 16:59:23+00:00   440.0      11.60  10.65
# 1572  JPM280121C00450000 2025-10-30 17:44:38+00:00   450.0       9.90  11.00
# 1573  JPM280121C00460000 2025-10-22 16:30:37+00:00   460.0       6.03   9.95
# 1574  JPM280121C00470000 2025-11-07 20:05:53+00:00   470.0       9.20   8.90
#
#         ask  change  percentChange  volume  openInterest  ...  currency  \
# 0      2.14    0.00       0.000000     3.0             2  ...       USD
# 1      2.17    0.00       0.000000    10.0            11  ...       USD
# 2      2.06    0.00       0.000000    10.0            82  ...       USD
# 3      2.22    0.00       0.000000     2.0             3  ...       USD
# 4      1.32    0.00       0.000000    27.0            66  ...       USD
# ...     ...     ...            ...     ...           ...  ...       ...
# 1570  15.10    0.00       0.000000     1.0             2  ...       USD
# 1571  14.45    0.00       0.000000     4.0            14  ...       USD
# 1572  12.90    0.00       0.000000     4.0            17  ...       USD
# 1573  11.55    0.00       0.000000     2.0             6  ...       USD
# 1574  10.35    0.48       5.504582    20.0           123  ...       USD
#
#       option_type  expiration       TTM dividendYield ticker  spot_price  \
# 0             put  2025-11-28  0.057534        0.0191    JPM  314.209991
# 1             put  2025-11-28  0.057534        0.0191    JPM  314.209991
# 2             put  2025-11-28  0.057534        0.0191    JPM  314.209991
# 3             put  2025-11-28  0.057534        0.0191    JPM  314.209991
# 4             put  2025-11-28  0.057534        0.0191    JPM  314.209991
# ...           ...         ...       ...           ...    ...         ...
# 1570         call  2028-01-21  2.205479        0.0191    JPM  314.209991
# 1571         call  2028-01-21  2.205479        0.0191    JPM  314.209991
# 1572         call  2028-01-21  2.205479        0.0191    JPM  314.209991
# 1573         call  2028-01-21  2.205479        0.0191    JPM  314.209991
# 1574         call  2028-01-21  2.205479        0.0191    JPM  314.209991
#
#       optionType     r  forward_log_moneyness
# 0            put  0.04              -0.357636
# 1            put  0.04              -0.270625
# 2            put  0.04              -0.250006
# 3            put  0.04              -0.229803
# 4            put  0.04              -0.210000
# ...          ...   ...                    ...
# 1570        call  0.04               0.267629
# 1571        call  0.04               0.290619
# 1572        call  0.04               0.313092
# 1573        call  0.04               0.335070
# 1574        call  0.04               0.356577
#
# [1575 rows x 23 columns]

# %% [markdown]
# Calculate Mid Price

# %%
def mid_price(bid: float, ask: float):
    """
    Calcualtes the mid-price of the option based on bid and ask prices

    Parameters
    ----------
    bid : float
        Current bid price of the option
    ask : float
        Current ask price of the option

    Returns
    -------
    Float
        - Mid price
    """

    return ((bid+ask)/2)

# %%
df["midPrice"] = mid_price(df["bid"], df["ask"])
df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251128P00220000 2025-10-17 14:28:32+00:00   220.0       0.39   0.00
# 1     JPM251128P00240000 2025-10-17 19:24:44+00:00   240.0       0.60   0.00
# 2     JPM251128P00245000 2025-10-27 19:48:25+00:00   245.0       0.29   0.00
# 3     JPM251128P00250000 2025-10-24 15:22:43+00:00   250.0       0.48   0.00
# 4     JPM251128P00255000 2025-10-28 19:46:32+00:00   255.0       0.41   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM280121C00430000 2025-10-21 19:58:31+00:00   430.0       9.85  13.70
# 1571  JPM280121C00440000 2025-10-31 16:59:23+00:00   440.0      11.60  10.65
# 1572  JPM280121C00450000 2025-10-30 17:44:38+00:00   450.0       9.90  11.00
# 1573  JPM280121C00460000 2025-10-22 16:30:37+00:00   460.0       6.03   9.95
# 1574  JPM280121C00470000 2025-11-07 20:05:53+00:00   470.0       9.20   8.90
#
#         ask  change  percentChange  volume  openInterest  ...  option_type  \
# 0      2.14    0.00       0.000000     3.0             2  ...          put
# 1      2.17    0.00       0.000000    10.0            11  ...          put
# 2      2.06    0.00       0.000000    10.0            82  ...          put
# 3      2.22    0.00       0.000000     2.0             3  ...          put
# 4      1.32    0.00       0.000000    27.0            66  ...          put
# ...     ...     ...            ...     ...           ...  ...          ...
# 1570  15.10    0.00       0.000000     1.0             2  ...         call
# 1571  14.45    0.00       0.000000     4.0            14  ...         call
# 1572  12.90    0.00       0.000000     4.0            17  ...         call
# 1573  11.55    0.00       0.000000     2.0             6  ...         call
# 1574  10.35    0.48       5.504582    20.0           123  ...         call
#
#       expiration       TTM dividendYield ticker  spot_price  optionType     r  \
# 0     2025-11-28  0.057534        0.0191    JPM  314.209991         put  0.04
# 1     2025-11-28  0.057534        0.0191    JPM  314.209991         put  0.04
# 2     2025-11-28  0.057534        0.0191    JPM  314.209991         put  0.04
# 3     2025-11-28  0.057534        0.0191    JPM  314.209991         put  0.04
# 4     2025-11-28  0.057534        0.0191    JPM  314.209991         put  0.04
# ...          ...       ...           ...    ...         ...         ...   ...
# 1570  2028-01-21  2.205479        0.0191    JPM  314.209991        call  0.04
# 1571  2028-01-21  2.205479        0.0191    JPM  314.209991        call  0.04
# 1572  2028-01-21  2.205479        0.0191    JPM  314.209991        call  0.04
# 1573  2028-01-21  2.205479        0.0191    JPM  314.209991        call  0.04
# 1574  2028-01-21  2.205479        0.0191    JPM  314.209991        call  0.04
#
#      forward_log_moneyness  midPrice
# 0                -0.357636     1.070
# 1                -0.270625     1.085
# 2                -0.250006     1.030
# 3                -0.229803     1.110
# 4                -0.210000     0.660
# ...                    ...       ...
# 1570              0.267629    14.400
# 1571              0.290619    12.550
# 1572              0.313092    11.950
# 1573              0.335070    10.750
# 1574              0.356577     9.625
#
# [1575 rows x 24 columns]

# %%
from heston import calibrate_and_price_heston_european

V_eu = calibrate_and_price_heston_european(df, group_cols=("ticker", ))
df = df.join(V_eu)
df
# Out:
# [deAm] === group start === :: group=('JPM',) | rows=1575
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.07 | hi=6.0 | f_hi=96.07828042325012 | P=1.07
# [deAm] sigma* :: tree=jr | sigma_star=0.8890845367284084
# [deAm] eu price :: tree=jr | p_eu=1.0778159756783583
# [deAm] IV: QL solver :: iv=0.8890845241561225 | price_for_iv=1.0778159756783583
# [deAm] helper IV :: idx=0 | iv=0.8890845241561225
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.085 | hi=6.0 | f_hi=109.87016879272952 | P=1.085
# [deAm] sigma* :: tree=jr | sigma_star=0.7072266264906322
# [deAm] eu price :: tree=jr | p_eu=1.0899722763137807
# [deAm] IV: QL solver :: iv=0.707226626498426 | price_for_iv=1.0899722763137807
# [deAm] helper IV :: idx=1 | iv=0.707226626498426
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.03 | hi=6.0 | f_hi=113.37722221136765 | P=1.03
# [deAm] sigma* :: tree=jr | sigma_star=0.6556204632725944
# [deAm] eu price :: tree=jr | p_eu=1.0346950358565448
# [deAm] IV: QL solver :: iv=0.6556204160901141 | price_for_iv=1.0346950358565448
# [deAm] helper IV :: idx=2 | iv=0.6556204160901141
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.11 | hi=6.0 | f_hi=116.84870801967396 | P=1.11
# [deAm] sigma* :: tree=jr | sigma_star=0.6225766136535199
# [deAm] eu price :: tree=jr | p_eu=1.1177745226377138
# [deAm] IV: QL solver :: iv=0.6225766124390193 | price_for_iv=1.1177745226377138
# [deAm] helper IV :: idx=3 | iv=0.6225766124390193
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.66 | hi=6.0 | f_hi=120.9216119601633 | P=0.66
# [deAm] sigma* :: tree=jr | sigma_star=0.5191510677296396
# [deAm] eu price :: tree=jr | p_eu=0.6641708781310727
# [deAm] IV: QL solver :: iv=0.51915107445906 | price_for_iv=0.6641708781310727
# [deAm] helper IV :: idx=4 | iv=0.51915107445906
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.24 | hi=6.0 | f_hi=124.964576420999 | P=0.24
# [deAm] sigma* :: tree=jr | sigma_star=0.40050210945316767
# [deAm] eu price :: tree=jr | p_eu=0.2427686488256072
# [deAm] IV: QL solver :: iv=0.4005021091576678 | price_for_iv=0.2427686488256072
# [deAm] helper IV :: idx=5 | iv=0.4005021091576678
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.29000000000000004 | hi=6.0 | f_hi=128.53760484298152 | P=0.29000000000000004
# [deAm] sigma* :: tree=jr | sigma_star=0.3778312079933656
# [deAm] eu price :: tree=jr | p_eu=0.2938540524052752
# [deAm] IV: QL solver :: iv=0.3778313278240576 | price_for_iv=0.2938540524052752
# [deAm] helper IV :: idx=6 | iv=0.3778313278240576
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.315 | hi=6.0 | f_hi=132.1357213551649 | P=0.315
# [deAm] sigma* :: tree=jr | sigma_star=0.3473932145911995
# [deAm] eu price :: tree=jr | p_eu=0.3169573241767938
# [deAm] IV: QL solver :: iv=0.34739321190617695 | price_for_iv=0.3169573241767938
# [deAm] helper IV :: idx=7 | iv=0.34739321190617695
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.41000000000000003 | hi=6.0 | f_hi=135.66393429123096 | P=0.41000000000000003
# [deAm] sigma* :: tree=jr | sigma_star=0.3281065031027063
# [deAm] eu price :: tree=jr | p_eu=0.41302108421822614
# [deAm] IV: QL solver :: iv=0.3281065044320466 | price_for_iv=0.41302108421822614
# [deAm] helper IV :: idx=8 | iv=0.3281065044320466
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.55 | hi=6.0 | f_hi=139.14728973730573 | P=0.55
# [deAm] sigma* :: tree=jr | sigma_star=0.309955176338976
# [deAm] eu price :: tree=jr | p_eu=0.5530173029218125
# [deAm] IV: QL solver :: iv=0.3099551442308315 | price_for_iv=0.5530173029218125
# [deAm] helper IV :: idx=9 | iv=0.3099551442308315
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.825 | hi=6.0 | f_hi=142.49589071063576 | P=0.825
# [deAm] sigma* :: tree=jr | sigma_star=0.29935762748371064
# [deAm] eu price :: tree=jr | p_eu=0.8294246948164625
# [deAm] IV: QL solver :: iv=0.29935762751501765 | price_for_iv=0.8294246948164625
# [deAm] helper IV :: idx=10 | iv=0.29935762751501765
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.0499999999999998 | hi=6.0 | f_hi=146.04423767802206 | P=1.0499999999999998
# [deAm] sigma* :: tree=jr | sigma_star=0.2758722306600403
# [deAm] eu price :: tree=jr | p_eu=1.0514802181623937
# [deAm] IV: QL solver :: iv=0.2758722416008415 | price_for_iv=1.0514802181623937
# [deAm] helper IV :: idx=11 | iv=0.2758722416008415
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.475 | hi=6.0 | f_hi=149.40354905575435 | P=1.475
# [deAm] sigma* :: tree=jr | sigma_star=0.25926096604824495
# [deAm] eu price :: tree=jr | p_eu=1.4755255060642172
# [deAm] IV: QL solver :: iv=0.259260966054467 | price_for_iv=1.4755255060642172
# [deAm] helper IV :: idx=12 | iv=0.259260966054467
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.205 | hi=6.0 | f_hi=152.45792252694105 | P=2.205
# [deAm] sigma* :: tree=jr | sigma_star=0.24839787208734374
# [deAm] eu price :: tree=jr | p_eu=2.206572272095569
# [deAm] IV: QL solver :: iv=0.24839786369867775 | price_for_iv=2.206572272095569
# [deAm] helper IV :: idx=13 | iv=0.24839786369867775
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.2 | hi=6.0 | f_hi=155.24735207783084 | P=3.2
# [deAm] sigma* :: tree=jr | sigma_star=0.2353101841298149
# [deAm] eu price :: tree=jr | p_eu=3.1962459040861786
# [deAm] IV: QL solver :: iv=0.23531015414738957 | price_for_iv=3.1962459040861786
# [deAm] helper IV :: idx=14 | iv=0.23531015414738957
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-4.75 | hi=6.0 | f_hi=157.4818676368838 | P=4.75
# [deAm] sigma* :: tree=jr | sigma_star=0.22773223749939697
# [deAm] eu price :: tree=jr | p_eu=4.74430268034056
# [deAm] IV: QL solver :: iv=0.22773223750391652 | price_for_iv=4.74430268034056
# [deAm] helper IV :: idx=15 | iv=0.22773223750391652
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-6.059991455078125 | hi=6.0 | f_hi=159.16646429184433 | P=6.85
# [deAm] sigma* :: tree=jr | sigma_star=0.22057658928159343
# [deAm] eu price :: tree=jr | p_eu=6.835936020625239
# [deAm] IV: QL solver :: iv=0.2205765905599946 | price_for_iv=6.835936020625239
# [deAm] helper IV :: idx=16 | iv=0.2205765905599946
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.7599914550781257 | hi=6.0 | f_hi=160.2511666038163 | P=9.55
# [deAm] sigma* :: tree=jr | sigma_star=0.21330975269592578
# [deAm] eu price :: tree=jr | p_eu=9.516396410205928
# [deAm] IV: QL solver :: iv=0.21330975314344067 | price_for_iv=9.516396410205928
# [deAm] helper IV :: idx=17 | iv=0.21330975314344067
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.209991455078125 | hi=6.0 | f_hi=160.3858728689881 | P=17.0
# [deAm] sigma* :: tree=jr | sigma_star=0.21236203719140356
# [deAm] eu price :: tree=jr | p_eu=16.906570343813563
# [deAm] IV: QL solver :: iv=0.21236213281035007 | price_for_iv=16.906570343813563
# [deAm] helper IV :: idx=18 | iv=0.21236213281035007
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.459991455078125 | hi=6.0 | f_hi=159.00548153958468 | P=26.25
# [deAm] sigma* :: tree=jr | sigma_star=0.23729146269713575
# [deAm] eu price :: tree=jr | p_eu=26.0888519470825
# [deAm] IV: QL solver :: iv=0.23729146338929752 | price_for_iv=26.0888519470825
# [deAm] helper IV :: idx=19 | iv=0.23729146338929752
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.06 | hi=6.0 | f_hi=20.853885520567612 | P=1.06
# [deAm] sigma* :: tree=jr | sigma_star=2.6936404671792804
# [deAm] eu price :: tree=jr | p_eu=1.0588413844763853
# [deAm] IV: QL solver :: iv=2.693640712313293 | price_for_iv=1.0588413844763853
# [deAm] helper IV :: idx=20 | iv=2.693640712313293
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.06 | hi=6.0 | f_hi=22.857678384244192 | P=1.06
# [deAm] sigma* :: tree=jr | sigma_star=2.588247763747291
# [deAm] eu price :: tree=jr | p_eu=1.0587173357477841
# [deAm] IV: QL solver :: iv=2.588247759830013 | price_for_iv=1.0587173357477841
# [deAm] helper IV :: idx=21 | iv=2.588247759830013
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.06 | hi=6.0 | f_hi=24.875668655839835 | P=1.06
# [deAm] sigma* :: tree=jr | sigma_star=2.487350312513779
# [deAm] eu price :: tree=jr | p_eu=1.0586945281601874
# [deAm] IV: QL solver :: iv=2.4873502609910343 | price_for_iv=1.0586945281601874
# [deAm] helper IV :: idx=22 | iv=2.4873502609910343
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.06 | hi=6.0 | f_hi=27.07457958157691 | P=1.06
# [deAm] sigma* :: tree=jr | sigma_star=2.39054391701557
# [deAm] eu price :: tree=jr | p_eu=1.058724404077322
# [deAm] IV: QL solver :: iv=2.390544113261274 | price_for_iv=1.058724404077322
# [deAm] helper IV :: idx=23 | iv=2.390544113261274
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.12 | hi=6.0 | f_hi=30.21354270717633 | P=0.12
# [deAm] sigma* :: tree=jr | sigma_star=1.7011694195405633
# [deAm] eu price :: tree=jr | p_eu=0.12062208581162451
# [deAm] IV: QL solver :: iv=1.7011695609834485 | price_for_iv=0.12062208581162451
# [deAm] helper IV :: idx=24 | iv=1.7011695609834485
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.125 | hi=6.0 | f_hi=32.4076448190861 | P=0.125
# [deAm] sigma* :: tree=jr | sigma_star=1.6397847052705024
# [deAm] eu price :: tree=jr | p_eu=0.12544645467824553
# [deAm] IV: QL solver :: iv=1.639784705993957 | price_for_iv=0.12544645467824553
# [deAm] helper IV :: idx=25 | iv=1.639784705993957
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.04 | hi=6.0 | f_hi=34.88251281048176 | P=0.04
# [deAm] sigma* :: tree=jr | sigma_star=1.3993432609275065
# [deAm] eu price :: tree=jr | p_eu=0.040594678378672096
# [deAm] IV: QL solver :: iv=1.3993434039234447 | price_for_iv=0.040594678378672096
# [deAm] helper IV :: idx=26 | iv=1.3993434039234447
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.06 | hi=6.0 | f_hi=36.25957136678936 | P=1.06
# [deAm] sigma* :: tree=jr | sigma_star=2.0378266763817536
# [deAm] eu price :: tree=jr | p_eu=1.0588591007574117
# [deAm] IV: QL solver :: iv=2.0378266763830584 | price_for_iv=1.0588591007574117
# [deAm] helper IV :: idx=27 | iv=2.0378266763830584
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.025 | hi=6.0 | f_hi=39.69171588841432 | P=0.025
# [deAm] sigma* :: tree=jr | sigma_star=1.231221666375224
# [deAm] eu price :: tree=jr | p_eu=0.025452682255102825
# [deAm] IV: QL solver :: iv=1.2312215228529269 | price_for_iv=0.025452682255102825
# [deAm] helper IV :: idx=28 | iv=1.2312215228529269
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.065 | hi=6.0 | f_hi=41.14207836810766 | P=1.065
# [deAm] sigma* :: tree=jr | sigma_star=1.8802423665953112
# [deAm] eu price :: tree=jr | p_eu=1.06384165714222
# [deAm] IV: QL solver :: iv=1.880242362589259 | price_for_iv=1.06384165714222
# [deAm] helper IV :: idx=29 | iv=1.880242362589259
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.19 | hi=6.0 | f_hi=44.613214691187274 | P=0.19
# [deAm] sigma* :: tree=jr | sigma_star=1.3971502004694465
# [deAm] eu price :: tree=jr | p_eu=0.191148363052397
# [deAm] IV: QL solver :: iv=1.3971502042998174 | price_for_iv=0.191148363052397
# [deAm] helper IV :: idx=30 | iv=1.3971502042998174
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.01 | hi=6.0 | f_hi=47.389406409376505 | P=0.01
# [deAm] sigma* :: tree=jr | sigma_star=0.9981923618805194
# [deAm] eu price :: tree=jr | p_eu=0.010150583517556834
# [deAm] IV: QL solver :: iv=0.998192493942043 | price_for_iv=0.010150583517556834
# [deAm] helper IV :: idx=31 | iv=0.998192493942043
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.065 | hi=6.0 | f_hi=48.93070240158606 | P=1.065
# [deAm] sigma* :: tree=jr | sigma_star=1.6586895046184342
# [deAm] eu price :: tree=jr | p_eu=1.0641448717103936
# [deAm] IV: QL solver :: iv=1.658689503227606 | price_for_iv=1.0641448717103936
# [deAm] helper IV :: idx=32 | iv=1.658689503227606
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.175 | hi=6.0 | f_hi=52.523237868566994 | P=0.175
# [deAm] sigma* :: tree=jr | sigma_star=1.2108874785695283
# [deAm] eu price :: tree=jr | p_eu=0.1756250736840293
# [deAm] IV: QL solver :: iv=1.2108874312213636 | price_for_iv=0.1756250736840293
# [deAm] helper IV :: idx=33 | iv=1.2108874312213636
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.065 | hi=6.0 | f_hi=54.42749777521725 | P=1.065
# [deAm] sigma* :: tree=jr | sigma_star=1.5209054071191244
# [deAm] eu price :: tree=jr | p_eu=1.0649351139444547
# [deAm] IV: QL solver :: iv=1.5209054039692302 | price_for_iv=1.0649351139444547
# [deAm] helper IV :: idx=34 | iv=1.5209054039692302
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.06 | hi=6.0 | f_hi=58.22681022524742 | P=0.06
# [deAm] sigma* :: tree=jr | sigma_star=0.975528124987342
# [deAm] eu price :: tree=jr | p_eu=0.0603754929471857
# [deAm] IV: QL solver :: iv=0.9755279181306195 | price_for_iv=0.0603754929471857
# [deAm] helper IV :: idx=35 | iv=0.9755279181306195
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.02 | hi=6.0 | f_hi=61.061211882556755 | P=0.02
# [deAm] sigma* :: tree=jr | sigma_star=0.834985717678145
# [deAm] eu price :: tree=jr | p_eu=0.02022750466198316
# [deAm] IV: QL solver :: iv=0.8349856730527194 | price_for_iv=0.02022750466198316
# [deAm] helper IV :: idx=36 | iv=0.8349856730527194
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.17 | hi=6.0 | f_hi=63.7280703303828 | P=0.17
# [deAm] sigma* :: tree=jr | sigma_star=0.9983873848389453
# [deAm] eu price :: tree=jr | p_eu=0.17116641802725147
# [deAm] IV: QL solver :: iv=0.9983873843026132 | price_for_iv=0.17116641802725147
# [deAm] helper IV :: idx=37 | iv=0.9983873843026132
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.05 | hi=6.0 | f_hi=66.83749816579659 | P=0.05
# [deAm] sigma* :: tree=jr | sigma_star=0.8235428995595244
# [deAm] eu price :: tree=jr | p_eu=0.050407299151018714
# [deAm] IV: QL solver :: iv=0.8235429088113704 | price_for_iv=0.050407299151018714
# [deAm] helper IV :: idx=38 | iv=0.8235429088113704
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.035 | hi=6.0 | f_hi=69.84197399269247 | P=0.035
# [deAm] sigma* :: tree=jr | sigma_star=0.7528918802963459
# [deAm] eu price :: tree=jr | p_eu=0.03529103607075141
# [deAm] IV: QL solver :: iv=0.752891876127787 | price_for_iv=0.03529103607075141
# [deAm] helper IV :: idx=39 | iv=0.752891876127787
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.025 | hi=6.0 | f_hi=72.8415110406686 | P=0.025
# [deAm] sigma* :: tree=jr | sigma_star=0.6894121592601654
# [deAm] eu price :: tree=jr | p_eu=0.025225202586390758
# [deAm] IV: QL solver :: iv=0.6894121582014526 | price_for_iv=0.025225202586390758
# [deAm] helper IV :: idx=40 | iv=0.6894121582014526
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.034999999999999996 | hi=6.0 | f_hi=75.82114411896009 | P=0.034999999999999996
# [deAm] sigma* :: tree=jr | sigma_star=0.6727159735342665
# [deAm] eu price :: tree=jr | p_eu=0.03526205071103352
# [deAm] IV: QL solver :: iv=0.6727159625109062 | price_for_iv=0.03526205071103352
# [deAm] helper IV :: idx=41 | iv=0.6727159625109062
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.02 | hi=6.0 | f_hi=78.85275363647207 | P=0.02
# [deAm] sigma* :: tree=jr | sigma_star=0.6006195336769833
# [deAm] eu price :: tree=jr | p_eu=0.020332490039070793
# [deAm] IV: QL solver :: iv=0.6006195115986097 | price_for_iv=0.020332490039070793
# [deAm] helper IV :: idx=42 | iv=0.6006195115986097
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.055 | hi=6.0 | f_hi=81.99757387600016 | P=0.055
# [deAm] sigma* :: tree=jr | sigma_star=0.625472010849025
# [deAm] eu price :: tree=jr | p_eu=0.05571437680863203
# [deAm] IV: QL solver :: iv=0.6254720099186905 | price_for_iv=0.05571437680863203
# [deAm] helper IV :: idx=43 | iv=0.6254720099186905
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.2 | hi=6.0 | f_hi=85.03244236747224 | P=0.2
# [deAm] sigma* :: tree=jr | sigma_star=0.6892433665861547
# [deAm] eu price :: tree=jr | p_eu=0.2013605082223298
# [deAm] IV: QL solver :: iv=0.689243366235742 | price_for_iv=0.2013605082223298
# [deAm] helper IV :: idx=44 | iv=0.689243366235742
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.03 | hi=6.0 | f_hi=88.38236500132629 | P=0.03
# [deAm] sigma* :: tree=jr | sigma_star=0.5130853083560817
# [deAm] eu price :: tree=jr | p_eu=0.03024027120056796
# [deAm] IV: QL solver :: iv=0.5130851434690719 | price_for_iv=0.03024027120056796
# [deAm] helper IV :: idx=45 | iv=0.5130851434690719
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.060000000000000005 | hi=6.0 | f_hi=91.53237672316907 | P=0.060000000000000005
# [deAm] sigma* :: tree=jr | sigma_star=0.5149449467065984
# [deAm] eu price :: tree=jr | p_eu=0.0604471843493964
# [deAm] IV: QL solver :: iv=0.5149448835720788 | price_for_iv=0.0604471843493964
# [deAm] helper IV :: idx=46 | iv=0.5149448835720788
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.065 | hi=6.0 | f_hi=94.7075147955412 | P=0.065
# [deAm] sigma* :: tree=jr | sigma_star=0.4819655953314905
# [deAm] eu price :: tree=jr | p_eu=0.06552529559769002
# [deAm] IV: QL solver :: iv=0.4819655912314053 | price_for_iv=0.06552529559769002
# [deAm] helper IV :: idx=47 | iv=0.4819655912314053
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.065 | hi=6.0 | f_hi=97.98822654740073 | P=0.065
# [deAm] sigma* :: tree=jr | sigma_star=0.4444188204863881
# [deAm] eu price :: tree=jr | p_eu=0.06527441439693903
# [deAm] IV: QL solver :: iv=0.44441883409183325 | price_for_iv=0.06527441439693903
# [deAm] helper IV :: idx=48 | iv=0.44441883409183325
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.13 | hi=6.0 | f_hi=101.2869357890814 | P=0.13
# [deAm] sigma* :: tree=jr | sigma_star=0.4462300026201507
# [deAm] eu price :: tree=jr | p_eu=0.13035749422644136
# [deAm] IV: QL solver :: iv=0.44622975682379346 | price_for_iv=0.13035749422644136
# [deAm] helper IV :: idx=49 | iv=0.44622975682379346
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.08 | hi=6.0 | f_hi=104.70069467403074 | P=0.08
# [deAm] sigma* :: tree=jr | sigma_star=0.3809828121412881
# [deAm] eu price :: tree=jr | p_eu=0.0801973315092905
# [deAm] IV: QL solver :: iv=0.380982811467005 | price_for_iv=0.0801973315092905
# [deAm] helper IV :: idx=50 | iv=0.380982811467005
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.16 | hi=6.0 | f_hi=107.98450988094959 | P=0.16
# [deAm] sigma* :: tree=jr | sigma_star=0.3798605084799535
# [deAm] eu price :: tree=jr | p_eu=0.16087755952176983
# [deAm] IV: QL solver :: iv=0.37986042121134755 | price_for_iv=0.16087755952176983
# [deAm] helper IV :: idx=51 | iv=0.37986042121134755
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.2 | hi=6.0 | f_hi=109.62644803062581 | P=0.2
# [deAm] sigma* :: tree=jr | sigma_star=0.37275154725017784
# [deAm] eu price :: tree=jr | p_eu=0.20040742755582516
# [deAm] IV: QL solver :: iv=0.37275157993707464 | price_for_iv=0.20040742755582516
# [deAm] helper IV :: idx=52 | iv=0.37275157993707464
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.23500000000000001 | hi=6.0 | f_hi=111.27341337016591 | P=0.23500000000000001
# [deAm] sigma* :: tree=jr | sigma_star=0.36192244441590576
# [deAm] eu price :: tree=jr | p_eu=0.23491145893827142
# [deAm] IV: QL solver :: iv=0.36192244365557896 | price_for_iv=0.23491145893827142
# [deAm] helper IV :: idx=53 | iv=0.36192244365557896
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.28 | hi=6.0 | f_hi=112.9103980116691 | P=0.28
# [deAm] sigma* :: tree=jr | sigma_star=0.352042349968309
# [deAm] eu price :: tree=jr | p_eu=0.2803802958785478
# [deAm] IV: QL solver :: iv=0.3520423489529282 | price_for_iv=0.2803802958785478
# [deAm] helper IV :: idx=54 | iv=0.3520423489529282
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.33499999999999996 | hi=6.0 | f_hi=114.5374274498168 | P=0.33499999999999996
# [deAm] sigma* :: tree=jr | sigma_star=0.34237952553971696
# [deAm] eu price :: tree=jr | p_eu=0.3365721938377545
# [deAm] IV: QL solver :: iv=0.3423795470001352 | price_for_iv=0.3365721938377545
# [deAm] helper IV :: idx=55 | iv=0.3423795470001352
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.38 | hi=6.0 | f_hi=116.17451308631128 | P=0.38
# [deAm] sigma* :: tree=jr | sigma_star=0.32844675179410276
# [deAm] eu price :: tree=jr | p_eu=0.3797397487233064
# [deAm] IV: QL solver :: iv=0.3284468679651661 | price_for_iv=0.3797397487233064
# [deAm] helper IV :: idx=56 | iv=0.3284468679651661
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.46499999999999997 | hi=6.0 | f_hi=117.81660348337289 | P=0.46499999999999997
# [deAm] sigma* :: tree=jr | sigma_star=0.31955952154718903
# [deAm] eu price :: tree=jr | p_eu=0.4643191103096558
# [deAm] IV: QL solver :: iv=0.31955951497111074 | price_for_iv=0.4643191103096558
# [deAm] helper IV :: idx=57 | iv=0.31955951497111074
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.5700000000000001 | hi=6.0 | f_hi=119.4813535986606 | P=0.5700000000000001
# [deAm] sigma* :: tree=jr | sigma_star=0.31071415033488353
# [deAm] eu price :: tree=jr | p_eu=0.5689489506620937
# [deAm] IV: QL solver :: iv=0.3107139858599608 | price_for_iv=0.5689489506620937
# [deAm] helper IV :: idx=58 | iv=0.3107139858599608
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.685 | hi=6.0 | f_hi=121.13611343965944 | P=0.685
# [deAm] sigma* :: tree=jr | sigma_star=0.30026944115083865
# [deAm] eu price :: tree=jr | p_eu=0.6834888116386278
# [deAm] IV: QL solver :: iv=0.3002694412030023 | price_for_iv=0.6834888116386278
# [deAm] helper IV :: idx=59 | iv=0.3002694412030023
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.8049999999999999 | hi=6.0 | f_hi=122.7858860965664 | P=0.8049999999999999
# [deAm] sigma* :: tree=jr | sigma_star=0.28781834672641965
# [deAm] eu price :: tree=jr | p_eu=0.8030811887165958
# [deAm] IV: QL solver :: iv=0.2878183455404919 | price_for_iv=0.8030811887165958
# [deAm] helper IV :: idx=60 | iv=0.2878183455404919
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.99 | hi=6.0 | f_hi=124.3706714576966 | P=0.99
# [deAm] sigma* :: tree=jr | sigma_star=0.27859207637206
# [deAm] eu price :: tree=jr | p_eu=0.9875181773029654
# [deAm] IV: QL solver :: iv=0.27859217565805827 | price_for_iv=0.9875181773029654
# [deAm] helper IV :: idx=61 | iv=0.27859217565805827
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.255 | hi=6.0 | f_hi=125.87546805752497 | P=1.255
# [deAm] sigma* :: tree=jr | sigma_star=0.2720904764755583
# [deAm] eu price :: tree=jr | p_eu=1.2540824125807672
# [deAm] IV: QL solver :: iv=0.2720904765083037 | price_for_iv=1.2540824125807672
# [deAm] helper IV :: idx=62 | iv=0.2720904765083037
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.51 | hi=6.0 | f_hi=127.39027739349022 | P=1.51
# [deAm] sigma* :: tree=jr | sigma_star=0.2607274274317252
# [deAm] eu price :: tree=jr | p_eu=1.5099599893126237
# [deAm] IV: QL solver :: iv=0.2607274540369941 | price_for_iv=1.5099599893126237
# [deAm] helper IV :: idx=63 | iv=0.2607274540369941
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.915 | hi=6.0 | f_hi=128.75510421657373 | P=1.915
# [deAm] sigma* :: tree=jr | sigma_star=0.25406511375303414
# [deAm] eu price :: tree=jr | p_eu=1.909370746277536
# [deAm] IV: QL solver :: iv=0.25406511022046235 | price_for_iv=1.909370746277536
# [deAm] helper IV :: idx=64 | iv=0.25406511022046235
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.385 | hi=6.0 | f_hi=130.05494861701698 | P=2.385
# [deAm] sigma* :: tree=jr | sigma_star=0.24630019333702782
# [deAm] eu price :: tree=jr | p_eu=2.38182077507231
# [deAm] IV: QL solver :: iv=0.2463001934178489 | price_for_iv=2.38182077507231
# [deAm] helper IV :: idx=65 | iv=0.2463001934178489
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.0149999999999997 | hi=6.0 | f_hi=131.19481530684644 | P=3.0149999999999997
# [deAm] sigma* :: tree=jr | sigma_star=0.24052433917473548
# [deAm] eu price :: tree=jr | p_eu=3.0056736600516984
# [deAm] IV: QL solver :: iv=0.24052433871598689 | price_for_iv=3.0056736600516984
# [deAm] helper IV :: idx=66 | iv=0.24052433871598689
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.825 | hi=6.0 | f_hi=132.15471054442114 | P=3.825
# [deAm] sigma* :: tree=jr | sigma_star=0.23700188554230128
# [deAm] eu price :: tree=jr | p_eu=3.8161422883638147
# [deAm] IV: QL solver :: iv=0.23700188569488587 | price_for_iv=3.8161422883638147
# [deAm] helper IV :: idx=67 | iv=0.23700188569488587
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-4.699999999999999 | hi=6.0 | f_hi=133.04962240428367 | P=4.699999999999999
# [deAm] sigma* :: tree=jr | sigma_star=0.22954012983166555
# [deAm] eu price :: tree=jr | p_eu=4.687810334930334
# [deAm] IV: QL solver :: iv=0.22954012857194683 | price_for_iv=4.687810334930334
# [deAm] helper IV :: idx=68 | iv=0.22954012857194683
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-5.109991455078125 | hi=6.0 | f_hi=133.61958394284517 | P=5.9
# [deAm] sigma* :: tree=jr | sigma_star=0.2284295121345663
# [deAm] eu price :: tree=jr | p_eu=5.88080621368889
# [deAm] IV: QL solver :: iv=0.2284295116358892 | price_for_iv=5.88080621368889
# [deAm] helper IV :: idx=69 | iv=0.2284295116358892
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.8599914550781254 | hi=6.0 | f_hi=134.13959578294032 | P=7.15
# [deAm] sigma* :: tree=jr | sigma_star=0.2221387089831427
# [deAm] eu price :: tree=jr | p_eu=7.125184468725746
# [deAm] IV: QL solver :: iv=0.22213853506288767 | price_for_iv=7.125184468725746
# [deAm] helper IV :: idx=70 | iv=0.22213853506288767
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.8599914550781254 | hi=6.0 | f_hi=134.43970181153222 | P=8.65
# [deAm] sigma* :: tree=jr | sigma_star=0.21866117365841747
# [deAm] eu price :: tree=jr | p_eu=8.619155257893127
# [deAm] IV: QL solver :: iv=0.21866107592162037 | price_for_iv=8.619155257893127
# [deAm] helper IV :: idx=71 | iv=0.21866107592162037
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.709991455078125 | hi=6.0 | f_hi=134.29565180448498 | P=12.5
# [deAm] sigma* :: tree=jr | sigma_star=0.22917954710801883
# [deAm] eu price :: tree=jr | p_eu=12.4520542871994
# [deAm] IV: QL solver :: iv=0.2291797520027434 | price_for_iv=12.4520542871994
# [deAm] helper IV :: idx=72 | iv=0.2291797520027434
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.8099914550781264 | hi=6.0 | f_hi=133.90164687593753 | P=16.6
# [deAm] sigma* :: tree=jr | sigma_star=0.2273365964675651
# [deAm] eu price :: tree=jr | p_eu=16.52970932202334
# [deAm] IV: QL solver :: iv=0.2273366285221408 | price_for_iv=16.52970932202334
# [deAm] helper IV :: idx=73 | iv=0.2273366285221408
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.4849914550781236 | hi=6.0 | f_hi=132.9326892871231 | P=21.275
# [deAm] sigma* :: tree=jr | sigma_star=0.24432701944933016
# [deAm] eu price :: tree=jr | p_eu=21.17976027540172
# [deAm] IV: QL solver :: iv=0.24432701945490343 | price_for_iv=21.17976027540172
# [deAm] helper IV :: idx=74 | iv=0.24432701945490343
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.5349914550781243 | hi=6.0 | f_hi=131.58878699888427 | P=26.325
# [deAm] sigma* :: tree=jr | sigma_star=0.29112455090947476
# [deAm] eu price :: tree=jr | p_eu=26.228415088914403
# [deAm] IV: QL solver :: iv=0.2911245509608109 | price_for_iv=26.228415088914403
# [deAm] helper IV :: idx=75 | iv=0.2911245509608109
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.4349914550781264 | hi=6.0 | f_hi=130.39495510313637 | P=31.225
# [deAm] sigma* :: tree=jr | sigma_star=0.31872077264663357
# [deAm] eu price :: tree=jr | p_eu=31.113784271536623
# [deAm] IV: QL solver :: iv=0.31872068868071796 | price_for_iv=31.113784271536623
# [deAm] helper IV :: idx=76 | iv=0.31872068868071796
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.08 | hi=6.0 | f_hi=169.7142797497539 | P=1.08
# [deAm] sigma* :: tree=jr | sigma_star=0.3149370364025559
# [deAm] eu price :: tree=jr | p_eu=1.076976944939353
# [deAm] IV: QL solver :: iv=0.3149370364139 | price_for_iv=1.076976944939353
# [deAm] helper IV :: idx=77 | iv=0.3149370364139
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.34 | hi=6.0 | f_hi=173.45397956317754 | P=1.34
# [deAm] sigma* :: tree=jr | sigma_star=0.2990464520447596
# [deAm] eu price :: tree=jr | p_eu=1.3376795873954808
# [deAm] IV: QL solver :: iv=0.29904655970462773 | price_for_iv=1.3376795873954808
# [deAm] helper IV :: idx=78 | iv=0.29904655970462773
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.7799999999999998 | hi=6.0 | f_hi=177.01381831118854 | P=1.7799999999999998
# [deAm] sigma* :: tree=jr | sigma_star=0.28842290860711567
# [deAm] eu price :: tree=jr | p_eu=1.7743746876416686
# [deAm] IV: QL solver :: iv=0.28842299792024034 | price_for_iv=1.7743746876416686
# [deAm] helper IV :: idx=79 | iv=0.28842299792024034
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.26 | hi=6.0 | f_hi=180.53380195411293 | P=2.26
# [deAm] sigma* :: tree=jr | sigma_star=0.2738250522374099
# [deAm] eu price :: tree=jr | p_eu=2.252747049442148
# [deAm] IV: QL solver :: iv=0.27382492747987613 | price_for_iv=2.252747049442148
# [deAm] helper IV :: idx=80 | iv=0.27382492747987613
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.145 | hi=6.0 | f_hi=183.6489861486119 | P=3.145
# [deAm] sigma* :: tree=jr | sigma_star=0.2687438771013482
# [deAm] eu price :: tree=jr | p_eu=3.1321427342069823
# [deAm] IV: QL solver :: iv=0.2687438765513092 | price_for_iv=3.1321427342069823
# [deAm] helper IV :: idx=81 | iv=0.2687438765513092
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.975 | hi=6.0 | f_hi=186.8635028847755 | P=3.975
# [deAm] sigma* :: tree=jr | sigma_star=0.25368425616169726
# [deAm] eu price :: tree=jr | p_eu=3.9593282924484914
# [deAm] IV: QL solver :: iv=0.25368425616299534 | price_for_iv=3.9593282924484914
# [deAm] helper IV :: idx=82 | iv=0.25368425616299534
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-5.4 | hi=6.0 | f_hi=189.57065752056786 | P=5.4
# [deAm] sigma* :: tree=jr | sigma_star=0.24871285041445562
# [deAm] eu price :: tree=jr | p_eu=5.376605498927007
# [deAm] IV: QL solver :: iv=0.2487128137317929 | price_for_iv=5.376605498927007
# [deAm] helper IV :: idx=83 | iv=0.2487128137317929
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-6.725 | hi=6.0 | f_hi=192.37788039478414 | P=6.725
# [deAm] sigma* :: tree=jr | sigma_star=0.23146277499253423
# [deAm] eu price :: tree=jr | p_eu=6.693382005268359
# [deAm] IV: QL solver :: iv=0.231462743656957 | price_for_iv=6.693382005268359
# [deAm] helper IV :: idx=84 | iv=0.231462743656957
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-8.459991455078125 | hi=6.0 | f_hi=193.98518469035764 | P=9.25
# [deAm] sigma* :: tree=jr | sigma_star=0.23537930614035654
# [deAm] eu price :: tree=jr | p_eu=9.19995059622476
# [deAm] IV: QL solver :: iv=0.23537932718629992 | price_for_iv=9.19995059622476
# [deAm] helper IV :: idx=85 | iv=0.23537932718629992
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.115 | hi=6.0 | f_hi=20.658928014708223 | P=0.115
# [deAm] sigma* :: tree=jr | sigma_star=1.9417742587833395
# [deAm] eu price :: tree=jr | p_eu=0.11575411977412543
# [deAm] IV: QL solver :: iv=1.9417742587862936 | price_for_iv=0.11575411977412543
# [deAm] helper IV :: idx=86 | iv=1.9417742587862936
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.065 | hi=6.0 | f_hi=28.216757718116593 | P=0.065
# [deAm] sigma* :: tree=jr | sigma_star=1.5278446323109223
# [deAm] eu price :: tree=jr | p_eu=0.0655276367091433
# [deAm] IV: QL solver :: iv=1.527844632869975 | price_for_iv=0.0655276367091433
# [deAm] helper IV :: idx=87 | iv=1.527844632869975
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.06 | hi=6.0 | f_hi=35.691982918730346 | P=1.06
# [deAm] sigma* :: tree=jr | sigma_star=1.8732356267985555
# [deAm] eu price :: tree=jr | p_eu=1.0629360754832617
# [deAm] IV: QL solver :: iv=1.8732355432438432 | price_for_iv=1.0629360754832617
# [deAm] helper IV :: idx=88 | iv=1.8732355432438432
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.88 | hi=6.0 | f_hi=40.478169054829394 | P=0.88
# [deAm] sigma* :: tree=jr | sigma_star=1.6399742406863609
# [deAm] eu price :: tree=jr | p_eu=0.8796103745268384
# [deAm] IV: QL solver :: iv=1.6399742313711536 | price_for_iv=0.8796103745268384
# [deAm] helper IV :: idx=89 | iv=1.6399742313711536
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.025 | hi=6.0 | f_hi=43.731881269457965 | P=0.025
# [deAm] sigma* :: tree=jr | sigma_star=0.9740103156283831
# [deAm] eu price :: tree=jr | p_eu=0.025229861733639586
# [deAm] IV: QL solver :: iv=0.9740101643293512 | price_for_iv=0.025229861733639586
# [deAm] helper IV :: idx=90 | iv=0.9740101643293512
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.19 | hi=6.0 | f_hi=48.46119757745253 | P=0.19
# [deAm] sigma* :: tree=jr | sigma_star=1.0925168579949325
# [deAm] eu price :: tree=jr | p_eu=0.19054211602363907
# [deAm] IV: QL solver :: iv=1.0925168835085342 | price_for_iv=0.19054211602363907
# [deAm] helper IV :: idx=91 | iv=1.0925168835085342
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.65 | hi=6.0 | f_hi=53.1970778569392 | P=0.65
# [deAm] sigma* :: tree=jr | sigma_star=1.1764045647571593
# [deAm] eu price :: tree=jr | p_eu=0.6534483697365947
# [deAm] IV: QL solver :: iv=1.1764044993936171 | price_for_iv=0.6534483697365947
# [deAm] helper IV :: idx=92 | iv=1.1764044993936171
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.05 | hi=6.0 | f_hi=56.39511082401382 | P=0.05
# [deAm] sigma* :: tree=jr | sigma_star=0.7656279012031151
# [deAm] eu price :: tree=jr | p_eu=0.05065303799251939
# [deAm] IV: QL solver :: iv=0.7656280325764435 | price_for_iv=0.05065303799251939
# [deAm] helper IV :: idx=93 | iv=0.7656280325764435
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.265 | hi=6.0 | f_hi=58.90279567959073 | P=0.265
# [deAm] sigma* :: tree=jr | sigma_star=0.8860655148778386
# [deAm] eu price :: tree=jr | p_eu=0.26545799216976396
# [deAm] IV: QL solver :: iv=0.8860655141988383 | price_for_iv=0.26545799216976396
# [deAm] helper IV :: idx=94 | iv=0.8860655141988383
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.08 | hi=6.0 | f_hi=61.883960657439246 | P=0.08
# [deAm] sigma* :: tree=jr | sigma_star=0.6978125895764052
# [deAm] eu price :: tree=jr | p_eu=0.08056712198316654
# [deAm] IV: QL solver :: iv=0.6978125921578027 | price_for_iv=0.08056712198316654
# [deAm] helper IV :: idx=95 | iv=0.6978125921578027
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.125 | hi=6.0 | f_hi=64.63516828729752 | P=0.125
# [deAm] sigma* :: tree=jr | sigma_star=0.6822680082215753
# [deAm] eu price :: tree=jr | p_eu=0.12535976654719924
# [deAm] IV: QL solver :: iv=0.6822679051381545 | price_for_iv=0.12535976654719924
# [deAm] helper IV :: idx=96 | iv=0.6822679051381545
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.03 | hi=6.0 | f_hi=67.52644552836522 | P=0.03
# [deAm] sigma* :: tree=jr | sigma_star=0.5265405698993805
# [deAm] eu price :: tree=jr | p_eu=0.030218066471170306
# [deAm] IV: QL solver :: iv=0.5265406471334699 | price_for_iv=0.030218066471170306
# [deAm] helper IV :: idx=97 | iv=0.5265406471334699
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.145 | hi=6.0 | f_hi=70.2932923317937 | P=0.145
# [deAm] sigma* :: tree=jr | sigma_star=0.5835224467794782
# [deAm] eu price :: tree=jr | p_eu=0.14540726926573042
# [deAm] IV: QL solver :: iv=0.5835224469351171 | price_for_iv=0.14540726926573042
# [deAm] helper IV :: idx=98 | iv=0.5835224469351171
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.125 | hi=6.0 | f_hi=73.3047543651314 | P=0.125
# [deAm] sigma* :: tree=jr | sigma_star=0.516750647001736
# [deAm] eu price :: tree=jr | p_eu=0.12580377851995198
# [deAm] IV: QL solver :: iv=0.5167506479700457 | price_for_iv=0.12580377851995198
# [deAm] helper IV :: idx=99 | iv=0.5167506479700457
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.175 | hi=6.0 | f_hi=76.24625270732741 | P=0.175
# [deAm] sigma* :: tree=jr | sigma_star=0.4864676019356488
# [deAm] eu price :: tree=jr | p_eu=0.17508762347920787
# [deAm] IV: QL solver :: iv=0.4864675592688852 | price_for_iv=0.17508762347920787
# [deAm] helper IV :: idx=100 | iv=0.4864675592688852
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.14 | hi=6.0 | f_hi=77.77702189665766 | P=0.14
# [deAm] sigma* :: tree=jr | sigma_star=0.44305823443412984
# [deAm] eu price :: tree=jr | p_eu=0.1412235337349642
# [deAm] IV: QL solver :: iv=0.4430582317012663 | price_for_iv=0.1412235337349642
# [deAm] helper IV :: idx=101 | iv=0.4430582317012663
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.11 | hi=6.0 | f_hi=79.3028057604995 | P=0.11
# [deAm] sigma* :: tree=jr | sigma_star=0.40023861102450703
# [deAm] eu price :: tree=jr | p_eu=0.11014374962779788
# [deAm] IV: QL solver :: iv=0.4002385398867879 | price_for_iv=0.11014374962779788
# [deAm] helper IV :: idx=102 | iv=0.4002385398867879
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.14 | hi=6.0 | f_hi=80.76862121804118 | P=0.14
# [deAm] sigma* :: tree=jr | sigma_star=0.3878338871005153
# [deAm] eu price :: tree=jr | p_eu=0.14010856733826674
# [deAm] IV: QL solver :: iv=0.38783387320117624 | price_for_iv=0.14010856733826674
# [deAm] helper IV :: idx=103 | iv=0.38783387320117624
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.185 | hi=6.0 | f_hi=82.21948137433887 | P=0.185
# [deAm] sigma* :: tree=jr | sigma_star=0.37757183805221783
# [deAm] eu price :: tree=jr | p_eu=0.18498349196729066
# [deAm] IV: QL solver :: iv=0.3775719898047141 | price_for_iv=0.18498349196729066
# [deAm] helper IV :: idx=104 | iv=0.3775719898047141
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.15 | hi=6.0 | f_hi=83.82341043324134 | P=0.15
# [deAm] sigma* :: tree=jr | sigma_star=0.33718895048342323
# [deAm] eu price :: tree=jr | p_eu=0.15061446524058184
# [deAm] IV: QL solver :: iv=0.3371889377365238 | price_for_iv=0.15061446524058184
# [deAm] helper IV :: idx=105 | iv=0.3371889377365238
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.235 | hi=6.0 | f_hi=85.3293862408696 | P=0.235
# [deAm] sigma* :: tree=jr | sigma_star=0.33555604074798606
# [deAm] eu price :: tree=jr | p_eu=0.23579914860845577
# [deAm] IV: QL solver :: iv=0.3355560029450212 | price_for_iv=0.23579914860845577
# [deAm] helper IV :: idx=106 | iv=0.3355560029450212
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.29000000000000004 | hi=6.0 | f_hi=86.8653692375135 | P=0.29000000000000004
# [deAm] sigma* :: tree=jr | sigma_star=0.31926588993663213
# [deAm] eu price :: tree=jr | p_eu=0.291037267092675
# [deAm] IV: QL solver :: iv=0.31926593990264585 | price_for_iv=0.291037267092675
# [deAm] helper IV :: idx=107 | iv=0.31926593990264585
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.41000000000000003 | hi=6.0 | f_hi=88.33635906807561 | P=0.41000000000000003
# [deAm] sigma* :: tree=jr | sigma_star=0.31136699688120795
# [deAm] eu price :: tree=jr | p_eu=0.4093507788888621
# [deAm] IV: QL solver :: iv=0.31136685120220736 | price_for_iv=0.4093507788888621
# [deAm] helper IV :: idx=108 | iv=0.31136685120220736
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.49 | hi=6.0 | f_hi=89.84736013127241 | P=0.49
# [deAm] sigma* :: tree=jr | sigma_star=0.2914186139897342
# [deAm] eu price :: tree=jr | p_eu=0.4891557416175982
# [deAm] IV: QL solver :: iv=0.2914186140209424 | price_for_iv=0.4891557416175982
# [deAm] helper IV :: idx=109 | iv=0.2914186140209424
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.635 | hi=6.0 | f_hi=91.29337754372804 | P=0.635
# [deAm] sigma* :: tree=jr | sigma_star=0.27681756584895983
# [deAm] eu price :: tree=jr | p_eu=0.6362803956975756
# [deAm] IV: QL solver :: iv=0.2768175712256998 | price_for_iv=0.6362803956975756
# [deAm] helper IV :: idx=110 | iv=0.2768175712256998
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.8400000000000001 | hi=6.0 | f_hi=92.6794071008933 | P=0.8400000000000001
# [deAm] sigma* :: tree=jr | sigma_star=0.26252649814792317
# [deAm] eu price :: tree=jr | p_eu=0.8383536761000674
# [deAm] IV: QL solver :: iv=0.2625264990031464 | price_for_iv=0.8383536761000674
# [deAm] helper IV :: idx=111 | iv=0.2625264990031464
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.1600000000000001 | hi=6.0 | f_hi=93.95045572136473 | P=1.1600000000000001
# [deAm] sigma* :: tree=jr | sigma_star=0.251958880089432
# [deAm] eu price :: tree=jr | p_eu=1.1573146101399514
# [deAm] IV: QL solver :: iv=0.25195888016661666 | price_for_iv=1.1573146101399514
# [deAm] helper IV :: idx=112 | iv=0.25195888016661666
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.615 | hi=6.0 | f_hi=95.08653755371674 | P=1.615
# [deAm] sigma* :: tree=jr | sigma_star=0.2427371675912546
# [deAm] eu price :: tree=jr | p_eu=1.611464393579264
# [deAm] IV: QL solver :: iv=0.24273716858989425 | price_for_iv=1.611464393579264
# [deAm] helper IV :: idx=113 | iv=0.24273716858989425
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.215 | hi=6.0 | f_hi=96.07767798736737 | P=2.215
# [deAm] sigma* :: tree=jr | sigma_star=0.23279613286781645
# [deAm] eu price :: tree=jr | p_eu=2.2120006291115883
# [deAm] IV: QL solver :: iv=0.23279618778606803 | price_for_iv=2.2120006291115883
# [deAm] helper IV :: idx=114 | iv=0.23279618778606803
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.1100000000000003 | hi=6.0 | f_hi=96.85379097451347 | P=3.1100000000000003
# [deAm] sigma* :: tree=jr | sigma_star=0.22847994202966002
# [deAm] eu price :: tree=jr | p_eu=3.1033312217600155
# [deAm] IV: QL solver :: iv=0.22847989739957134 | price_for_iv=3.1033312217600155
# [deAm] helper IV :: idx=115 | iv=0.22847989739957134
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.334991455078125 | hi=6.0 | f_hi=97.52175124697025 | P=4.125
# [deAm] sigma* :: tree=jr | sigma_star=0.21739221025197747
# [deAm] eu price :: tree=jr | p_eu=4.117279041129255
# [deAm] IV: QL solver :: iv=0.21739205173218304 | price_for_iv=4.117279041129255
# [deAm] helper IV :: idx=116 | iv=0.21739205173218304
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.259991455078125 | hi=6.0 | f_hi=97.77971918038489 | P=5.55
# [deAm] sigma* :: tree=jr | sigma_star=0.21474035952944284
# [deAm] eu price :: tree=jr | p_eu=5.536190914177055
# [deAm] IV: QL solver :: iv=0.2147403610533275 | price_for_iv=5.536190914177055
# [deAm] helper IV :: idx=117 | iv=0.2147403610533275
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.6599914550781252 | hi=6.0 | f_hi=97.56269410086807 | P=7.45
# [deAm] sigma* :: tree=jr | sigma_star=0.2273240783140999
# [deAm] eu price :: tree=jr | p_eu=7.433684657366696
# [deAm] IV: QL solver :: iv=0.2273238671086422 | price_for_iv=7.433684657366696
# [deAm] helper IV :: idx=118 | iv=0.2273238671086422
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.334991455078125 | hi=6.0 | f_hi=95.61972471031368 | P=16.125
# [deAm] sigma* :: tree=jr | sigma_star=0.2538538496723001
# [deAm] eu price :: tree=jr | p_eu=16.082320634564333
# [deAm] IV: QL solver :: iv=0.25385385012206446 | price_for_iv=16.082320634564333
# [deAm] helper IV :: idx=119 | iv=0.25385385012206446
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.209991455078125 | hi=6.0 | f_hi=94.11087214493152 | P=21.0
# [deAm] sigma* :: tree=jr | sigma_star=0.2867589042177702
# [deAm] eu price :: tree=jr | p_eu=20.94514249991809
# [deAm] IV: QL solver :: iv=0.28675878693457607 | price_for_iv=20.94514249991809
# [deAm] helper IV :: idx=120 | iv=0.28675878693457607
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.5650000000000001 | hi=6.0 | f_hi=120.82169875826102 | P=0.5650000000000001
# [deAm] sigma* :: tree=jr | sigma_star=0.6110214108612231
# [deAm] eu price :: tree=jr | p_eu=0.564925099884181
# [deAm] IV: QL solver :: iv=0.6110213557563704 | price_for_iv=0.564925099884181
# [deAm] helper IV :: idx=121 | iv=0.6110213557563704
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.175 | hi=6.0 | f_hi=128.6146010046534 | P=0.175
# [deAm] sigma* :: tree=jr | sigma_star=0.44885116644099177
# [deAm] eu price :: tree=jr | p_eu=0.17585458254291705
# [deAm] IV: QL solver :: iv=0.4488512132056216 | price_for_iv=0.17585458254291705
# [deAm] helper IV :: idx=122 | iv=0.4488512132056216
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.27999999999999997 | hi=6.0 | f_hi=135.91308140369694 | P=0.27999999999999997
# [deAm] sigma* :: tree=jr | sigma_star=0.4172951736612383
# [deAm] eu price :: tree=jr | p_eu=0.28017120760791175
# [deAm] IV: QL solver :: iv=0.41729516525332466 | price_for_iv=0.28017120760791175
# [deAm] helper IV :: idx=123 | iv=0.41729516525332466
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.345 | hi=6.0 | f_hi=143.4636836824633 | P=0.345
# [deAm] sigma* :: tree=jr | sigma_star=0.36836905251247926
# [deAm] eu price :: tree=jr | p_eu=0.34554415654620446
# [deAm] IV: QL solver :: iv=0.3683690267526129 | price_for_iv=0.34554415654620446
# [deAm] helper IV :: idx=124 | iv=0.3683690267526129
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.38 | hi=6.0 | f_hi=147.28580360041036 | P=0.38
# [deAm] sigma* :: tree=jr | sigma_star=0.3428413279198458
# [deAm] eu price :: tree=jr | p_eu=0.3795896403318122
# [deAm] IV: QL solver :: iv=0.34284132689280633 | price_for_iv=0.3795896403318122
# [deAm] helper IV :: idx=125 | iv=0.34284132689280633
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.52 | hi=6.0 | f_hi=151.00300302043212 | P=0.52
# [deAm] sigma* :: tree=jr | sigma_star=0.33076002850464026
# [deAm] eu price :: tree=jr | p_eu=0.5197214059944102
# [deAm] IV: QL solver :: iv=0.3307600285078329 | price_for_iv=0.5197214059944102
# [deAm] helper IV :: idx=126 | iv=0.3307600285078329
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.6699999999999999 | hi=6.0 | f_hi=154.71028526975422 | P=0.6699999999999999
# [deAm] sigma* :: tree=jr | sigma_star=0.3147596161747374
# [deAm] eu price :: tree=jr | p_eu=0.6716527046805149
# [deAm] IV: QL solver :: iv=0.3147595739752076 | price_for_iv=0.6716527046805149
# [deAm] helper IV :: idx=127 | iv=0.3147595739752076
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.9400000000000001 | hi=6.0 | f_hi=158.29765825113435 | P=0.9400000000000001
# [deAm] sigma* :: tree=jr | sigma_star=0.30399902573635723
# [deAm] eu price :: tree=jr | p_eu=0.9373344154535238
# [deAm] IV: QL solver :: iv=0.3039990257385737 | price_for_iv=0.9373344154535238
# [deAm] helper IV :: idx=128 | iv=0.3039990257385737
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.3 | hi=6.0 | f_hi=161.79513050643615 | P=1.3
# [deAm] sigma* :: tree=jr | sigma_star=0.2929849281480325
# [deAm] eu price :: tree=jr | p_eu=1.297922648118507
# [deAm] IV: QL solver :: iv=0.2929849290040307 | price_for_iv=1.297922648118507
# [deAm] helper IV :: idx=129 | iv=0.2929849290040307
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.49 | hi=6.0 | f_hi=165.46275548650746 | P=1.49
# [deAm] sigma* :: tree=jr | sigma_star=0.26567279448872616
# [deAm] eu price :: tree=jr | p_eu=1.4859713071198175
# [deAm] IV: QL solver :: iv=0.26567295264325763 | price_for_iv=1.4859713071198175
# [deAm] helper IV :: idx=130 | iv=0.26567295264325763
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.15 | hi=6.0 | f_hi=168.66053497627243 | P=2.15
# [deAm] sigma* :: tree=jr | sigma_star=0.2573176750635706
# [deAm] eu price :: tree=jr | p_eu=2.1429802839058025
# [deAm] IV: QL solver :: iv=0.25731767632239766 | price_for_iv=2.1429802839058025
# [deAm] helper IV :: idx=131 | iv=0.25731767632239766
# ...
# [deAm] Heston EU price :: K=155.0 | T=1.189041095890411 | p=161.02559539140722
# [deAm] Heston EU price :: K=160.0 | T=1.189041095890411 | p=156.47585752605968
# [deAm] Heston EU price :: K=165.0 | T=1.189041095890411 | p=151.9478714575421
# [deAm] Heston EU price :: K=170.0 | T=1.189041095890411 | p=147.44325765807605
# [deAm] Heston EU price :: K=175.0 | T=1.189041095890411 | p=142.9637282578546
# [deAm] Heston EU price :: K=180.0 | T=1.189041095890411 | p=138.51109113096632
# [deAm] Heston EU price :: K=185.0 | T=1.189041095890411 | p=134.0872540043918
# [deAm] Heston EU price :: K=190.0 | T=1.189041095890411 | p=129.69422854666854
# [deAm] Heston EU price :: K=195.0 | T=1.189041095890411 | p=125.33413438187479
# [deAm] Heston EU price :: K=200.0 | T=1.189041095890411 | p=121.00920296161017
# [deAm] Heston EU price :: K=210.0 | T=1.189041095890411 | p=112.47433485777208
# [deAm] Heston EU price :: K=220.0 | T=1.189041095890411 | p=104.10984187691756
# [deAm] Heston EU price :: K=230.0 | T=1.189041095890411 | p=95.9379188408659
# [deAm] Heston EU price :: K=240.0 | T=1.189041095890411 | p=87.9827674302641
# [deAm] Heston EU price :: K=250.0 | T=1.189041095890411 | p=80.27054712346077
# [deAm] Heston EU price :: K=260.0 | T=1.189041095890411 | p=72.82920984278427
# [deAm] Heston EU price :: K=270.0 | T=1.189041095890411 | p=65.68817118144392
# [deAm] Heston EU price :: K=280.0 | T=1.189041095890411 | p=58.87776333676434
# [deAm] Heston EU price :: K=290.0 | T=1.189041095890411 | p=52.42841314875022
# [deAm] Heston EU price :: K=300.0 | T=1.189041095890411 | p=46.36949953255356
# [deAm] Heston EU price :: K=310.0 | T=1.189041095890411 | p=40.72787657908076
# [deAm] Heston EU price :: K=320.0 | T=1.189041095890411 | p=35.52610932307692
# [deAm] Heston EU price :: K=330.0 | T=1.189041095890411 | p=30.780559407996346
# [deAm] Heston EU price :: K=340.0 | T=1.189041095890411 | p=26.49956291752238
# [deAm] Heston EU price :: K=350.0 | T=1.189041095890411 | p=22.68202641949913
# [deAm] Heston EU price :: K=360.0 | T=1.189041095890411 | p=19.316778779216442
# [deAm] Heston EU price :: K=370.0 | T=1.189041095890411 | p=16.382915350010283
# [deAm] Heston EU price :: K=380.0 | T=1.189041095890411 | p=13.851163859892898
# [deAm] Heston EU price :: K=390.0 | T=1.189041095890411 | p=11.686055919708608
# [deAm] Heston EU price :: K=400.0 | T=1.189041095890411 | p=9.848505565175646
# [deAm] Heston EU price :: K=410.0 | T=1.189041095890411 | p=8.298349251277358
# [deAm] Heston EU price :: K=420.0 | T=1.189041095890411 | p=6.996491145833315
# [deAm] Heston EU price :: K=430.0 | T=1.189041095890411 | p=5.9064621523056235
# [deAm] Heston EU price :: K=440.0 | T=1.189041095890411 | p=4.995364574357936
# [deAm] Heston EU price :: K=450.0 | T=1.189041095890411 | p=4.2342872209007325
# [deAm] Heston EU price :: K=460.0 | T=1.189041095890411 | p=3.598326640870189
# [deAm] Heston EU price :: K=470.0 | T=1.189041095890411 | p=3.0663531588112822
# [deAm] Heston EU price :: K=145.0 | T=1.6082191780821917 | p=170.66368932969317
# [deAm] Heston EU price :: K=150.0 | T=1.6082191780821917 | p=166.2280427834304
# [deAm] Heston EU price :: K=155.0 | T=1.6082191780821917 | p=161.81673817222614
# [deAm] Heston EU price :: K=160.0 | T=1.6082191780821917 | p=157.4313666505455
# [deAm] Heston EU price :: K=170.0 | T=1.6082191780821917 | p=148.74509614105386
# [deAm] Heston EU price :: K=175.0 | T=1.6082191780821917 | p=144.44768927188252
# [deAm] Heston EU price :: K=180.0 | T=1.6082191780821917 | p=140.1831999472098
# [deAm] Heston EU price :: K=195.0 | T=1.6082191780821917 | p=127.6065581658976
# [deAm] Heston EU price :: K=200.0 | T=1.6082191780821917 | p=123.49336183319649
# [deAm] Heston EU price :: K=210.0 | T=1.6082191780821917 | p=115.39823820153917
# [deAm] Heston EU price :: K=220.0 | T=1.6082191780821917 | p=107.49300795539169
# [deAm] Heston EU price :: K=230.0 | T=1.6082191780821917 | p=99.79615272370515
# [deAm] Heston EU price :: K=240.0 | T=1.6082191780821917 | p=92.32673195470066
# [deAm] Heston EU price :: K=250.0 | T=1.6082191780821917 | p=85.10415725474716
# [deAm] Heston EU price :: K=255.0 | T=1.6082191780821917 | p=81.59152887638488
# [deAm] Heston EU price :: K=260.0 | T=1.6082191780821917 | p=78.1478988777311
# [deAm] Heston EU price :: K=265.0 | T=1.6082191780821917 | p=74.77564984983218
# [deAm] Heston EU price :: K=270.0 | T=1.6082191780821917 | p=71.47711783410409
# [deAm] Heston EU price :: K=275.0 | T=1.6082191780821917 | p=68.25457662865453
# [deAm] Heston EU price :: K=280.0 | T=1.6082191780821917 | p=65.11022099633314
# [deAm] Heston EU price :: K=285.0 | T=1.6082191780821917 | p=62.04614888866536
# [deAm] Heston EU price :: K=290.0 | T=1.6082191780821917 | p=59.06434284467071
# [deAm] Heston EU price :: K=295.0 | T=1.6082191780821917 | p=56.166650772266316
# [deAm] Heston EU price :: K=300.0 | T=1.6082191780821917 | p=53.354766371080444
# [deAm] Heston EU price :: K=305.0 | T=1.6082191780821917 | p=50.63020950709443
# [deAm] Heston EU price :: K=310.0 | T=1.6082191780821917 | p=47.99430689907515
# [deAm] Heston EU price :: K=315.0 | T=1.6082191780821917 | p=45.448173521228085
# [deAm] Heston EU price :: K=320.0 | T=1.6082191780821917 | p=42.99269516247771
# [deAm] Heston EU price :: K=330.0 | T=1.6082191780821917 | p=38.35600790590227
# [deAm] Heston EU price :: K=340.0 | T=1.6082191780821917 | p=34.086202576777474
# [deAm] Heston EU price :: K=350.0 | T=1.6082191780821917 | p=30.18081399466554
# [deAm] Heston EU price :: K=360.0 | T=1.6082191780821917 | p=26.632862418010852
# [deAm] Heston EU price :: K=370.0 | T=1.6082191780821917 | p=23.431003289384112
# [deAm] Heston EU price :: K=380.0 | T=1.6082191780821917 | p=20.559921182873268
# [deAm] Heston EU price :: K=390.0 | T=1.6082191780821917 | p=18.00093920183933
# [deAm] Heston EU price :: K=400.0 | T=1.6082191780821917 | p=15.732787189204572
# [deAm] Heston EU price :: K=410.0 | T=1.6082191780821917 | p=13.732454070178267
# [deAm] Heston EU price :: K=420.0 | T=1.6082191780821917 | p=11.976045164776377
# [deAm] Heston EU price :: K=430.0 | T=1.6082191780821917 | p=10.439574175634714
# [deAm] Heston EU price :: K=440.0 | T=1.6082191780821917 | p=9.099638086755862
# [deAm] Heston EU price :: K=450.0 | T=1.6082191780821917 | p=7.933945935736227
# [deAm] Heston EU price :: K=460.0 | T=1.6082191780821917 | p=6.921694108761377
# [deAm] Heston EU price :: K=470.0 | T=1.6082191780821917 | p=6.0437978602982705
# [deAm] Heston EU price :: K=105.0 | T=2.1095890410958904 | p=206.19458487004118
# [deAm] Heston EU price :: K=110.0 | T=2.1095890410958904 | p=201.75273500944033
# [deAm] Heston EU price :: K=115.0 | T=2.1095890410958904 | p=197.32906022910117
# [deAm] Heston EU price :: K=120.0 | T=2.1095890410958904 | p=192.92485922092072
# [deAm] Heston EU price :: K=125.0 | T=2.1095890410958904 | p=188.54146969960163
# [deAm] Heston EU price :: K=130.0 | T=2.1095890410958904 | p=184.18026777325858
# [deAm] Heston EU price :: K=135.0 | T=2.1095890410958904 | p=179.84266718383202
# [deAm] Heston EU price :: K=140.0 | T=2.1095890410958904 | p=175.53011840403764
# [deAm] Heston EU price :: K=145.0 | T=2.1095890410958904 | p=171.24410757718164
# [deAm] Heston EU price :: K=150.0 | T=2.1095890410958904 | p=166.98615528579631
# [deAm] Heston EU price :: K=155.0 | T=2.1095890410958904 | p=162.75781513471392
# [deAm] Heston EU price :: K=160.0 | T=2.1095890410958904 | p=158.560672133931
# [deAm] Heston EU price :: K=165.0 | T=2.1095890410958904 | p=154.3963408664342
# [deAm] Heston EU price :: K=170.0 | T=2.1095890410958904 | p=150.26646342609652
# [deAm] Heston EU price :: K=175.0 | T=2.1095890410958904 | p=146.17270711083486
# [deAm] Heston EU price :: K=180.0 | T=2.1095890410958904 | p=142.11676185647852
# [deAm] Heston EU price :: K=185.0 | T=2.1095890410958904 | p=138.10033739726737
# [deAm] Heston EU price :: K=190.0 | T=2.1095890410958904 | p=134.12516013961206
# [deAm] Heston EU price :: K=195.0 | T=2.1095890410958904 | p=130.19296973674983
# [deAm] Heston EU price :: K=200.0 | T=2.1095890410958904 | p=126.30551535325189
# [deAm] Heston EU price :: K=210.0 | T=2.1095890410958904 | p=118.67183420254037
# [deAm] Heston EU price :: K=220.0 | T=2.1095890410958904 | p=111.2381379366851
# [deAm] Heston EU price :: K=230.0 | T=2.1095890410958904 | p=104.01830619457088
# [deAm] Heston EU price :: K=240.0 | T=2.1095890410958904 | p=97.0258998347128
# [deAm] Heston EU price :: K=250.0 | T=2.1095890410958904 | p=90.27396384625648
# [deAm] Heston EU price :: K=260.0 | T=2.1095890410958904 | p=83.77481275183612
# [deAm] Heston EU price :: K=270.0 | T=2.1095890410958904 | p=77.53980248125171
# [deAm] Heston EU price :: K=280.0 | T=2.1095890410958904 | p=71.57909445687426
# [deAm] Heston EU price :: K=290.0 | T=2.1095890410958904 | p=65.90141947484935
# [deAm] Heston EU price :: K=300.0 | T=2.1095890410958904 | p=60.513850719732325
# [deAm] Heston EU price :: K=310.0 | T=2.1095890410958904 | p=55.421596688734056
# [deAm] Heston EU price :: K=320.0 | T=2.1095890410958904 | p=50.62782566289661
# [deAm] Heston EU price :: K=330.0 | T=2.1095890410958904 | p=46.133533381327446
# [deAm] Heston EU price :: K=340.0 | T=2.1095890410958904 | p=41.93746453348968
# [deAm] Heston EU price :: K=350.0 | T=2.1095890410958904 | p=38.036096471561514
# [deAm] Heston EU price :: K=360.0 | T=2.1095890410958904 | p=34.42369020714985
# [deAm] Heston EU price :: K=370.0 | T=2.1095890410958904 | p=31.092409531497093
# [deAm] Heston EU price :: K=380.0 | T=2.1095890410958904 | p=28.032504406140426
# [deAm] Heston EU price :: K=390.0 | T=2.1095890410958904 | p=25.232550161918805
# [deAm] Heston EU price :: K=400.0 | T=2.1095890410958904 | p=22.67973010457972
# [deAm] Heston EU price :: K=410.0 | T=2.1095890410958904 | p=20.360146364296195
# [deAm] Heston EU price :: K=420.0 | T=2.1095890410958904 | p=18.259142573815147
# [deAm] Heston EU price :: K=430.0 | T=2.1095890410958904 | p=16.361622302942454
# [deAm] Heston EU price :: K=440.0 | T=2.1095890410958904 | p=14.65234895468129
# [deAm] Heston EU price :: K=470.0 | T=2.1095890410958904 | p=10.5049400982497
# [deAm] Heston EU price :: K=155.0 | T=2.2054794520547945 | p=162.9348608699914
# [deAm] Heston EU price :: K=160.0 | T=2.2054794520547945 | p=158.77252235262193
# [deAm] Heston EU price :: K=170.0 | T=2.2054794520547945 | p=150.55031451667088
# [deAm] Heston EU price :: K=175.0 | T=2.2054794520547945 | p=146.49369137711713
# [deAm] Heston EU price :: K=180.0 | T=2.2054794520547945 | p=142.4755814416899
# [deAm] Heston EU price :: K=185.0 | T=2.2054794520547945 | p=138.4976462225483
# [deAm] Heston EU price :: K=190.0 | T=2.2054794520547945 | p=134.56155693755795
# [deAm] Heston EU price :: K=200.0 | T=2.2054794520547945 | p=126.82162802048954
# [deAm] Heston EU price :: K=210.0 | T=2.2054794520547945 | p=119.26921707232889
# [deAm] Heston EU price :: K=220.0 | T=2.2054794520547945 | p=111.91764684777554
# [deAm] Heston EU price :: K=230.0 | T=2.2054794520547945 | p=104.77998837167691
# [deAm] Heston EU price :: K=240.0 | T=2.2054794520547945 | p=97.86889252821247
# [deAm] Heston EU price :: K=250.0 | T=2.2054794520547945 | p=91.19640709168223
# [deAm] Heston EU price :: K=260.0 | T=2.2054794520547945 | p=84.77378207431632
# [deAm] Heston EU price :: K=270.0 | T=2.2054794520547945 | p=78.6112675346757
# [deAm] Heston EU price :: K=280.0 | T=2.2054794520547945 | p=72.71790933380649
# [deAm] Heston EU price :: K=290.0 | T=2.2054794520547945 | p=67.10134964243868
# [deAm] Heston EU price :: K=300.0 | T=2.2054794520547945 | p=61.76764015279227
# [deAm] Heston EU price :: K=310.0 | T=2.2054794520547945 | p=56.721076766741604
# [deAm] Heston EU price :: K=320.0 | T=2.2054794520547945 | p=51.96406484090619
# [deAm] Heston EU price :: K=330.0 | T=2.2054794520547945 | p=47.49702370643909
# [deAm] Heston EU price :: K=340.0 | T=2.2054794520547945 | p=43.31833803288185
# [deAm] Heston EU price :: K=350.0 | T=2.2054794520547945 | p=39.42436164021684
# [deAm] Heston EU price :: K=360.0 | T=2.2054794520547945 | p=35.80947666023173
# [deAm] Heston EU price :: K=370.0 | T=2.2054794520547945 | p=32.46620770775262
# [deAm] Heston EU price :: K=380.0 | T=2.2054794520547945 | p=29.38538725250742
# [deAm] Heston EU price :: K=390.0 | T=2.2054794520547945 | p=26.556365060305346
# [deAm] Heston EU price :: K=400.0 | T=2.2054794520547945 | p=23.96725178328258
# [deAm] Heston EU price :: K=410.0 | T=2.2054794520547945 | p=21.605184848761567
# [deAm] Heston EU price :: K=430.0 | T=2.2054794520547945 | p=17.50752354162736
# [deAm] Heston EU price :: K=440.0 | T=2.2054794520547945 | p=15.743791535629956
# [deAm] Heston EU price :: K=450.0 | T=2.2054794520547945 | p=14.151324371723897
# [deAm] Heston EU price :: K=460.0 | T=2.2054794520547945 | p=12.716312472986308
# [deAm] Heston EU price :: K=470.0 | T=2.2054794520547945 | p=11.425391691151011
# [deAm] group priced :: group=('JPM',)
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251128P00220000 2025-10-17 14:28:32+00:00   220.0       0.39   0.00
# 1     JPM251128P00240000 2025-10-17 19:24:44+00:00   240.0       0.60   0.00
# 2     JPM251128P00245000 2025-10-27 19:48:25+00:00   245.0       0.29   0.00
# 3     JPM251128P00250000 2025-10-24 15:22:43+00:00   250.0       0.48   0.00
# 4     JPM251128P00255000 2025-10-28 19:46:32+00:00   255.0       0.41   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM280121C00430000 2025-10-21 19:58:31+00:00   430.0       9.85  13.70
# 1571  JPM280121C00440000 2025-10-31 16:59:23+00:00   440.0      11.60  10.65
# 1572  JPM280121C00450000 2025-10-30 17:44:38+00:00   450.0       9.90  11.00
# 1573  JPM280121C00460000 2025-10-22 16:30:37+00:00   460.0       6.03   9.95
# 1574  JPM280121C00470000 2025-11-07 20:05:53+00:00   470.0       9.20   8.90
#
#         ask  change  percentChange  volume  openInterest  ...  expiration  \
# 0      2.14    0.00       0.000000     3.0             2  ...  2025-11-28
# 1      2.17    0.00       0.000000    10.0            11  ...  2025-11-28
# 2      2.06    0.00       0.000000    10.0            82  ...  2025-11-28
# 3      2.22    0.00       0.000000     2.0             3  ...  2025-11-28
# 4      1.32    0.00       0.000000    27.0            66  ...  2025-11-28
# ...     ...     ...            ...     ...           ...  ...         ...
# 1570  15.10    0.00       0.000000     1.0             2  ...  2028-01-21
# 1571  14.45    0.00       0.000000     4.0            14  ...  2028-01-21
# 1572  12.90    0.00       0.000000     4.0            17  ...  2028-01-21
# 1573  11.55    0.00       0.000000     2.0             6  ...  2028-01-21
# 1574  10.35    0.48       5.504582    20.0           123  ...  2028-01-21
#
#            TTM dividendYield ticker  spot_price optionType     r  \
# 0     0.057534        0.0191    JPM  314.209991        put  0.04
# 1     0.057534        0.0191    JPM  314.209991        put  0.04
# 2     0.057534        0.0191    JPM  314.209991        put  0.04
# 3     0.057534        0.0191    JPM  314.209991        put  0.04
# 4     0.057534        0.0191    JPM  314.209991        put  0.04
# ...        ...           ...    ...         ...        ...   ...
# 1570  2.205479        0.0191    JPM  314.209991       call  0.04
# 1571  2.205479        0.0191    JPM  314.209991       call  0.04
# 1572  2.205479        0.0191    JPM  314.209991       call  0.04
# 1573  2.205479        0.0191    JPM  314.209991       call  0.04
# 1574  2.205479        0.0191    JPM  314.209991       call  0.04
#
#       forward_log_moneyness midPrice  V_EU_Heston
# 0                 -0.357636    1.070     0.026537
# 1                 -0.270625    1.085     0.088794
# 2                 -0.250006    1.030     0.118372
# 3                 -0.229803    1.110     0.157003
# 4                 -0.210000    0.660     0.207268
# ...                     ...      ...          ...
# 1570               0.267629   14.400    17.507524
# 1571               0.290619   12.550    15.743792
# 1572               0.313092   11.950    14.151324
# 1573               0.335070   10.750    12.716312
# 1574               0.356577    9.625    11.425392
#
# [1575 rows x 25 columns]

# %%
df.describe()
# Out:
#             strike    lastPrice          bid          ask       change  \
# count  1575.000000  1575.000000  1575.000000  1575.000000  1575.000000
# mean    262.500000    37.428844    37.450444    39.068203    -0.022857
# std      87.490288    51.703350    53.208820    54.254441     1.104338
# min      65.000000     0.010000     0.000000     0.000000   -11.660000
# 25%     190.000000     1.285000     0.920000     1.965000     0.000000
# 50%     270.000000    10.950000    10.450000    11.550000     0.000000
# 75%     321.250000    54.325000    52.700000    54.750000     0.000000
# max     470.000000   240.200000   242.750000   246.100000    13.110001
#
#        percentChange       volume  openInterest  impliedVolatility  \
# count    1575.000000  1575.000000   1575.000000        1575.000000
# mean        9.457881    56.989206    488.363175           0.469281
# std       182.361424   290.838084    969.676568           0.480324
# min       -98.461540     1.000000      0.000000           0.000010
# 25%         0.000000     2.000000     20.000000           0.259910
# 50%         0.000000     5.000000    102.000000           0.329841
# 75%         0.000000    22.000000    488.000000           0.488958
# max      4800.004400  6744.000000   8789.000000           6.646486
#
#                TTM  dividendYield   spot_price             r  \
# count  1575.000000   1.575000e+03  1575.000000  1.575000e+03
# mean      0.627869   1.910000e-02   314.209991  4.000000e-02
# std       0.654474   3.470549e-18     0.000000  6.941098e-18
# min       0.000000   1.910000e-02   314.209991  4.000000e-02
# 25%       0.115068   1.910000e-02   314.209991  4.000000e-02
# 50%       0.364384   1.910000e-02   314.209991  4.000000e-02
# 75%       0.987671   1.910000e-02   314.209991  4.000000e-02
# max       2.205479   1.910000e-02   314.209991  4.000000e-02
#
#        forward_log_moneyness     midPrice   V_EU_Heston
# count            1575.000000  1575.000000  1.575000e+03
# mean               -0.257373    38.259324  3.892001e+01
# std                 0.377912    53.730146  5.576793e+01
# min                -1.578079     0.000000 -5.041858e-12
# 25%                -0.510663     1.172500  1.195223e+00
# 50%                -0.161366    10.775000  1.050494e+01
# 75%                 0.017458    53.725000  5.426174e+01
# max                 0.384634   244.425000  2.488187e+02

# %%
df.columns
# Out:
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        'impliedVolatility', 'inTheMoney', 'contractSize', 'currency',
#        'option_type', 'expiration', 'TTM', 'dividendYield', 'ticker',
#        'spot_price', 'optionType', 'r', 'forward_log_moneyness', 'midPrice',
#        'V_EU_Heston'],
#       dtype='object')
