# %% [markdown]
# **Imports**

# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
from typing import Tuple
from concurrent.futures import ThreadPoolExecutor, as_completed
import numpy as np
import math
import QuantLib as ql

# %% [markdown]
# **Define price fetcher**

# %%
def get_spot_price(ticker):
    """
    Fetches the current spot price for a stock ticker. Falls back to the most recent
    close if a live price is not available.

    Parameters
    ----------
    ticker : str
        Stock ticker symbol (e.g., 'AAPL').

    Returns
    -------
    float or None
        Spot price (live if available, else last close). Returns None if unavailable.
    """

    try:
        tk = yf.Ticker(ticker)
        
        # Attempt to fetch live price
        live_price = tk.fast_info.get("last_price", None)
        if live_price and live_price > 0:
            return live_price

        # Fallback: most recent close
        hist = tk.history(period="1d")
        if not hist.empty:
            fallback_price = hist["Close"].iloc[-1]
            print(f"[{ticker}] Live price unavailable — using last close: {fallback_price:.2f}")
            return fallback_price

        print(f"[{ticker}] No live or historical data available.")
        return None

    except Exception as e:
        print(f"[{ticker}] Spot price fetch failed: {e}")
        return None

# %% [markdown]
# **Define Option Chain Fetcher**

# %%
def get_option_chains_all(ticker: str,
                                  max_workers: int = 8) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Fetches option chains (calls and puts) for every available expiry of a given ticker,
    performing API requests in parallel to reduce total fetch time.

    Parameters
    ----------
    ticker : str
        Stock ticker symbol (e.g., 'AAPL').
    max_workers : int, optional
        Maximum number of threads to use for concurrent fetching (default is 8).

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        - calls_df: DataFrame containing all calls across expiries, with added columns:
            * 'option_type' = 'call'
            * 'expiration'  = expiry date string 'YYYY-MM-DD'
            * 'TTM'         = time to maturity in years
        - puts_df: DataFrame containing all puts with the same added columns.
    """
    stock = yf.Ticker(ticker)
    expiries = stock.options  # list of expiry date strings
    today = datetime.now().date()

    calls_accum = []
    puts_accum  = []

    def fetch_chain(expiry: str):
        """Fetch calls/puts for a single expiry and return (expiry, calls_df, puts_df)."""
        try:
            chain = stock.option_chain(expiry)
            calls = chain.calls.copy()
            puts  = chain.puts.copy()
        except Exception as e:
            # Return None on error so we can skip later
            return expiry, None, None

        # Tag each row with type and expiration
        calls['option_type']  = 'call'
        puts ['option_type']  = 'put'
        calls['expiration']   = expiry
        puts ['expiration']   = expiry

        # Compute time-to-maturity once
        exp_date = datetime.strptime(expiry, "%Y-%m-%d").date()
        ttm = max((exp_date - today).days / 365.0, 0.0)
        calls['TTM'] = ttm
        puts ['TTM'] = ttm

        return expiry, calls, puts

    # Fetch in parallel
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(fetch_chain, exp) for exp in expiries]
        for future in as_completed(futures):
            expiry, calls_df, puts_df = future.result()
            if calls_df is not None and not calls_df.empty:
                calls_accum.append(calls_df)
            if puts_df  is not None and not puts_df.empty:
                puts_accum.append(puts_df)

    # Concatenate results
    all_calls = pd.concat(calls_accum, ignore_index=True) if calls_accum else pd.DataFrame()
    all_puts  = pd.concat(puts_accum,  ignore_index=True) if puts_accum  else pd.DataFrame()

    # Fetch dividend yield for the company
    dividendYield = stock.info.get("dividendYield")/100 # percentages on decimal basis
    all_calls["dividendYield"] = dividendYield
    all_puts["dividendYield"] = dividendYield

    all_calls["ticker"] = ticker
    all_puts["ticker"] = ticker

    spot_price = get_spot_price(ticker)
    all_calls["spot_price"] = spot_price
    all_puts["spot_price"] = spot_price

    return all_calls, all_puts

# %% [markdown]
# Get option chain and dividend yield

# %%
calls, puts = get_option_chains_all("JPM")
# Out:
# [JPM] Live price unavailable — using last close: 314.21

# %%
calls
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    JPM251114C00160000 2025-10-30 13:50:42+00:00   160.0     150.00  152.30
# 1    JPM251114C00205000 2025-10-22 16:30:41+00:00   205.0      87.50  107.40
# 2    JPM251114C00225000 2025-10-22 16:30:50+00:00   225.0      67.05   87.40
# 3    JPM251114C00240000 2025-10-22 16:30:45+00:00   240.0      52.75   72.40
# 4    JPM251114C00245000 2025-10-22 16:30:51+00:00   245.0      47.40   67.45
# ..                  ...                       ...     ...        ...     ...
# 879  JPM271217C00430000 2025-10-29 17:11:50+00:00   430.0      10.75   13.05
# 880  JPM271217C00440000 2025-11-07 19:50:17+00:00   440.0      12.15   11.10
# 881  JPM271217C00450000 2025-10-28 13:38:06+00:00   450.0       8.33   10.45
# 882  JPM271217C00460000 2025-10-09 16:57:09+00:00   460.0       7.50    7.00
# 883  JPM271217C00470000 2025-10-31 16:57:42+00:00   470.0       7.25    6.00
#
#         ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0    156.15  0.000000       0.000000     2.0             4           1.484378
# 1    110.85  0.000000       0.000000     NaN             1           1.820802
# 2     90.95  0.000000       0.000000     NaN             1           1.506350
# 3     75.65  0.000000       0.000000     NaN             2           1.212895
# 4     70.00  0.000000       0.000000     NaN             2           1.000982
# ..      ...       ...            ...     ...           ...                ...
# 879   14.45  0.000000       0.000000     2.0             8           0.251671
# 880   12.55  2.259999      22.851357    10.0           125           0.248192
# 881   11.50  0.000000       0.000000     NaN             1           0.249809
# 882   10.90  0.000000       0.000000     NaN             2           0.254173
# 883    9.85  0.000000       0.000000     2.0            11           0.254295
#
#      inTheMoney contractSize currency option_type  expiration       TTM  \
# 0          True      REGULAR      USD        call  2025-11-14  0.019178
# 1          True      REGULAR      USD        call  2025-11-14  0.019178
# 2          True      REGULAR      USD        call  2025-11-14  0.019178
# 3          True      REGULAR      USD        call  2025-11-14  0.019178
# 4          True      REGULAR      USD        call  2025-11-14  0.019178
# ..          ...          ...      ...         ...         ...       ...
# 879       False      REGULAR      USD        call  2027-12-17  2.109589
# 880       False      REGULAR      USD        call  2027-12-17  2.109589
# 881       False      REGULAR      USD        call  2027-12-17  2.109589
# 882       False      REGULAR      USD        call  2027-12-17  2.109589
# 883       False      REGULAR      USD        call  2027-12-17  2.109589
#
#      dividendYield ticker  spot_price
# 0           0.0191    JPM  314.209991
# 1           0.0191    JPM  314.209991
# 2           0.0191    JPM  314.209991
# 3           0.0191    JPM  314.209991
# 4           0.0191    JPM  314.209991
# ..             ...    ...         ...
# 879         0.0191    JPM  314.209991
# 880         0.0191    JPM  314.209991
# 881         0.0191    JPM  314.209991
# 882         0.0191    JPM  314.209991
# 883         0.0191    JPM  314.209991
#
# [884 rows x 20 columns]

# %%
puts
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    JPM251114P00160000 2025-10-27 13:46:23+00:00   160.0       0.01    0.00
# 1    JPM251114P00170000 2025-10-22 19:01:42+00:00   170.0       0.04    0.00
# 2    JPM251114P00180000 2025-11-07 18:01:01+00:00   180.0       0.04    0.00
# 3    JPM251114P00190000 2025-10-21 18:52:08+00:00   190.0       0.03    0.00
# 4    JPM251114P00195000 2025-10-06 17:31:40+00:00   195.0       0.24    0.00
# ..                  ...                       ...     ...        ...     ...
# 778  JPM271217P00370000 2025-10-21 18:48:09+00:00   370.0      80.30   69.00
# 779  JPM271217P00390000 2025-08-07 18:50:02+00:00   390.0     103.85   96.55
# 780  JPM271217P00400000 2025-09-05 17:33:06+00:00   400.0     107.07   94.00
# 781  JPM271217P00410000 2025-09-29 16:41:08+00:00   410.0      99.90   99.00
# 782  JPM271217P00450000 2025-10-13 18:21:13+00:00   450.0     142.04  134.50
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0      0.23     0.0        0.00000     5.0             6           1.812501
# 1      2.13     0.0        0.00000     NaN             2           2.286625
# 2      0.13    -0.1      -71.42857     1.0             1           1.425784
# 3      2.12     0.0        0.00000     NaN             4           1.919434
# 4      2.12     0.0        0.00000     NaN             1           1.833985
# ..      ...     ...            ...     ...           ...                ...
# 778   74.00     0.0        0.00000     8.0            31           0.203591
# 779  100.00     0.0        0.00000     NaN             2           0.266716
# 780   97.80     0.0        0.00000     1.0             7           0.202889
# 781  103.00     0.0        0.00000     3.0             2           0.178002
# 782  138.50     0.0        0.00000     NaN             0           0.167214
#
#      inTheMoney contractSize currency option_type  expiration       TTM  \
# 0         False      REGULAR      USD         put  2025-11-14  0.019178
# 1         False      REGULAR      USD         put  2025-11-14  0.019178
# 2         False      REGULAR      USD         put  2025-11-14  0.019178
# 3         False      REGULAR      USD         put  2025-11-14  0.019178
# 4         False      REGULAR      USD         put  2025-11-14  0.019178
# ..          ...          ...      ...         ...         ...       ...
# 778        True      REGULAR      USD         put  2027-12-17  2.109589
# 779        True      REGULAR      USD         put  2027-12-17  2.109589
# 780        True      REGULAR      USD         put  2027-12-17  2.109589
# 781        True      REGULAR      USD         put  2027-12-17  2.109589
# 782        True      REGULAR      USD         put  2027-12-17  2.109589
#
#      dividendYield ticker  spot_price
# 0           0.0191    JPM  314.209991
# 1           0.0191    JPM  314.209991
# 2           0.0191    JPM  314.209991
# 3           0.0191    JPM  314.209991
# 4           0.0191    JPM  314.209991
# ..             ...    ...         ...
# 778         0.0191    JPM  314.209991
# 779         0.0191    JPM  314.209991
# 780         0.0191    JPM  314.209991
# 781         0.0191    JPM  314.209991
# 782         0.0191    JPM  314.209991
#
# [783 rows x 20 columns]

# %%
calls.describe()
# Out:
#            strike   lastPrice         bid         ask      change  \
# count  884.000000  884.000000  884.000000  884.000000  884.000000
# mean   279.736991   59.886765   61.534706   63.706968    0.009514
# std     94.121347   59.276993   61.384402   62.465660    1.283287
# min     65.000000    0.010000    0.000000    0.000000   -5.450005
# 25%    200.000000    7.097500    6.487500    7.737500    0.000000
# 50%    287.500000   38.625000   38.475000   40.750000    0.000000
# 75%    350.000000  107.340000  111.487500  114.225000    0.000000
# max    470.000000  240.200000  242.750000  246.100000   13.110001
#
#        percentChange       volume  openInterest  impliedVolatility  \
# count     884.000000   837.000000    884.000000         884.000000
# mean        1.305206    65.540024    436.348416           0.433174
# std        34.770268   362.538300    993.660580           0.387665
# min       -98.461540     1.000000      0.000000           0.000010
# 25%         0.000000     2.000000     12.000000           0.259918
# 50%         0.000000     4.000000     72.000000           0.327292
# 75%         0.000000    20.000000    349.750000           0.482732
# max       800.000240  6744.000000   8789.000000           6.646486
#
#               TTM  dividendYield  spot_price
# count  884.000000       884.0000  884.000000
# mean     0.635917         0.0191  314.209991
# std      0.652016         0.0000    0.000000
# min      0.000000         0.0191  314.209991
# 25%      0.115068         0.0191  314.209991
# 50%      0.364384         0.0191  314.209991
# 75%      1.112329         0.0191  314.209991
# max      2.205479         0.0191  314.209991

# %% [markdown]
# Initial Dataset Clean

# %%
def initial_dataset_clean(dataset : pd.DataFrame):
    # Removing columns that will not be used for training or filtering
    #cols_to_drop = ["contractSymbol", "lastTradeDate", "change", "percentChange", "expiration", "inTheMoney"]
    #dataset.drop(columns=[c for c in cols_to_drop if c in dataset.columns], inplace=True)

    # Removing NA values for stale options
    dataset.dropna(axis=0,subset=["volume"], inplace=True)

    
    return dataset

# %%
calls_clean = initial_dataset_clean(calls)
calls_clean
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    JPM251114C00160000 2025-10-30 13:50:42+00:00   160.0     150.00  152.30
# 7    JPM251114C00270000 2025-11-06 15:14:00+00:00   270.0      41.50   42.50
# 8    JPM251114C00275000 2025-11-03 18:55:24+00:00   275.0      35.64   37.50
# 9    JPM251114C00280000 2025-11-03 18:55:24+00:00   280.0      30.71   32.55
# 11   JPM251114C00285000 2025-10-30 13:50:20+00:00   285.0      24.90   27.60
# ..                  ...                       ...     ...        ...     ...
# 877  JPM271217C00410000 2025-11-07 18:46:59+00:00   410.0      17.10   16.25
# 878  JPM271217C00420000 2025-10-29 18:58:44+00:00   420.0      12.40   15.40
# 879  JPM271217C00430000 2025-10-29 17:11:50+00:00   430.0      10.75   13.05
# 880  JPM271217C00440000 2025-11-07 19:50:17+00:00   440.0      12.15   11.10
# 883  JPM271217C00470000 2025-10-31 16:57:42+00:00   470.0       7.25    6.00
#
#         ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0    156.15  0.000000       0.000000     2.0             4           1.484378
# 7     45.30  0.000000       0.000000     5.0             6           0.721194
# 8     39.85  0.000000       0.000000    10.0            21           0.576909
# 9     35.25  0.000000       0.000000    10.0            25           0.577397
# 11    30.10  0.000000       0.000000     1.0             6           0.489019
# ..      ...       ...            ...     ...           ...                ...
# 877   18.30  1.600000      10.322582    10.0           120           0.255188
# 878   16.25  0.000000       0.000000     1.0            40           0.253212
# 879   14.45  0.000000       0.000000     2.0             8           0.251671
# 880   12.55  2.259999      22.851357    10.0           125           0.248192
# 883    9.85  0.000000       0.000000     2.0            11           0.254295
#
#      inTheMoney contractSize currency option_type  expiration       TTM  \
# 0          True      REGULAR      USD        call  2025-11-14  0.019178
# 7          True      REGULAR      USD        call  2025-11-14  0.019178
# 8          True      REGULAR      USD        call  2025-11-14  0.019178
# 9          True      REGULAR      USD        call  2025-11-14  0.019178
# 11         True      REGULAR      USD        call  2025-11-14  0.019178
# ..          ...          ...      ...         ...         ...       ...
# 877       False      REGULAR      USD        call  2027-12-17  2.109589
# 878       False      REGULAR      USD        call  2027-12-17  2.109589
# 879       False      REGULAR      USD        call  2027-12-17  2.109589
# 880       False      REGULAR      USD        call  2027-12-17  2.109589
# 883       False      REGULAR      USD        call  2027-12-17  2.109589
#
#      dividendYield ticker  spot_price
# 0           0.0191    JPM  314.209991
# 7           0.0191    JPM  314.209991
# 8           0.0191    JPM  314.209991
# 9           0.0191    JPM  314.209991
# 11          0.0191    JPM  314.209991
# ..             ...    ...         ...
# 877         0.0191    JPM  314.209991
# 878         0.0191    JPM  314.209991
# 879         0.0191    JPM  314.209991
# 880         0.0191    JPM  314.209991
# 883         0.0191    JPM  314.209991
#
# [837 rows x 20 columns]

# %%
calls_clean.describe()
# Out:
#            strike   lastPrice         bid         ask      change  \
# count  837.000000  837.000000  837.000000  837.000000  837.000000
# mean   280.400239   59.668220   61.124504   63.278292    0.010048
# std     93.288559   59.706082   61.695467   62.784608    1.318865
# min     65.000000    0.010000    0.000000    0.000000   -5.450005
# 25%    205.000000    7.000000    6.500000    7.800000    0.000000
# 50%    290.000000   37.330000   37.250000   39.700000    0.000000
# 75%    350.000000  107.010000  110.550000  113.300000    0.000000
# max    470.000000  240.200000  242.750000  246.100000   13.110001
#
#        percentChange       volume  openInterest  impliedVolatility  \
# count     837.000000   837.000000    837.000000         837.000000
# mean        1.378497    65.540024    460.659498           0.428916
# std        35.732882   362.538300   1015.745730           0.388136
# min       -98.461540     1.000000      0.000000           0.000010
# 25%         0.000000     2.000000     18.000000           0.259926
# 50%         0.000000     4.000000     82.000000           0.323218
# 75%         0.000000    20.000000    384.000000           0.468999
# max       800.000240  6744.000000   8789.000000           6.646486
#
#               TTM  dividendYield  spot_price
# count  837.000000   8.370000e+02  837.000000
# mean     0.644006   1.910000e-02  314.209991
# std      0.653501   3.471521e-18    0.000000
# min      0.000000   1.910000e-02  314.209991
# 25%      0.115068   1.910000e-02  314.209991
# 50%      0.364384   1.910000e-02  314.209991
# 75%      1.112329   1.910000e-02  314.209991
# max      2.205479   1.910000e-02  314.209991

# %%
puts_clean = initial_dataset_clean(puts)
puts_clean
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    JPM251114P00160000 2025-10-27 13:46:23+00:00   160.0       0.01   0.00
# 2    JPM251114P00180000 2025-11-07 18:01:01+00:00   180.0       0.04   0.00
# 5    JPM251114P00200000 2025-10-31 14:42:36+00:00   200.0       0.05   0.00
# 6    JPM251114P00210000 2025-10-14 14:27:52+00:00   210.0       1.12   0.00
# 7    JPM251114P00215000 2025-10-31 14:52:31+00:00   215.0       0.08   0.00
# ..                  ...                       ...     ...        ...    ...
# 776  JPM271217P00350000 2025-10-21 18:49:29+00:00   350.0      66.55  57.70
# 777  JPM271217P00360000 2025-10-21 18:48:14+00:00   360.0      73.20  64.15
# 778  JPM271217P00370000 2025-10-21 18:48:09+00:00   370.0      80.30  69.00
# 780  JPM271217P00400000 2025-09-05 17:33:06+00:00   400.0     107.07  94.00
# 781  JPM271217P00410000 2025-09-29 16:41:08+00:00   410.0      99.90  99.00
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0      0.23     0.0        0.00000     5.0             6           1.812501
# 2      0.13    -0.1      -71.42857     1.0             1           1.425784
# 5      2.12     0.0        0.00000     2.0             4           1.750001
# 6      1.76     0.0        0.00000     1.0             2           1.532717
# 7      0.05     0.0        0.00000     5.0            15           0.906251
# ..      ...     ...            ...     ...           ...                ...
# 776   60.55     0.0        0.00000    20.0            39           0.209763
# 777   67.10     0.0        0.00000     8.0            21           0.206642
# 778   74.00     0.0        0.00000     8.0            31           0.203591
# 780   97.80     0.0        0.00000     1.0             7           0.202889
# 781  103.00     0.0        0.00000     3.0             2           0.178002
#
#      inTheMoney contractSize currency option_type  expiration       TTM  \
# 0         False      REGULAR      USD         put  2025-11-14  0.019178
# 2         False      REGULAR      USD         put  2025-11-14  0.019178
# 5         False      REGULAR      USD         put  2025-11-14  0.019178
# 6         False      REGULAR      USD         put  2025-11-14  0.019178
# 7         False      REGULAR      USD         put  2025-11-14  0.019178
# ..          ...          ...      ...         ...         ...       ...
# 776        True      REGULAR      USD         put  2027-12-17  2.109589
# 777        True      REGULAR      USD         put  2027-12-17  2.109589
# 778        True      REGULAR      USD         put  2027-12-17  2.109589
# 780        True      REGULAR      USD         put  2027-12-17  2.109589
# 781        True      REGULAR      USD         put  2027-12-17  2.109589
#
#      dividendYield ticker  spot_price
# 0           0.0191    JPM  314.209991
# 2           0.0191    JPM  314.209991
# 5           0.0191    JPM  314.209991
# 6           0.0191    JPM  314.209991
# 7           0.0191    JPM  314.209991
# ..             ...    ...         ...
# 776         0.0191    JPM  314.209991
# 777         0.0191    JPM  314.209991
# 778         0.0191    JPM  314.209991
# 780         0.0191    JPM  314.209991
# 781         0.0191    JPM  314.209991
#
# [738 rows x 20 columns]

# %% [markdown]
# **Join Calls and Puts**

# %%
df = pd.concat([puts_clean, calls_clean], ignore_index=True)
df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251114P00160000 2025-10-27 13:46:23+00:00   160.0       0.01   0.00
# 1     JPM251114P00180000 2025-11-07 18:01:01+00:00   180.0       0.04   0.00
# 2     JPM251114P00200000 2025-10-31 14:42:36+00:00   200.0       0.05   0.00
# 3     JPM251114P00210000 2025-10-14 14:27:52+00:00   210.0       1.12   0.00
# 4     JPM251114P00215000 2025-10-31 14:52:31+00:00   215.0       0.08   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM271217C00410000 2025-11-07 18:46:59+00:00   410.0      17.10  16.25
# 1571  JPM271217C00420000 2025-10-29 18:58:44+00:00   420.0      12.40  15.40
# 1572  JPM271217C00430000 2025-10-29 17:11:50+00:00   430.0      10.75  13.05
# 1573  JPM271217C00440000 2025-11-07 19:50:17+00:00   440.0      12.15  11.10
# 1574  JPM271217C00470000 2025-10-31 16:57:42+00:00   470.0       7.25   6.00
#
#         ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0      0.23  0.000000       0.000000     5.0             6           1.812501
# 1      0.13 -0.100000     -71.428570     1.0             1           1.425784
# 2      2.12  0.000000       0.000000     2.0             4           1.750001
# 3      1.76  0.000000       0.000000     1.0             2           1.532717
# 4      0.05  0.000000       0.000000     5.0            15           0.906251
# ...     ...       ...            ...     ...           ...                ...
# 1570  18.30  1.600000      10.322582    10.0           120           0.255188
# 1571  16.25  0.000000       0.000000     1.0            40           0.253212
# 1572  14.45  0.000000       0.000000     2.0             8           0.251671
# 1573  12.55  2.259999      22.851357    10.0           125           0.248192
# 1574   9.85  0.000000       0.000000     2.0            11           0.254295
#
#       inTheMoney contractSize currency option_type  expiration       TTM  \
# 0          False      REGULAR      USD         put  2025-11-14  0.019178
# 1          False      REGULAR      USD         put  2025-11-14  0.019178
# 2          False      REGULAR      USD         put  2025-11-14  0.019178
# 3          False      REGULAR      USD         put  2025-11-14  0.019178
# 4          False      REGULAR      USD         put  2025-11-14  0.019178
# ...          ...          ...      ...         ...         ...       ...
# 1570       False      REGULAR      USD        call  2027-12-17  2.109589
# 1571       False      REGULAR      USD        call  2027-12-17  2.109589
# 1572       False      REGULAR      USD        call  2027-12-17  2.109589
# 1573       False      REGULAR      USD        call  2027-12-17  2.109589
# 1574       False      REGULAR      USD        call  2027-12-17  2.109589
#
#       dividendYield ticker  spot_price
# 0            0.0191    JPM  314.209991
# 1            0.0191    JPM  314.209991
# 2            0.0191    JPM  314.209991
# 3            0.0191    JPM  314.209991
# 4            0.0191    JPM  314.209991
# ...             ...    ...         ...
# 1570         0.0191    JPM  314.209991
# 1571         0.0191    JPM  314.209991
# 1572         0.0191    JPM  314.209991
# 1573         0.0191    JPM  314.209991
# 1574         0.0191    JPM  314.209991
#
# [1575 rows x 20 columns]

# %%
def optionType(OPTtype):
    # Puts are type 1
    if OPTtype == "put":
        return "put"
    else:
    # Calls are type 0
        return "call"

# %%
df["optionType"] = df["option_type"].apply(optionType)
#df.drop(columns="option_type", inplace=True)
df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251114P00160000 2025-10-27 13:46:23+00:00   160.0       0.01   0.00
# 1     JPM251114P00180000 2025-11-07 18:01:01+00:00   180.0       0.04   0.00
# 2     JPM251114P00200000 2025-10-31 14:42:36+00:00   200.0       0.05   0.00
# 3     JPM251114P00210000 2025-10-14 14:27:52+00:00   210.0       1.12   0.00
# 4     JPM251114P00215000 2025-10-31 14:52:31+00:00   215.0       0.08   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM271217C00410000 2025-11-07 18:46:59+00:00   410.0      17.10  16.25
# 1571  JPM271217C00420000 2025-10-29 18:58:44+00:00   420.0      12.40  15.40
# 1572  JPM271217C00430000 2025-10-29 17:11:50+00:00   430.0      10.75  13.05
# 1573  JPM271217C00440000 2025-11-07 19:50:17+00:00   440.0      12.15  11.10
# 1574  JPM271217C00470000 2025-10-31 16:57:42+00:00   470.0       7.25   6.00
#
#         ask    change  percentChange  volume  openInterest  ...  inTheMoney  \
# 0      0.23  0.000000       0.000000     5.0             6  ...       False
# 1      0.13 -0.100000     -71.428570     1.0             1  ...       False
# 2      2.12  0.000000       0.000000     2.0             4  ...       False
# 3      1.76  0.000000       0.000000     1.0             2  ...       False
# 4      0.05  0.000000       0.000000     5.0            15  ...       False
# ...     ...       ...            ...     ...           ...  ...         ...
# 1570  18.30  1.600000      10.322582    10.0           120  ...       False
# 1571  16.25  0.000000       0.000000     1.0            40  ...       False
# 1572  14.45  0.000000       0.000000     2.0             8  ...       False
# 1573  12.55  2.259999      22.851357    10.0           125  ...       False
# 1574   9.85  0.000000       0.000000     2.0            11  ...       False
#
#       contractSize currency option_type  expiration       TTM  dividendYield  \
# 0          REGULAR      USD         put  2025-11-14  0.019178         0.0191
# 1          REGULAR      USD         put  2025-11-14  0.019178         0.0191
# 2          REGULAR      USD         put  2025-11-14  0.019178         0.0191
# 3          REGULAR      USD         put  2025-11-14  0.019178         0.0191
# 4          REGULAR      USD         put  2025-11-14  0.019178         0.0191
# ...            ...      ...         ...         ...       ...            ...
# 1570       REGULAR      USD        call  2027-12-17  2.109589         0.0191
# 1571       REGULAR      USD        call  2027-12-17  2.109589         0.0191
# 1572       REGULAR      USD        call  2027-12-17  2.109589         0.0191
# 1573       REGULAR      USD        call  2027-12-17  2.109589         0.0191
# 1574       REGULAR      USD        call  2027-12-17  2.109589         0.0191
#
#       ticker  spot_price  optionType
# 0        JPM  314.209991         put
# 1        JPM  314.209991         put
# 2        JPM  314.209991         put
# 3        JPM  314.209991         put
# 4        JPM  314.209991         put
# ...      ...         ...         ...
# 1570     JPM  314.209991        call
# 1571     JPM  314.209991        call
# 1572     JPM  314.209991        call
# 1573     JPM  314.209991        call
# 1574     JPM  314.209991        call
#
# [1575 rows x 21 columns]

# %% [markdown]
# **Interest Rate Interpolation**

# %%
from interest.interest_rates import fetch_treasury_yield_curve_latest, interest_rate_interpolation
as_of, curve_series = fetch_treasury_yield_curve_latest()
df["r"] = interest_rate_interpolation(curve_series, df["TTM"])

# %%
df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251114P00160000 2025-10-27 13:46:23+00:00   160.0       0.01   0.00
# 1     JPM251114P00180000 2025-11-07 18:01:01+00:00   180.0       0.04   0.00
# 2     JPM251114P00200000 2025-10-31 14:42:36+00:00   200.0       0.05   0.00
# 3     JPM251114P00210000 2025-10-14 14:27:52+00:00   210.0       1.12   0.00
# 4     JPM251114P00215000 2025-10-31 14:52:31+00:00   215.0       0.08   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM271217C00410000 2025-11-07 18:46:59+00:00   410.0      17.10  16.25
# 1571  JPM271217C00420000 2025-10-29 18:58:44+00:00   420.0      12.40  15.40
# 1572  JPM271217C00430000 2025-10-29 17:11:50+00:00   430.0      10.75  13.05
# 1573  JPM271217C00440000 2025-11-07 19:50:17+00:00   440.0      12.15  11.10
# 1574  JPM271217C00470000 2025-10-31 16:57:42+00:00   470.0       7.25   6.00
#
#         ask    change  percentChange  volume  openInterest  ...  contractSize  \
# 0      0.23  0.000000       0.000000     5.0             6  ...       REGULAR
# 1      0.13 -0.100000     -71.428570     1.0             1  ...       REGULAR
# 2      2.12  0.000000       0.000000     2.0             4  ...       REGULAR
# 3      1.76  0.000000       0.000000     1.0             2  ...       REGULAR
# 4      0.05  0.000000       0.000000     5.0            15  ...       REGULAR
# ...     ...       ...            ...     ...           ...  ...           ...
# 1570  18.30  1.600000      10.322582    10.0           120  ...       REGULAR
# 1571  16.25  0.000000       0.000000     1.0            40  ...       REGULAR
# 1572  14.45  0.000000       0.000000     2.0             8  ...       REGULAR
# 1573  12.55  2.259999      22.851357    10.0           125  ...       REGULAR
# 1574   9.85  0.000000       0.000000     2.0            11  ...       REGULAR
#
#       currency option_type  expiration       TTM dividendYield  ticker  \
# 0          USD         put  2025-11-14  0.019178        0.0191     JPM
# 1          USD         put  2025-11-14  0.019178        0.0191     JPM
# 2          USD         put  2025-11-14  0.019178        0.0191     JPM
# 3          USD         put  2025-11-14  0.019178        0.0191     JPM
# 4          USD         put  2025-11-14  0.019178        0.0191     JPM
# ...        ...         ...         ...       ...           ...     ...
# 1570       USD        call  2027-12-17  2.109589        0.0191     JPM
# 1571       USD        call  2027-12-17  2.109589        0.0191     JPM
# 1572       USD        call  2027-12-17  2.109589        0.0191     JPM
# 1573       USD        call  2027-12-17  2.109589        0.0191     JPM
# 1574       USD        call  2027-12-17  2.109589        0.0191     JPM
#
#       spot_price optionType         r
# 0     314.209991        put  0.040331
# 1     314.209991        put  0.040331
# 2     314.209991        put  0.040331
# 3     314.209991        put  0.040331
# 4     314.209991        put  0.040331
# ...          ...        ...       ...
# 1570  314.209991       call  0.035504
# 1571  314.209991       call  0.035504
# 1572  314.209991       call  0.035504
# 1573  314.209991       call  0.035504
# 1574  314.209991       call  0.035504
#
# [1575 rows x 22 columns]

# %% [markdown]
# **Forward log-Moneyness**

# %% [markdown]
# We decided to use forward log-moneyness because its adjusted for r and q which are crucial in pricing the EEP

# %%
def forward_log_moneyness(S: float, r:float, q:float, T:float, K:float):
    """
    Calculates the log_moneyness in relation to the Forward Price of the stock

    Parameters
    ----------
    S : float
        Current spot_price of the stock.
    r : float
        Risk-free rate associated with that particular option maturity
    q : float
        Dividend-yield rate associated with that particular option maturity
    T : float
        Maturity of the option contract
    K : float
        Strike price of the option contract

    Returns
    -------
    Float
        - Forward log moneyness 
    """
    forward_price = S * np.exp((r - q)*T)
    
    return np.log(K/forward_price)

# %%
df["forward_log_moneyness"] = forward_log_moneyness(
    S=df["spot_price"].to_numpy(),
    r=df["r"].to_numpy(),
    q=df["dividendYield"].to_numpy(),
    T=df["TTM"].to_numpy(),
    K=df["strike"].to_numpy(),
)

df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251114P00160000 2025-10-27 13:46:23+00:00   160.0       0.01   0.00
# 1     JPM251114P00180000 2025-11-07 18:01:01+00:00   180.0       0.04   0.00
# 2     JPM251114P00200000 2025-10-31 14:42:36+00:00   200.0       0.05   0.00
# 3     JPM251114P00210000 2025-10-14 14:27:52+00:00   210.0       1.12   0.00
# 4     JPM251114P00215000 2025-10-31 14:52:31+00:00   215.0       0.08   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM271217C00410000 2025-11-07 18:46:59+00:00   410.0      17.10  16.25
# 1571  JPM271217C00420000 2025-10-29 18:58:44+00:00   420.0      12.40  15.40
# 1572  JPM271217C00430000 2025-10-29 17:11:50+00:00   430.0      10.75  13.05
# 1573  JPM271217C00440000 2025-11-07 19:50:17+00:00   440.0      12.15  11.10
# 1574  JPM271217C00470000 2025-10-31 16:57:42+00:00   470.0       7.25   6.00
#
#         ask    change  percentChange  volume  openInterest  ...  currency  \
# 0      0.23  0.000000       0.000000     5.0             6  ...       USD
# 1      0.13 -0.100000     -71.428570     1.0             1  ...       USD
# 2      2.12  0.000000       0.000000     2.0             4  ...       USD
# 3      1.76  0.000000       0.000000     1.0             2  ...       USD
# 4      0.05  0.000000       0.000000     5.0            15  ...       USD
# ...     ...       ...            ...     ...           ...  ...       ...
# 1570  18.30  1.600000      10.322582    10.0           120  ...       USD
# 1571  16.25  0.000000       0.000000     1.0            40  ...       USD
# 1572  14.45  0.000000       0.000000     2.0             8  ...       USD
# 1573  12.55  2.259999      22.851357    10.0           125  ...       USD
# 1574   9.85  0.000000       0.000000     2.0            11  ...       USD
#
#       option_type  expiration       TTM dividendYield ticker  spot_price  \
# 0             put  2025-11-14  0.019178        0.0191    JPM  314.209991
# 1             put  2025-11-14  0.019178        0.0191    JPM  314.209991
# 2             put  2025-11-14  0.019178        0.0191    JPM  314.209991
# 3             put  2025-11-14  0.019178        0.0191    JPM  314.209991
# 4             put  2025-11-14  0.019178        0.0191    JPM  314.209991
# ...           ...         ...       ...           ...    ...         ...
# 1570         call  2027-12-17  2.109589        0.0191    JPM  314.209991
# 1571         call  2027-12-17  2.109589        0.0191    JPM  314.209991
# 1572         call  2027-12-17  2.109589        0.0191    JPM  314.209991
# 1573         call  2027-12-17  2.109589        0.0191    JPM  314.209991
# 1574         call  2027-12-17  2.109589        0.0191    JPM  314.209991
#
#       optionType         r  forward_log_moneyness
# 0            put  0.040331              -0.675295
# 1            put  0.040331              -0.557512
# 2            put  0.040331              -0.452151
# 3            put  0.040331              -0.403361
# 4            put  0.040331              -0.379831
# ...          ...       ...                    ...
# 1570        call  0.035504               0.231491
# 1571        call  0.035504               0.255588
# 1572        call  0.035504               0.279119
# 1573        call  0.035504               0.302108
# 1574        call  0.035504               0.368066
#
# [1575 rows x 23 columns]

# %% [markdown]
# Calculate Mid Price

# %%
def mid_price(bid: float, ask: float):
    """
    Calcualtes the mid-price of the option based on bid and ask prices

    Parameters
    ----------
    bid : float
        Current bid price of the option
    ask : float
        Current ask price of the option

    Returns
    -------
    Float
        - Mid price
    """

    return ((bid+ask)/2)

# %%
df["midPrice"] = mid_price(df["bid"], df["ask"])
df
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251114P00160000 2025-10-27 13:46:23+00:00   160.0       0.01   0.00
# 1     JPM251114P00180000 2025-11-07 18:01:01+00:00   180.0       0.04   0.00
# 2     JPM251114P00200000 2025-10-31 14:42:36+00:00   200.0       0.05   0.00
# 3     JPM251114P00210000 2025-10-14 14:27:52+00:00   210.0       1.12   0.00
# 4     JPM251114P00215000 2025-10-31 14:52:31+00:00   215.0       0.08   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM271217C00410000 2025-11-07 18:46:59+00:00   410.0      17.10  16.25
# 1571  JPM271217C00420000 2025-10-29 18:58:44+00:00   420.0      12.40  15.40
# 1572  JPM271217C00430000 2025-10-29 17:11:50+00:00   430.0      10.75  13.05
# 1573  JPM271217C00440000 2025-11-07 19:50:17+00:00   440.0      12.15  11.10
# 1574  JPM271217C00470000 2025-10-31 16:57:42+00:00   470.0       7.25   6.00
#
#         ask    change  percentChange  volume  openInterest  ...  option_type  \
# 0      0.23  0.000000       0.000000     5.0             6  ...          put
# 1      0.13 -0.100000     -71.428570     1.0             1  ...          put
# 2      2.12  0.000000       0.000000     2.0             4  ...          put
# 3      1.76  0.000000       0.000000     1.0             2  ...          put
# 4      0.05  0.000000       0.000000     5.0            15  ...          put
# ...     ...       ...            ...     ...           ...  ...          ...
# 1570  18.30  1.600000      10.322582    10.0           120  ...         call
# 1571  16.25  0.000000       0.000000     1.0            40  ...         call
# 1572  14.45  0.000000       0.000000     2.0             8  ...         call
# 1573  12.55  2.259999      22.851357    10.0           125  ...         call
# 1574   9.85  0.000000       0.000000     2.0            11  ...         call
#
#       expiration       TTM dividendYield ticker  spot_price  optionType  \
# 0     2025-11-14  0.019178        0.0191    JPM  314.209991         put
# 1     2025-11-14  0.019178        0.0191    JPM  314.209991         put
# 2     2025-11-14  0.019178        0.0191    JPM  314.209991         put
# 3     2025-11-14  0.019178        0.0191    JPM  314.209991         put
# 4     2025-11-14  0.019178        0.0191    JPM  314.209991         put
# ...          ...       ...           ...    ...         ...         ...
# 1570  2027-12-17  2.109589        0.0191    JPM  314.209991        call
# 1571  2027-12-17  2.109589        0.0191    JPM  314.209991        call
# 1572  2027-12-17  2.109589        0.0191    JPM  314.209991        call
# 1573  2027-12-17  2.109589        0.0191    JPM  314.209991        call
# 1574  2027-12-17  2.109589        0.0191    JPM  314.209991        call
#
#              r forward_log_moneyness  midPrice
# 0     0.040331             -0.675295     0.115
# 1     0.040331             -0.557512     0.065
# 2     0.040331             -0.452151     1.060
# 3     0.040331             -0.403361     0.880
# 4     0.040331             -0.379831     0.025
# ...        ...                   ...       ...
# 1570  0.035504              0.231491    17.275
# 1571  0.035504              0.255588    15.825
# 1572  0.035504              0.279119    13.750
# 1573  0.035504              0.302108    11.825
# 1574  0.035504              0.368066     7.925
#
# [1575 rows x 24 columns]

# %%
from heston.heston import calibrate_and_price_heston_european

V_eu = calibrate_and_price_heston_european(df, group_cols=("ticker", ))
df = df.join(V_eu)
df
# Out:
# [deAm] === group start === :: group=('JPM',) | rows=1575
# [deAm] sigma* :: tree=jr | sigma_star=1.9417908934993187
# [deAm] eu price :: tree=jr | p_eu=0.11575397690562907
# [deAm] sigma* :: tree=jr | sigma_star=1.5278603982629049
# [deAm] eu price :: tree=jr | p_eu=0.06552750699011953
# [deAm] sigma* :: tree=jr | sigma_star=1.873257371715758
# [deAm] eu price :: tree=jr | p_eu=1.062933755909612
# [deAm] sigma* :: tree=jr | sigma_star=1.6399957625074617
# [deAm] eu price :: tree=jr | p_eu=0.8796088158972276
# [deAm] sigma* :: tree=jr | sigma_star=0.9740250925434901
# [deAm] eu price :: tree=jr | p_eu=0.025229794212848523
# [deAm] sigma* :: tree=jr | sigma_star=1.0925347861026808
# [deAm] eu price :: tree=jr | p_eu=0.1905415319445549
# [deAm] sigma* :: tree=jr | sigma_star=1.1764253766154213
# [deAm] eu price :: tree=jr | p_eu=0.6534457253865147
# [deAm] sigma* :: tree=jr | sigma_star=0.7656440321772998
# [deAm] eu price :: tree=jr | p_eu=0.050652949490163135
# [deAm] sigma* :: tree=jr | sigma_star=0.8860846805843237
# [deAm] eu price :: tree=jr | p_eu=0.26545727529828206
# [deAm] sigma* :: tree=jr | sigma_star=0.697829330807275
# [deAm] eu price :: tree=jr | p_eu=0.08056667029077076
# [deAm] sigma* :: tree=jr | sigma_star=0.6822858616829028
# [deAm] eu price :: tree=jr | p_eu=0.1253593345924127
# [deAm] sigma* :: tree=jr | sigma_star=0.5265562358482905
# [deAm] eu price :: tree=jr | p_eu=0.03021794338105979
# [deAm] sigma* :: tree=jr | sigma_star=0.5835409296549869
# [deAm] eu price :: tree=jr | p_eu=0.1454067217733391
# [deAm] sigma* :: tree=jr | sigma_star=0.5167691116271199
# [deAm] eu price :: tree=jr | p_eu=0.12580339740825408
# [deAm] sigma* :: tree=jr | sigma_star=0.4864867652435999
# [deAm] eu price :: tree=jr | p_eu=0.17508646901197633
# [deAm] sigma* :: tree=jr | sigma_star=0.4430767012603301
# [deAm] eu price :: tree=jr | p_eu=0.1412217941064683
# [deAm] sigma* :: tree=jr | sigma_star=0.4002570849596558
# [deAm] eu price :: tree=jr | p_eu=0.11014297033915818
# [deAm] sigma* :: tree=jr | sigma_star=0.38785303169175483
# [deAm] eu price :: tree=jr | p_eu=0.1401075412938664
# [deAm] sigma* :: tree=jr | sigma_star=0.37759170503463
# [deAm] eu price :: tree=jr | p_eu=0.18498176813089415
# [deAm] sigma* :: tree=jr | sigma_star=0.3372087965896126
# [deAm] eu price :: tree=jr | p_eu=0.15061364380225384
# [deAm] sigma* :: tree=jr | sigma_star=0.33557663419106165
# [deAm] eu price :: tree=jr | p_eu=0.2357953389516723
# [deAm] sigma* :: tree=jr | sigma_star=0.31928728293116637
# [deAm] eu price :: tree=jr | p_eu=0.29103197962562477
# [deAm] sigma* :: tree=jr | sigma_star=0.31139024781146646
# [deAm] eu price :: tree=jr | p_eu=0.4093456023593852
# [deAm] sigma* :: tree=jr | sigma_star=0.29144286211112963
# [deAm] eu price :: tree=jr | p_eu=0.48914830739638804
# [deAm] sigma* :: tree=jr | sigma_star=0.27684411316058427
# [deAm] eu price :: tree=jr | p_eu=0.6362752965451212
# [deAm] sigma* :: tree=jr | sigma_star=0.26255425091712836
# [deAm] eu price :: tree=jr | p_eu=0.8383369462481811
# [deAm] sigma* :: tree=jr | sigma_star=0.2519895103764353
# [deAm] eu price :: tree=jr | p_eu=1.157290849911984
# [deAm] sigma* :: tree=jr | sigma_star=0.24277115233239166
# [deAm] eu price :: tree=jr | p_eu=1.611424387227876
# [deAm] sigma* :: tree=jr | sigma_star=0.23283399679382735
# [deAm] eu price :: tree=jr | p_eu=2.2119284032228967
# [deAm] sigma* :: tree=jr | sigma_star=0.22852577570839935
# [deAm] eu price :: tree=jr | p_eu=3.10325298140799
# [deAm] sigma* :: tree=jr | sigma_star=0.21744405714340131
# [deAm] eu price :: tree=jr | p_eu=4.11711078026241
# [deAm] sigma* :: tree=jr | sigma_star=0.21480527731835194
# [deAm] eu price :: tree=jr | p_eu=5.53597709966864
# [deAm] sigma* :: tree=jr | sigma_star=0.22739974490384138
# [deAm] eu price :: tree=jr | p_eu=7.433351300354887
# [deAm] sigma* :: tree=jr | sigma_star=0.25403336808498184
# [deAm] eu price :: tree=jr | p_eu=16.08162347661101
# [deAm] sigma* :: tree=jr | sigma_star=0.28698960788351074
# [deAm] eu price :: tree=jr | p_eu=20.944273305111484
# [deAm] sigma* :: tree=jr | sigma_star=1.0913727302973817
# [deAm] eu price :: tree=jr | p_eu=0.015314303787144379
# [deAm] sigma* :: tree=jr | sigma_star=1.0660025066283145
# [deAm] eu price :: tree=jr | p_eu=0.020197350567652355
# [deAm] sigma* :: tree=jr | sigma_star=1.5795551620771955
# [deAm] eu price :: tree=jr | p_eu=0.9236345221070367
# [deAm] sigma* :: tree=jr | sigma_star=0.9751158026457194
# [deAm] eu price :: tree=jr | p_eu=0.02019688237933577
# [deAm] sigma* :: tree=jr | sigma_star=1.1267193691600965
# [deAm] eu price :: tree=jr | p_eu=0.14150727747632083
# [deAm] sigma* :: tree=jr | sigma_star=0.960921938504592
# [deAm] eu price :: tree=jr | p_eu=0.04530106760776715
# [deAm] sigma* :: tree=jr | sigma_star=0.8747747007037677
# [deAm] eu price :: tree=jr | p_eu=0.025499176251997612
# [deAm] sigma* :: tree=jr | sigma_star=1.2915720451651735
# [deAm] eu price :: tree=jr | p_eu=0.9734173414049468
# [deAm] sigma* :: tree=jr | sigma_star=0.8286348721512916
# [deAm] eu price :: tree=jr | p_eu=0.03543299854734777
# [deAm] sigma* :: tree=jr | sigma_star=0.7950516689859329
# [deAm] eu price :: tree=jr | p_eu=0.035409581232538866
# [deAm] sigma* :: tree=jr | sigma_star=0.7726000942539559
# [deAm] eu price :: tree=jr | p_eu=0.040558244201028715
# [deAm] sigma* :: tree=jr | sigma_star=0.7706050789842507
# [deAm] eu price :: tree=jr | p_eu=0.06046083608537419
# [deAm] sigma* :: tree=jr | sigma_star=0.7265735802962516
# [deAm] eu price :: tree=jr | p_eu=0.05045819356447142
# [deAm] sigma* :: tree=jr | sigma_star=0.7265478938331459
# [deAm] eu price :: tree=jr | p_eu=0.07597683223526411
# [deAm] sigma* :: tree=jr | sigma_star=0.7361680856709379
# [deAm] eu price :: tree=jr | p_eu=0.12533768819250254
# [deAm] sigma* :: tree=jr | sigma_star=0.6893609007629176
# [deAm] eu price :: tree=jr | p_eu=0.10068173059968932
# [deAm] sigma* :: tree=jr | sigma_star=0.6415898538298979
# [deAm] eu price :: tree=jr | p_eu=0.0760570997555609
# [deAm] sigma* :: tree=jr | sigma_star=0.5957780557771083
# [deAm] eu price :: tree=jr | p_eu=0.055790837680423214
# [deAm] sigma* :: tree=jr | sigma_star=0.6077560523751029
# [deAm] eu price :: tree=jr | p_eu=0.10083318036231219
# [deAm] sigma* :: tree=jr | sigma_star=0.6211290779094877
# [deAm] eu price :: tree=jr | p_eu=0.17526226410481008
# [deAm] sigma* :: tree=jr | sigma_star=0.5841750103627684
# [deAm] eu price :: tree=jr | p_eu=0.15114309150769
# [deAm] sigma* :: tree=jr | sigma_star=0.5589159903221264
# [deAm] eu price :: tree=jr | p_eu=0.1509540814851178
# [deAm] sigma* :: tree=jr | sigma_star=0.546459344353255
# [deAm] eu price :: tree=jr | p_eu=0.18071327237472817
# [deAm] sigma* :: tree=jr | sigma_star=0.5610847814466727
# [deAm] eu price :: tree=jr | p_eu=0.30992565602216665
# [deAm] sigma* :: tree=jr | sigma_star=0.5052123935595129
# [deAm] eu price :: tree=jr | p_eu=0.2007943131741645
# [deAm] sigma* :: tree=jr | sigma_star=0.5137134241194414
# [deAm] eu price :: tree=jr | p_eu=0.3205860101222718
# [deAm] sigma* :: tree=jr | sigma_star=0.4961615012505622
# [deAm] eu price :: tree=jr | p_eu=0.35139907541755155
# [deAm] sigma* :: tree=jr | sigma_star=0.4758867488440652
# [deAm] eu price :: tree=jr | p_eu=0.3698087330678056
# [deAm] sigma* :: tree=jr | sigma_star=0.4449737534245558
# [deAm] eu price :: tree=jr | p_eu=0.3314574365109651
# [deAm] sigma* :: tree=jr | sigma_star=0.435552519903254
# [deAm] eu price :: tree=jr | p_eu=0.40615494213450287
# [deAm] sigma* :: tree=jr | sigma_star=0.4274155430991444
# [deAm] eu price :: tree=jr | p_eu=0.5046524511852666
# [deAm] sigma* :: tree=jr | sigma_star=0.42698696447035567
# [deAm] eu price :: tree=jr | p_eu=0.6909854494491448
# [deAm] sigma* :: tree=jr | sigma_star=0.3988289590097082
# [deAm] eu price :: tree=jr | p_eu=0.6499618079949953
# [deAm] sigma* :: tree=jr | sigma_star=0.37474041782673534
# [deAm] eu price :: tree=jr | p_eu=0.6409310506969366
# [deAm] sigma* :: tree=jr | sigma_star=0.3736553612251344
# [deAm] eu price :: tree=jr | p_eu=0.8753668459384454
# [deAm] sigma* :: tree=jr | sigma_star=0.36370241433108336
# [deAm] eu price :: tree=jr | p_eu=1.050960537385315
# [deAm] sigma* :: tree=jr | sigma_star=0.3572498078567742
# [deAm] eu price :: tree=jr | p_eu=1.3151261732526007
# [deAm] sigma* :: tree=jr | sigma_star=0.34563042315473863
# [deAm] eu price :: tree=jr | p_eu=1.540169676276681
# [deAm] sigma* :: tree=jr | sigma_star=0.334897600129228
# [deAm] eu price :: tree=jr | p_eu=1.822233738792013
# [deAm] sigma* :: tree=jr | sigma_star=0.32858677644104817
# [deAm] eu price :: tree=jr | p_eu=2.2601961195378903
# [deAm] sigma* :: tree=jr | sigma_star=0.31713102537996063
# [deAm] eu price :: tree=jr | p_eu=2.6471448452101716
# [deAm] sigma* :: tree=jr | sigma_star=0.3083695995194244
# [deAm] eu price :: tree=jr | p_eu=3.1837775506199573
# [deAm] sigma* :: tree=jr | sigma_star=0.29914462252455515
# [deAm] eu price :: tree=jr | p_eu=3.804818958301315
# [deAm] sigma* :: tree=jr | sigma_star=0.29222379171060564
# [deAm] eu price :: tree=jr | p_eu=4.626610614200594
# [deAm] sigma* :: tree=jr | sigma_star=0.28474879326852204
# [deAm] eu price :: tree=jr | p_eu=5.575696657762409
# [deAm] sigma* :: tree=jr | sigma_star=0.27784554929840954
# [deAm] eu price :: tree=jr | p_eu=6.717945045025897
# [deAm] sigma* :: tree=jr | sigma_star=0.27287386248662165
# [deAm] eu price :: tree=jr | p_eu=8.147851322784458
# [deAm] sigma* :: tree=jr | sigma_star=0.266573955486013
# [deAm] eu price :: tree=jr | p_eu=9.736244870556309
# [deAm] sigma* :: tree=jr | sigma_star=0.26102130640270904
# [deAm] eu price :: tree=jr | p_eu=11.604197504662261
# [deAm] sigma* :: tree=jr | sigma_star=0.25659783454443064
# [deAm] eu price :: tree=jr | p_eu=13.794100267401587
# [deAm] sigma* :: tree=jr | sigma_star=0.251095365148854
# [deAm] eu price :: tree=jr | p_eu=16.199412922123283
# [deAm] sigma* :: tree=jr | sigma_star=0.24741431575107592
# [deAm] eu price :: tree=jr | p_eu=18.984496721443875
# [deAm] sigma* :: tree=jr | sigma_star=0.24659449065770972
# [deAm] eu price :: tree=jr | p_eu=22.194239509369527
# [deAm] sigma* :: tree=jr | sigma_star=0.23971018046873563
# [deAm] eu price :: tree=jr | p_eu=25.365646455085614
# [deAm] sigma* :: tree=jr | sigma_star=0.24111582261037487
# [deAm] eu price :: tree=jr | p_eu=29.18184566748748
# [deAm] sigma* :: tree=jr | sigma_star=0.24586507220154333
# [deAm] eu price :: tree=jr | p_eu=33.32759343808246
# [deAm] sigma* :: tree=jr | sigma_star=0.27391086914696644
# [deAm] eu price :: tree=jr | p_eu=38.50529495649229
# [deAm] sigma* :: tree=jr | sigma_star=0.25183116284519524
# [deAm] eu price :: tree=jr | p_eu=41.90697628546878
# [deAm] sigma* :: tree=jr | sigma_star=0.24988685394752677
# [deAm] eu price :: tree=jr | p_eu=46.232273792718296
# [deAm] sigma* :: tree=jr | sigma_star=1.537455989107511
# [deAm] eu price :: tree=jr | p_eu=148.6029200955606
# [deAm] sigma* :: tree=jr | sigma_star=0.4578524490586616
# [deAm] eu price :: tree=jr | p_eu=134.67337260459442
# [deAm] sigma* :: tree=jr | sigma_star=2.6936647062293857
# [deAm] eu price :: tree=jr | p_eu=1.0588398775160064
# [deAm] sigma* :: tree=jr | sigma_star=2.588271949644828
# [deAm] eu price :: tree=jr | p_eu=1.0587157457789185
# [deAm] sigma* :: tree=jr | sigma_star=2.4873744594544416
# [deAm] eu price :: tree=jr | p_eu=1.0586928654224033
# [deAm] sigma* :: tree=jr | sigma_star=2.390568036045083
# [deAm] eu price :: tree=jr | p_eu=1.0587226736002084
# [deAm] sigma* :: tree=jr | sigma_star=1.7011880234407288
# [deAm] eu price :: tree=jr | p_eu=0.12062186264620049
# [deAm] sigma* :: tree=jr | sigma_star=1.6398033811517503
# [deAm] eu price :: tree=jr | p_eu=0.12544621252458268
# [deAm] sigma* :: tree=jr | sigma_star=1.3993601339863073
# [deAm] eu price :: tree=jr | p_eu=0.04059459977982205
# [deAm] sigma* :: tree=jr | sigma_star=2.03785076947278
# [deAm] eu price :: tree=jr | p_eu=1.0588571134820426
# [deAm] sigma* :: tree=jr | sigma_star=1.2312378511162914
# [deAm] eu price :: tree=jr | p_eu=0.025452610934926435
# [deAm] sigma* :: tree=jr | sigma_star=1.8802664882148026
# [deAm] eu price :: tree=jr | p_eu=1.063839468423405
# [deAm] sigma* :: tree=jr | sigma_star=1.3971696868943644
# [deAm] eu price :: tree=jr | p_eu=0.1911478411417753
# [deAm] sigma* :: tree=jr | sigma_star=0.9982075476981969
# [deAm] eu price :: tree=jr | p_eu=0.010150554667781392
# [deAm] sigma* :: tree=jr | sigma_star=1.6587136774609281
# [deAm] eu price :: tree=jr | p_eu=1.0641422894907708
# [deAm] sigma* :: tree=jr | sigma_star=1.2109068838717225
# [deAm] eu price :: tree=jr | p_eu=0.1756245393633163
# [deAm] sigma* :: tree=jr | sigma_star=1.5209296296139512
# [deAm] eu price :: tree=jr | p_eu=1.0649321467228723
# [deAm] sigma* :: tree=jr | sigma_star=0.9755456998174374
# [deAm] eu price :: tree=jr | p_eu=0.06037528396019138
# [deAm] sigma* :: tree=jr | sigma_star=0.8350017888220255
# [deAm] eu price :: tree=jr | p_eu=0.02022742651288701
# [deAm] sigma* :: tree=jr | sigma_star=0.9984068160068591
# [deAm] eu price :: tree=jr | p_eu=0.17116567471868682
# [deAm] sigma* :: tree=jr | sigma_star=0.8235603965182705
# [deAm] eu price :: tree=jr | p_eu=0.05040714604275601
# [deAm] sigma* :: tree=jr | sigma_star=0.7529088697502493
# [deAm] eu price :: tree=jr | p_eu=0.03529091204546271
# [deAm] sigma* :: tree=jr | sigma_star=0.689428679909421
# [deAm] eu price :: tree=jr | p_eu=0.025225089294360337
# [deAm] sigma* :: tree=jr | sigma_star=0.6727329971272361
# [deAm] eu price :: tree=jr | p_eu=0.03526187934054379
# [deAm] sigma* :: tree=jr | sigma_star=0.60063598788398
# [deAm] eu price :: tree=jr | p_eu=0.020332429327294163
# [deAm] sigma* :: tree=jr | sigma_star=0.6254900338089826
# [deAm] eu price :: tree=jr | p_eu=0.05571421963452832
# [deAm] sigma* :: tree=jr | sigma_star=0.6892639734325853
# [deAm] eu price :: tree=jr | p_eu=0.20135988811811834
# [deAm] sigma* :: tree=jr | sigma_star=0.5131023226490917
# [deAm] eu price :: tree=jr | p_eu=0.03024005483362078
# [deAm] sigma* :: tree=jr | sigma_star=0.514963059558231
# [deAm] eu price :: tree=jr | p_eu=0.060446666603433306
# [deAm] sigma* :: tree=jr | sigma_star=0.4819842248310244
# [deAm] eu price :: tree=jr | p_eu=0.06552500715062765
# [deAm] sigma* :: tree=jr | sigma_star=0.44443747209677775
# [deAm] eu price :: tree=jr | p_eu=0.06527399140559657
# [deAm] sigma* :: tree=jr | sigma_star=0.44624997299214514
# [deAm] eu price :: tree=jr | p_eu=0.1303561964638644
# [deAm] sigma* :: tree=jr | sigma_star=0.3810020841408896
# [deAm] eu price :: tree=jr | p_eu=0.0801966152073005
# [deAm] sigma* :: tree=jr | sigma_star=0.37988115306947734
# [deAm] eu price :: tree=jr | p_eu=0.16087512605346238
# [deAm] sigma* :: tree=jr | sigma_star=0.3727729395879183
# [deAm] eu price :: tree=jr | p_eu=0.2004046321259017
# [deAm] sigma* :: tree=jr | sigma_star=0.36194462641112013
# [deAm] eu price :: tree=jr | p_eu=0.234908967328588
# [deAm] sigma* :: tree=jr | sigma_star=0.35206537566553936
# [deAm] eu price :: tree=jr | p_eu=0.28037801024507597
# [deAm] sigma* :: tree=jr | sigma_star=0.34240345060863414
# [deAm] eu price :: tree=jr | p_eu=0.33657009269926796
# [deAm] sigma* :: tree=jr | sigma_star=0.3284706844070822
# [deAm] eu price :: tree=jr | p_eu=0.3797336759646316
# [deAm] sigma* :: tree=jr | sigma_star=0.3195844253511608
# [deAm] eu price :: tree=jr | p_eu=0.46431170095809926
# [deAm] sigma* :: tree=jr | sigma_star=0.3107400996208553
# [deAm] eu price :: tree=jr | p_eu=0.568939518596178
# [deAm] sigma* :: tree=jr | sigma_star=0.3002965115186909
# [deAm] eu price :: tree=jr | p_eu=0.6834772481673091
# [deAm] sigma* :: tree=jr | sigma_star=0.2878466297048877
# [deAm] eu price :: tree=jr | p_eu=0.8030677132356222
# [deAm] sigma* :: tree=jr | sigma_star=0.27862163457764455
# [deAm] eu price :: tree=jr | p_eu=0.98749791236753
# [deAm] sigma* :: tree=jr | sigma_star=0.2721213599838701
# [deAm] eu price :: tree=jr | p_eu=1.2540476347811018
# [deAm] sigma* :: tree=jr | sigma_star=0.26076163029640553
# [deAm] eu price :: tree=jr | p_eu=1.509938886457213
# [deAm] sigma* :: tree=jr | sigma_star=0.25410103201409934
# [deAm] eu price :: tree=jr | p_eu=1.909324883562764
# [deAm] sigma* :: tree=jr | sigma_star=0.24633786054417792
# [deAm] eu price :: tree=jr | p_eu=2.3817355858768106
# [deAm] sigma* :: tree=jr | sigma_star=0.24056663322069363
# [deAm] eu price :: tree=jr | p_eu=3.005585155799091
# [deAm] sigma* :: tree=jr | sigma_star=0.2370496820936711
# [deAm] eu price :: tree=jr | p_eu=3.8160460202201962
# [deAm] sigma* :: tree=jr | sigma_star=0.22959051623406496
# [deAm] eu price :: tree=jr | p_eu=4.687608809411231
# [deAm] sigma* :: tree=jr | sigma_star=0.2284871894141821
# [deAm] eu price :: tree=jr | p_eu=5.880564957335497
# [deAm] sigma* :: tree=jr | sigma_star=0.22220522286298236
# [deAm] eu price :: tree=jr | p_eu=7.124886534972439
# [deAm] sigma* :: tree=jr | sigma_star=0.2187386197309777
# [deAm] eu price :: tree=jr | p_eu=8.618780977454627
# [deAm] sigma* :: tree=jr | sigma_star=0.22927793183743128
# [deAm] eu price :: tree=jr | p_eu=12.45140029968073
# [deAm] sigma* :: tree=jr | sigma_star=0.22747959796295297
# [deAm] eu price :: tree=jr | p_eu=16.528843765680634
# [deAm] sigma* :: tree=jr | sigma_star=0.2444990810973509
# [deAm] eu price :: tree=jr | p_eu=21.178518443729704
# [deAm] sigma* :: tree=jr | sigma_star=0.29129719980667634
# [deAm] eu price :: tree=jr | p_eu=26.227006016464824
# [deAm] sigma* :: tree=jr | sigma_star=0.3189429921970464
# [deAm] eu price :: tree=jr | p_eu=31.112445137657826
# [deAm] sigma* :: tree=jr | sigma_star=0.6110367960333248
# [deAm] eu price :: tree=jr | p_eu=0.5649228570308179
# [deAm] sigma* :: tree=jr | sigma_star=0.4488645125390777
# [deAm] eu price :: tree=jr | p_eu=0.17585319404853086
# [deAm] sigma* :: tree=jr | sigma_star=0.4173094691294371
# [deAm] eu price :: tree=jr | p_eu=0.2801689955025002
# [deAm] sigma* :: tree=jr | sigma_star=0.36838386285805935
# [deAm] eu price :: tree=jr | p_eu=0.3455404970665531
# [deAm] sigma* :: tree=jr | sigma_star=0.3428566832837154
# [deAm] eu price :: tree=jr | p_eu=0.37958664660757974
# [deAm] sigma* :: tree=jr | sigma_star=0.330775991616102
# [deAm] eu price :: tree=jr | p_eu=0.5197151515917866
# [deAm] sigma* :: tree=jr | sigma_star=0.3147761971522873
# [deAm] eu price :: tree=jr | p_eu=0.6716421247866454
# [deAm] sigma* :: tree=jr | sigma_star=0.30401706389962235
# [deAm] eu price :: tree=jr | p_eu=0.9373228875145493
# [deAm] sigma* :: tree=jr | sigma_star=0.2930046286356163
# [deAm] eu price :: tree=jr | p_eu=1.2979100297965436
# [deAm] sigma* :: tree=jr | sigma_star=0.2656934057385285
# [deAm] eu price :: tree=jr | p_eu=1.4859529316898108
# [deAm] sigma* :: tree=jr | sigma_star=0.25734037604253773
# [deAm] eu price :: tree=jr | p_eu=2.142949380077501
# [deAm] sigma* :: tree=jr | sigma_star=0.24925186921199574
# [deAm] eu price :: tree=jr | p_eu=3.052701858166189
# [deAm] sigma* :: tree=jr | sigma_star=0.24051908562014326
# [deAm] eu price :: tree=jr | p_eu=4.257155820275797
# [deAm] sigma* :: tree=jr | sigma_star=0.23372089295462056
# [deAm] eu price :: tree=jr | p_eu=5.9068725767153385
# [deAm] sigma* :: tree=jr | sigma_star=0.22618005203649152
# [deAm] eu price :: tree=jr | p_eu=7.98520070526344
# [deAm] sigma* :: tree=jr | sigma_star=0.21897235933749676
# [deAm] eu price :: tree=jr | p_eu=10.57355421187913
# [deAm] sigma* :: tree=jr | sigma_star=0.23268012534097532
# [deAm] eu price :: tree=jr | p_eu=14.321443298835606
# [deAm] sigma* :: tree=jr | sigma_star=0.31355352633922723
# [deAm] eu price :: tree=jr | p_eu=50.65579784133698
# [deAm] sigma* :: tree=jr | sigma_star=0.889106702555942
# [deAm] eu price :: tree=jr | p_eu=1.077809972904669
# [deAm] sigma* :: tree=jr | sigma_star=0.7072495679762804
# [deAm] eu price :: tree=jr | p_eu=1.0899663254768182
# [deAm] sigma* :: tree=jr | sigma_star=0.6556434013729148
# [deAm] eu price :: tree=jr | p_eu=1.0346889917552389
# [deAm] sigma* :: tree=jr | sigma_star=0.6225996165177778
# [deAm] eu price :: tree=jr | p_eu=1.1177643837161308
# [deAm] sigma* :: tree=jr | sigma_star=0.5191730451218929
# [deAm] eu price :: tree=jr | p_eu=0.6641666671591937
# [deAm] sigma* :: tree=jr | sigma_star=0.4005216662008401
# [deAm] eu price :: tree=jr | p_eu=0.24276706877989293
# [deAm] sigma* :: tree=jr | sigma_star=0.37785149508544386
# [deAm] eu price :: tree=jr | p_eu=0.2938523185663623
# [deAm] sigma* :: tree=jr | sigma_star=0.3474135316739633
# [deAm] eu price :: tree=jr | p_eu=0.3169531895303491
# [deAm] sigma* :: tree=jr | sigma_star=0.3281275891334451
# [deAm] eu price :: tree=jr | p_eu=0.4130138328845982
# [deAm] sigma* :: tree=jr | sigma_star=0.3099780085253602
# [deAm] eu price :: tree=jr | p_eu=0.5530112740407624
# [deAm] sigma* :: tree=jr | sigma_star=0.2993824798031131
# [deAm] eu price :: tree=jr | p_eu=0.829415817572612
# [deAm] sigma* :: tree=jr | sigma_star=0.27589817897804736
# [deAm] eu price :: tree=jr | p_eu=1.051459803019544
# [deAm] sigma* :: tree=jr | sigma_star=0.259289425867061
# [deAm] eu price :: tree=jr | p_eu=1.4754943124372093
# [deAm] sigma* :: tree=jr | sigma_star=0.24842916597425013
# [deAm] eu price :: tree=jr | p_eu=2.2065044118742168
# [deAm] sigma* :: tree=jr | sigma_star=0.23534705138706663
# [deAm] eu price :: tree=jr | p_eu=3.1961656138148054
# [deAm] sigma* :: tree=jr | sigma_star=0.22777634943010097
# [deAm] eu price :: tree=jr | p_eu=4.744182327996063
# [deAm] sigma* :: tree=jr | sigma_star=0.22063028095647305
# [deAm] eu price :: tree=jr | p_eu=6.835733808889653
# [deAm] sigma* :: tree=jr | sigma_star=0.21337624144920975
# [deAm] eu price :: tree=jr | p_eu=9.51603317732483
# [deAm] sigma* :: tree=jr | sigma_star=0.21247043523316653
# [deAm] eu price :: tree=jr | p_eu=16.905674474406826
# [deAm] sigma* :: tree=jr | sigma_star=0.23744802239308596
# [deAm] eu price :: tree=jr | p_eu=26.08732252811804
# [deAm] sigma* :: tree=jr | sigma_star=0.31494721359080247
# [deAm] eu price :: tree=jr | p_eu=1.076969061371845
# [deAm] sigma* :: tree=jr | sigma_star=0.29905707014979066
# [deAm] eu price :: tree=jr | p_eu=1.3376673125641394
# [deAm] sigma* :: tree=jr | sigma_star=0.2884345400185603
# [deAm] eu price :: tree=jr | p_eu=1.774362488981452
# [deAm] sigma* :: tree=jr | sigma_star=0.27383722243881237
# [deAm] eu price :: tree=jr | p_eu=2.2527229715761385
# [deAm] sigma* :: tree=jr | sigma_star=0.2687573223747702
# [deAm] eu price :: tree=jr | p_eu=3.1321092269697464
# [deAm] sigma* :: tree=jr | sigma_star=0.2536992261763023
# [deAm] eu price :: tree=jr | p_eu=3.9592901572869774
# [deAm] sigma* :: tree=jr | sigma_star=0.2487296093468198
# [deAm] eu price :: tree=jr | p_eu=5.376546361834598
# [deAm] sigma* :: tree=jr | sigma_star=0.23148165601718643
# [deAm] eu price :: tree=jr | p_eu=6.6932969851115445
# [deAm] sigma* :: tree=jr | sigma_star=0.23540072642326998
# [deAm] eu price :: tree=jr | p_eu=9.199806401169084
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=160.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.1
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=165.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.1
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=175.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.1
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=180.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.1
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=190.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.1
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=195.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.015
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=200.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.24
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=205.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.285
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=210.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.225
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=215.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.445
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=230.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.005
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=235.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.295
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=240.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.005
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=245.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.405
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=250.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.02
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=255.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.05
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=260.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.125
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=265.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.01
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=267.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.25
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=270.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.01
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=272.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.51
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=275.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.11
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=277.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.1
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=280.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.005
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=282.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.37
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=285.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.1
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=287.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.83
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=290.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.035
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=292.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.615
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=295.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.01
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=297.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.005
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=300.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.005
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=302.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.01
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=305.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.025
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=307.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.005
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=310.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.005
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=312.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.005
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=315.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=0.8300000000000001
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=317.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=3.39
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=320.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=5.800000000000001
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=322.5 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=8.4
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=325.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=10.7
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=330.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=16.025
# [deAm] IV: bad inputs :: S=314.2099914550781 | K=335.0 | T=0.0 | r=0.04039999999999999 | q=0.0191 | P=20.85
# [deAm] sigma* :: tree=jr | sigma_star=1.5410745755949047
# [deAm] eu price :: tree=jr | p_eu=0.025849087635523776
# [deAm] sigma* :: tree=jr | sigma_star=1.469205898896121
# [deAm] eu price :: tree=jr | p_eu=0.025736896755743234
# [deAm] sigma* :: tree=jr | sigma_star=2.1825365610839307
# [deAm] eu price :: tree=jr | p_eu=1.0741767531484856
# [deAm] sigma* :: tree=jr | sigma_star=2.086828703594356
# [deAm] eu price :: tree=jr | p_eu=1.072030834241231
# [deAm] sigma* :: tree=jr | sigma_star=1.9977945486495203
# [deAm] eu price :: tree=jr | p_eu=1.0711191480505406
# [deAm] sigma* :: tree=jr | sigma_star=1.9144924502071923
# [deAm] eu price :: tree=jr | p_eu=1.0710400430775355
# [deAm] sigma* :: tree=jr | sigma_star=1.764883392607183
# [deAm] eu price :: tree=jr | p_eu=0.8403231311667967
# [deAm] sigma* :: tree=jr | sigma_star=1.7622165450242069
# [deAm] eu price :: tree=jr | p_eu=1.0723031730955672
# [deAm] sigma* :: tree=jr | sigma_star=1.6921280054069179
# [deAm] eu price :: tree=jr | p_eu=1.0732777575758392
# [deAm] sigma* :: tree=jr | sigma_star=1.625484713086526
# [deAm] eu price :: tree=jr | p_eu=1.074312929501411
# [deAm] sigma* :: tree=jr | sigma_star=1.5619327852282572
# [deAm] eu price :: tree=jr | p_eu=1.0753225916128957
# [deAm] sigma* :: tree=jr | sigma_star=0.971332878117522
# [deAm] eu price :: tree=jr | p_eu=0.030916688848993693
# [deAm] sigma* :: tree=jr | sigma_star=1.4429411622748332
# [deAm] eu price :: tree=jr | p_eu=1.0770292666463739
# [deAm] sigma* :: tree=jr | sigma_star=0.9374685206389877
# [deAm] eu price :: tree=jr | p_eu=0.05109531215442159
# [deAm] sigma* :: tree=jr | sigma_star=0.9706792952441489
# [deAm] eu price :: tree=jr | p_eu=0.10659290707715634
# [deAm] sigma* :: tree=jr | sigma_star=1.2813462138305514
# [deAm] eu price :: tree=jr | p_eu=1.0783114439069386
# [deAm] sigma* :: tree=jr | sigma_star=1.2312735772706047
# [deAm] eu price :: tree=jr | p_eu=1.0783398219242946
# [deAm] sigma* :: tree=jr | sigma_star=0.8927995068063311
# [deAm] eu price :: tree=jr | p_eu=0.15196032663334344
# [deAm] sigma* :: tree=jr | sigma_star=0.927854806821118
# [deAm] eu price :: tree=jr | p_eu=0.2879082313480121
# [deAm] sigma* :: tree=jr | sigma_star=0.9733289153315542
# [deAm] eu price :: tree=jr | p_eu=0.5394759350166255
# [deAm] sigma* :: tree=jr | sigma_star=0.9989796021861727
# [deAm] eu price :: tree=jr | p_eu=0.8236068944546381
# [deAm] tree attempt failed :: tree=jr | err=bad inputs
# [deAm] tree attempt failed :: tree=trigeorgis | err=bad inputs
# [deAm] tree attempt failed :: tree=tian | err=bad inputs
# [deAm] tree attempt failed :: tree=crr | err=bad inputs
# [deAm] tree attempt failed :: tree=lr | err=bad inputs
# [deAm] IV: deAm failed :: P_raw=0.0 | P_eu=None
# [deAm] sigma* :: tree=jr | sigma_star=0.7821058525781222
# [deAm] eu price :: tree=jr | p_eu=0.28815533579644154
# [deAm] sigma* :: tree=jr | sigma_star=0.580784157479438
# [deAm] eu price :: tree=jr | p_eu=0.030924542122992803
# [deAm] sigma* :: tree=jr | sigma_star=0.5982098631963519
# [deAm] eu price :: tree=jr | p_eu=0.06619816683534907
# [deAm] sigma* :: tree=jr | sigma_star=0.5609214232124146
# [deAm] eu price :: tree=jr | p_eu=0.05638523874911147
# [deAm] sigma* :: tree=jr | sigma_star=0.6014449157642561
# [deAm] eu price :: tree=jr | p_eu=0.15829481819143643
# [deAm] sigma* :: tree=jr | sigma_star=0.6320433815213531
# [deAm] eu price :: tree=jr | p_eu=0.32790121646653164
# [deAm] sigma* :: tree=jr | sigma_star=0.5906663753916628
# [deAm] eu price :: tree=jr | p_eu=0.2894051109378525
# [deAm] sigma* :: tree=jr | sigma_star=0.5244577257408832
# [deAm] eu price :: tree=jr | p_eu=0.1769905635853815
# [deAm] sigma* :: tree=jr | sigma_star=0.5383069579331534
# [deAm] eu price :: tree=jr | p_eu=0.31257554384108344
# [deAm] sigma* :: tree=jr | sigma_star=0.4882231202793542
# [deAm] eu price :: tree=jr | p_eu=0.23238257026292705
# [deAm] sigma* :: tree=jr | sigma_star=0.49189296052032755
# [deAm] eu price :: tree=jr | p_eu=0.3587625465545141
# [deAm] sigma* :: tree=jr | sigma_star=0.4646382978522523
# [deAm] eu price :: tree=jr | p_eu=0.3627992977994315
# [deAm] sigma* :: tree=jr | sigma_star=0.4202830418985271
# [deAm] eu price :: tree=jr | p_eu=0.2824889161523814
# [deAm] sigma* :: tree=jr | sigma_star=0.4204377192262233
# [deAm] eu price :: tree=jr | p_eu=0.4239975481705472
# [deAm] sigma* :: tree=jr | sigma_star=0.3821107894280597
# [deAm] eu price :: tree=jr | p_eu=0.3581066687389605
# [deAm] sigma* :: tree=jr | sigma_star=0.3718376520593146
# [deAm] eu price :: tree=jr | p_eu=0.46380195171480837
# [deAm] sigma* :: tree=jr | sigma_star=0.368845372444474
# [deAm] eu price :: tree=jr | p_eu=0.6635939948692287
# [deAm] sigma* :: tree=jr | sigma_star=0.3406024931744099
# [deAm] eu price :: tree=jr | p_eu=0.6623695240178876
# [deAm] sigma* :: tree=jr | sigma_star=0.32645605940348804
# [deAm] eu price :: tree=jr | p_eu=0.8122392575957679
# [deAm] sigma* :: tree=jr | sigma_star=0.31363125731652347
# [deAm] eu price :: tree=jr | p_eu=1.0170169256419024
# [deAm] sigma* :: tree=jr | sigma_star=0.30944141465799646
# [deAm] eu price :: tree=jr | p_eu=1.420435830184017
# [deAm] sigma* :: tree=jr | sigma_star=0.2930864121481044
# [deAm] eu price :: tree=jr | p_eu=1.7034942020505168
# [deAm] sigma* :: tree=jr | sigma_star=0.2822555500282916
# [deAm] eu price :: tree=jr | p_eu=2.1838549402605163
# [deAm] sigma* :: tree=jr | sigma_star=0.2728344928263773
# [deAm] eu price :: tree=jr | p_eu=2.833903109537945
# [deAm] sigma* :: tree=jr | sigma_star=0.26367383570931635
# [deAm] eu price :: tree=jr | p_eu=3.6682752733653543
# [deAm] sigma* :: tree=jr | sigma_star=0.2543138340150336
# [deAm] eu price :: tree=jr | p_eu=4.713790388986549
# [deAm] sigma* :: tree=jr | sigma_star=0.2466607297694897
# [deAm] eu price :: tree=jr | p_eu=6.086929269527743
# [deAm] sigma* :: tree=jr | sigma_star=0.23834532308554887
# [deAm] eu price :: tree=jr | p_eu=7.751242329739394
# [deAm] sigma* :: tree=jr | sigma_star=0.23200681927372643
# [deAm] eu price :: tree=jr | p_eu=9.858196045482362
# [deAm] sigma* :: tree=jr | sigma_star=0.22509616937790755
# [deAm] eu price :: tree=jr | p_eu=12.336105452253417
# [deAm] sigma* :: tree=jr | sigma_star=0.2187771020105544
# [deAm] eu price :: tree=jr | p_eu=15.250503753107596
# [deAm] sigma* :: tree=jr | sigma_star=0.22764904508551315
# [deAm] eu price :: tree=jr | p_eu=19.11698530367714
# [deAm] sigma* :: tree=jr | sigma_star=0.22586958556057352
# [deAm] eu price :: tree=jr | p_eu=22.892871624162282
# [deAm] sigma* :: tree=jr | sigma_star=0.22602839357831556
# [deAm] eu price :: tree=jr | p_eu=27.008286967752095
# [deAm] sigma* :: tree=jr | sigma_star=0.2262890933683658
# [deAm] eu price :: tree=jr | p_eu=35.856851346129865
# [deAm] sigma* :: tree=jr | sigma_star=0.826747859615417
# [deAm] eu price :: tree=jr | p_eu=64.01499427195438
# [deAm] tree attempt failed :: tree=jr | err=bad inputs
# [deAm] tree attempt failed :: tree=trigeorgis | err=bad inputs
# [deAm] tree attempt failed :: tree=tian | err=bad inputs
# [deAm] tree attempt failed :: tree=crr | err=bad inputs
# [deAm] tree attempt failed :: tree=lr | err=bad inputs
# [deAm] IV: deAm failed :: P_raw=0.0 | P_eu=None
# [deAm] sigma* :: tree=jr | sigma_star=0.9944694617303618
# [deAm] eu price :: tree=jr | p_eu=93.33689641936911
# [deAm] sigma* :: tree=jr | sigma_star=1.0502511356406503
# [deAm] eu price :: tree=jr | p_eu=103.36612270412454
# [deAm] sigma* :: tree=jr | sigma_star=0.7324980565438753
# [deAm] eu price :: tree=jr | p_eu=0.9295608066420687
# [deAm] sigma* :: tree=jr | sigma_star=0.5523535663086536
# [deAm] eu price :: tree=jr | p_eu=0.44444087858591635
# [deAm] sigma* :: tree=jr | sigma_star=0.6178309673915009
# [deAm] eu price :: tree=jr | p_eu=1.1352464488620373
# [deAm] sigma* :: tree=jr | sigma_star=0.5159473426415394
# [deAm] eu price :: tree=jr | p_eu=0.5023264705113663
# [deAm] sigma* :: tree=jr | sigma_star=0.4969234838574461
# [deAm] eu price :: tree=jr | p_eu=0.5249097289263973
# [deAm] sigma* :: tree=jr | sigma_star=0.48451264936883404
# [deAm] eu price :: tree=jr | p_eu=0.5946986180335484
# [deAm] sigma* :: tree=jr | sigma_star=0.49760531742139474
# [deAm] eu price :: tree=jr | p_eu=0.9087754204727041
# [deAm] sigma* :: tree=jr | sigma_star=0.4167982207201035
# [deAm] eu price :: tree=jr | p_eu=0.41461194478346153
# [deAm] sigma* :: tree=jr | sigma_star=0.41307618549058517
# [deAm] eu price :: tree=jr | p_eu=0.5338250086002567
# [deAm] sigma* :: tree=jr | sigma_star=0.40443172446314346
# [deAm] eu price :: tree=jr | p_eu=0.6342188964377861
# [deAm] sigma* :: tree=jr | sigma_star=0.40206510956646246
# [deAm] eu price :: tree=jr | p_eu=0.8188368106382538
# [deAm] sigma* :: tree=jr | sigma_star=0.3760161795150655
# [deAm] eu price :: tree=jr | p_eu=0.7563970651157914
# [deAm] sigma* :: tree=jr | sigma_star=0.3685827748924101
# [deAm] eu price :: tree=jr | p_eu=0.9089818016450661
# [deAm] sigma* :: tree=jr | sigma_star=0.36303852304982437
# [deAm] eu price :: tree=jr | p_eu=1.1162312475502612
# [deAm] sigma* :: tree=jr | sigma_star=0.3532664863793871
# [deAm] eu price :: tree=jr | p_eu=1.2901046179599986
# [deAm] sigma* :: tree=jr | sigma_star=0.34967597362322217
# [deAm] eu price :: tree=jr | p_eu=1.608962669127668
# [deAm] sigma* :: tree=jr | sigma_star=0.3434800797698672
# [deAm] eu price :: tree=jr | p_eu=1.930919344470696
# [deAm] sigma* :: tree=jr | sigma_star=0.3294125093254298
# [deAm] eu price :: tree=jr | p_eu=2.1096259193943165
# [deAm] sigma* :: tree=jr | sigma_star=0.324601530281751
# [deAm] eu price :: tree=jr | p_eu=2.5609960093617583
# [deAm] sigma* :: tree=jr | sigma_star=0.3140264333114958
# [deAm] eu price :: tree=jr | p_eu=2.9104360330408774
# [deAm] sigma* :: tree=jr | sigma_star=0.3092392779588958
# [deAm] eu price :: tree=jr | p_eu=3.5074909115031008
# [deAm] sigma* :: tree=jr | sigma_star=0.30695771017869744
# [deAm] eu price :: tree=jr | p_eu=4.300668125285977
# [deAm] sigma* :: tree=jr | sigma_star=0.2949165539744013
# [deAm] eu price :: tree=jr | p_eu=4.807502379012604
# [deAm] sigma* :: tree=jr | sigma_star=0.2881191830685169
# [deAm] eu price :: tree=jr | p_eu=5.623998592768391
# [deAm] sigma* :: tree=jr | sigma_star=0.282421654261388
# [deAm] eu price :: tree=jr | p_eu=6.615575239049522
# [deAm] sigma* :: tree=jr | sigma_star=0.27732158529447803
# [deAm] eu price :: tree=jr | p_eu=7.782134884902741
# [deAm] sigma* :: tree=jr | sigma_star=0.2723754590904708
# [deAm] eu price :: tree=jr | p_eu=9.119080198850279
# [deAm] sigma* :: tree=jr | sigma_star=0.2664760515889264
# [deAm] eu price :: tree=jr | p_eu=10.57458703941053
# [deAm] sigma* :: tree=jr | sigma_star=0.2622902226004821
# [deAm] eu price :: tree=jr | p_eu=12.323870642460005
# [deAm] sigma* :: tree=jr | sigma_star=0.2545429286867811
# [deAm] eu price :: tree=jr | p_eu=14.046399476611077
# [deAm] sigma* :: tree=jr | sigma_star=0.25223048954277266
# [deAm] eu price :: tree=jr | p_eu=16.33851590586074
# [deAm] sigma* :: tree=jr | sigma_star=0.254349115051898
# [deAm] eu price :: tree=jr | p_eu=19.154498250680625
# [deAm] sigma* :: tree=jr | sigma_star=0.24323579539128187
# [deAm] eu price :: tree=jr | p_eu=21.316811446412768
# [deAm] sigma* :: tree=jr | sigma_star=0.24526183310610802
# [deAm] eu price :: tree=jr | p_eu=24.576130941888756
# [deAm] sigma* :: tree=jr | sigma_star=0.23870217459082382
# [deAm] eu price :: tree=jr | p_eu=27.504190519982977
# [deAm] sigma* :: tree=jr | sigma_star=0.24573473936878798
# [deAm] eu price :: tree=jr | p_eu=31.471222274667042
# [deAm] sigma* :: tree=jr | sigma_star=0.24066368654684997
# [deAm] eu price :: tree=jr | p_eu=38.798593967273234
# [deAm] sigma* :: tree=jr | sigma_star=0.23510940233015715
# [deAm] eu price :: tree=jr | p_eu=42.58828022277568
# [deAm] sigma* :: tree=jr | sigma_star=0.9546713956005445
# [deAm] eu price :: tree=jr | p_eu=1.069071555292421
# [deAm] sigma* :: tree=jr | sigma_star=0.8541259123107412
# [deAm] eu price :: tree=jr | p_eu=0.6871424556584051
# [deAm] sigma* :: tree=jr | sigma_star=0.8810053549291338
# [deAm] eu price :: tree=jr | p_eu=1.067686579438718
# [deAm] sigma* :: tree=jr | sigma_star=0.6983341537579787
# [deAm] eu price :: tree=jr | p_eu=0.2914400904445101
# [deAm] sigma* :: tree=jr | sigma_star=0.7541171299313055
# [deAm] eu price :: tree=jr | p_eu=0.666731588431335
# [deAm] sigma* :: tree=jr | sigma_star=0.7455275752556065
# [deAm] eu price :: tree=jr | p_eu=0.7980277270375601
# [deAm] sigma* :: tree=jr | sigma_star=0.7539148922476206
# [deAm] eu price :: tree=jr | p_eu=1.0820899638588908
# [deAm] sigma* :: tree=jr | sigma_star=0.7270478537947896
# [deAm] eu price :: tree=jr | p_eu=1.1023494611253015
# [deAm] sigma* :: tree=jr | sigma_star=0.6982139055229174
# [deAm] eu price :: tree=jr | p_eu=1.0971634385700495
# [deAm] sigma* :: tree=jr | sigma_star=0.6742357011592011
# [deAm] eu price :: tree=jr | p_eu=1.1280319846308031
# [deAm] sigma* :: tree=jr | sigma_star=0.6466745488992031
# [deAm] eu price :: tree=jr | p_eu=1.1177005009060272
# [deAm] sigma* :: tree=jr | sigma_star=0.5446562082625562
# [deAm] eu price :: tree=jr | p_eu=0.5018462950179629
# [deAm] sigma* :: tree=jr | sigma_star=0.5664456692824669
# [deAm] eu price :: tree=jr | p_eu=0.833496589854636
# [deAm] sigma* :: tree=jr | sigma_star=0.5330301253960986
# [deAm] eu price :: tree=jr | p_eu=0.7436671319484266
# [deAm] sigma* :: tree=jr | sigma_star=0.4799451996329671
# [deAm] eu price :: tree=jr | p_eu=0.5027497180417116
# [deAm] sigma* :: tree=jr | sigma_star=0.45939584874249006
# [deAm] eu price :: tree=jr | p_eu=0.5020285130955758
# [deAm] sigma* :: tree=jr | sigma_star=0.4120001216914205
# [deAm] eu price :: tree=jr | p_eu=0.32484924431007445
# [deAm] sigma* :: tree=jr | sigma_star=0.4222893512599794
# [deAm] eu price :: tree=jr | p_eu=0.5193625072504499
# [deAm] sigma* :: tree=jr | sigma_star=0.4109548169664138
# [deAm] eu price :: tree=jr | p_eu=0.5843512410425461
# [deAm] sigma* :: tree=jr | sigma_star=0.40096703101039904
# [deAm] eu price :: tree=jr | p_eu=0.6687598332064407
# [deAm] sigma* :: tree=jr | sigma_star=0.39395407427328694
# [deAm] eu price :: tree=jr | p_eu=0.796486163525458
# [deAm] sigma* :: tree=jr | sigma_star=0.37622762126374415
# [deAm] eu price :: tree=jr | p_eu=0.810465382100307
# [deAm] sigma* :: tree=jr | sigma_star=0.3796971505174577
# [deAm] eu price :: tree=jr | p_eu=1.1112294434050087
# [deAm] sigma* :: tree=jr | sigma_star=0.36148817581835413
# [deAm] eu price :: tree=jr | p_eu=1.1249378150659421
# [deAm] sigma* :: tree=jr | sigma_star=0.34923346716759274
# [deAm] eu price :: tree=jr | p_eu=1.2336114204330069
# [deAm] sigma* :: tree=jr | sigma_star=0.35251182212881516
# [deAm] eu price :: tree=jr | p_eu=1.6575964666338978
# [deAm] sigma* :: tree=jr | sigma_star=0.3443136047341255
# [deAm] eu price :: tree=jr | p_eu=1.9069719528613978
# [deAm] sigma* :: tree=jr | sigma_star=0.3371959212288786
# [deAm] eu price :: tree=jr | p_eu=2.217388235207117
# [deAm] sigma* :: tree=jr | sigma_star=0.33315437432470335
# [deAm] eu price :: tree=jr | p_eu=2.6609206701474717
# [deAm] sigma* :: tree=jr | sigma_star=0.32165588469186707
# [deAm] eu price :: tree=jr | p_eu=2.932829776575067
# [deAm] sigma* :: tree=jr | sigma_star=0.3140157107941454
# [deAm] eu price :: tree=jr | p_eu=3.3683380946956953
# [deAm] sigma* :: tree=jr | sigma_star=0.3086099244865313
# [deAm] eu price :: tree=jr | p_eu=3.948569503976214
# [deAm] sigma* :: tree=jr | sigma_star=0.30174330642633435
# [deAm] eu price :: tree=jr | p_eu=4.5486609500087205
# [deAm] sigma* :: tree=jr | sigma_star=0.295898574781496
# [deAm] eu price :: tree=jr | p_eu=5.276203803491565
# [deAm] sigma* :: tree=jr | sigma_star=0.2902951569054554
# [deAm] eu price :: tree=jr | p_eu=6.113322971275479
# [deAm] sigma* :: tree=jr | sigma_star=0.2835482874205862
# [deAm] eu price :: tree=jr | p_eu=6.997531480165332
# [deAm] sigma* :: tree=jr | sigma_star=0.2791988368929833
# [deAm] eu price :: tree=jr | p_eu=8.133621150940467
# [deAm] sigma* :: tree=jr | sigma_star=0.27336171673954907
# [deAm] eu price :: tree=jr | p_eu=9.318359496559673
# [deAm] sigma* :: tree=jr | sigma_star=0.2680041434215368
# [deAm] eu price :: tree=jr | p_eu=10.676533788539782
# [deAm] sigma* :: tree=jr | sigma_star=0.2646671503385509
# [deAm] eu price :: tree=jr | p_eu=12.331124143646653
# [deAm] sigma* :: tree=jr | sigma_star=0.2605244804019111
# [deAm] eu price :: tree=jr | p_eu=14.107175188468638
# [deAm] sigma* :: tree=jr | sigma_star=0.25823759753147324
# [deAm] eu price :: tree=jr | p_eu=16.203166063216358
# [deAm] sigma* :: tree=jr | sigma_star=0.2542684273159098
# [deAm] eu price :: tree=jr | p_eu=18.369311533028434
# [deAm] sigma* :: tree=jr | sigma_star=0.25059433880157994
# [deAm] eu price :: tree=jr | p_eu=20.754216038152496
# [deAm] sigma* :: tree=jr | sigma_star=0.250172317890807
# [deAm] eu price :: tree=jr | p_eu=23.58288957914055
# [deAm] sigma* :: tree=jr | sigma_star=0.2418583741028163
# [deAm] eu price :: tree=jr | p_eu=26.026050773669084
# [deAm] sigma* :: tree=jr | sigma_star=0.24231337806578823
# [deAm] eu price :: tree=jr | p_eu=29.314036509644357
# [deAm] sigma* :: tree=jr | sigma_star=0.23853776634604007
# [deAm] eu price :: tree=jr | p_eu=32.48939962071443
# [deAm] sigma* :: tree=jr | sigma_star=0.2393642073213093
# [deAm] eu price :: tree=jr | p_eu=36.158767028298236
# [deAm] sigma* :: tree=jr | sigma_star=0.2383274036786764
# [deAm] eu price :: tree=jr | p_eu=39.86495433368271
# [deAm] sigma* :: tree=jr | sigma_star=0.5525427265835843
# [deAm] eu price :: tree=jr | p_eu=83.45942623155884
# [deAm] sigma* :: tree=jr | sigma_star=0.23003536677551617
# [deAm] eu price :: tree=jr | p_eu=69.36571258024806
# [deAm] sigma* :: tree=jr | sigma_star=0.5804977841127065
# [deAm] eu price :: tree=jr | p_eu=93.00738035361407
# [deAm] sigma* :: tree=jr | sigma_star=0.39832009978229344
# [deAm] eu price :: tree=jr | p_eu=1.0821140497664503
# [deAm] sigma* :: tree=jr | sigma_star=0.3961499249253725
# [deAm] eu price :: tree=jr | p_eu=1.3380731828077659
# [deAm] sigma* :: tree=jr | sigma_star=0.3810617244192859
# [deAm] eu price :: tree=jr | p_eu=1.760211689658127
# [deAm] sigma* :: tree=jr | sigma_star=0.37008155084500766
# [deAm] eu price :: tree=jr | p_eu=1.9308959739098666
# [deAm] sigma* :: tree=jr | sigma_star=0.35805614179598155
# [deAm] eu price :: tree=jr | p_eu=2.089829354242801
# [deAm] sigma* :: tree=jr | sigma_star=0.3460134353556837
# [deAm] eu price :: tree=jr | p_eu=2.2595114723308174
# [deAm] sigma* :: tree=jr | sigma_star=0.3385380798791836
# [deAm] eu price :: tree=jr | p_eu=3.1699265993439973
# [deAm] sigma* :: tree=jr | sigma_star=0.3321634680581829
# [deAm] eu price :: tree=jr | p_eu=3.626777306420926
# [deAm] sigma* :: tree=jr | sigma_star=0.32512165181570063
# [deAm] eu price :: tree=jr | p_eu=4.111992969560555
# [deAm] sigma* :: tree=jr | sigma_star=0.319905139713959
# [deAm] eu price :: tree=jr | p_eu=4.732726488457411
# [deAm] sigma* :: tree=jr | sigma_star=0.3068459872882547
# [deAm] eu price :: tree=jr | p_eu=5.060049157961871
# [deAm] sigma* :: tree=jr | sigma_star=0.3063941816972212
# [deAm] eu price :: tree=jr | p_eu=6.049757787336943
# [deAm] sigma* :: tree=jr | sigma_star=0.304454505966208
# [deAm] eu price :: tree=jr | p_eu=7.087214650161128
# [deAm] sigma* :: tree=jr | sigma_star=0.2921658868776576
# [deAm] eu price :: tree=jr | p_eu=7.636416693199874
# [deAm] sigma* :: tree=jr | sigma_star=0.29169909441032865
# [deAm] eu price :: tree=jr | p_eu=8.97956074381201
# [deAm] sigma* :: tree=jr | sigma_star=0.2900636540125253
# [deAm] eu price :: tree=jr | p_eu=10.396514139910517
# [deAm] sigma* :: tree=jr | sigma_star=0.2803028560937248
# [deAm] eu price :: tree=jr | p_eu=11.389311623224643
# [deAm] sigma* :: tree=jr | sigma_star=0.2784586863989979
# [deAm] eu price :: tree=jr | p_eu=13.065990379518208
# [deAm] sigma* :: tree=jr | sigma_star=0.274840483196264
# [deAm] eu price :: tree=jr | p_eu=14.76727115448001
# [deAm] sigma* :: tree=jr | sigma_star=0.2683156665974096
# [deAm] eu price :: tree=jr | p_eu=16.395108623756823
# [deAm] sigma* :: tree=jr | sigma_star=0.26667182106427434
# [deAm] eu price :: tree=jr | p_eu=18.567944560635265
# [deAm] sigma* :: tree=jr | sigma_star=0.26349532065730236
# [deAm] eu price :: tree=jr | p_eu=20.788513776678876
# [deAm] sigma* :: tree=jr | sigma_star=0.2598727254823223
# [deAm] eu price :: tree=jr | p_eu=23.144154695922243
# [deAm] sigma* :: tree=jr | sigma_star=0.26095291480328336
# [deAm] eu price :: tree=jr | p_eu=26.061381957824306
# [deAm] sigma* :: tree=jr | sigma_star=0.24945212485926146
# [deAm] eu price :: tree=jr | p_eu=31.2976477585023
# [deAm] sigma* :: tree=jr | sigma_star=0.24774118630970682
# [deAm] eu price :: tree=jr | p_eu=41.639192130228466
# [deAm] sigma* :: tree=jr | sigma_star=0.5992802262630993
# [deAm] eu price :: tree=jr | p_eu=1.2234081917175355
# [deAm] tree attempt failed :: tree=jr | err=bad inputs
# [deAm] tree attempt failed :: tree=trigeorgis | err=bad inputs
# [deAm] tree attempt failed :: tree=tian | err=bad inputs
# [deAm] tree attempt failed :: tree=crr | err=bad inputs
# [deAm] tree attempt failed :: tree=lr | err=bad inputs
# [deAm] IV: deAm failed :: P_raw=0.0 | P_eu=None
# [deAm] sigma* :: tree=jr | sigma_star=0.5004339198160759
# [deAm] eu price :: tree=jr | p_eu=0.6764080666500789
# [deAm] sigma* :: tree=jr | sigma_star=0.49087109673916435
# [deAm] eu price :: tree=jr | p_eu=0.7723401839845861
# [deAm] sigma* :: tree=jr | sigma_star=0.46166443947870534
# [deAm] eu price :: tree=jr | p_eu=0.6824650191697658
# [deAm] sigma* :: tree=jr | sigma_star=0.45234022885251185
# [deAm] eu price :: tree=jr | p_eu=0.7769541827779622
# [deAm] sigma* :: tree=jr | sigma_star=0.48381292399460035
# [deAm] eu price :: tree=jr | p_eu=1.4244227792567135
# [deAm] sigma* :: tree=jr | sigma_star=0.4040050415840733
# ...
# [deAm] eu price :: tree=jr | p_eu=70.70115662560866
# [deAm] sigma* :: tree=jr | sigma_star=0.28990931203518966
# [deAm] eu price :: tree=jr | p_eu=67.426484754451
# [deAm] sigma* :: tree=jr | sigma_star=0.29055740562349625
# [deAm] eu price :: tree=jr | p_eu=64.72807202531133
# [deAm] sigma* :: tree=jr | sigma_star=0.28612984904126465
# [deAm] eu price :: tree=jr | p_eu=61.44099299269167
# [deAm] sigma* :: tree=jr | sigma_star=0.2815113505450047
# [deAm] eu price :: tree=jr | p_eu=58.188230104812206
# [deAm] sigma* :: tree=jr | sigma_star=0.27616644965430887
# [deAm] eu price :: tree=jr | p_eu=54.89505381682199
# [deAm] sigma* :: tree=jr | sigma_star=0.279202760592223
# [deAm] eu price :: tree=jr | p_eu=52.862631902579324
# [deAm] sigma* :: tree=jr | sigma_star=0.2750330731709846
# [deAm] eu price :: tree=jr | p_eu=49.884590898480454
# [deAm] sigma* :: tree=jr | sigma_star=0.27330356621044355
# [deAm] eu price :: tree=jr | p_eu=47.33674334261453
# [deAm] sigma* :: tree=jr | sigma_star=0.2696878926593847
# [deAm] eu price :: tree=jr | p_eu=44.58709420201131
# [deAm] sigma* :: tree=jr | sigma_star=0.2680808903418614
# [deAm] eu price :: tree=jr | p_eu=42.21604707744038
# [deAm] sigma* :: tree=jr | sigma_star=0.26360911453904406
# [deAm] eu price :: tree=jr | p_eu=37.52446888659259
# [deAm] sigma* :: tree=jr | sigma_star=0.258064412704259
# [deAm] eu price :: tree=jr | p_eu=32.98695500820324
# [deAm] sigma* :: tree=jr | sigma_star=0.25239522182877505
# [deAm] eu price :: tree=jr | p_eu=28.750973039598374
# [deAm] sigma* :: tree=jr | sigma_star=0.25188938571802727
# [deAm] eu price :: tree=jr | p_eu=25.620852486918455
# [deAm] sigma* :: tree=jr | sigma_star=0.24723115607543747
# [deAm] eu price :: tree=jr | p_eu=22.16556421745676
# [deAm] sigma* :: tree=jr | sigma_star=0.24403153974560907
# [deAm] eu price :: tree=jr | p_eu=19.22744734324427
# [deAm] sigma* :: tree=jr | sigma_star=0.24187266884731604
# [deAm] eu price :: tree=jr | p_eu=16.71756310456242
# [deAm] sigma* :: tree=jr | sigma_star=0.24439143597496932
# [deAm] eu price :: tree=jr | p_eu=15.086644222219485
# [deAm] sigma* :: tree=jr | sigma_star=0.23722786265524584
# [deAm] eu price :: tree=jr | p_eu=12.414351608555805
# [deAm] sigma* :: tree=jr | sigma_star=0.23926677769419397
# [deAm] eu price :: tree=jr | p_eu=11.128117860564885
# [deAm] sigma* :: tree=jr | sigma_star=0.2333656240890153
# [deAm] eu price :: tree=jr | p_eu=9.105867308151353
# [deAm] sigma* :: tree=jr | sigma_star=0.23458928924326403
# [deAm] eu price :: tree=jr | p_eu=8.065010868532996
# [deAm] sigma* :: tree=jr | sigma_star=0.23680875399797668
# [deAm] eu price :: tree=jr | p_eu=7.246027135204076
# [deAm] sigma* :: tree=jr | sigma_star=0.23289128911302365
# [deAm] eu price :: tree=jr | p_eu=5.972079092028082
# [deAm] sigma* :: tree=jr | sigma_star=0.23752226872368654
# [deAm] eu price :: tree=jr | p_eu=5.57244969209188
# [deAm] sigma* :: tree=jr | sigma_star=0.360213528813752
# [deAm] eu price :: tree=jr | p_eu=162.00056070335108
# [deAm] sigma* :: tree=jr | sigma_star=0.35317774074203934
# [deAm] eu price :: tree=jr | p_eu=157.66831427481702
# [deAm] sigma* :: tree=jr | sigma_star=0.33989812900873084
# [deAm] eu price :: tree=jr | p_eu=149.06766899521625
# [deAm] sigma* :: tree=jr | sigma_star=0.3460061317306135
# [deAm] eu price :: tree=jr | p_eu=145.53717953648922
# [deAm] sigma* :: tree=jr | sigma_star=0.33375420571037373
# [deAm] eu price :: tree=jr | p_eu=140.94561902504662
# [deAm] sigma* :: tree=jr | sigma_star=0.3423308630050388
# [deAm] eu price :: tree=jr | p_eu=137.73939199633014
# [deAm] sigma* :: tree=jr | sigma_star=0.3395270998846594
# [deAm] eu price :: tree=jr | p_eu=133.84268950964
# [deAm] sigma* :: tree=jr | sigma_star=0.3288295761947612
# [deAm] eu price :: tree=jr | p_eu=125.75361032223695
# [deAm] sigma* :: tree=jr | sigma_star=0.32251224393159433
# [deAm] eu price :: tree=jr | p_eu=118.14960057454245
# [deAm] sigma* :: tree=jr | sigma_star=0.31621232389456677
# [deAm] eu price :: tree=jr | p_eu=110.71493589308422
# [deAm] sigma* :: tree=jr | sigma_star=0.3035801638010935
# [deAm] eu price :: tree=jr | p_eu=102.76416490786892
# [deAm] sigma* :: tree=jr | sigma_star=0.29907926935748824
# [deAm] eu price :: tree=jr | p_eu=95.8406729101539
# [deAm] sigma* :: tree=jr | sigma_star=0.29593191292896825
# [deAm] eu price :: tree=jr | p_eu=89.31248181585686
# [deAm] sigma* :: tree=jr | sigma_star=0.2882736660341948
# [deAm] eu price :: tree=jr | p_eu=82.42469501600614
# [deAm] sigma* :: tree=jr | sigma_star=0.2812879209674566
# [deAm] eu price :: tree=jr | p_eu=75.81728961763606
# [deAm] sigma* :: tree=jr | sigma_star=0.2813988512863703
# [deAm] eu price :: tree=jr | p_eu=70.48899162450256
# [deAm] sigma* :: tree=jr | sigma_star=0.27944792874925417
# [deAm] eu price :: tree=jr | p_eu=65.14700223980988
# [deAm] sigma* :: tree=jr | sigma_star=0.270172162513077
# [deAm] eu price :: tree=jr | p_eu=58.88178797546304
# [deAm] sigma* :: tree=jr | sigma_star=0.2704550920238075
# [deAm] eu price :: tree=jr | p_eu=54.43961687703609
# [deAm] sigma* :: tree=jr | sigma_star=0.26836515989547677
# [deAm] eu price :: tree=jr | p_eu=49.884254101598394
# [deAm] sigma* :: tree=jr | sigma_star=0.2607878676971374
# [deAm] eu price :: tree=jr | p_eu=44.634190213582606
# [deAm] sigma* :: tree=jr | sigma_star=0.2593808859685372
# [deAm] eu price :: tree=jr | p_eu=40.72843679573262
# [deAm] sigma* :: tree=jr | sigma_star=0.2544196004312908
# [deAm] eu price :: tree=jr | p_eu=36.45408659149858
# [deAm] sigma* :: tree=jr | sigma_star=0.25213616647754733
# [deAm] eu price :: tree=jr | p_eu=32.91578205595705
# [deAm] sigma* :: tree=jr | sigma_star=0.24843696256744163
# [deAm] eu price :: tree=jr | p_eu=29.37970042429329
# [deAm] sigma* :: tree=jr | sigma_star=0.24807104947393002
# [deAm] eu price :: tree=jr | p_eu=26.672943735691913
# [deAm] sigma* :: tree=jr | sigma_star=0.2450757546460233
# [deAm] eu price :: tree=jr | p_eu=23.740712917578144
# [deAm] sigma* :: tree=jr | sigma_star=0.24368567226410423
# [deAm] eu price :: tree=jr | p_eu=21.304579781739037
# [deAm] sigma* :: tree=jr | sigma_star=0.2435736268842811
# [deAm] eu price :: tree=jr | p_eu=19.279259326006777
# [deAm] sigma* :: tree=jr | sigma_star=0.23421113016809475
# [deAm] eu price :: tree=jr | p_eu=14.395276204154833
# [deAm] sigma* :: tree=jr | sigma_star=0.23136232168501675
# [deAm] eu price :: tree=jr | p_eu=12.53999807596533
# [deAm] sigma* :: tree=jr | sigma_star=0.23679556598707724
# [deAm] eu price :: tree=jr | p_eu=11.97190009287879
# [deAm] sigma* :: tree=jr | sigma_star=0.23660100407132725
# [deAm] eu price :: tree=jr | p_eu=10.74294542392416
# [deAm] sigma* :: tree=jr | sigma_star=0.23640206701829916
# [deAm] eu price :: tree=jr | p_eu=9.632843485519427
# [deAm] sigma* :: tree=jr | sigma_star=0.4454096772154758
# [deAm] eu price :: tree=jr | p_eu=206.11213705921227
# [deAm] tree attempt failed :: tree=jr | err=no-arb violation
# [deAm] tree attempt failed :: tree=trigeorgis | err=no-arb violation
# [deAm] tree attempt failed :: tree=tian | err=no-arb violation
# [deAm] tree attempt failed :: tree=crr | err=no-arb violation
# [deAm] tree attempt failed :: tree=lr | err=no-arb violation
# [deAm] IV: deAm failed :: P_raw=192.0 | P_eu=None
# [deAm] sigma* :: tree=jr | sigma_star=0.4268171049538503
# [deAm] eu price :: tree=jr | p_eu=197.17425561340988
# [deAm] sigma* :: tree=jr | sigma_star=0.40587085755830254
# [deAm] eu price :: tree=jr | p_eu=192.41326452518223
# [deAm] tree attempt failed :: tree=jr | err=no-arb violation
# [deAm] tree attempt failed :: tree=trigeorgis | err=no-arb violation
# [deAm] tree attempt failed :: tree=tian | err=no-arb violation
# [deAm] tree attempt failed :: tree=crr | err=no-arb violation
# [deAm] tree attempt failed :: tree=lr | err=no-arb violation
# [deAm] IV: deAm failed :: P_raw=183.0 | P_eu=None
# [deAm] sigma* :: tree=jr | sigma_star=0.4030207891006879
# [deAm] eu price :: tree=jr | p_eu=183.9016733654807
# [deAm] sigma* :: tree=jr | sigma_star=0.38366431543751167
# [deAm] eu price :: tree=jr | p_eu=179.11972961021215
# [deAm] sigma* :: tree=jr | sigma_star=0.3794711695847369
# [deAm] eu price :: tree=jr | p_eu=174.81133084525067
# [deAm] sigma* :: tree=jr | sigma_star=0.3747545413315993
# [deAm] eu price :: tree=jr | p_eu=170.50792310254144
# [deAm] sigma* :: tree=jr | sigma_star=0.36885486171079984
# [deAm] eu price :: tree=jr | p_eu=166.17834624879234
# [deAm] tree attempt failed :: tree=jr | err=no-arb violation
# [deAm] tree attempt failed :: tree=trigeorgis | err=no-arb violation
# [deAm] tree attempt failed :: tree=tian | err=no-arb violation
# [deAm] tree attempt failed :: tree=crr | err=no-arb violation
# [deAm] tree attempt failed :: tree=lr | err=no-arb violation
# [deAm] IV: deAm failed :: P_raw=151.5 | P_eu=None
# [deAm] sigma* :: tree=jr | sigma_star=0.35568520614640886
# [deAm] eu price :: tree=jr | p_eu=157.49938310444583
# [deAm] sigma* :: tree=jr | sigma_star=0.35313555068593844
# [deAm] eu price :: tree=jr | p_eu=153.37609932302885
# [deAm] sigma* :: tree=jr | sigma_star=0.3586817504754046
# [deAm] eu price :: tree=jr | p_eu=149.74015438629704
# [deAm] tree attempt failed :: tree=jr | err=no-arb violation
# [deAm] tree attempt failed :: tree=trigeorgis | err=no-arb violation
# [deAm] tree attempt failed :: tree=tian | err=no-arb violation
# [deAm] tree attempt failed :: tree=crr | err=no-arb violation
# [deAm] tree attempt failed :: tree=lr | err=no-arb violation
# [deAm] IV: deAm failed :: P_raw=129.05 | P_eu=None
# [deAm] sigma* :: tree=jr | sigma_star=0.34107200264257864
# [deAm] eu price :: tree=jr | p_eu=140.97265645505638
# [deAm] sigma* :: tree=jr | sigma_star=0.3433237895911564
# [deAm] eu price :: tree=jr | p_eu=137.31543005201195
# [deAm] sigma* :: tree=jr | sigma_star=0.3328524275843296
# [deAm] eu price :: tree=jr | p_eu=132.84065239785147
# [deAm] sigma* :: tree=jr | sigma_star=0.3267864528232844
# [deAm] eu price :: tree=jr | p_eu=128.6759828361547
# [deAm] sigma* :: tree=jr | sigma_star=0.3277336798183302
# [deAm] eu price :: tree=jr | p_eu=125.07597879855295
# [deAm] sigma* :: tree=jr | sigma_star=0.3179978204190373
# [deAm] eu price :: tree=jr | p_eu=117.09064006307689
# [deAm] sigma* :: tree=jr | sigma_star=0.3125927852631091
# [deAm] eu price :: tree=jr | p_eu=109.63288651702253
# [deAm] sigma* :: tree=jr | sigma_star=0.3119720964044612
# [deAm] eu price :: tree=jr | p_eu=102.88017252473564
# [deAm] sigma* :: tree=jr | sigma_star=0.3010200005453786
# [deAm] eu price :: tree=jr | p_eu=95.22349532065263
# [deAm] sigma* :: tree=jr | sigma_star=0.29498321034771496
# [deAm] eu price :: tree=jr | p_eu=88.29022292957434
# [deAm] sigma* :: tree=jr | sigma_star=0.2883026706419001
# [deAm] eu price :: tree=jr | p_eu=81.47980830061526
# [deAm] sigma* :: tree=jr | sigma_star=0.285711734591826
# [deAm] eu price :: tree=jr | p_eu=75.45170720200394
# [deAm] sigma* :: tree=jr | sigma_star=0.28345360746586096
# [deAm] eu price :: tree=jr | p_eu=69.75157869774411
# [deAm] sigma* :: tree=jr | sigma_star=0.2752220559748907
# [deAm] eu price :: tree=jr | p_eu=63.407297035165215
# [deAm] sigma* :: tree=jr | sigma_star=0.2710654157142272
# [deAm] eu price :: tree=jr | p_eu=57.93260041923949
# [deAm] sigma* :: tree=jr | sigma_star=0.27123052376395446
# [deAm] eu price :: tree=jr | p_eu=53.44398589805168
# [deAm] sigma* :: tree=jr | sigma_star=0.2662964590767241
# [deAm] eu price :: tree=jr | p_eu=48.39194880320673
# [deAm] sigma* :: tree=jr | sigma_star=0.2648661625385805
# [deAm] eu price :: tree=jr | p_eu=44.2085865814886
# [deAm] sigma* :: tree=jr | sigma_star=0.25841532907724163
# [deAm] eu price :: tree=jr | p_eu=39.42738396358612
# [deAm] sigma* :: tree=jr | sigma_star=0.2555530150718812
# [deAm] eu price :: tree=jr | p_eu=35.53756730119874
# [deAm] sigma* :: tree=jr | sigma_star=0.2543033111568679
# [deAm] eu price :: tree=jr | p_eu=32.19422146408285
# [deAm] sigma* :: tree=jr | sigma_star=0.2462103438691163
# [deAm] eu price :: tree=jr | p_eu=27.925616301981638
# [deAm] sigma* :: tree=jr | sigma_star=0.2458876638471885
# [deAm] eu price :: tree=jr | p_eu=25.252902393730277
# [deAm] sigma* :: tree=jr | sigma_star=0.24510455315671065
# [deAm] eu price :: tree=jr | p_eu=22.73195394813958
# [deAm] sigma* :: tree=jr | sigma_star=0.24234282073064675
# [deAm] eu price :: tree=jr | p_eu=20.109432463705783
# [deAm] sigma* :: tree=jr | sigma_star=0.23666335080551093
# [deAm] eu price :: tree=jr | p_eu=17.259734970595705
# [deAm] sigma* :: tree=jr | sigma_star=0.23892489169936326
# [deAm] eu price :: tree=jr | p_eu=15.83966314102919
# [deAm] sigma* :: tree=jr | sigma_star=0.23557852256345838
# [deAm] eu price :: tree=jr | p_eu=13.76055173233817
# [deAm] sigma* :: tree=jr | sigma_star=0.23176313085062747
# [deAm] eu price :: tree=jr | p_eu=11.819032647423228
# [deAm] sigma* :: tree=jr | sigma_star=0.22750051538147725
# [deAm] eu price :: tree=jr | p_eu=7.930771812860372
# [deAm] group priced :: group=('JPM',)
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0     JPM251114P00160000 2025-10-27 13:46:23+00:00   160.0       0.01   0.00
# 1     JPM251114P00180000 2025-11-07 18:01:01+00:00   180.0       0.04   0.00
# 2     JPM251114P00200000 2025-10-31 14:42:36+00:00   200.0       0.05   0.00
# 3     JPM251114P00210000 2025-10-14 14:27:52+00:00   210.0       1.12   0.00
# 4     JPM251114P00215000 2025-10-31 14:52:31+00:00   215.0       0.08   0.00
# ...                  ...                       ...     ...        ...    ...
# 1570  JPM271217C00410000 2025-11-07 18:46:59+00:00   410.0      17.10  16.25
# 1571  JPM271217C00420000 2025-10-29 18:58:44+00:00   420.0      12.40  15.40
# 1572  JPM271217C00430000 2025-10-29 17:11:50+00:00   430.0      10.75  13.05
# 1573  JPM271217C00440000 2025-11-07 19:50:17+00:00   440.0      12.15  11.10
# 1574  JPM271217C00470000 2025-10-31 16:57:42+00:00   470.0       7.25   6.00
#
#         ask    change  percentChange  volume  openInterest  ...  expiration  \
# 0      0.23  0.000000       0.000000     5.0             6  ...  2025-11-14
# 1      0.13 -0.100000     -71.428570     1.0             1  ...  2025-11-14
# 2      2.12  0.000000       0.000000     2.0             4  ...  2025-11-14
# 3      1.76  0.000000       0.000000     1.0             2  ...  2025-11-14
# 4      0.05  0.000000       0.000000     5.0            15  ...  2025-11-14
# ...     ...       ...            ...     ...           ...  ...         ...
# 1570  18.30  1.600000      10.322582    10.0           120  ...  2027-12-17
# 1571  16.25  0.000000       0.000000     1.0            40  ...  2027-12-17
# 1572  14.45  0.000000       0.000000     2.0             8  ...  2027-12-17
# 1573  12.55  2.259999      22.851357    10.0           125  ...  2027-12-17
# 1574   9.85  0.000000       0.000000     2.0            11  ...  2027-12-17
#
#            TTM dividendYield ticker  spot_price optionType         r  \
# 0     0.019178        0.0191    JPM  314.209991        put  0.040331
# 1     0.019178        0.0191    JPM  314.209991        put  0.040331
# 2     0.019178        0.0191    JPM  314.209991        put  0.040331
# 3     0.019178        0.0191    JPM  314.209991        put  0.040331
# 4     0.019178        0.0191    JPM  314.209991        put  0.040331
# ...        ...           ...    ...         ...        ...       ...
# 1570  2.109589        0.0191    JPM  314.209991       call  0.035504
# 1571  2.109589        0.0191    JPM  314.209991       call  0.035504
# 1572  2.109589        0.0191    JPM  314.209991       call  0.035504
# 1573  2.109589        0.0191    JPM  314.209991       call  0.035504
# 1574  2.109589        0.0191    JPM  314.209991       call  0.035504
#
#       forward_log_moneyness midPrice   V_EU_Heston
# 0                 -0.675295    0.115  1.241352e-10
# 1                 -0.557512    0.065  9.148236e-09
# 2                 -0.452151    1.060  4.159050e-07
# 3                 -0.403361    0.880  2.408185e-06
# 4                 -0.379831    0.025  5.600794e-06
# ...                     ...      ...           ...
# 1570               0.231491   17.275  2.073435e+01
# 1571               0.255588   15.825  1.861589e+01
# 1572               0.279119   13.750  1.670044e+01
# 1573               0.302108   11.825  1.497301e+01
# 1574               0.368066    7.925  1.077197e+01
#
# [1575 rows x 25 columns]

# %%
df.describe()
# Out:
#             strike    lastPrice          bid          ask       change  \
# count  1575.000000  1575.000000  1575.000000  1575.000000  1575.000000
# mean    262.500000    37.428844    37.450444    39.068203    -0.022857
# std      87.490288    51.703350    53.208820    54.254441     1.104338
# min      65.000000     0.010000     0.000000     0.000000   -11.660000
# 25%     190.000000     1.285000     0.920000     1.965000     0.000000
# 50%     270.000000    10.950000    10.450000    11.550000     0.000000
# 75%     321.250000    54.325000    52.700000    54.750000     0.000000
# max     470.000000   240.200000   242.750000   246.100000    13.110001
#
#        percentChange       volume  openInterest  impliedVolatility  \
# count    1575.000000  1575.000000   1575.000000        1575.000000
# mean        9.457881    56.989206    488.363175           0.469281
# std       182.361424   290.838084    969.676568           0.480324
# min       -98.461540     1.000000      0.000000           0.000010
# 25%         0.000000     2.000000     20.000000           0.259910
# 50%         0.000000     5.000000    102.000000           0.329841
# 75%         0.000000    22.000000    488.000000           0.488958
# max      4800.004400  6744.000000   8789.000000           6.646486
#
#                TTM  dividendYield   spot_price            r  \
# count  1575.000000   1.575000e+03  1575.000000  1575.000000
# mean      0.627869   1.910000e-02   314.209991     0.038123
# std       0.654474   3.470549e-18     0.000000     0.001797
# min       0.000000   1.910000e-02   314.209991     0.035504
# 25%       0.115068   1.910000e-02   314.209991     0.036360
# 50%       0.364384   1.910000e-02   314.209991     0.038055
# 75%       0.987671   1.910000e-02   314.209991     0.040003
# max       2.205479   1.910000e-02   314.209991     0.040400
#
#        forward_log_moneyness     midPrice   V_EU_Heston
# count            1575.000000  1575.000000  1.575000e+03
# mean               -0.255126    38.259324  3.900012e+01
# std                 0.377693    53.730146  5.578327e+01
# min                -1.578080     0.000000 -5.950684e-12
# 25%                -0.509323     1.172500  1.212767e+00
# 50%                -0.159748    10.775000  1.072229e+01
# 75%                 0.017650    53.725000  5.429268e+01
# max                 0.387519   244.425000  2.488211e+02

# %%
df.columns
# Out:
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        'impliedVolatility', 'inTheMoney', 'contractSize', 'currency',
#        'option_type', 'expiration', 'TTM', 'dividendYield', 'ticker',
#        'spot_price', 'optionType', 'r', 'forward_log_moneyness', 'midPrice',
#        'V_EU_Heston'],
#       dtype='object')
