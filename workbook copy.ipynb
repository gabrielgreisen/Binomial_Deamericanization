# %% [markdown]
# **Imports**

# %%
import yfinance as yf
from datetime import datetime
import pandas as pd
from typing import Tuple
from concurrent.futures import ThreadPoolExecutor, as_completed
import numpy as np
import math
import QuantLib as ql

# %% [markdown]
# **Define price fetcher**

# %%
def get_spot_price(ticker):
    """
    Fetches the current spot price for a stock ticker. Falls back to the most recent
    close if a live price is not available.

    Parameters
    ----------
    ticker : str
        Stock ticker symbol (e.g., 'AAPL').

    Returns
    -------
    float or None
        Spot price (live if available, else last close). Returns None if unavailable.
    """

    try:
        tk = yf.Ticker(ticker)
        
        # Attempt to fetch live price
        live_price = tk.fast_info.get("last_price", None)
        if live_price and live_price > 0:
            return live_price

        # Fallback: most recent close
        hist = tk.history(period="1d")
        if not hist.empty:
            fallback_price = hist["Close"].iloc[-1]
            print(f"[{ticker}] Live price unavailable — using last close: {fallback_price:.2f}")
            return fallback_price

        print(f"[{ticker}] No live or historical data available.")
        return None

    except Exception as e:
        print(f"[{ticker}] Spot price fetch failed: {e}")
        return None

# %% [markdown]
# **Define Option Chain Fetcher**

# %%
def get_option_chains_all(ticker: str,
                                  max_workers: int = 8) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Fetches option chains (calls and puts) for every available expiry of a given ticker,
    performing API requests in parallel to reduce total fetch time.

    Parameters
    ----------
    ticker : str
        Stock ticker symbol (e.g., 'AAPL').
    max_workers : int, optional
        Maximum number of threads to use for concurrent fetching (default is 8).

    Returns
    -------
    Tuple[pd.DataFrame, pd.DataFrame]
        - calls_df: DataFrame containing all calls across expiries, with added columns:
            * 'option_type' = 'call'
            * 'expiration'  = expiry date string 'YYYY-MM-DD'
            * 'TTM'         = time to maturity in years
        - puts_df: DataFrame containing all puts with the same added columns.
    """
    stock = yf.Ticker(ticker)
    expiries = stock.options  # list of expiry date strings
    today = datetime.now().date()

    calls_accum = []
    puts_accum  = []

    def fetch_chain(expiry: str):
        """Fetch calls/puts for a single expiry and return (expiry, calls_df, puts_df)."""
        try:
            chain = stock.option_chain(expiry)
            calls = chain.calls.copy()
            puts  = chain.puts.copy()
        except Exception as e:
            # Return None on error so we can skip later
            return expiry, None, None

        # Tag each row with type and expiration
        calls['option_type']  = 'call'
        puts ['option_type']  = 'put'
        calls['expiration']   = expiry
        puts ['expiration']   = expiry

        # Compute time-to-maturity once
        exp_date = datetime.strptime(expiry, "%Y-%m-%d").date()
        ttm = max((exp_date - today).days / 365.0, 0.0)
        calls['TTM'] = ttm
        puts ['TTM'] = ttm

        return expiry, calls, puts

    # Fetch in parallel
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(fetch_chain, exp) for exp in expiries]
        for future in as_completed(futures):
            expiry, calls_df, puts_df = future.result()
            if calls_df is not None and not calls_df.empty:
                calls_accum.append(calls_df)
            if puts_df  is not None and not puts_df.empty:
                puts_accum.append(puts_df)

    # Concatenate results
    all_calls = pd.concat(calls_accum, ignore_index=True) if calls_accum else pd.DataFrame()
    all_puts  = pd.concat(puts_accum,  ignore_index=True) if puts_accum  else pd.DataFrame()

    # Fetch dividend yield for the company
    dividendYield = stock.info.get("dividendYield")/100 # percentages on decimal basis
    all_calls["dividendYield"] = dividendYield
    all_puts["dividendYield"] = dividendYield

    all_calls["ticker"] = ticker
    all_puts["ticker"] = ticker

    spot_price = get_spot_price(ticker)
    all_calls["spot_price"] = spot_price
    all_puts["spot_price"] = spot_price

    return all_calls, all_puts

# %% [markdown]
# Get option chain and dividend yield

# %%
calls, puts = get_option_chains_all("AAPL")
# Out:
# [AAPL] Live price unavailable — using last close: 268.45

# %%
calls
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice  \
# 0     AAPL251205C00165000 2025-10-31 13:30:12+00:00   165.0     111.70
# 1     AAPL251205C00170000 2025-10-31 14:11:10+00:00   170.0     100.24
# 2     AAPL251205C00185000 2025-10-31 13:30:12+00:00   185.0      92.00
# 3     AAPL251205C00190000 2025-11-06 18:19:57+00:00   190.0      81.70
# 4     AAPL251205C00200000 2025-11-05 17:02:02+00:00   200.0      70.70
# ...                   ...                       ...     ...        ...
# 1221  AAPL280121C00490000 2025-10-31 19:49:20+00:00   490.0       4.90
# 1222  AAPL280121C00500000 2025-11-07 18:21:15+00:00   500.0       4.35
# 1223  AAPL280121C00510000 2025-11-06 16:40:48+00:00   510.0       4.05
# 1224  AAPL280121C00520000 2025-11-07 15:34:36+00:00   520.0       3.69
# 1225  AAPL280121C00530000 2025-11-07 20:03:15+00:00   530.0       3.05
#
#          bid     ask  change  percentChange  volume  openInterest  \
# 0     100.80  104.35    0.00       0.000000     1.0             1
# 1      96.05   98.50    0.00       0.000000     1.0             1
# 2      81.00   84.50    0.00       0.000000    10.0            10
# 3      76.20   79.30    0.00       0.000000     2.0            29
# 4      66.10   69.20    0.00       0.000000     5.0             6
# ...      ...     ...     ...            ...     ...           ...
# 1221    4.50    4.70    0.00       0.000000     1.0            25
# 1222    4.05    4.25    0.00       0.000000     7.0           285
# 1223    3.60    3.80    0.00       0.000000    10.0            54
# 1224    3.25    3.45    0.11       3.072630     1.0            14
# 1225    2.96    3.15   -0.10      -3.174608    42.0           354
#
#       impliedVolatility  inTheMoney contractSize currency option_type  \
# 0              0.978516        True      REGULAR      USD        call
# 1              0.615238        True      REGULAR      USD        call
# 2              0.802980        True      REGULAR      USD        call
# 3              0.723391        True      REGULAR      USD        call
# 4              0.616947        True      REGULAR      USD        call
# ...                 ...         ...          ...      ...         ...
# 1221           0.276954       False      REGULAR      USD        call
# 1222           0.277015       False      REGULAR      USD        call
# 1223           0.276374       False      REGULAR      USD        call
# 1224           0.276649       False      REGULAR      USD        call
# 1225           0.277198       False      REGULAR      USD        call
#
#       expiration       TTM  dividendYield ticker  spot_price
# 0     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 1     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 2     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 3     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 4     2025-12-05  0.076712         0.0039   AAPL  268.450012
# ...          ...       ...            ...    ...         ...
# 1221  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1222  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1223  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1224  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1225  2028-01-21  2.205479         0.0039   AAPL  268.450012
#
# [1226 rows x 20 columns]

# %%
puts
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice  \
# 0     AAPL251205P00140000 2025-11-06 18:53:03+00:00   140.0       0.01
# 1     AAPL251205P00160000 2025-11-04 14:35:00+00:00   160.0       0.03
# 2     AAPL251205P00165000 2025-11-05 20:24:52+00:00   165.0       0.02
# 3     AAPL251205P00175000 2025-11-04 20:57:14+00:00   175.0       0.04
# 4     AAPL251205P00180000 2025-11-06 15:20:53+00:00   180.0       0.03
# ...                   ...                       ...     ...        ...
# 1052  AAPL280121P00380000 2025-10-31 18:34:12+00:00   380.0     108.95
# 1053  AAPL280121P00390000 2025-11-05 15:56:30+00:00   390.0     121.25
# 1054  AAPL280121P00400000 2025-10-30 16:43:32+00:00   400.0     128.50
# 1055  AAPL280121P00450000 2025-10-29 13:35:18+00:00   450.0     180.74
# 1056  AAPL280121P00500000 2025-10-28 16:04:08+00:00   500.0     230.95
#
#          bid     ask  change  percentChange  volume  openInterest  \
# 0       0.00    0.02     0.0            0.0     1.0            14
# 1       0.01    0.03     0.0            0.0     1.0             0
# 2       0.02    0.04     0.0            0.0     1.0             6
# 3       0.03    0.05     0.0            0.0     2.0             2
# 4       0.03    0.06     0.0            0.0     1.0             1
# ...      ...     ...     ...            ...     ...           ...
# 1052  112.90  113.50     0.0            0.0     5.0             8
# 1053  122.50  123.10     0.0            0.0     2.0            24
# 1054  132.50  133.10     0.0            0.0     NaN             0
# 1055  180.50  185.00     0.0            0.0     NaN             0
# 1056  230.50  235.00     0.0            0.0     NaN             0
#
#       impliedVolatility  inTheMoney contractSize currency option_type  \
# 0              0.734378       False      REGULAR      USD         put
# 1              0.632816       False      REGULAR      USD         put
# 2              0.621098       False      REGULAR      USD         put
# 3              0.566411       False      REGULAR      USD         put
# 4              0.539067       False      REGULAR      USD         put
# ...                 ...         ...          ...      ...         ...
# 1052           0.153756        True      REGULAR      USD         put
# 1053           0.154885        True      REGULAR      USD         put
# 1054           0.162850        True      REGULAR      USD         put
# 1055           0.232857        True      REGULAR      USD         put
# 1056           0.266395        True      REGULAR      USD         put
#
#       expiration       TTM  dividendYield ticker  spot_price
# 0     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 1     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 2     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 3     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 4     2025-12-05  0.076712         0.0039   AAPL  268.450012
# ...          ...       ...            ...    ...         ...
# 1052  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1053  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1054  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1055  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1056  2028-01-21  2.205479         0.0039   AAPL  268.450012
#
# [1057 rows x 20 columns]

# %%
calls.describe()
# Out:
#             strike    lastPrice          bid          ask       change  \
# count  1226.000000  1226.000000  1226.000000  1226.000000  1226.000000
# mean    241.272431    66.715783    65.478083    66.689576    -0.670294
# std     115.648359    70.227935    69.984938    71.235853     3.231657
# min       5.000000     0.010000     0.000000     0.000000    -8.389999
# 25%     155.000000     2.915000     2.515000     2.605000    -1.707500
# 50%     240.000000    40.450000    38.450000    39.350000    -0.060000
# 75%     320.000000   118.677500   116.125000   117.975000     0.000000
# max     530.000000   266.040000   260.850000   264.500000    70.640000
#
#        percentChange        volume  openInterest  impliedVolatility  \
# count    1226.000000   1204.000000   1226.000000        1226.000000
# mean       -6.752271    479.211794   2808.033442           0.560822
# std        14.039237   3856.273992   7073.409427           0.721523
# min       -99.371070      1.000000      0.000000           0.000010
# 25%        -8.279793      2.000000     65.000000           0.274238
# 50%        -1.518472     11.000000    379.000000           0.343757
# 75%         0.000000     68.250000   2013.500000           0.553273
# max       100.000000  89573.000000  88993.000000           7.632813
#
#                TTM  dividendYield   spot_price
# count  1226.000000   1.226000e+03  1226.000000
# mean      0.672525   3.900000e-03   268.450012
# std       0.695275   4.338578e-19     0.000000
# min       0.000000   3.900000e-03   268.450012
# 25%       0.095890   3.900000e-03   268.450012
# 50%       0.441096   3.900000e-03   268.450012
# 75%       1.112329   3.900000e-03   268.450012
# max       2.205479   3.900000e-03   268.450012

# %% [markdown]
# Initial Dataset Clean

# %%
def initial_dataset_clean(dataset : pd.DataFrame):
    # Removing columns that will not be used for training or filtering
    #cols_to_drop = ["contractSymbol", "lastTradeDate", "change", "percentChange", "expiration", "inTheMoney"]
    #dataset.drop(columns=[c for c in cols_to_drop if c in dataset.columns], inplace=True)

    # Removing NA values for stale options
    dataset.dropna(axis=0,subset=["volume"], inplace=True)

    
    return dataset

# %%
calls_clean = initial_dataset_clean(calls)
calls_clean
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice  \
# 0     AAPL251205C00165000 2025-10-31 13:30:12+00:00   165.0     111.70
# 1     AAPL251205C00170000 2025-10-31 14:11:10+00:00   170.0     100.24
# 2     AAPL251205C00185000 2025-10-31 13:30:12+00:00   185.0      92.00
# 3     AAPL251205C00190000 2025-11-06 18:19:57+00:00   190.0      81.70
# 4     AAPL251205C00200000 2025-11-05 17:02:02+00:00   200.0      70.70
# ...                   ...                       ...     ...        ...
# 1221  AAPL280121C00490000 2025-10-31 19:49:20+00:00   490.0       4.90
# 1222  AAPL280121C00500000 2025-11-07 18:21:15+00:00   500.0       4.35
# 1223  AAPL280121C00510000 2025-11-06 16:40:48+00:00   510.0       4.05
# 1224  AAPL280121C00520000 2025-11-07 15:34:36+00:00   520.0       3.69
# 1225  AAPL280121C00530000 2025-11-07 20:03:15+00:00   530.0       3.05
#
#          bid     ask  change  percentChange  volume  openInterest  \
# 0     100.80  104.35    0.00       0.000000     1.0             1
# 1      96.05   98.50    0.00       0.000000     1.0             1
# 2      81.00   84.50    0.00       0.000000    10.0            10
# 3      76.20   79.30    0.00       0.000000     2.0            29
# 4      66.10   69.20    0.00       0.000000     5.0             6
# ...      ...     ...     ...            ...     ...           ...
# 1221    4.50    4.70    0.00       0.000000     1.0            25
# 1222    4.05    4.25    0.00       0.000000     7.0           285
# 1223    3.60    3.80    0.00       0.000000    10.0            54
# 1224    3.25    3.45    0.11       3.072630     1.0            14
# 1225    2.96    3.15   -0.10      -3.174608    42.0           354
#
#       impliedVolatility  inTheMoney contractSize currency option_type  \
# 0              0.978516        True      REGULAR      USD        call
# 1              0.615238        True      REGULAR      USD        call
# 2              0.802980        True      REGULAR      USD        call
# 3              0.723391        True      REGULAR      USD        call
# 4              0.616947        True      REGULAR      USD        call
# ...                 ...         ...          ...      ...         ...
# 1221           0.276954       False      REGULAR      USD        call
# 1222           0.277015       False      REGULAR      USD        call
# 1223           0.276374       False      REGULAR      USD        call
# 1224           0.276649       False      REGULAR      USD        call
# 1225           0.277198       False      REGULAR      USD        call
#
#       expiration       TTM  dividendYield ticker  spot_price
# 0     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 1     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 2     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 3     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 4     2025-12-05  0.076712         0.0039   AAPL  268.450012
# ...          ...       ...            ...    ...         ...
# 1221  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1222  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1223  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1224  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1225  2028-01-21  2.205479         0.0039   AAPL  268.450012
#
# [1204 rows x 20 columns]

# %%
calls_clean.describe()
# Out:
#             strike    lastPrice          bid          ask       change  \
# count  1204.000000  1204.000000  1204.000000  1204.000000  1204.000000
# mean    240.901163    66.652924    65.563679    66.773140    -0.682542
# std     114.663472    70.007036    69.687471    70.933147     3.259790
# min       5.000000     0.010000     0.000000     0.000000    -8.389999
# 25%     155.000000     3.050000     2.902500     2.952500    -1.727501
# 50%     240.000000    40.450000    38.925000    39.525000    -0.090000
# 75%     320.000000   118.415000   116.275000   118.237500     0.000000
# max     530.000000   266.040000   260.850000   264.500000    70.640000
#
#        percentChange        volume  openInterest  impliedVolatility  \
# count    1204.000000   1204.000000   1204.000000        1204.000000
# mean       -6.875652    479.211794   2858.700166           0.558275
# std        14.137031   3856.273992   7127.748409           0.723745
# min       -99.371070      1.000000      0.000000           0.000010
# 25%        -8.382243      2.000000     72.000000           0.273948
# 50%        -1.738211     11.000000    397.500000           0.343017
# 75%         0.000000     68.250000   2058.000000           0.546361
# max       100.000000  89573.000000  88993.000000           7.632813
#
#                TTM  dividendYield   spot_price
# count  1204.000000   1.204000e+03  1204.000000
# mean      0.676867   3.900000e-03   268.450012
# std       0.697032   4.338611e-19     0.000000
# min       0.000000   3.900000e-03   268.450012
# 25%       0.095890   3.900000e-03   268.450012
# 50%       0.441096   3.900000e-03   268.450012
# 75%       1.112329   3.900000e-03   268.450012
# max       2.205479   3.900000e-03   268.450012

# %%
puts_clean = initial_dataset_clean(puts)
puts_clean
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice  \
# 0     AAPL251205P00140000 2025-11-06 18:53:03+00:00   140.0       0.01
# 1     AAPL251205P00160000 2025-11-04 14:35:00+00:00   160.0       0.03
# 2     AAPL251205P00165000 2025-11-05 20:24:52+00:00   165.0       0.02
# 3     AAPL251205P00175000 2025-11-04 20:57:14+00:00   175.0       0.04
# 4     AAPL251205P00180000 2025-11-06 15:20:53+00:00   180.0       0.03
# ...                   ...                       ...     ...        ...
# 1048  AAPL280121P00340000 2025-11-06 20:55:40+00:00   340.0      77.62
# 1049  AAPL280121P00350000 2025-11-06 19:29:53+00:00   350.0      83.55
# 1050  AAPL280121P00360000 2025-11-04 17:50:40+00:00   360.0      92.33
# 1052  AAPL280121P00380000 2025-10-31 18:34:12+00:00   380.0     108.95
# 1053  AAPL280121P00390000 2025-11-05 15:56:30+00:00   390.0     121.25
#
#          bid     ask  change  percentChange  volume  openInterest  \
# 0       0.00    0.02     0.0            0.0     1.0            14
# 1       0.01    0.03     0.0            0.0     1.0             0
# 2       0.02    0.04     0.0            0.0     1.0             6
# 3       0.03    0.05     0.0            0.0     2.0             2
# 4       0.03    0.06     0.0            0.0     1.0             1
# ...      ...     ...     ...            ...     ...           ...
# 1048   78.90   79.55     0.0            0.0     5.0            11
# 1049   86.70   87.45     0.0            0.0     3.0           114
# 1050   94.95   95.65     0.0            0.0     2.0             9
# 1052  112.90  113.50     0.0            0.0     5.0             8
# 1053  122.50  123.10     0.0            0.0     2.0            24
#
#       impliedVolatility  inTheMoney contractSize currency option_type  \
# 0              0.734378       False      REGULAR      USD         put
# 1              0.632816       False      REGULAR      USD         put
# 2              0.621098       False      REGULAR      USD         put
# 3              0.566411       False      REGULAR      USD         put
# 4              0.539067       False      REGULAR      USD         put
# ...                 ...         ...          ...      ...         ...
# 1048           0.177849        True      REGULAR      USD         put
# 1049           0.171334        True      REGULAR      USD         put
# 1050           0.163750        True      REGULAR      USD         put
# 1052           0.153756        True      REGULAR      USD         put
# 1053           0.154885        True      REGULAR      USD         put
#
#       expiration       TTM  dividendYield ticker  spot_price
# 0     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 1     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 2     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 3     2025-12-05  0.076712         0.0039   AAPL  268.450012
# 4     2025-12-05  0.076712         0.0039   AAPL  268.450012
# ...          ...       ...            ...    ...         ...
# 1048  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1049  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1050  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1052  2028-01-21  2.205479         0.0039   AAPL  268.450012
# 1053  2028-01-21  2.205479         0.0039   AAPL  268.450012
#
# [1027 rows x 20 columns]

# %% [markdown]
# **Join Calls and Puts**

# %%
df = pd.concat([puts_clean, calls_clean], ignore_index=True)
df
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0     AAPL251205P00140000 2025-11-06 18:53:03+00:00   140.0       0.01  0.00
# 1     AAPL251205P00160000 2025-11-04 14:35:00+00:00   160.0       0.03  0.01
# 2     AAPL251205P00165000 2025-11-05 20:24:52+00:00   165.0       0.02  0.02
# 3     AAPL251205P00175000 2025-11-04 20:57:14+00:00   175.0       0.04  0.03
# 4     AAPL251205P00180000 2025-11-06 15:20:53+00:00   180.0       0.03  0.03
# ...                   ...                       ...     ...        ...   ...
# 2226  AAPL280121C00490000 2025-10-31 19:49:20+00:00   490.0       4.90  4.50
# 2227  AAPL280121C00500000 2025-11-07 18:21:15+00:00   500.0       4.35  4.05
# 2228  AAPL280121C00510000 2025-11-06 16:40:48+00:00   510.0       4.05  3.60
# 2229  AAPL280121C00520000 2025-11-07 15:34:36+00:00   520.0       3.69  3.25
# 2230  AAPL280121C00530000 2025-11-07 20:03:15+00:00   530.0       3.05  2.96
#
#        ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0     0.02    0.00       0.000000     1.0            14           0.734378
# 1     0.03    0.00       0.000000     1.0             0           0.632816
# 2     0.04    0.00       0.000000     1.0             6           0.621098
# 3     0.05    0.00       0.000000     2.0             2           0.566411
# 4     0.06    0.00       0.000000     1.0             1           0.539067
# ...    ...     ...            ...     ...           ...                ...
# 2226  4.70    0.00       0.000000     1.0            25           0.276954
# 2227  4.25    0.00       0.000000     7.0           285           0.277015
# 2228  3.80    0.00       0.000000    10.0            54           0.276374
# 2229  3.45    0.11       3.072630     1.0            14           0.276649
# 2230  3.15   -0.10      -3.174608    42.0           354           0.277198
#
#       inTheMoney contractSize currency option_type  expiration       TTM  \
# 0          False      REGULAR      USD         put  2025-12-05  0.076712
# 1          False      REGULAR      USD         put  2025-12-05  0.076712
# 2          False      REGULAR      USD         put  2025-12-05  0.076712
# 3          False      REGULAR      USD         put  2025-12-05  0.076712
# 4          False      REGULAR      USD         put  2025-12-05  0.076712
# ...          ...          ...      ...         ...         ...       ...
# 2226       False      REGULAR      USD        call  2028-01-21  2.205479
# 2227       False      REGULAR      USD        call  2028-01-21  2.205479
# 2228       False      REGULAR      USD        call  2028-01-21  2.205479
# 2229       False      REGULAR      USD        call  2028-01-21  2.205479
# 2230       False      REGULAR      USD        call  2028-01-21  2.205479
#
#       dividendYield ticker  spot_price
# 0            0.0039   AAPL  268.450012
# 1            0.0039   AAPL  268.450012
# 2            0.0039   AAPL  268.450012
# 3            0.0039   AAPL  268.450012
# 4            0.0039   AAPL  268.450012
# ...             ...    ...         ...
# 2226         0.0039   AAPL  268.450012
# 2227         0.0039   AAPL  268.450012
# 2228         0.0039   AAPL  268.450012
# 2229         0.0039   AAPL  268.450012
# 2230         0.0039   AAPL  268.450012
#
# [2231 rows x 20 columns]

# %%
def optionType(OPTtype):
    # Puts are type 1
    if OPTtype == "put":
        return "put"
    else:
    # Calls are type 0
        return "call"

# %%
df["optionType"] = df["option_type"].apply(optionType)
#df.drop(columns="option_type", inplace=True)
df
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0     AAPL251205P00140000 2025-11-06 18:53:03+00:00   140.0       0.01  0.00
# 1     AAPL251205P00160000 2025-11-04 14:35:00+00:00   160.0       0.03  0.01
# 2     AAPL251205P00165000 2025-11-05 20:24:52+00:00   165.0       0.02  0.02
# 3     AAPL251205P00175000 2025-11-04 20:57:14+00:00   175.0       0.04  0.03
# 4     AAPL251205P00180000 2025-11-06 15:20:53+00:00   180.0       0.03  0.03
# ...                   ...                       ...     ...        ...   ...
# 2226  AAPL280121C00490000 2025-10-31 19:49:20+00:00   490.0       4.90  4.50
# 2227  AAPL280121C00500000 2025-11-07 18:21:15+00:00   500.0       4.35  4.05
# 2228  AAPL280121C00510000 2025-11-06 16:40:48+00:00   510.0       4.05  3.60
# 2229  AAPL280121C00520000 2025-11-07 15:34:36+00:00   520.0       3.69  3.25
# 2230  AAPL280121C00530000 2025-11-07 20:03:15+00:00   530.0       3.05  2.96
#
#        ask  change  percentChange  volume  openInterest  ...  inTheMoney  \
# 0     0.02    0.00       0.000000     1.0            14  ...       False
# 1     0.03    0.00       0.000000     1.0             0  ...       False
# 2     0.04    0.00       0.000000     1.0             6  ...       False
# 3     0.05    0.00       0.000000     2.0             2  ...       False
# 4     0.06    0.00       0.000000     1.0             1  ...       False
# ...    ...     ...            ...     ...           ...  ...         ...
# 2226  4.70    0.00       0.000000     1.0            25  ...       False
# 2227  4.25    0.00       0.000000     7.0           285  ...       False
# 2228  3.80    0.00       0.000000    10.0            54  ...       False
# 2229  3.45    0.11       3.072630     1.0            14  ...       False
# 2230  3.15   -0.10      -3.174608    42.0           354  ...       False
#
#       contractSize currency option_type  expiration       TTM  dividendYield  \
# 0          REGULAR      USD         put  2025-12-05  0.076712         0.0039
# 1          REGULAR      USD         put  2025-12-05  0.076712         0.0039
# 2          REGULAR      USD         put  2025-12-05  0.076712         0.0039
# 3          REGULAR      USD         put  2025-12-05  0.076712         0.0039
# 4          REGULAR      USD         put  2025-12-05  0.076712         0.0039
# ...            ...      ...         ...         ...       ...            ...
# 2226       REGULAR      USD        call  2028-01-21  2.205479         0.0039
# 2227       REGULAR      USD        call  2028-01-21  2.205479         0.0039
# 2228       REGULAR      USD        call  2028-01-21  2.205479         0.0039
# 2229       REGULAR      USD        call  2028-01-21  2.205479         0.0039
# 2230       REGULAR      USD        call  2028-01-21  2.205479         0.0039
#
#       ticker  spot_price  optionType
# 0       AAPL  268.450012         put
# 1       AAPL  268.450012         put
# 2       AAPL  268.450012         put
# 3       AAPL  268.450012         put
# 4       AAPL  268.450012         put
# ...      ...         ...         ...
# 2226    AAPL  268.450012        call
# 2227    AAPL  268.450012        call
# 2228    AAPL  268.450012        call
# 2229    AAPL  268.450012        call
# 2230    AAPL  268.450012        call
#
# [2231 rows x 21 columns]

# %% [markdown]
# **Interest Rate Interpolation**

# %%
# Needs to figure out if we're using a interpolation structure to match each of them, also considering zero bond rates for the interpolation
def interest_rate(row):
    # Need to change this to interpolation calculation
    return (0.04)

# %%
df["r"] = .04
df
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0     AAPL251205P00140000 2025-11-06 18:53:03+00:00   140.0       0.01  0.00
# 1     AAPL251205P00160000 2025-11-04 14:35:00+00:00   160.0       0.03  0.01
# 2     AAPL251205P00165000 2025-11-05 20:24:52+00:00   165.0       0.02  0.02
# 3     AAPL251205P00175000 2025-11-04 20:57:14+00:00   175.0       0.04  0.03
# 4     AAPL251205P00180000 2025-11-06 15:20:53+00:00   180.0       0.03  0.03
# ...                   ...                       ...     ...        ...   ...
# 2226  AAPL280121C00490000 2025-10-31 19:49:20+00:00   490.0       4.90  4.50
# 2227  AAPL280121C00500000 2025-11-07 18:21:15+00:00   500.0       4.35  4.05
# 2228  AAPL280121C00510000 2025-11-06 16:40:48+00:00   510.0       4.05  3.60
# 2229  AAPL280121C00520000 2025-11-07 15:34:36+00:00   520.0       3.69  3.25
# 2230  AAPL280121C00530000 2025-11-07 20:03:15+00:00   530.0       3.05  2.96
#
#        ask  change  percentChange  volume  openInterest  ...  contractSize  \
# 0     0.02    0.00       0.000000     1.0            14  ...       REGULAR
# 1     0.03    0.00       0.000000     1.0             0  ...       REGULAR
# 2     0.04    0.00       0.000000     1.0             6  ...       REGULAR
# 3     0.05    0.00       0.000000     2.0             2  ...       REGULAR
# 4     0.06    0.00       0.000000     1.0             1  ...       REGULAR
# ...    ...     ...            ...     ...           ...  ...           ...
# 2226  4.70    0.00       0.000000     1.0            25  ...       REGULAR
# 2227  4.25    0.00       0.000000     7.0           285  ...       REGULAR
# 2228  3.80    0.00       0.000000    10.0            54  ...       REGULAR
# 2229  3.45    0.11       3.072630     1.0            14  ...       REGULAR
# 2230  3.15   -0.10      -3.174608    42.0           354  ...       REGULAR
#
#       currency option_type  expiration       TTM dividendYield  ticker  \
# 0          USD         put  2025-12-05  0.076712        0.0039    AAPL
# 1          USD         put  2025-12-05  0.076712        0.0039    AAPL
# 2          USD         put  2025-12-05  0.076712        0.0039    AAPL
# 3          USD         put  2025-12-05  0.076712        0.0039    AAPL
# 4          USD         put  2025-12-05  0.076712        0.0039    AAPL
# ...        ...         ...         ...       ...           ...     ...
# 2226       USD        call  2028-01-21  2.205479        0.0039    AAPL
# 2227       USD        call  2028-01-21  2.205479        0.0039    AAPL
# 2228       USD        call  2028-01-21  2.205479        0.0039    AAPL
# 2229       USD        call  2028-01-21  2.205479        0.0039    AAPL
# 2230       USD        call  2028-01-21  2.205479        0.0039    AAPL
#
#       spot_price optionType     r
# 0     268.450012        put  0.04
# 1     268.450012        put  0.04
# 2     268.450012        put  0.04
# 3     268.450012        put  0.04
# 4     268.450012        put  0.04
# ...          ...        ...   ...
# 2226  268.450012       call  0.04
# 2227  268.450012       call  0.04
# 2228  268.450012       call  0.04
# 2229  268.450012       call  0.04
# 2230  268.450012       call  0.04
#
# [2231 rows x 22 columns]

# %% [markdown]
# **Forward log-Moneyness**

# %% [markdown]
# We decided to use forward log-moneyness because its adjusted for r and q which are crucial in pricing the EEP

# %%
def forward_log_moneyness(S: float, r:float, q:float, T:float, K:float):
    """
    Calculates the log_moneyness in relation to the Forward Price of the stock

    Parameters
    ----------
    S : float
        Current spot_price of the stock.
    r : float
        Risk-free rate associated with that particular option maturity
    q : float
        Dividend-yield rate associated with that particular option maturity
    T : float
        Maturity of the option contract
    K : float
        Strike price of the option contract

    Returns
    -------
    Float
        - Forward log moneyness 
    """
    forward_price = S * np.exp((r - q)*T)
    
    return np.log(K/forward_price)

# %%
df["forward_log_moneyness"] = forward_log_moneyness(
    S=df["spot_price"].to_numpy(),
    r=df["r"].to_numpy(),
    q=df["dividendYield"].to_numpy(),
    T=df["TTM"].to_numpy(),
    K=df["strike"].to_numpy(),
)

df
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0     AAPL251205P00140000 2025-11-06 18:53:03+00:00   140.0       0.01  0.00
# 1     AAPL251205P00160000 2025-11-04 14:35:00+00:00   160.0       0.03  0.01
# 2     AAPL251205P00165000 2025-11-05 20:24:52+00:00   165.0       0.02  0.02
# 3     AAPL251205P00175000 2025-11-04 20:57:14+00:00   175.0       0.04  0.03
# 4     AAPL251205P00180000 2025-11-06 15:20:53+00:00   180.0       0.03  0.03
# ...                   ...                       ...     ...        ...   ...
# 2226  AAPL280121C00490000 2025-10-31 19:49:20+00:00   490.0       4.90  4.50
# 2227  AAPL280121C00500000 2025-11-07 18:21:15+00:00   500.0       4.35  4.05
# 2228  AAPL280121C00510000 2025-11-06 16:40:48+00:00   510.0       4.05  3.60
# 2229  AAPL280121C00520000 2025-11-07 15:34:36+00:00   520.0       3.69  3.25
# 2230  AAPL280121C00530000 2025-11-07 20:03:15+00:00   530.0       3.05  2.96
#
#        ask  change  percentChange  volume  openInterest  ...  currency  \
# 0     0.02    0.00       0.000000     1.0            14  ...       USD
# 1     0.03    0.00       0.000000     1.0             0  ...       USD
# 2     0.04    0.00       0.000000     1.0             6  ...       USD
# 3     0.05    0.00       0.000000     2.0             2  ...       USD
# 4     0.06    0.00       0.000000     1.0             1  ...       USD
# ...    ...     ...            ...     ...           ...  ...       ...
# 2226  4.70    0.00       0.000000     1.0            25  ...       USD
# 2227  4.25    0.00       0.000000     7.0           285  ...       USD
# 2228  3.80    0.00       0.000000    10.0            54  ...       USD
# 2229  3.45    0.11       3.072630     1.0            14  ...       USD
# 2230  3.15   -0.10      -3.174608    42.0           354  ...       USD
#
#       option_type  expiration       TTM dividendYield ticker  spot_price  \
# 0             put  2025-12-05  0.076712        0.0039   AAPL  268.450012
# 1             put  2025-12-05  0.076712        0.0039   AAPL  268.450012
# 2             put  2025-12-05  0.076712        0.0039   AAPL  268.450012
# 3             put  2025-12-05  0.076712        0.0039   AAPL  268.450012
# 4             put  2025-12-05  0.076712        0.0039   AAPL  268.450012
# ...           ...         ...       ...           ...    ...         ...
# 2226         call  2028-01-21  2.205479        0.0039   AAPL  268.450012
# 2227         call  2028-01-21  2.205479        0.0039   AAPL  268.450012
# 2228         call  2028-01-21  2.205479        0.0039   AAPL  268.450012
# 2229         call  2028-01-21  2.205479        0.0039   AAPL  268.450012
# 2230         call  2028-01-21  2.205479        0.0039   AAPL  268.450012
#
#       optionType     r  forward_log_moneyness
# 0            put  0.04              -0.653792
# 1            put  0.04              -0.520260
# 2            put  0.04              -0.489489
# 3            put  0.04              -0.430648
# 4            put  0.04              -0.402477
# ...          ...   ...                    ...
# 2226        call  0.04               0.522123
# 2227        call  0.04               0.542326
# 2228        call  0.04               0.562128
# 2229        call  0.04               0.581546
# 2230        call  0.04               0.600594
#
# [2231 rows x 23 columns]

# %% [markdown]
# Calculate Mid Price

# %%
def midPrice(bid: float, ask: float):
    """
    Calcualtes the mid-price of the option based on bid and ask prices

    Parameters
    ----------
    bid : float
        Current bid price of the option
    ask : float
        Current ask price of the option

    Returns
    -------
    Float
        - Mid price
    """

    return ((bid+ask)/2)

# %%
df["midPrice"] = midPrice(df["bid"], df["ask"])
df
# Out:
#            contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0     AAPL251205P00140000 2025-11-06 18:53:03+00:00   140.0       0.01  0.00
# 1     AAPL251205P00160000 2025-11-04 14:35:00+00:00   160.0       0.03  0.01
# 2     AAPL251205P00165000 2025-11-05 20:24:52+00:00   165.0       0.02  0.02
# 3     AAPL251205P00175000 2025-11-04 20:57:14+00:00   175.0       0.04  0.03
# 4     AAPL251205P00180000 2025-11-06 15:20:53+00:00   180.0       0.03  0.03
# ...                   ...                       ...     ...        ...   ...
# 2226  AAPL280121C00490000 2025-10-31 19:49:20+00:00   490.0       4.90  4.50
# 2227  AAPL280121C00500000 2025-11-07 18:21:15+00:00   500.0       4.35  4.05
# 2228  AAPL280121C00510000 2025-11-06 16:40:48+00:00   510.0       4.05  3.60
# 2229  AAPL280121C00520000 2025-11-07 15:34:36+00:00   520.0       3.69  3.25
# 2230  AAPL280121C00530000 2025-11-07 20:03:15+00:00   530.0       3.05  2.96
#
#        ask  change  percentChange  volume  openInterest  ...  option_type  \
# 0     0.02    0.00       0.000000     1.0            14  ...          put
# 1     0.03    0.00       0.000000     1.0             0  ...          put
# 2     0.04    0.00       0.000000     1.0             6  ...          put
# 3     0.05    0.00       0.000000     2.0             2  ...          put
# 4     0.06    0.00       0.000000     1.0             1  ...          put
# ...    ...     ...            ...     ...           ...  ...          ...
# 2226  4.70    0.00       0.000000     1.0            25  ...         call
# 2227  4.25    0.00       0.000000     7.0           285  ...         call
# 2228  3.80    0.00       0.000000    10.0            54  ...         call
# 2229  3.45    0.11       3.072630     1.0            14  ...         call
# 2230  3.15   -0.10      -3.174608    42.0           354  ...         call
#
#       expiration       TTM dividendYield ticker  spot_price  optionType     r  \
# 0     2025-12-05  0.076712        0.0039   AAPL  268.450012         put  0.04
# 1     2025-12-05  0.076712        0.0039   AAPL  268.450012         put  0.04
# 2     2025-12-05  0.076712        0.0039   AAPL  268.450012         put  0.04
# 3     2025-12-05  0.076712        0.0039   AAPL  268.450012         put  0.04
# 4     2025-12-05  0.076712        0.0039   AAPL  268.450012         put  0.04
# ...          ...       ...           ...    ...         ...         ...   ...
# 2226  2028-01-21  2.205479        0.0039   AAPL  268.450012        call  0.04
# 2227  2028-01-21  2.205479        0.0039   AAPL  268.450012        call  0.04
# 2228  2028-01-21  2.205479        0.0039   AAPL  268.450012        call  0.04
# 2229  2028-01-21  2.205479        0.0039   AAPL  268.450012        call  0.04
# 2230  2028-01-21  2.205479        0.0039   AAPL  268.450012        call  0.04
#
#      forward_log_moneyness  midPrice
# 0                -0.653792     0.010
# 1                -0.520260     0.020
# 2                -0.489489     0.030
# 3                -0.430648     0.040
# 4                -0.402477     0.045
# ...                    ...       ...
# 2226              0.522123     4.600
# 2227              0.542326     4.150
# 2228              0.562128     3.700
# 2229              0.581546     3.350
# 2230              0.600594     3.055
#
# [2231 rows x 24 columns]

# %%
# =========================
# Debug helper
# =========================
def _d(msg, **k):
    items = " | ".join(f"{kk}={vv}" for kk, vv in k.items())
    print(f"[deAm] {msg}" + (f" :: {items}" if items else ""))

def _get_mid(row):
    """Return mid price from either 'midPrice' or 'mid_price' if present, else None."""
    v = row.get('midPrice', row.get('mid_price', None))
    try:
        return float(v) if v is not None else None
    except Exception:
        return None

# =========================
# Curves & maturity
# =========================
def _setup_ts(eval_date, r, q):
    """
    Flat, continuously compounded r and q term structures.
    """
    dc = ql.Actual365Fixed()
    r_ts = ql.YieldTermStructureHandle(
        ql.FlatForward(eval_date, ql.QuoteHandle(ql.SimpleQuote(float(r))),
                       dc, ql.Continuous, ql.NoFrequency))
    q_ts = ql.YieldTermStructureHandle(
        ql.FlatForward(eval_date, ql.QuoteHandle(ql.SimpleQuote(float(q))),
                       dc, ql.Continuous, ql.NoFrequency))
    return dc, r_ts, q_ts

def _to_maturity(eval_date, T_years):
    """
    Convert year fraction to Date using Actual/365, with ≥ 1 day.
    """
    days = max(1, int(round(float(T_years) * 365.0)))
    return eval_date + days

# =========================
# Core: de-Americanize via binomial inversion (robust)
# =========================
def _deam_one_tree(row, eval_date, steps, tree, sigma_floor=1e-3):
    """
    Attempt de-Americanization using a single tree flavor. Returns (price or None, errstr or None).
    """
    S = float(row['spot_price'])
    K = float(row['strike'])
    T = float(row['TTM'])
    r = float(row['r'])
    q = float(row['dividendYield'])
    P = _get_mid(row)
    opt_is_call = str(row.get('optionType', row.get('option_type'))).lower() == 'call'

    # ---------- input guards ----------
    if P is None or T <= 0 or not np.isfinite(P) or P <= 0 or S <= 0 or K <= 0:
        return None, "bad inputs"
    if q > 1.0:  # defensive if someone passed percent
        q = q / 100.0
        _d("q looked like percent; converted to decimal", q=q)

    # ---------- no-arb bounds ----------
    df_r = np.exp(-r*T); df_q = np.exp(-q*T)
    if opt_is_call:
        lb, ub = max(0.0, S*df_q - K*df_r), S*df_q
    else:
        lb, ub = max(0.0, K*df_r - S*df_q), K*df_r
    if not (lb - 1e-8 <= P <= ub + 1e-8):
        return None, "no-arb violation"

    # ---------- trivial case: American call with ~zero dividend ----------
    if opt_is_call and abs(q) <= 1e-4:
        return float(P), None

    # ---------- engine & instruments ----------
    ql.Settings.instance().evaluationDate = eval_date
    dc, r_ts, q_ts = _setup_ts(eval_date, r, q)
    spot = ql.QuoteHandle(ql.SimpleQuote(S))

    # keep SimpleQuote so we can mutate σ during solve
    vol_sq = ql.SimpleQuote(max(0.30, sigma_floor))
    vol_h  = ql.QuoteHandle(vol_sq)
    vol_ts = ql.BlackVolTermStructureHandle(ql.BlackConstantVol(eval_date, ql.NullCalendar(), vol_h, dc))
    process = ql.BlackScholesMertonProcess(spot, q_ts, r_ts, vol_ts)

    maturity = _to_maturity(eval_date, T)
    ql_type = ql.Option.Call if opt_is_call else ql.Option.Put
    am_opt = ql.VanillaOption(ql.PlainVanillaPayoff(ql_type, K), ql.AmericanExercise(eval_date, maturity))
    eu_opt = ql.VanillaOption(ql.PlainVanillaPayoff(ql_type, K), ql.EuropeanExercise(maturity))

    # Tree-specific adjustments
    t = tree.lower()
    use_steps = int(steps)
    if t == "lr" and use_steps % 2 == 0:
        use_steps += 1  # LR needs odd
    try:
        am_opt.setPricingEngine(ql.BinomialVanillaEngine(process, t, use_steps))
    except Exception as e:
        return None, f"engine init failed: {e}"

    # ---------- target function f(σ) with exception safety ----------
    class _Res:
        def __call__(self, sigma):
            s = max(float(sigma), sigma_floor)
            try:
                vol_sq.setValue(s)
                val = am_opt.NPV()  # can throw "negative probability" if p ∉ [0,1]
                if not np.isfinite(val):
                    _d("am NPV not finite", sigma=s, steps=use_steps, tree=t)
                    return np.nan
                return val - P
            except Exception as e:
                _d("am NPV exception", tree=t, steps=use_steps, sigma=s, err=str(e))
                return np.nan  # signal to bracket-expander to adjust

    f = _Res()

    # ---------- bracket with robust expansion ----------
    lo, hi = max(sigma_floor, 1e-3), 6.0
    f_lo, f_hi = f(lo), f(hi)
    _d("initial bracket", tree=t, steps=use_steps, lo=lo, f_lo=f_lo, hi=hi, f_hi=f_hi, P=P)
    expands = 0
    while (not np.isfinite(f_lo) or not np.isfinite(f_hi) or f_lo * f_hi > 0) and expands < 12:
        lo *= 0.6
        hi *= 1.7
        lo = max(lo, sigma_floor)
        f_lo, f_hi = f(lo), f(hi)
        expands += 1
        _d("expand bracket", tree=t, expands=expands, lo=lo, f_lo=f_lo, hi=hi, f_hi=f_hi)
    if not np.isfinite(f_lo) or not np.isfinite(f_hi) or f_lo * f_hi > 0:
        return None, "no sigma bracket"

    # ---------- root solve ----------
    try:
        sigma_star = float(ql.Brent().solve(f, 1e-8, max(0.30, lo*1.5), lo, hi))
        _d("sigma*", tree=t, sigma_star=sigma_star)
    except Exception as e:
        return None, f"Brent failed: {e}"

    # ---------- European analytic price ----------
    try:
        vol_sq.setValue(max(sigma_star, sigma_floor))
        eu_opt.setPricingEngine(ql.AnalyticEuropeanEngine(process))
        p_eu = float(eu_opt.NPV())
        _d("eu price", tree=t, p_eu=p_eu)
        return p_eu, None
    except Exception as e:
        return None, f"eu analytic failed: {e}"

def _deamericanize_price_binomial(row, eval_date=None, steps=400, tree="jr"):
    """
    Convert an American mid price to a European-equivalent price.
    Tries a sequence of trees for robustness if the chosen one fails.
    """
    if eval_date is None:
        eval_date = ql.Date.todaysDate()

    # First try requested tree, then robust fallbacks
    tree_try = [tree.lower()]
    for t in ["jr", "trigeorgis", "tian", "crr", "lr"]:
        if t not in tree_try:
            tree_try.append(t)

    for t in tree_try:
        p, err = _deam_one_tree(row, eval_date, steps, t, sigma_floor=1e-3)
        if p is not None and np.isfinite(p) and p > 0:
            return p
        _d("tree attempt failed", tree=t, err=err)
    return None

# =========================
# BS IV from price (robust)
# =========================
def _row_bs_iv_from_price(row, eval_date=None, iv_guess=0.25, use_deam=True):
    """
    Compute BS implied vol. If use_deam, first de-Americanize to a European price.
    Returns float IV or None.
    """
    S = float(row['spot_price']); K = float(row['strike']); T = float(row['TTM'])
    r = float(row['r']); q = float(row['dividendYield'])
    P_raw = _get_mid(row)
    opt_is_call = str(row.get('optionType', row.get('option_type'))).lower() == 'call'

    if P_raw is None or T <= 0 or S <= 0 or K <= 0:
        _d("IV: bad inputs", S=S, K=K, T=T, r=r, q=q, P=P_raw)
        return None

    if eval_date is None:
        eval_date = ql.Date.todaysDate()
    ql.Settings.instance().evaluationDate = eval_date

    price_for_iv = P_raw
    if use_deam:
        P_eu = _deamericanize_price_binomial(row, eval_date=eval_date)
        if P_eu is None or not np.isfinite(P_eu) or P_eu <= 0:
            _d("IV: deAm failed", P_raw=P_raw, P_eu=P_eu)
            return None
        price_for_iv = float(P_eu)

    dc, r_ts, q_ts = _setup_ts(eval_date, r, q)
    cal = ql.NullCalendar()
    maturity = _to_maturity(eval_date, T)
    spot = ql.QuoteHandle(ql.SimpleQuote(S))
    vol_ts = ql.BlackVolTermStructureHandle(ql.BlackConstantVol(eval_date, cal, iv_guess, dc))
    proc = ql.BlackScholesMertonProcess(spot, q_ts, r_ts, vol_ts)
    ql_type = ql.Option.Call if opt_is_call else ql.Option.Put
    opt = ql.VanillaOption(ql.PlainVanillaPayoff(ql_type, K), ql.EuropeanExercise(maturity))

    # Try QuantLib's built-in solver with wide bounds
    try:
        iv = opt.impliedVolatility(price_for_iv, proc, 1e-6, 2000, 1e-9, 12.0)
        iv = float(iv) if np.isfinite(iv) and iv > 0 else None
        _d("IV: QL solver", iv=iv, price_for_iv=price_for_iv)
        if iv is not None:
            return iv
    except Exception as e:
        _d("IV: QL solver exception", err=str(e), price_for_iv=price_for_iv)

    # Fallback: bisection using analytic engine (monotone in vol)
    try:
        lo, hi = 1e-9, 12.0
        for it in range(120):
            mid = 0.5 * (lo + hi)
            vts = ql.BlackVolTermStructureHandle(ql.BlackConstantVol(eval_date, cal, mid, dc))
            p = ql.BlackScholesMertonProcess(spot, q_ts, r_ts, vts)
            opt.setPricingEngine(ql.AnalyticEuropeanEngine(p))
            p_mid = opt.NPV()
            if not np.isfinite(p_mid):
                _d("IV: fallback p_mid not finite", it=it, mid=mid)
                return None
            if abs(p_mid - price_for_iv) < 1e-8:
                _d("IV: fallback converged", it=it, mid=mid)
                return mid
            if p_mid < price_for_iv:
                lo = mid
            else:
                hi = mid
        _d("IV: fallback no converge", lo=lo, hi=hi)
        return None
    except Exception as e:
        _d("IV: fallback exception", err=str(e))
        return None

# =========================
# Heston calibration & pricing
# =========================
def _calibrate_heston(group_df: pd.DataFrame, eval_date=None, init=None):
    """
    Calibrate a Heston model to one group (same instrument/day) using IVs from mid prices.
    Requires ≥ ~5 valid helpers across strikes/maturities.
    """
    if eval_date is None:
        eval_date = ql.Date.todaysDate()
    ql.Settings.instance().evaluationDate = eval_date

    S = float(group_df['spot_price'].iloc[0])
    r = float(group_df['r'].iloc[0])
    q = float(group_df['dividendYield'].iloc[0])

    _, r_ts, q_ts = _setup_ts(eval_date, r, q)
    cal = ql.NullCalendar()
    spot_h = ql.QuoteHandle(ql.SimpleQuote(S))

    helpers = []
    for idx, row in group_df.iterrows():
        iv = _row_bs_iv_from_price(row, eval_date=eval_date, use_deam=True)
        _d("helper IV", idx=idx, iv=iv)
        if iv is None:
            continue
        K = float(row['strike']); T = float(row['TTM'])
        tenor = ql.Period((_to_maturity(eval_date, T) - eval_date), ql.Days)
        helpers.append(ql.HestonModelHelper(tenor, cal,S, K,
                                            ql.QuoteHandle(ql.SimpleQuote(iv)),r_ts,q_ts)
)

    _d("helpers count", n=len(helpers))
    if len(helpers) < 5:
        raise ValueError("Not enough valid options to calibrate Heston (need ≥ ~5 across strikes/maturities).")

    # Initial params (can be overridden with init)
    p = dict(v0=0.04, kappa=1.5, theta=0.04, sigma=0.3, rho=-0.7)
    if init: p.update(init)

    process = ql.HestonProcess(r_ts, q_ts, spot_h, p['v0'], p['kappa'], p['theta'], p['sigma'], p['rho'])
    model = ql.HestonModel(process)
    engine = ql.AnalyticHestonEngine(model)
    for h in helpers:
        h.setPricingEngine(engine)

    om = ql.LevenbergMarquardt(1e-8, 1e-8, 1e-8)
    endc = ql.EndCriteria(500, 50, 1e-8, 1e-8, 1e-8)
    model.calibrate(helpers, om, endc)

    # Dump fitted params for visibility
    try:
        v0, kappa, theta, sigma, rho = model.params()
        _d("Heston calibrated", v0=v0, kappa=kappa, theta=theta, sigma=sigma, rho=rho)
    except Exception:
        pass
    return model

def _price_eu_heston(row, model: ql.HestonModel, eval_date=None):
    """
    Price a single European option under calibrated Heston.
    """
    if eval_date is None:
        eval_date = ql.Date.todaysDate()
    ql.Settings.instance().evaluationDate = eval_date

    K = float(row['strike'])
    T = float(row['TTM'])
    maturity = _to_maturity(eval_date, T)
    ql_type = ql.Option.Call if str(row.get('optionType', row.get('option_type'))).lower() == 'call' else ql.Option.Put

    opt = ql.VanillaOption(ql.PlainVanillaPayoff(ql_type, K), ql.EuropeanExercise(maturity))
    opt.setPricingEngine(ql.AnalyticHestonEngine(model))
    p = float(opt.NPV())
    _d("Heston EU price", K=K, T=T, p=p)
    return p

# =========================
# Public API
# =========================
def calibrate_and_price_heston_european(df: pd.DataFrame,
                                        group_cols=('ticker',),
                                        eval_date: ql.Date | None = None,
                                        init: dict | None = None) -> pd.Series:
    """
    Calibrate Heston per group from mid prices, then return ONLY the European-equivalent
    price for each row as 'V_EU_Heston'.
    """
    if eval_date is None:
        eval_date = ql.Date.todaysDate()

    results = pd.Series(index=df.index, dtype=float, name='V_EU_Heston')

    # Attach index to help correlate debug lines to inputs
    df = df.copy()
    df['idx'] = df.index

    for gkey, grp in df.groupby(list(group_cols), dropna=False):
        g = grp.copy()
        _d("=== group start ===", group=gkey, rows=len(g))
        try:
            model = _calibrate_heston(g, eval_date=eval_date, init=init)
        except Exception as e:
            _d("group calibration FAILED", group=gkey, err=str(e))
            continue

        prices = g.apply(lambda r: _price_eu_heston(r, model, eval_date), axis=1)
        results.loc[g.index] = prices.values
        _d("group priced", group=gkey)

    return results

# %%
V_eu = calibrate_and_price_heston_european(df, group_cols=("ticker", ))
df = df.join(V_eu)
df
# Out:
# [deAm] === group start === :: group=('AAPL',) | rows=2231
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.01 | hi=6.0 | f_hi=63.80411442899315 | P=0.01
# [deAm] sigma* :: tree=jr | sigma_star=0.7578521652106623
# [deAm] eu price :: tree=jr | p_eu=0.01024206702687044
# [deAm] IV: QL solver :: iv=0.7578521643836771 | price_for_iv=0.01024206702687044
# [deAm] helper IV :: idx=0 | iv=0.7578521643836771
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.02 | hi=6.0 | f_hi=77.3969249696465 | P=0.02
# [deAm] sigma* :: tree=jr | sigma_star=0.6488294647775062
# [deAm] eu price :: tree=jr | p_eu=0.020414608365889424
# [deAm] IV: QL solver :: iv=0.6488292672541204 | price_for_iv=0.020414608365889424
# [deAm] helper IV :: idx=1 | iv=0.6488292672541204
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.03 | hi=6.0 | f_hi=80.92193096758939 | P=0.03
# [deAm] sigma* :: tree=jr | sigma_star=0.6365817140461942
# [deAm] eu price :: tree=jr | p_eu=0.030427951273926914
# [deAm] IV: QL solver :: iv=0.6365816846440295 | price_for_iv=0.030427951273926914
# [deAm] helper IV :: idx=2 | iv=0.6365816846440295
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.04 | hi=6.0 | f_hi=87.98231066814246 | P=0.04
# [deAm] sigma* :: tree=jr | sigma_star=0.5821136193528563
# [deAm] eu price :: tree=jr | p_eu=0.040529998628858456
# [deAm] IV: QL solver :: iv=0.5821137837278805 | price_for_iv=0.040529998628858456
# [deAm] helper IV :: idx=3 | iv=0.5821137837278805
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.045 | hi=6.0 | f_hi=91.5127894860476 | P=0.045
# [deAm] sigma* :: tree=jr | sigma_star=0.553404362130325
# [deAm] eu price :: tree=jr | p_eu=0.045227728287889304
# [deAm] IV: QL solver :: iv=0.553404586268458 | price_for_iv=0.045227728287889304
# [deAm] helper IV :: idx=4 | iv=0.553404586268458
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.05500000000000001 | hi=6.0 | f_hi=95.09155118421835 | P=0.05500000000000001
# [deAm] sigma* :: tree=jr | sigma_star=0.5304655148316002
# [deAm] eu price :: tree=jr | p_eu=0.05541585317609921
# [deAm] IV: QL solver :: iv=0.5304656941054107 | price_for_iv=0.05541585317609921
# [deAm] helper IV :: idx=5 | iv=0.5304656941054107
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.07 | hi=6.0 | f_hi=98.77778122916443 | P=0.07
# [deAm] sigma* :: tree=jr | sigma_star=0.5101594876928978
# [deAm] eu price :: tree=jr | p_eu=0.0708096142884622
# [deAm] IV: QL solver :: iv=0.5101594414343431 | price_for_iv=0.0708096142884622
# [deAm] helper IV :: idx=6 | iv=0.5101594414343431
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.08 | hi=6.0 | f_hi=102.4691138081069 | P=0.08
# [deAm] sigma* :: tree=jr | sigma_star=0.48283004168541466
# [deAm] eu price :: tree=jr | p_eu=0.08021197476162259
# [deAm] IV: QL solver :: iv=0.48283003973360245 | price_for_iv=0.08021197476162259
# [deAm] helper IV :: idx=7 | iv=0.48283003973360245
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.1 | hi=6.0 | f_hi=106.1505466722809 | P=0.1
# [deAm] sigma* :: tree=jr | sigma_star=0.4612657582919619
# [deAm] eu price :: tree=jr | p_eu=0.10018559672108586
# [deAm] IV: QL solver :: iv=0.4612657703811293 | price_for_iv=0.10018559672108586
# [deAm] helper IV :: idx=8 | iv=0.4612657703811293
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.12 | hi=6.0 | f_hi=109.83211074365883 | P=0.12
# [deAm] sigma* :: tree=jr | sigma_star=0.43753126724119784
# [deAm] eu price :: tree=jr | p_eu=0.12068190395651864
# [deAm] IV: QL solver :: iv=0.43753128351405507 | price_for_iv=0.12068190395651864
# [deAm] helper IV :: idx=9 | iv=0.43753128351405507
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.15000000000000002 | hi=6.0 | f_hi=113.50385256316198 | P=0.15000000000000002
# [deAm] sigma* :: tree=jr | sigma_star=0.4159666962641408
# [deAm] eu price :: tree=jr | p_eu=0.1511776442986825
# [deAm] IV: QL solver :: iv=0.4159666963866848 | price_for_iv=0.1511776442986825
# [deAm] helper IV :: idx=10 | iv=0.4159666963866848
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.19 | hi=6.0 | f_hi=117.16586760161725 | P=0.19
# [deAm] sigma* :: tree=jr | sigma_star=0.394818544605434
# [deAm] eu price :: tree=jr | p_eu=0.19134494441343397
# [deAm] IV: QL solver :: iv=0.39481854418249346 | price_for_iv=0.19134494441343397
# [deAm] helper IV :: idx=11 | iv=0.39481854418249346
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.24 | hi=6.0 | f_hi=120.92479610438762 | P=0.24
# [deAm] sigma* :: tree=jr | sigma_star=0.37319147700572136
# [deAm] eu price :: tree=jr | p_eu=0.2414032758254874
# [deAm] IV: QL solver :: iv=0.37319152984394344 | price_for_iv=0.2414032758254874
# [deAm] helper IV :: idx=12 | iv=0.37319152984394344
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.31 | hi=6.0 | f_hi=124.71194311603298 | P=0.31
# [deAm] sigma* :: tree=jr | sigma_star=0.3523588507453198
# [deAm] eu price :: tree=jr | p_eu=0.3105217242846212
# [deAm] IV: QL solver :: iv=0.3523588487310901 | price_for_iv=0.3105217242846212
# [deAm] helper IV :: idx=13 | iv=0.3523588487310901
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.405 | hi=6.0 | f_hi=128.47418941550046 | P=0.405
# [deAm] sigma* :: tree=jr | sigma_star=0.33175486698695633
# [deAm] eu price :: tree=jr | p_eu=0.40399614734355754
# [deAm] IV: QL solver :: iv=0.3317548690095255 | price_for_iv=0.40399614734355754
# [deAm] helper IV :: idx=14 | iv=0.3317548690095255
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.545 | hi=6.0 | f_hi=132.19152363531802 | P=0.545
# [deAm] sigma* :: tree=jr | sigma_star=0.31280223514924904
# [deAm] eu price :: tree=jr | p_eu=0.5438508025167774
# [deAm] IV: QL solver :: iv=0.31280220889317656 | price_for_iv=0.5438508025167774
# [deAm] helper IV :: idx=15 | iv=0.31280220889317656
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.77 | hi=6.0 | f_hi=135.8239701917595 | P=0.77
# [deAm] sigma* :: tree=jr | sigma_star=0.29654379444174106
# [deAm] eu price :: tree=jr | p_eu=0.7666430635342885
# [deAm] IV: QL solver :: iv=0.2965437944493547 | price_for_iv=0.7666430635342885
# [deAm] helper IV :: idx=16 | iv=0.2965437944493547
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.135 | hi=6.0 | f_hi=139.3165741131673 | P=1.135
# [deAm] sigma* :: tree=jr | sigma_star=0.2835524581024791
# [deAm] eu price :: tree=jr | p_eu=1.129439508571688
# [deAm] IV: QL solver :: iv=0.2835524581331331 | price_for_iv=1.129439508571688
# [deAm] helper IV :: idx=17 | iv=0.2835524581331331
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.6749999999999998 | hi=6.0 | f_hi=142.6343440224008 | P=1.6749999999999998
# [deAm] sigma* :: tree=jr | sigma_star=0.2712314186941178
# [deAm] eu price :: tree=jr | p_eu=1.6656995190028616
# [deAm] IV: QL solver :: iv=0.27123141436533993 | price_for_iv=1.6656995190028616
# [deAm] helper IV :: idx=18 | iv=0.27123141436533993
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.54 | hi=6.0 | f_hi=145.6274419674094 | P=2.54
# [deAm] sigma* :: tree=jr | sigma_star=0.2633600060771604
# [deAm] eu price :: tree=jr | p_eu=2.5300136506751896
# [deAm] IV: QL solver :: iv=0.2633601300533055 | price_for_iv=2.5300136506751896
# [deAm] helper IV :: idx=19 | iv=0.2633601300533055
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.775 | hi=6.0 | f_hi=148.3739483726049 | P=3.775
# [deAm] sigma* :: tree=jr | sigma_star=0.25580984088111836
# [deAm] eu price :: tree=jr | p_eu=3.750104837681104
# [deAm] IV: QL solver :: iv=0.2558098404485946 | price_for_iv=3.750104837681104
# [deAm] helper IV :: idx=20 | iv=0.2558098404485946
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-5.5 | hi=6.0 | f_hi=150.65079235790523 | P=5.5
# [deAm] sigma* :: tree=jr | sigma_star=0.25050628068320474
# [deAm] eu price :: tree=jr | p_eu=5.4661114125908945
# [deAm] IV: QL solver :: iv=0.2505061808843865 | price_for_iv=5.4661114125908945
# [deAm] helper IV :: idx=21 | iv=0.2505061808843865
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-6.32501220703125 | hi=6.0 | f_hi=152.27772638619507 | P=7.875
# [deAm] sigma* :: tree=jr | sigma_star=0.24949491183968697
# [deAm] eu price :: tree=jr | p_eu=7.816450587903993
# [deAm] IV: QL solver :: iv=0.24949489933801744 | price_for_iv=7.816450587903993
# [deAm] helper IV :: idx=22 | iv=0.24949489933801744
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-4.275012207031249 | hi=6.0 | f_hi=153.32973767893884 | P=10.825
# [deAm] sigma* :: tree=jr | sigma_star=0.24982089012167663
# [deAm] eu price :: tree=jr | p_eu=10.733331145771562
# [deAm] IV: QL solver :: iv=0.24982089017134265 | price_for_iv=10.733331145771562
# [deAm] helper IV :: idx=23 | iv=0.24982089017134265
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.9250122070312514 | hi=6.0 | f_hi=153.68185544228882 | P=14.475000000000001
# [deAm] sigma* :: tree=jr | sigma_star=0.25828911794581966
# [deAm] eu price :: tree=jr | p_eu=14.349858780583341
# [deAm] IV: QL solver :: iv=0.25828909659424837 | price_for_iv=14.349858780583341
# [deAm] helper IV :: idx=24 | iv=0.25828909659424837
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.07501220703125 | hi=6.0 | f_hi=153.534077354495 | P=18.625
# [deAm] sigma* :: tree=jr | sigma_star=0.2724716469280242
# [deAm] eu price :: tree=jr | p_eu=18.46100231256533
# [deAm] IV: QL solver :: iv=0.27247142664609786 | price_for_iv=18.46100231256533
# [deAm] helper IV :: idx=25 | iv=0.27247142664609786
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.6000122070312486 | hi=6.0 | f_hi=153.01145110721234 | P=23.15
# [deAm] sigma* :: tree=jr | sigma_star=0.2932288455519621
# [deAm] eu price :: tree=jr | p_eu=22.94413384907082
# [deAm] IV: QL solver :: iv=0.2932288483232127 | price_for_iv=22.94413384907082
# [deAm] helper IV :: idx=26 | iv=0.2932288483232127
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.32501220703125 | hi=6.0 | f_hi=152.2889725581227 | P=27.875
# [deAm] sigma* :: tree=jr | sigma_star=0.3181760768244504
# [deAm] eu price :: tree=jr | p_eu=27.64016125469729
# [deAm] IV: QL solver :: iv=0.31817607682586324 | price_for_iv=27.64016125469729
# [deAm] helper IV :: idx=27 | iv=0.31817607682586324
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.20001220703125 | hi=6.0 | f_hi=151.41676380736052 | P=32.75
# [deAm] sigma* :: tree=jr | sigma_star=0.3476464088536292
# [deAm] eu price :: tree=jr | p_eu=32.490076546705716
# [deAm] IV: QL solver :: iv=0.34764660249450896 | price_for_iv=32.490076546705716
# [deAm] helper IV :: idx=28 | iv=0.34764660249450896
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.2750122070312528 | hi=6.0 | f_hi=148.69519891708154 | P=47.825
# [deAm] sigma* :: tree=jr | sigma_star=0.4555269745497971
# [deAm] eu price :: tree=jr | p_eu=47.53307545272072
# [deAm] IV: QL solver :: iv=0.45552697455407737 | price_for_iv=47.53307545272072
# [deAm] helper IV :: idx=29 | iv=0.45552697455407737
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.1250122070312472 | hi=6.0 | f_hi=147.9801441507244 | P=52.675
# [deAm] sigma* :: tree=jr | sigma_star=0.4756069859835914
# [deAm] eu price :: tree=jr | p_eu=52.35620861895516
# [deAm] IV: QL solver :: iv=0.47560698639156906 | price_for_iv=52.35620861895516
# [deAm] helper IV :: idx=30 | iv=0.47560698639156906
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.1000122070312557 | hi=6.0 | f_hi=147.1401551684065 | P=57.650000000000006
# [deAm] sigma* :: tree=jr | sigma_star=0.5040394324471168
# [deAm] eu price :: tree=jr | p_eu=57.31720870396498
# [deAm] IV: QL solver :: iv=0.5040394329733372 | price_for_iv=57.31720870396498
# [deAm] helper IV :: idx=31 | iv=0.5040394329733372
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.2750122070312528 | hi=6.0 | f_hi=146.10027143386105 | P=62.825
# [deAm] sigma* :: tree=jr | sigma_star=0.5481722174878484
# [deAm] eu price :: tree=jr | p_eu=62.49516635962144
# [deAm] IV: QL solver :: iv=0.5481722175116381 | price_for_iv=62.49516635962144
# [deAm] helper IV :: idx=32 | iv=0.5481722175116381
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=9.747679799087393 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=1.9357083987571708
# [deAm] eu price :: tree=jr | p_eu=0.005169735380645181
# [deAm] IV: QL solver :: iv=1.9357083997075282 | price_for_iv=0.005169735380645181
# [deAm] helper IV :: idx=33 | iv=1.9357083997075282
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=17.1705093964368 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=1.508275196238852
# [deAm] eu price :: tree=jr | p_eu=0.005145247153327068
# [deAm] IV: QL solver :: iv=1.5082753721590647 | price_for_iv=0.005145247153327068
# [deAm] helper IV :: idx=34 | iv=1.5082753721590647
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=18.932833710418695 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=1.4321570892288409
# [deAm] eu price :: tree=jr | p_eu=0.005136260597726748
# [deAm] IV: QL solver :: iv=1.4321570893728286 | price_for_iv=0.005136260597726748
# [deAm] helper IV :: idx=35 | iv=1.4321570893728286
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=22.62922011601912 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=1.2875295771485766
# [deAm] eu price :: tree=jr | p_eu=0.005116938159243507
# [deAm] IV: QL solver :: iv=1.287529577689922 | price_for_iv=0.005116938159243507
# [deAm] helper IV :: idx=36 | iv=1.287529577689922
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=24.634415522792963 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=1.2186813917106785
# [deAm] eu price :: tree=jr | p_eu=0.005107593006257059
# [deAm] IV: QL solver :: iv=1.2186813919412562 | price_for_iv=0.005107593006257059
# [deAm] helper IV :: idx=37 | iv=1.2186813919412562
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=26.639683191142655 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=1.1519453573404483
# [deAm] eu price :: tree=jr | p_eu=0.005099281976336831
# [deAm] IV: QL solver :: iv=1.1519453883620374 | price_for_iv=0.005099281976336831
# [deAm] helper IV :: idx=38 | iv=1.1519453883620374
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=28.797666015524523 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=1.087190351141287
# [deAm] eu price :: tree=jr | p_eu=0.005092780563388889
# [deAm] IV: QL solver :: iv=1.0871903813059753 | price_for_iv=0.005092780563388889
# [deAm] helper IV :: idx=39 | iv=1.0871903813059753
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=30.99816968617172 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=1.024297197197479
# [deAm] eu price :: tree=jr | p_eu=0.005089030780672268
# [deAm] IV: QL solver :: iv=1.0242972629669669 | price_for_iv=0.005089030780672268
# [deAm] helper IV :: idx=40 | iv=1.0242972629669669
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=33.19881628885718 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=0.9631572387670346
# [deAm] eu price :: tree=jr | p_eu=0.005089190372123358
# [deAm] IV: QL solver :: iv=0.9631571860377502 | price_for_iv=0.005089190372123358
# [deAm] helper IV :: idx=41 | iv=0.9631571860377502
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=35.595680827379816 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=0.9036712245219162
# [deAm] eu price :: tree=jr | p_eu=0.005094709064924173
# [deAm] IV: QL solver :: iv=0.9036712203194751 | price_for_iv=0.005094709064924173
# [deAm] helper IV :: idx=42 | iv=0.9036712203194751
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=37.99443136561621 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=0.845748110599556
# [deAm] eu price :: tree=jr | p_eu=0.0051074162721822455
# [deAm] IV: QL solver :: iv=0.8457481584283906 | price_for_iv=0.0051074162721822455
# [deAm] helper IV :: idx=43 | iv=0.8457481584283906
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=40.39331797733249 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=0.789304128775679
# [deAm] eu price :: tree=jr | p_eu=0.0051296576058802515
# [deAm] IV: QL solver :: iv=0.7893041637886049 | price_for_iv=0.0051296576058802515
# [deAm] helper IV :: idx=44 | iv=0.7893041637886049
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=42.98281383953459 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=0.7342371560616275
# [deAm] eu price :: tree=jr | p_eu=0.005162305785037268
# [deAm] IV: QL solver :: iv=0.7342371229219804 | price_for_iv=0.005162305785037268
# [deAm] helper IV :: idx=45 | iv=0.7342371229219804
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.015 | hi=6.0 | f_hi=45.57079330599451 | P=0.015
# [deAm] sigma* :: tree=jr | sigma_star=0.747316222202382
# [deAm] eu price :: tree=jr | p_eu=0.015345685132533158
# [deAm] IV: QL solver :: iv=0.7473161912438129 | price_for_iv=0.015345685132533158
# [deAm] helper IV :: idx=46 | iv=0.7473161912438129
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.01 | hi=6.0 | f_hi=48.17386736100851 | P=0.01
# [deAm] sigma* :: tree=jr | sigma_star=0.6643368861371092
# [deAm] eu price :: tree=jr | p_eu=0.010217189130373006
# [deAm] IV: QL solver :: iv=0.6643368124240856 | price_for_iv=0.010217189130373006
# [deAm] helper IV :: idx=47 | iv=0.6643368124240856
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.015 | hi=6.0 | f_hi=50.89806651081573 | P=0.015
# [deAm] sigma* :: tree=jr | sigma_star=0.6322756194024743
# [deAm] eu price :: tree=jr | p_eu=0.01516139519255677
# [deAm] IV: QL solver :: iv=0.6322755671249 | price_for_iv=0.01516139519255677
# [deAm] helper IV :: idx=48 | iv=0.6322755671249
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.02 | hi=6.0 | f_hi=53.689274117541736 | P=0.02
# [deAm] sigma* :: tree=jr | sigma_star=0.593304761443168
# [deAm] eu price :: tree=jr | p_eu=0.020184069501281158
# [deAm] IV: QL solver :: iv=0.5933047615130116 | price_for_iv=0.020184069501281158
# [deAm] helper IV :: idx=49 | iv=0.5933047615130116
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.025 | hi=6.0 | f_hi=56.48054950939602 | P=0.025
# [deAm] sigma* :: tree=jr | sigma_star=0.5501632889378264
# [deAm] eu price :: tree=jr | p_eu=0.025280908882001157
# [deAm] IV: QL solver :: iv=0.5501633427606062 | price_for_iv=0.025280908882001157
# [deAm] helper IV :: idx=50 | iv=0.5501633427606062
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.035 | hi=6.0 | f_hi=59.28259767596021 | P=0.035
# [deAm] sigma* :: tree=jr | sigma_star=0.5124740736444483
# [deAm] eu price :: tree=jr | p_eu=0.035180593164430715
# [deAm] IV: QL solver :: iv=0.5124739199673705 | price_for_iv=0.035180593164430715
# [deAm] helper IV :: idx=51 | iv=0.5124739199673705
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.045 | hi=6.0 | f_hi=62.26408073151895 | P=0.045
# [deAm] sigma* :: tree=jr | sigma_star=0.4690723723128165
# [deAm] eu price :: tree=jr | p_eu=0.04516271970417773
# [deAm] IV: QL solver :: iv=0.4690725991224465 | price_for_iv=0.04516271970417773
# [deAm] helper IV :: idx=52 | iv=0.4690725991224465
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.065 | hi=6.0 | f_hi=65.23561737207875 | P=0.065
# [deAm] sigma* :: tree=jr | sigma_star=0.43143586803617084
# [deAm] eu price :: tree=jr | p_eu=0.06555174265244607
# [deAm] IV: QL solver :: iv=0.4314358076458498 | price_for_iv=0.06555174265244607
# [deAm] helper IV :: idx=53 | iv=0.4314358076458498
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.07500000000000001 | hi=6.0 | f_hi=66.72140912413612 | P=0.07500000000000001
# [deAm] sigma* :: tree=jr | sigma_star=0.40910210064854624
# [deAm] eu price :: tree=jr | p_eu=0.07511582278650664
# [deAm] IV: QL solver :: iv=0.4091021097272127 | price_for_iv=0.07511582278650664
# [deAm] helper IV :: idx=54 | iv=0.4091021097272127
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.095 | hi=6.0 | f_hi=68.19723444114261 | P=0.095
# [deAm] sigma* :: tree=jr | sigma_star=0.39201025059827704
# [deAm] eu price :: tree=jr | p_eu=0.09506567695087118
# [deAm] IV: QL solver :: iv=0.39201025011954294 | price_for_iv=0.09506567695087118
# [deAm] helper IV :: idx=55 | iv=0.39201025011954294
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.11499999999999999 | hi=6.0 | f_hi=69.67310055015534 | P=0.11499999999999999
# [deAm] sigma* :: tree=jr | sigma_star=0.37175899161245013
# [deAm] eu price :: tree=jr | p_eu=0.11504776963349944
# [deAm] IV: QL solver :: iv=0.3717590030282511 | price_for_iv=0.11504776963349944
# [deAm] helper IV :: idx=56 | iv=0.3717590030282511
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.14500000000000002 | hi=6.0 | f_hi=71.17481326672943 | P=0.14500000000000002
# [deAm] sigma* :: tree=jr | sigma_star=0.353236642932012
# [deAm] eu price :: tree=jr | p_eu=0.14493562728281448
# [deAm] IV: QL solver :: iv=0.35323664046040765 | price_for_iv=0.14493562728281448
# [deAm] helper IV :: idx=57 | iv=0.35323664046040765
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.185 | hi=6.0 | f_hi=72.72580195150377 | P=0.185
# [deAm] sigma* :: tree=jr | sigma_star=0.3347407086470277
# [deAm] eu price :: tree=jr | p_eu=0.1848122670458405
# [deAm] IV: QL solver :: iv=0.33474089944374025 | price_for_iv=0.1848122670458405
# [deAm] helper IV :: idx=58 | iv=0.33474089944374025
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.245 | hi=6.0 | f_hi=74.25680126813484 | P=0.245
# [deAm] sigma* :: tree=jr | sigma_star=0.3180688686011162
# [deAm] eu price :: tree=jr | p_eu=0.24555885166131547
# [deAm] IV: QL solver :: iv=0.3180689081201974 | price_for_iv=0.24555885166131547
# [deAm] helper IV :: idx=59 | iv=0.3180689081201974
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.345 | hi=6.0 | f_hi=75.74781695965079 | P=0.345
# [deAm] sigma* :: tree=jr | sigma_star=0.30434866885206435
# [deAm] eu price :: tree=jr | p_eu=0.34424263457101173
# [deAm] IV: QL solver :: iv=0.30434843127210665 | price_for_iv=0.34424263457101173
# [deAm] helper IV :: idx=60 | iv=0.30434843127210665
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.505 | hi=6.0 | f_hi=77.17884577061248 | P=0.505
# [deAm] sigma* :: tree=jr | sigma_star=0.2936095922038829
# [deAm] eu price :: tree=jr | p_eu=0.5037634037928433
# [deAm] IV: QL solver :: iv=0.29360959141254694 | price_for_iv=0.5037634037928433
# [deAm] helper IV :: idx=61 | iv=0.29360959141254694
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.745 | hi=6.0 | f_hi=78.5298906980927 | P=0.745
# [deAm] sigma* :: tree=jr | sigma_star=0.2840106344409838
# [deAm] eu price :: tree=jr | p_eu=0.7428758103518522
# [deAm] IV: QL solver :: iv=0.2840106441923008 | price_for_iv=0.7428758103518522
# [deAm] helper IV :: idx=62 | iv=0.2840106441923008
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.12 | hi=6.0 | f_hi=79.74596856201198 | P=1.12
# [deAm] sigma* :: tree=jr | sigma_star=0.277673399546396
# [deAm] eu price :: tree=jr | p_eu=1.1171481814529483
# [deAm] IV: QL solver :: iv=0.27767339955600867 | price_for_iv=1.1171481814529483
# [deAm] helper IV :: idx=63 | iv=0.27767339955600867
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.6749999999999998 | hi=6.0 | f_hi=80.78207633495629 | P=1.6749999999999998
# [deAm] sigma* :: tree=jr | sigma_star=0.27389585201144057
# [deAm] eu price :: tree=jr | p_eu=1.6723187070310683
# [deAm] IV: QL solver :: iv=0.27389585202885686 | price_for_iv=1.6723187070310683
# [deAm] helper IV :: idx=64 | iv=0.27389585202885686
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.45 | hi=6.0 | f_hi=81.59828081985617 | P=2.45
# [deAm] sigma* :: tree=jr | sigma_star=0.27151592534209856
# [deAm] eu price :: tree=jr | p_eu=2.442309072934138
# [deAm] IV: QL solver :: iv=0.2715159081758367 | price_for_iv=2.442309072934138
# [deAm] helper IV :: idx=65 | iv=0.2715159081758367
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.475 | hi=6.0 | f_hi=82.24873120238908 | P=3.475
# [deAm] sigma* :: tree=jr | sigma_star=0.2709554326349831
# [deAm] eu price :: tree=jr | p_eu=3.4675671563692867
# [deAm] IV: QL solver :: iv=0.2709554322970435 | price_for_iv=3.4675671563692867
# [deAm] helper IV :: idx=66 | iv=0.2709554322970435
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-3.32501220703125 | hi=6.0 | f_hi=82.53171079719759 | P=4.875
# [deAm] sigma* :: tree=jr | sigma_star=0.27862991758246464
# [deAm] eu price :: tree=jr | p_eu=4.859480132190864
# [deAm] IV: QL solver :: iv=0.2786299159828435 | price_for_iv=4.859480132190864
# [deAm] helper IV :: idx=67 | iv=0.2786299159828435
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-2.45001220703125 | hi=6.0 | f_hi=82.5897037276539 | P=6.5
# [deAm] sigma* :: tree=jr | sigma_star=0.28629202175528967
# [deAm] eu price :: tree=jr | p_eu=6.480957180716172
# [deAm] IV: QL solver :: iv=0.2862920060409555 | price_for_iv=6.480957180716172
# [deAm] helper IV :: idx=68 | iv=0.2862920060409555
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.9250122070312496 | hi=6.0 | f_hi=82.29771271143223 | P=8.475
# [deAm] sigma* :: tree=jr | sigma_star=0.3056438582766105
# [deAm] eu price :: tree=jr | p_eu=8.449826876197841
# [deAm] IV: QL solver :: iv=0.30564374672143313 | price_for_iv=8.449826876197841
# [deAm] helper IV :: idx=69 | iv=0.30564374672143313
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.57501220703125 | hi=6.0 | f_hi=81.83073543945711 | P=10.625
# [deAm] sigma* :: tree=jr | sigma_star=0.328835110925122
# [deAm] eu price :: tree=jr | p_eu=10.593732648389551
# [deAm] IV: QL solver :: iv=0.328835190092984 | price_for_iv=10.593732648389551
# [deAm] helper IV :: idx=70 | iv=0.328835190092984
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.45001220703125 | hi=6.0 | f_hi=81.13877575462566 | P=13.0
# [deAm] sigma* :: tree=jr | sigma_star=0.3651250641461443
# [deAm] eu price :: tree=jr | p_eu=12.96456138902522
# [deAm] IV: QL solver :: iv=0.3651249482511952 | price_for_iv=12.96456138902522
# [deAm] helper IV :: idx=71 | iv=0.3651249482511952
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.500012207031249 | hi=6.0 | f_hi=80.27185056288215 | P=15.549999999999999
# [deAm] sigma* :: tree=jr | sigma_star=0.41525952471601524
# [deAm] eu price :: tree=jr | p_eu=15.516867177532198
# [deAm] IV: QL solver :: iv=0.4152595248001123 | price_for_iv=15.516867177532198
# [deAm] helper IV :: idx=72 | iv=0.4152595248001123
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.5000122070312472 | hi=6.0 | f_hi=79.45495289574431 | P=18.049999999999997
# [deAm] sigma* :: tree=jr | sigma_star=0.458038482158508
# [deAm] eu price :: tree=jr | p_eu=18.010734478936737
# [deAm] IV: QL solver :: iv=0.45803852449816235 | price_for_iv=18.010734478936737
# [deAm] helper IV :: idx=73 | iv=0.45803852449816235
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.5500122070312514 | hi=6.0 | f_hi=78.58813094092181 | P=20.6
# [deAm] sigma* :: tree=jr | sigma_star=0.5053461883831014
# [deAm] eu price :: tree=jr | p_eu=20.563530295642835
# [deAm] IV: QL solver :: iv=0.5053461881037208 | price_for_iv=20.563530295642835
# [deAm] helper IV :: idx=74 | iv=0.5053461881037208
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.4750122070312486 | hi=6.0 | f_hi=77.91013423557996 | P=23.025
# [deAm] sigma* :: tree=jr | sigma_star=0.5370182809488385
# [deAm] eu price :: tree=jr | p_eu=22.98178034210525
# [deAm] IV: QL solver :: iv=0.5370182189729279 | price_for_iv=22.98178034210525
# [deAm] helper IV :: idx=75 | iv=0.5370182189729279
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.5250122070312528 | hi=6.0 | f_hi=77.13106325127382 | P=25.575000000000003
# [deAm] sigma* :: tree=jr | sigma_star=0.5821604243417998
# [deAm] eu price :: tree=jr | p_eu=25.53518866742186
# [deAm] IV: QL solver :: iv=0.5821606032823581 | price_for_iv=25.53518866742186
# [deAm] helper IV :: idx=76 | iv=0.5821606032823581
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.4000122070312493 | hi=6.0 | f_hi=76.52700390680756 | P=27.95
# [deAm] sigma* :: tree=jr | sigma_star=0.6046147899240877
# [deAm] eu price :: tree=jr | p_eu=27.902138137193475
# [deAm] IV: QL solver :: iv=0.6046147920643851 | price_for_iv=27.902138137193475
# [deAm] helper IV :: idx=77 | iv=0.6046147920643851
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.5250122070312528 | hi=6.0 | f_hi=75.67296188197267 | P=30.575000000000003
# [deAm] sigma* :: tree=jr | sigma_star=0.6566934966406546
# [deAm] eu price :: tree=jr | p_eu=30.527520996240362
# [deAm] IV: QL solver :: iv=0.6566934975836615 | price_for_iv=30.527520996240362
# [deAm] helper IV :: idx=78 | iv=0.6566934975836615
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.5000122070312472 | hi=6.0 | f_hi=74.96893278867962 | P=33.05
# [deAm] sigma* :: tree=jr | sigma_star=0.6903375256391383
# [deAm] eu price :: tree=jr | p_eu=33.0058402872574
# [deAm] IV: QL solver :: iv=0.6903375286867803 | price_for_iv=33.0058402872574
# [deAm] helper IV :: idx=79 | iv=0.6903375286867803
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.5250122070312528 | hi=6.0 | f_hi=74.21492016691285 | P=35.575
# [deAm] sigma* :: tree=jr | sigma_star=0.7282620961283935
# [deAm] eu price :: tree=jr | p_eu=35.52520540465115
# [deAm] IV: QL solver :: iv=0.7282621005430163 | price_for_iv=35.52520540465115
# [deAm] helper IV :: idx=80 | iv=0.7282621005430163
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.5000122070312472 | hi=6.0 | f_hi=72.05304716722695 | P=43.05
# [deAm] sigma* :: tree=jr | sigma_star=0.8270225677513598
# [deAm] eu price :: tree=jr | p_eu=42.99953956153552
# [deAm] IV: QL solver :: iv=0.8270225830224645 | price_for_iv=42.99953956153552
# [deAm] helper IV :: idx=81 | iv=0.8270225830224645
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.5000122070312472 | hi=6.0 | f_hi=69.36519230538424 | P=53.05
# [deAm] sigma* :: tree=jr | sigma_star=0.9538757491474328
# [deAm] eu price :: tree=jr | p_eu=52.99426998927471
# [deAm] IV: QL solver :: iv=0.9538757478660165 | price_for_iv=52.99426998927471
# [deAm] helper IV :: idx=82 | iv=0.9538757478660165
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.4250122070312514 | hi=6.0 | f_hi=68.79440930440535 | P=55.475
# [deAm] sigma* :: tree=jr | sigma_star=0.9721879350635766
# [deAm] eu price :: tree=jr | p_eu=55.41404470585129
# [deAm] IV: QL solver :: iv=0.9721879341115189 | price_for_iv=55.41404470585129
# [deAm] helper IV :: idx=83 | iv=0.9721879341115189
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.32501220703125 | hi=6.0 | f_hi=68.24864050825695 | P=57.875
# [deAm] sigma* :: tree=jr | sigma_star=0.9854309199941643
# [deAm] eu price :: tree=jr | p_eu=57.809859864204675
# [deAm] IV: QL solver :: iv=0.9854309193229779 | price_for_iv=57.809859864204675
# [deAm] helper IV :: idx=84 | iv=0.9854309193229779
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.2750122070312528 | hi=6.0 | f_hi=67.00715083969548 | P=62.825
# [deAm] sigma* :: tree=jr | sigma_star=1.035254842091941
# [deAm] eu price :: tree=jr | p_eu=62.7615973159751
# [deAm] IV: QL solver :: iv=1.0352548420418297 | price_for_iv=62.7615973159751
# [deAm] helper IV :: idx=85 | iv=1.0352548420418297
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.4750122070312557 | hi=6.0 | f_hi=61.9447625368922 | P=83.025
# [deAm] sigma* :: tree=jr | sigma_star=1.2864677797083497
# [deAm] eu price :: tree=jr | p_eu=82.95191342480575
# [deAm] IV: QL solver :: iv=1.2864677624520198 | price_for_iv=82.95191342480575
# [deAm] helper IV :: idx=86 | iv=1.2864677624520198
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-1.5000122070312472 | hi=6.0 | f_hi=60.78431656964982 | P=88.05
# [deAm] sigma* :: tree=jr | sigma_star=1.343060984931604
# [deAm] eu price :: tree=jr | p_eu=87.97933583011505
# [deAm] IV: QL solver :: iv=1.3430609849329191 | price_for_iv=87.97933583011505
# [deAm] helper IV :: idx=87 | iv=1.3430609849329191
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=110.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=88 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=125.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=89 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=135.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=90 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=140.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=91 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=145.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=92 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=150.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=93 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=155.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=94 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=160.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=95 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=165.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=96 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=170.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=97 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=175.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=98 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=180.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=99 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=185.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=100 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=190.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=101 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=195.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=102 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=200.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=103 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=205.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=104 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=210.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=105 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=215.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=106 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=220.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=107 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=222.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=108 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=225.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=109 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=227.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=110 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=230.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=111 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=232.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=112 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=235.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=113 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=237.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=114 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=240.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=115 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=242.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=116 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=245.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=117 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=247.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=118 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=250.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=119 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=252.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=120 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=255.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=121 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=257.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=122 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=260.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=123 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=262.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=124 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=265.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.005
# [deAm] helper IV :: idx=125 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=267.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=0.345
# [deAm] helper IV :: idx=126 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=270.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=2.565
# [deAm] helper IV :: idx=127 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=272.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=5.075
# [deAm] helper IV :: idx=128 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=275.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=7.575
# [deAm] helper IV :: idx=129 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=277.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=10.05
# [deAm] helper IV :: idx=130 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=280.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=12.55
# [deAm] helper IV :: idx=131 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=282.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=15.075
# [deAm] helper IV :: idx=132 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=285.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=17.55
# [deAm] helper IV :: idx=133 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=287.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=20.025
# [deAm] helper IV :: idx=134 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=290.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=22.65
# [deAm] helper IV :: idx=135 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=292.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=25.1
# [deAm] helper IV :: idx=136 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=295.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=27.6
# [deAm] helper IV :: idx=137 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=297.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=30.1
# [deAm] helper IV :: idx=138 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=300.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=32.725
# [deAm] helper IV :: idx=139 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=302.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=35.099999999999994
# [deAm] helper IV :: idx=140 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=305.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=37.599999999999994
# [deAm] helper IV :: idx=141 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=307.5 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=40.099999999999994
# [deAm] helper IV :: idx=142 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=310.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=42.625
# [deAm] helper IV :: idx=143 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=315.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=47.599999999999994
# [deAm] helper IV :: idx=144 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=320.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=52.625
# [deAm] helper IV :: idx=145 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=325.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=57.599999999999994
# [deAm] helper IV :: idx=146 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=370.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=102.625
# [deAm] helper IV :: idx=147 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=375.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=107.8
# [deAm] helper IV :: idx=148 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=380.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=112.94999999999999
# [deAm] helper IV :: idx=149 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=385.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=117.8
# [deAm] helper IV :: idx=150 | iv=None
# [deAm] IV: bad inputs :: S=268.45001220703125 | K=395.0 | T=0.0 | r=0.04 | q=0.0039000000000000003 | P=127.92500000000001
# [deAm] helper IV :: idx=151 | iv=None
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=40.413495268631074 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=1.0147738853053239
# [deAm] eu price :: tree=jr | p_eu=0.005181750430294464
# [deAm] IV: QL solver :: iv=1.0147741034379063 | price_for_iv=0.005181750430294464
# [deAm] helper IV :: idx=152 | iv=1.0147741034379063
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=46.195404706671546 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=0.918435114508333
# [deAm] eu price :: tree=jr | p_eu=0.005183286487111389
# [deAm] IV: QL solver :: iv=0.9184349185228992 | price_for_iv=0.005183286487111389
# [deAm] helper IV :: idx=153 | iv=0.9184349185228992
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.005 | hi=6.0 | f_hi=55.16976637450189 | P=0.005
# [deAm] sigma* :: tree=jr | sigma_star=0.7868437744542596
# [deAm] eu price :: tree=jr | p_eu=0.005192932504422475
# [deAm] IV: QL solver :: iv=0.7868438332067702 | price_for_iv=0.005192932504422475
# [deAm] helper IV :: idx=154 | iv=0.7868438332067702
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.01 | hi=6.0 | f_hi=58.248934425946594 | P=0.01
# [deAm] sigma* :: tree=jr | sigma_star=0.787046097087565
# [deAm] eu price :: tree=jr | p_eu=0.010291018759964665
# [deAm] IV: QL solver :: iv=0.7870461028067786 | price_for_iv=0.010291018759964665
# [deAm] helper IV :: idx=155 | iv=0.7870461028067786
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.01 | hi=6.0 | f_hi=61.3332673632068 | P=0.01
# [deAm] sigma* :: tree=jr | sigma_star=0.7453823596317801
# [deAm] eu price :: tree=jr | p_eu=0.01029260605673575
# [deAm] IV: QL solver :: iv=0.7453823419029519 | price_for_iv=0.01029260605673575
# [deAm] helper IV :: idx=156 | iv=0.7453823419029519
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.01 | hi=6.0 | f_hi=64.47608998945164 | P=0.01
# [deAm] sigma* :: tree=jr | sigma_star=0.7050014062902386
# [deAm] eu price :: tree=jr | p_eu=0.010298861770285979
# [deAm] IV: QL solver :: iv=0.70500156325653 | price_for_iv=0.010298861770285979
# [deAm] helper IV :: idx=157 | iv=0.70500156325653
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.01 | hi=6.0 | f_hi=67.74757457186946 | P=0.01
# [deAm] sigma* :: tree=jr | sigma_star=0.6658228791550388
# [deAm] eu price :: tree=jr | p_eu=0.010311502620914712
# [deAm] IV: QL solver :: iv=0.665822811022365 | price_for_iv=0.010311502620914712
# [deAm] helper IV :: idx=158 | iv=0.665822811022365
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.02 | hi=6.0 | f_hi=71.0091492757108 | P=0.02
# [deAm] sigma* :: tree=jr | sigma_star=0.6668171570139516
# [deAm] eu price :: tree=jr | p_eu=0.020475872087077268
# [deAm] IV: QL solver :: iv=0.6668171090594606 | price_for_iv=0.020475872087077268
# [deAm] helper IV :: idx=159 | iv=0.6668171090594606
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.02 | hi=6.0 | f_hi=74.28083742481307 | P=0.02
# [deAm] sigma* :: tree=jr | sigma_star=0.6277117141210613
# [deAm] eu price :: tree=jr | p_eu=0.0205033966808676
# [deAm] IV: QL solver :: iv=0.6277116316414229 | price_for_iv=0.0205033966808676
# [deAm] helper IV :: idx=160 | iv=0.6277116316414229
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.03 | hi=6.0 | f_hi=77.54271169435312 | P=0.03
# [deAm] sigma* :: tree=jr | sigma_star=0.6133947363919279
# [deAm] eu price :: tree=jr | p_eu=0.030877810791062044
# [deAm] IV: QL solver :: iv=0.6133946836815347 | price_for_iv=0.030877810791062044
# [deAm] helper IV :: idx=161 | iv=0.6133946836815347
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.04 | hi=6.0 | f_hi=80.87781384768563 | P=0.04
# [deAm] sigma* :: tree=jr | sigma_star=0.5917889451698735
# [deAm] eu price :: tree=jr | p_eu=0.04093452384585409
# [deAm] IV: QL solver :: iv=0.591788953372589 | price_for_iv=0.04093452384585409
# [deAm] helper IV :: idx=162 | iv=0.591788953372589
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.04 | hi=6.0 | f_hi=84.32941858244617 | P=0.04
# [deAm] sigma* :: tree=jr | sigma_star=0.5534175808739537
# [deAm] eu price :: tree=jr | p_eu=0.041115590122778885
# [deAm] IV: QL solver :: iv=0.5534178170825079 | price_for_iv=0.041115590122778885
# [deAm] helper IV :: idx=163 | iv=0.5534178170825079
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.05 | hi=6.0 | f_hi=87.77110748429175 | P=0.05
# [deAm] sigma* :: tree=jr | sigma_star=0.5278396827866064
# [deAm] eu price :: tree=jr | p_eu=0.050907376081407656
# [deAm] IV: QL solver :: iv=0.5278398962579754 | price_for_iv=0.050907376081407656
# [deAm] helper IV :: idx=164 | iv=0.5278398962579754
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.060000000000000005 | hi=6.0 | f_hi=91.21289720093847 | P=0.060000000000000005
# [deAm] sigma* :: tree=jr | sigma_star=0.5002335578684991
# [deAm] eu price :: tree=jr | p_eu=0.06086973278647467
# [deAm] IV: QL solver :: iv=0.5002335102209254 | price_for_iv=0.06086973278647467
# [deAm] helper IV :: idx=165 | iv=0.5002335102209254
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.08 | hi=6.0 | f_hi=94.64483425994966 | P=0.08
# [deAm] sigma* :: tree=jr | sigma_star=0.4788459125408298
# [deAm] eu price :: tree=jr | p_eu=0.08100065300232208
# [deAm] IV: QL solver :: iv=0.4788461554124678 | price_for_iv=0.08100065300232208
# [deAm] helper IV :: idx=166 | iv=0.4788461554124678
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.095 | hi=6.0 | f_hi=98.08200931279265 | P=0.095
# [deAm] sigma* :: tree=jr | sigma_star=0.4507950178244272
# [deAm] eu price :: tree=jr | p_eu=0.09650937119904797
# [deAm] IV: QL solver :: iv=0.4507950185455343 | price_for_iv=0.09650937119904797
# [deAm] helper IV :: idx=167 | iv=0.4507950185455343
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.125 | hi=6.0 | f_hi=101.63099720075232 | P=0.125
# [deAm] sigma* :: tree=jr | sigma_star=0.42816886164009316
# [deAm] eu price :: tree=jr | p_eu=0.1265744409739031
# [deAm] IV: QL solver :: iv=0.42816890703658284 | price_for_iv=0.1265744409739031
# [deAm] helper IV :: idx=168 | iv=0.42816890703658284
# [deAm] initial bracket :: tree=jr | steps=400 | lo=0.001 | f_lo=-0.16 | hi=6.0 | f_hi=105.2189749637594 | P=0.16
# [deAm] sigma* :: tree=jr | sigma_star=0.4036426541302204
# [deAm] eu price :: tree=jr | p_eu=0.1616860466490281
# ...
# [deAm] Heston EU price :: K=305.0 | T=2.1095890410958904 | p=35.52339748706296
# [deAm] Heston EU price :: K=310.0 | T=2.1095890410958904 | p=33.87827693024163
# [deAm] Heston EU price :: K=315.0 | T=2.1095890410958904 | p=32.30383247956335
# [deAm] Heston EU price :: K=320.0 | T=2.1095890410958904 | p=30.79770225036687
# [deAm] Heston EU price :: K=325.0 | T=2.1095890410958904 | p=29.357530303279393
# [deAm] Heston EU price :: K=330.0 | T=2.1095890410958904 | p=27.98097576408188
# [deAm] Heston EU price :: K=335.0 | T=2.1095890410958904 | p=26.665720873853946
# [deAm] Heston EU price :: K=340.0 | T=2.1095890410958904 | p=25.40947803636411
# [deAm] Heston EU price :: K=345.0 | T=2.1095890410958904 | p=24.209995931087004
# [deAm] Heston EU price :: K=350.0 | T=2.1095890410958904 | p=23.065064760424587
# [deAm] Heston EU price :: K=355.0 | T=2.1095890410958904 | p=21.972520698913623
# [deAm] Heston EU price :: K=360.0 | T=2.1095890410958904 | p=20.93024961061954
# [deAm] Heston EU price :: K=365.0 | T=2.1095890410958904 | p=19.936190098725064
# [deAm] Heston EU price :: K=370.0 | T=2.1095890410958904 | p=18.98833594866705
# [deAm] Heston EU price :: K=375.0 | T=2.1095890410958904 | p=18.084738023189917
# [deAm] Heston EU price :: K=380.0 | T=2.1095890410958904 | p=17.223505664472444
# [deAm] Heston EU price :: K=385.0 | T=2.1095890410958904 | p=16.40280765513841
# [deAm] Heston EU price :: K=390.0 | T=2.1095890410958904 | p=15.620872786553171
# [deAm] Heston EU price :: K=395.0 | T=2.1095890410958904 | p=14.875990079398905
# [deAm] Heston EU price :: K=400.0 | T=2.1095890410958904 | p=14.1665086981579
# [deAm] Heston EU price :: K=405.0 | T=2.1095890410958904 | p=13.490837597852954
# [deAm] Heston EU price :: K=410.0 | T=2.1095890410958904 | p=12.847444938227284
# [deAm] Heston EU price :: K=415.0 | T=2.1095890410958904 | p=12.23485729751273
# [deAm] Heston EU price :: K=420.0 | T=2.1095890410958904 | p=11.651658715050987
# [deAm] Heston EU price :: K=425.0 | T=2.1095890410958904 | p=11.096489589306175
# [deAm] Heston EU price :: K=430.0 | T=2.1095890410958904 | p=10.568045455246887
# [deAm] Heston EU price :: K=435.0 | T=2.1095890410958904 | p=10.065075662681028
# [deAm] Heston EU price :: K=440.0 | T=2.1095890410958904 | p=9.586381974897849
# [deAm] Heston EU price :: K=450.0 | T=2.1095890410958904 | p=8.697283204654166
# [deAm] Heston EU price :: K=460.0 | T=2.1095890410958904 | p=7.89215482943927
# [deAm] Heston EU price :: K=480.0 | T=2.1095890410958904 | p=6.5030875709837055
# [deAm] Heston EU price :: K=500.0 | T=2.1095890410958904 | p=5.364346636892772
# [deAm] Heston EU price :: K=530.0 | T=2.1095890410958904 | p=4.028633585750957
# [deAm] Heston EU price :: K=5.0 | T=1.189041095890411 | p=262.4402631187707
# [deAm] Heston EU price :: K=10.0 | T=1.189041095890411 | p=257.6725046650848
# [deAm] Heston EU price :: K=15.0 | T=1.189041095890411 | p=252.90474621139884
# [deAm] Heston EU price :: K=20.0 | T=1.189041095890411 | p=248.136987757713
# [deAm] Heston EU price :: K=25.0 | T=1.189041095890411 | p=243.36922930402704
# [deAm] Heston EU price :: K=30.0 | T=1.189041095890411 | p=238.60147085034117
# [deAm] Heston EU price :: K=35.0 | T=1.189041095890411 | p=233.83371239665576
# [deAm] Heston EU price :: K=40.0 | T=1.189041095890411 | p=229.06595394298253
# [deAm] Heston EU price :: K=45.0 | T=1.189041095890411 | p=224.29819548948456
# [deAm] Heston EU price :: K=50.0 | T=1.189041095890411 | p=219.53043703772428
# [deAm] Heston EU price :: K=60.0 | T=1.189041095890411 | p=209.99492023128872
# [deAm] Heston EU price :: K=70.0 | T=1.189041095890411 | p=200.45940542490078
# [deAm] Heston EU price :: K=80.0 | T=1.189041095890411 | p=190.92391250938505
# [deAm] Heston EU price :: K=85.0 | T=1.189041095890411 | p=186.1562039192143
# [deAm] Heston EU price :: K=90.0 | T=1.189041095890411 | p=181.38857015459027
# [deAm] Heston EU price :: K=95.0 | T=1.189041095890411 | p=176.62109812439988
# [deAm] Heston EU price :: K=100.0 | T=1.189041095890411 | p=171.85395004814131
# [deAm] Heston EU price :: K=105.0 | T=1.189041095890411 | p=167.08740844405582
# [deAm] Heston EU price :: K=110.0 | T=1.189041095890411 | p=162.32193582643427
# [deAm] Heston EU price :: K=115.0 | T=1.189041095890411 | p=157.55824852985475
# [deAm] Heston EU price :: K=120.0 | T=1.189041095890411 | p=152.79740195592967
# [deAm] Heston EU price :: K=125.0 | T=1.189041095890411 | p=148.0408824240034
# [deAm] Heston EU price :: K=130.0 | T=1.189041095890411 | p=143.29069907965484
# [deAm] Heston EU price :: K=135.0 | T=1.189041095890411 | p=138.54946828538155
# [deAm] Heston EU price :: K=140.0 | T=1.189041095890411 | p=133.82048276751956
# [deAm] Heston EU price :: K=145.0 | T=1.189041095890411 | p=129.1077585464625
# [deAm] Heston EU price :: K=150.0 | T=1.189041095890411 | p=124.41605421193876
# [deAm] Heston EU price :: K=155.0 | T=1.189041095890411 | p=119.75085919288071
# [deAm] Heston EU price :: K=160.0 | T=1.189041095890411 | p=115.11835002914967
# [deAm] Heston EU price :: K=165.0 | T=1.189041095890411 | p=110.52531599480041
# [deAm] Heston EU price :: K=170.0 | T=1.189041095890411 | p=105.97905750447032
# [deAm] Heston EU price :: K=175.0 | T=1.189041095890411 | p=101.48726237750752
# [deAm] Heston EU price :: K=180.0 | T=1.189041095890411 | p=97.05786613779708
# [deAm] Heston EU price :: K=185.0 | T=1.189041095890411 | p=92.69890306466738
# [deAm] Heston EU price :: K=190.0 | T=1.189041095890411 | p=88.41835471763297
# [deAm] Heston EU price :: K=195.0 | T=1.189041095890411 | p=84.2240022155402
# [deAm] Heston EU price :: K=200.0 | T=1.189041095890411 | p=80.12328776540119
# [deAm] Heston EU price :: K=210.0 | T=1.189041095890411 | p=72.23011594117446
# [deAm] Heston EU price :: K=220.0 | T=1.189041095890411 | p=64.78730226625903
# [deAm] Heston EU price :: K=230.0 | T=1.189041095890411 | p=57.83183131019891
# [deAm] Heston EU price :: K=240.0 | T=1.189041095890411 | p=51.38799414463074
# [deAm] Heston EU price :: K=250.0 | T=1.189041095890411 | p=45.467336161308346
# [deAm] Heston EU price :: K=260.0 | T=1.189041095890411 | p=40.06952962359664
# [deAm] Heston EU price :: K=270.0 | T=1.189041095890411 | p=35.183883293421474
# [deAm] Heston EU price :: K=280.0 | T=1.189041095890411 | p=30.791209000500917
# [deAm] Heston EU price :: K=290.0 | T=1.189041095890411 | p=26.865807426810093
# [deAm] Heston EU price :: K=300.0 | T=1.189041095890411 | p=23.37739324561431
# [deAm] Heston EU price :: K=310.0 | T=1.189041095890411 | p=20.29283904150608
# [deAm] Heston EU price :: K=320.0 | T=1.189041095890411 | p=17.577669694050098
# [deAm] Heston EU price :: K=330.0 | T=1.189041095890411 | p=15.197280243493635
# [deAm] Heston EU price :: K=340.0 | T=1.189041095890411 | p=13.117879941080385
# [deAm] Heston EU price :: K=350.0 | T=1.189041095890411 | p=11.307184344457179
# [deAm] Heston EU price :: K=360.0 | T=1.189041095890411 | p=9.734887937012125
# [deAm] Heston EU price :: K=370.0 | T=1.189041095890411 | p=8.372954014624906
# [deAm] Heston EU price :: K=380.0 | T=1.189041095890411 | p=7.195758500566934
# [deAm] Heston EU price :: K=390.0 | T=1.189041095890411 | p=6.180121571544472
# [deAm] Heston EU price :: K=400.0 | T=1.189041095890411 | p=5.3052567599743865
# [deAm] Heston EU price :: K=410.0 | T=1.189041095890411 | p=4.552662426141205
# [deAm] Heston EU price :: K=420.0 | T=1.189041095890411 | p=3.905975749632387
# [deAm] Heston EU price :: K=430.0 | T=1.189041095890411 | p=3.350805017973007
# [deAm] Heston EU price :: K=440.0 | T=1.189041095890411 | p=2.874552167860218
# [deAm] Heston EU price :: K=450.0 | T=1.189041095890411 | p=2.4662343224770256
# [deAm] Heston EU price :: K=460.0 | T=1.189041095890411 | p=2.116310456599327
# [deAm] Heston EU price :: K=470.0 | T=1.189041095890411 | p=1.8165172580387876
# [deAm] Heston EU price :: K=480.0 | T=1.189041095890411 | p=1.5597166680750423
# [deAm] Heston EU price :: K=490.0 | T=1.189041095890411 | p=1.3397563977551987
# [deAm] Heston EU price :: K=500.0 | T=1.189041095890411 | p=1.151343856675514
# [deAm] Heston EU price :: K=520.0 | T=1.189041095890411 | p=0.8516258264499604
# [deAm] Heston EU price :: K=530.0 | T=1.189041095890411 | p=0.7330808061123245
# [deAm] Heston EU price :: K=5.0 | T=2.2054794520547945 | p=261.57307547585833
# [deAm] Heston EU price :: K=10.0 | T=2.2054794520547945 | p=256.99527455583257
# [deAm] Heston EU price :: K=50.0 | T=2.2054794520547945 | p=220.37288428776526
# [deAm] Heston EU price :: K=60.0 | T=2.2054794520547945 | p=211.21745224185315
# [deAm] Heston EU price :: K=70.0 | T=2.2054794520547945 | p=202.06286418718426
# [deAm] Heston EU price :: K=80.0 | T=2.2054794520547945 | p=192.9113902084893
# [deAm] Heston EU price :: K=90.0 | T=2.2054794520547945 | p=183.76852786507308
# [deAm] Heston EU price :: K=110.0 | T=2.2054794520547945 | p=165.55771791838194
# [deAm] Heston EU price :: K=120.0 | T=2.2054794520547945 | p=156.53150484761233
# [deAm] Heston EU price :: K=130.0 | T=2.2054794520547945 | p=147.59751229929395
# [deAm] Heston EU price :: K=135.0 | T=2.2054794520547945 | p=143.17637298659255
# [deAm] Heston EU price :: K=140.0 | T=2.2054794520547945 | p=138.7923035809895
# [deAm] Heston EU price :: K=145.0 | T=2.2054794520547945 | p=134.45035349460798
# [deAm] Heston EU price :: K=150.0 | T=2.2054794520547945 | p=130.15562130952526
# [deAm] Heston EU price :: K=155.0 | T=2.2054794520547945 | p=125.9131805133068
# [deAm] Heston EU price :: K=160.0 | T=2.2054794520547945 | p=121.7280093198368
# [deAm] Heston EU price :: K=165.0 | T=2.2054794520547945 | p=117.60492630981415
# [deAm] Heston EU price :: K=170.0 | T=2.2054794520547945 | p=113.54853314736606
# [deAm] Heston EU price :: K=175.0 | T=2.2054794520547945 | p=109.56316518267543
# [deAm] Heston EU price :: K=180.0 | T=2.2054794520547945 | p=105.65285035291673
# [deAm] Heston EU price :: K=185.0 | T=2.2054794520547945 | p=101.82127645491406
# [deAm] Heston EU price :: K=190.0 | T=2.2054794520547945 | p=98.07176658635879
# [deAm] Heston EU price :: K=195.0 | T=2.2054794520547945 | p=94.40726233715569
# [deAm] Heston EU price :: K=200.0 | T=2.2054794520547945 | p=90.8303141543633
# [deAm] Heston EU price :: K=210.0 | T=2.2054794520547945 | p=83.94731893510466
# [deAm] Heston EU price :: K=220.0 | T=2.2054794520547945 | p=77.43537953689089
# [deAm] Heston EU price :: K=230.0 | T=2.2054794520547945 | p=71.3011645943207
# [deAm] Heston EU price :: K=240.0 | T=2.2054794520547945 | p=65.54593310173435
# [deAm] Heston EU price :: K=250.0 | T=2.2054794520547945 | p=60.166192116133985
# [deAm] Heston EU price :: K=260.0 | T=2.2054794520547945 | p=55.15442077997315
# [deAm] Heston EU price :: K=270.0 | T=2.2054794520547945 | p=50.499805739001054
# [deAm] Heston EU price :: K=280.0 | T=2.2054794520547945 | p=46.18894836961612
# [deAm] Heston EU price :: K=290.0 | T=2.2054794520547945 | p=42.20651756028146
# [deAm] Heston EU price :: K=300.0 | T=2.2054794520547945 | p=38.53583262960175
# [deAm] Heston EU price :: K=310.0 | T=2.2054794520547945 | p=35.15936929176988
# [deAm] Heston EU price :: K=320.0 | T=2.2054794520547945 | p=32.05918763890569
# [deAm] Heston EU price :: K=330.0 | T=2.2054794520547945 | p=29.217285256963542
# [deAm] Heston EU price :: K=340.0 | T=2.2054794520547945 | p=26.615881212925476
# [deAm] Heston EU price :: K=350.0 | T=2.2054794520547945 | p=24.237638108486074
# [deAm] Heston EU price :: K=360.0 | T=2.2054794520547945 | p=22.065830004126425
# [deAm] Heston EU price :: K=370.0 | T=2.2054794520547945 | p=20.084464035760373
# [deAm] Heston EU price :: K=380.0 | T=2.2054794520547945 | p=18.278363177097557
# [deAm] Heston EU price :: K=390.0 | T=2.2054794520547945 | p=16.63321699814934
# [deAm] Heston EU price :: K=400.0 | T=2.2054794520547945 | p=15.135606545992784
# [deAm] Heston EU price :: K=410.0 | T=2.2054794520547945 | p=13.773008706693966
# [deAm] Heston EU price :: K=420.0 | T=2.2054794520547945 | p=12.533784649940506
# [deAm] Heston EU price :: K=430.0 | T=2.2054794520547945 | p=11.407156243743978
# [deAm] Heston EU price :: K=440.0 | T=2.2054794520547945 | p=10.383173674650884
# [deAm] Heston EU price :: K=450.0 | T=2.2054794520547945 | p=9.452676928335014
# [deAm] Heston EU price :: K=460.0 | T=2.2054794520547945 | p=8.607253278502055
# [deAm] Heston EU price :: K=470.0 | T=2.2054794520547945 | p=7.839192496572139
# [deAm] Heston EU price :: K=480.0 | T=2.2054794520547945 | p=7.141441125774392
# [deAm] Heston EU price :: K=490.0 | T=2.2054794520547945 | p=6.507556854815722
# [deAm] Heston EU price :: K=500.0 | T=2.2054794520547945 | p=5.931663771278642
# [deAm] Heston EU price :: K=510.0 | T=2.2054794520547945 | p=5.408409066444892
# [deAm] Heston EU price :: K=520.0 | T=2.2054794520547945 | p=4.932921594715244
# [deAm] Heston EU price :: K=530.0 | T=2.2054794520547945 | p=4.500772556107911
# [deAm] group priced :: group=('AAPL',)
#            contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 0     AAPL251205P00140000 2025-11-06 18:53:03+00:00   140.0       0.01  0.00
# 1     AAPL251205P00160000 2025-11-04 14:35:00+00:00   160.0       0.03  0.01
# 2     AAPL251205P00165000 2025-11-05 20:24:52+00:00   165.0       0.02  0.02
# 3     AAPL251205P00175000 2025-11-04 20:57:14+00:00   175.0       0.04  0.03
# 4     AAPL251205P00180000 2025-11-06 15:20:53+00:00   180.0       0.03  0.03
# ...                   ...                       ...     ...        ...   ...
# 2226  AAPL280121C00490000 2025-10-31 19:49:20+00:00   490.0       4.90  4.50
# 2227  AAPL280121C00500000 2025-11-07 18:21:15+00:00   500.0       4.35  4.05
# 2228  AAPL280121C00510000 2025-11-06 16:40:48+00:00   510.0       4.05  3.60
# 2229  AAPL280121C00520000 2025-11-07 15:34:36+00:00   520.0       3.69  3.25
# 2230  AAPL280121C00530000 2025-11-07 20:03:15+00:00   530.0       3.05  2.96
#
#        ask  change  percentChange  volume  openInterest  ...  expiration  \
# 0     0.02    0.00       0.000000     1.0            14  ...  2025-12-05
# 1     0.03    0.00       0.000000     1.0             0  ...  2025-12-05
# 2     0.04    0.00       0.000000     1.0             6  ...  2025-12-05
# 3     0.05    0.00       0.000000     2.0             2  ...  2025-12-05
# 4     0.06    0.00       0.000000     1.0             1  ...  2025-12-05
# ...    ...     ...            ...     ...           ...  ...         ...
# 2226  4.70    0.00       0.000000     1.0            25  ...  2028-01-21
# 2227  4.25    0.00       0.000000     7.0           285  ...  2028-01-21
# 2228  3.80    0.00       0.000000    10.0            54  ...  2028-01-21
# 2229  3.45    0.11       3.072630     1.0            14  ...  2028-01-21
# 2230  3.15   -0.10      -3.174608    42.0           354  ...  2028-01-21
#
#            TTM dividendYield ticker  spot_price optionType     r  \
# 0     0.076712        0.0039   AAPL  268.450012        put  0.04
# 1     0.076712        0.0039   AAPL  268.450012        put  0.04
# 2     0.076712        0.0039   AAPL  268.450012        put  0.04
# 3     0.076712        0.0039   AAPL  268.450012        put  0.04
# 4     0.076712        0.0039   AAPL  268.450012        put  0.04
# ...        ...           ...    ...         ...        ...   ...
# 2226  2.205479        0.0039   AAPL  268.450012       call  0.04
# 2227  2.205479        0.0039   AAPL  268.450012       call  0.04
# 2228  2.205479        0.0039   AAPL  268.450012       call  0.04
# 2229  2.205479        0.0039   AAPL  268.450012       call  0.04
# 2230  2.205479        0.0039   AAPL  268.450012       call  0.04
#
#       forward_log_moneyness midPrice   V_EU_Heston
# 0                 -0.653792    0.010  0.000000e+00
# 1                 -0.520260    0.020  1.275058e-13
# 2                 -0.489489    0.030  1.374230e-12
# 3                 -0.430648    0.040  1.153786e-10
# 4                 -0.402477    0.045  9.257916e-10
# ...                     ...      ...           ...
# 2226               0.522123    4.600  6.507557e+00
# 2227               0.542326    4.150  5.931664e+00
# 2228               0.562128    3.700  5.408409e+00
# 2229               0.581546    3.350  4.932922e+00
# 2230               0.600594    3.055  4.500773e+00
#
# [2231 rows x 25 columns]

# %%
df.describe()
# Out:
#             strike    lastPrice          bid          ask       change  \
# count  2231.000000  2231.000000  2231.000000  2231.000000  2231.000000
# mean    224.989915    44.579121    43.601147    44.436867    -0.228391
# std     107.163084    61.775048    60.870248    61.977807     2.487978
# min       5.000000     0.010000     0.000000     0.000000    -8.389999
# 25%     145.000000     0.445000     0.410000     0.450000    -0.244999
# 50%     225.000000    11.350000    10.950000    11.100000     0.000000
# 75%     300.000000    72.165000    69.300000    69.800000     0.000000
# max     530.000000   266.040000   260.850000   264.500000    70.640000
#
#        percentChange        volume  openInterest  impliedVolatility  \
# count    2231.000000   2231.000000   2231.000000        2231.000000
# mean       -1.278455    444.853429   2598.144330           0.551284
# std        16.849884   3616.518884   6261.611005           0.652002
# min       -99.371070      1.000000      0.000000           0.000010
# 25%        -3.020617      2.000000     69.500000           0.273170
# 50%         0.000000     10.000000    449.000000           0.359381
# 75%         0.000000     62.000000   2153.000000           0.556386
# max       200.000000  89573.000000  88993.000000           7.632813
#
#                TTM  dividendYield   spot_price        r  \
# count  2231.000000      2231.0000  2231.000000  2231.00
# mean      0.670727         0.0039   268.450012     0.04
# std       0.690688         0.0000     0.000000     0.00
# min       0.000000         0.0039   268.450012     0.04
# 25%       0.095890         0.0039   268.450012     0.04
# 50%       0.441096         0.0039   268.450012     0.04
# 75%       1.112329         0.0039   268.450012     0.04
# max       2.205479         0.0039   268.450012     0.04
#
#        forward_log_moneyness     midPrice   V_EU_Heston
# count            2231.000000  2231.000000  2.231000e+03
# mean               -0.373159    44.019007  4.398766e+01
# std                 0.705515    61.423369  6.251795e+01
# min                -4.062845     0.000000 -4.727788e-11
# 25%                -0.634624     0.427500  2.897539e-02
# 50%                -0.197510    11.025000  1.060016e+01
# 75%                 0.085825    69.550000  6.919841e+01
# max                 0.649057   262.425000  2.633525e+02
